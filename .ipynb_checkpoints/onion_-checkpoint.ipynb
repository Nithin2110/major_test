# %%
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.preprocessing import MinMaxScaler
from statsmodels.tsa.stattools import kpss

# %%
df=pd.read_csv("DATA/onion.csv")

df
# Out:
#                     Date  price
# 0    2000-01-01 00:00:00   89.8
# 1    2000-02-01 00:00:00   77.4
# 2    2000-03-01 00:00:00   83.0
# 3    2000-04-01 00:00:00   81.6
# 4    2000-05-01 00:00:00   88.9
# ..                   ...    ...
# 277  2023-02-01 00:00:00  159.5
# 278  2023-03-01 00:00:00  138.1
# 279  2023-04-01 00:00:00  128.2
# 280  2023-05-01 00:00:00  129.2
# 281  2023-06-01 00:00:00  144.4
#
# [282 rows x 2 columns]

# %%
import pandas as pd


# Convert 'Date' column to datetime type
df['Date'] = pd.to_datetime(df['Date'])

# Check for missing values
print("Missing values:")
print(df.isnull().sum())

# Check for duplicates
print("\nDuplicates:")
print(df.duplicated().sum())

# Check basic statistics of the 'Price' column
print("\nBasic statistics of Price:")
print(df['price'].describe())

# Plot the time series data
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(df['Date'], df['price'], marker='o')
plt.title('Time Series Data')
plt.xlabel('Date')
plt.ylabel('Price')
plt.grid(True)
plt.show()
# Out:
# Missing values:
# Date     0
# price    0
# dtype: int64
#
# Duplicates:
# 0
#
# Basic statistics of Price:
# count    282.000000
# mean     227.401064
# std      129.259780
# min       77.400000
# 25%      138.475000
# 50%      199.400000
# 75%      268.275000
# max      845.600000
# Name: price, dtype: float64

# %%
sn.boxplot(df['price'])
# Out:
# <Axes: >

# %%
import pandas as pd
from scipy.stats import mstats
def winsorize_outliers(series, lower_percentile=0.05, upper_percentile=0.95):
    lower_limit = series.quantile(lower_percentile)
    upper_limit = series.quantile(upper_percentile)
    winsorized_values = mstats.winsorize(series, limits=(lower_percentile, 1 - upper_percentile))  # Correcting the upper percentile value
    return winsorized_values


# Winsorize the 'Price' column
#df['Price_winsorized'] = winsorize_outliers(df['price'])
df['price1'] = winsorize_outliers(df['price'], lower_percentile=0.05, upper_percentile=0.95)


# Plot the original and winsorized time series data
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(df['Date'], df['price'], marker='o', label='Original Price')
plt.plot(df['Date'], df['price1'], marker='o', label='Winsorized Price')
plt.title('Original vs. Winsorized Time Series Data')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
plt.show()

# %%
sn.boxplot(df['price1'])
# Out:
# <Axes: >

# %%
t=kpss(df['price1'],'ct')
t
# Out:
# /var/folders/35/vcbg9sn9479dqrdl_3fgrrkh0000gn/T/ipykernel_28449/4116826920.py:1: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   t=kpss(df['price1'],'ct')
# (0.3467564624197358,
#  0.01,
#  9,
#  {'10%': 0.119, '5%': 0.146, '2.5%': 0.176, '1%': 0.216})

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose

# Assuming df is your DataFrame with a 'date' column and a 'value' column representing the time series
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)

# Perform seasonal decomposition
decomposition = seasonal_decompose(df['price1'], model='additive')

# Plot the original time series
plt.figure(figsize=(10, 6))
plt.subplot(411)
plt.plot(df['price1'], label='Original', color='blue')
plt.legend(loc='upper left')

# Plot the trend component
plt.subplot(412)
plt.plot(decomposition.trend, label='Trend', color='green')
plt.legend(loc='upper left')

# Plot the seasonal component
plt.subplot(413)
plt.plot(decomposition.seasonal, label='Seasonal', color='red')
plt.legend(loc='upper left')

# Plot the residual component
plt.subplot(414)
plt.plot(decomposition.resid, label='Residual', color='purple')
plt.legend(loc='upper left')

plt.tight_layout()
plt.show()

# %%
df=pd.read_csv("DATA/Backup/onion.csv")

# %%
import pandas as pd


# Convert 'Date' column to datetime type
df['Date'] = pd.to_datetime(df['Date'])

# Check for missing values
print("Missing values:")
print(df.isnull().sum())

# Check for duplicates
print("\nDuplicates:")
print(df.duplicated().sum())

# Check basic statistics of the 'Price' column
print("\nBasic statistics of Price:")
print(df['price'].describe())

# Plot the time series data
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(df['Date'], df['price'], marker='o')
plt.title('Time Series Data')
plt.xlabel('Date')
plt.ylabel('Price')
plt.grid(True)
plt.show()
# Out:
# Missing values:
# Date     0
# price    0
# dtype: int64
#
# Duplicates:
# 0
#
# Basic statistics of Price:
# count    288.000000
# mean     229.182292
# std      129.215875
# min       77.400000
# 25%      139.525000
# 50%      201.800000
# 75%      273.375000
# max      845.600000
# Name: price, dtype: float64

# %%
import pandas as pd
from scipy.stats import mstats
def winsorize_outliers(series, lower_percentile=0.05, upper_percentile=0.95):
    lower_limit = series.quantile(lower_percentile)
    upper_limit = series.quantile(upper_percentile)
    winsorized_values = mstats.winsorize(series, limits=(lower_percentile, 1 - upper_percentile))  # Correcting the upper percentile value
    return winsorized_values


# Winsorize the 'Price' column
#df['Price_winsorized'] = winsorize_outliers(df['price'])
df['price1'] = winsorize_outliers(df['price'], lower_percentile=0.05, upper_percentile=0.95)


# Plot the original and winsorized time series data
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(df['Date'], df['price'], marker='o', label='Original Price')
plt.plot(df['Date'], df['price1'], marker='o', label='Winsorized Price')
plt.title('Original vs. Winsorized Time Series Data')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
plt.show()

# %%
df.pop('price')
df['price']=df.pop('price1')
df
# Out:
#           Date  price
# 0   2000-01-01  100.8
# 1   2000-02-01  100.8
# 2   2000-03-01  100.8
# 3   2000-04-01  100.8
# 4   2000-05-01  100.8
# ..         ...    ...
# 283 2023-08-01  233.9
# 284 2023-09-01  271.9
# 285 2023-10-01  343.4
# 286 2023-11-01  445.3
# 287 2023-12-01  372.6
#
# [288 rows x 2 columns]

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
df['price'] = scaler.fit_transform(df['price'].values.reshape(-1,1))
import matplotlib.pyplot as plt
plt.plot(df['Date'],df['price'])

# %%
# Convert 'date' column to datetime if it's not already
# Shift the 'price' column to create new columns
scaler = MinMaxScaler(feature_range=(0, 1))
df['price'] = scaler.fit_transform(df['price'].values.reshape(-1,1))
#import matplotlib.pyplot as plt
#plt.plot(df['Date'],df['price'])
shift=7
for i in range(shift):
    df['target-'+str(i+1)] = df['price'].shift(i+1)
#df['target-1'] = df['price'].shift(1)
#df['target-2'] = df['price'].shift(2)
#df['target-3'] = df['price'].shift(3)
#df['target-4'] = df['price'].shift(4)
#df['target-5'] = df['price'].shift(5)
#df['target-6'] = df['price'].shift(6)
#df['target-7'] = df['price'].shift(7)
#df['target-8'] = df['price'].shift(8)
#df['target-9'] = df['price'].shift(9)
#df['target-10'] = df['price'].shift(10)

# %%
d=df[shift:]
d
# Out:
#           Date     price  target-1  target-2  target-3  target-4  target-5  \
# 7   2000-08-01  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 8   2000-09-01  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 9   2000-10-01  0.033382  0.000000  0.000000  0.000000  0.000000  0.000000
# 10  2000-11-01  0.099855  0.033382  0.000000  0.000000  0.000000  0.000000
# 11  2000-12-01  0.121045  0.099855  0.033382  0.000000  0.000000  0.000000
# ..         ...       ...       ...       ...       ...       ...       ...
# 283 2023-08-01  0.386357  0.242380  0.126560  0.082438  0.079536  0.108273
# 284 2023-09-01  0.496662  0.386357  0.242380  0.126560  0.082438  0.079536
# 285 2023-10-01  0.704209  0.496662  0.386357  0.242380  0.126560  0.082438
# 286 2023-11-01  1.000000  0.704209  0.496662  0.386357  0.242380  0.126560
# 287 2023-12-01  0.788970  1.000000  0.704209  0.496662  0.386357  0.242380
#
#      target-6  target-7
# 7    0.000000  0.000000
# 8    0.000000  0.000000
# 9    0.000000  0.000000
# 10   0.000000  0.000000
# 11   0.000000  0.000000
# ..        ...       ...
# 283  0.170392  0.289405
# 284  0.108273  0.170392
# 285  0.079536  0.108273
# 286  0.082438  0.079536
# 287  0.126560  0.082438
#
# [281 rows x 9 columns]

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
    df_as_np = windowed_dataframe.to_numpy()
    dates = df_as_np[:, 0]
    middle_matrix = df_as_np[:, 2:]
    X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))
    Y = df_as_np[:, 1:2]
    return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(d)

dates.shape, X.shape, y.shape
# Out:
# ((281,), (281, 7, 1), (281, 1))

# %%
#y

# %%
#dates
#X
#y

# %%
q_80 = int(len(dates) * .8)
q_90 = int(len(dates) * .9)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %%
#X_train

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers.legacy import Adam
from tensorflow.keras import layers
from keras.callbacks import EarlyStopping
from keras.regularizers import l2

#early_stopping = EarlyStopping(monitor='val_loss', patience=10, mode='min')

model = Sequential([layers.Input((shift, 1)),
                    #layers.GRU(64),
                    layers.LSTM(64),
                    #layers.LSTM(64, return_sequences=True),
                    #layers.LSTM(64),
                    #layers.Bidirectional(layers.LSTM(64)),
                    #layers.Conv1D(filters=64, kernel_size=3, activation='relu'),
                    #layers.Flatten(),
                    layers.Dense(64, activation='relu'),
                    #layers.Dense(64, activation='relu'),
                    layers.Dense(1)
                   ])

model.compile(loss='mse', 
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

x=model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=200)
# Out:
# Epoch 1/200
# 7/7 [==============================] - 1s 28ms/step - loss: 0.1250 - mean_absolute_error: 0.2641 - val_loss: 0.1573 - val_mean_absolute_error: 0.3009
# Epoch 2/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0517 - mean_absolute_error: 0.1769 - val_loss: 0.1384 - val_mean_absolute_error: 0.3234
# Epoch 3/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0491 - mean_absolute_error: 0.1841 - val_loss: 0.1376 - val_mean_absolute_error: 0.3214
# Epoch 4/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0441 - mean_absolute_error: 0.1693 - val_loss: 0.1382 - val_mean_absolute_error: 0.3059
# Epoch 5/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0436 - mean_absolute_error: 0.1624 - val_loss: 0.1353 - val_mean_absolute_error: 0.3082
# Epoch 6/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0416 - mean_absolute_error: 0.1623 - val_loss: 0.1341 - val_mean_absolute_error: 0.3150
# Epoch 7/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0402 - mean_absolute_error: 0.1602 - val_loss: 0.1311 - val_mean_absolute_error: 0.3090
# Epoch 8/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0389 - mean_absolute_error: 0.1557 - val_loss: 0.1290 - val_mean_absolute_error: 0.3028
# Epoch 9/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0381 - mean_absolute_error: 0.1533 - val_loss: 0.1263 - val_mean_absolute_error: 0.3040
# Epoch 10/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0365 - mean_absolute_error: 0.1506 - val_loss: 0.1221 - val_mean_absolute_error: 0.2952
# Epoch 11/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0362 - mean_absolute_error: 0.1472 - val_loss: 0.1171 - val_mean_absolute_error: 0.2883
# Epoch 12/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0338 - mean_absolute_error: 0.1439 - val_loss: 0.1124 - val_mean_absolute_error: 0.2827
# Epoch 13/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0338 - mean_absolute_error: 0.1428 - val_loss: 0.1051 - val_mean_absolute_error: 0.2703
# Epoch 14/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0314 - mean_absolute_error: 0.1373 - val_loss: 0.1013 - val_mean_absolute_error: 0.2634
# Epoch 15/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0327 - mean_absolute_error: 0.1362 - val_loss: 0.0954 - val_mean_absolute_error: 0.2539
# Epoch 16/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0296 - mean_absolute_error: 0.1319 - val_loss: 0.0908 - val_mean_absolute_error: 0.2465
# Epoch 17/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0282 - mean_absolute_error: 0.1277 - val_loss: 0.0849 - val_mean_absolute_error: 0.2360
# Epoch 18/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0266 - mean_absolute_error: 0.1230 - val_loss: 0.0832 - val_mean_absolute_error: 0.2318
# Epoch 19/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0264 - mean_absolute_error: 0.1205 - val_loss: 0.0745 - val_mean_absolute_error: 0.2191
# Epoch 20/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0260 - mean_absolute_error: 0.1186 - val_loss: 0.0711 - val_mean_absolute_error: 0.2155
# Epoch 21/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0241 - mean_absolute_error: 0.1156 - val_loss: 0.0682 - val_mean_absolute_error: 0.2107
# Epoch 22/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0234 - mean_absolute_error: 0.1132 - val_loss: 0.0637 - val_mean_absolute_error: 0.2037
# Epoch 23/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0234 - mean_absolute_error: 0.1123 - val_loss: 0.0607 - val_mean_absolute_error: 0.1983
# Epoch 24/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0227 - mean_absolute_error: 0.1095 - val_loss: 0.0580 - val_mean_absolute_error: 0.1949
# Epoch 25/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0236 - mean_absolute_error: 0.1144 - val_loss: 0.0618 - val_mean_absolute_error: 0.1962
# Epoch 26/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0240 - mean_absolute_error: 0.1160 - val_loss: 0.0657 - val_mean_absolute_error: 0.2012
# Epoch 27/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0237 - mean_absolute_error: 0.1126 - val_loss: 0.0553 - val_mean_absolute_error: 0.1897
# Epoch 28/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0221 - mean_absolute_error: 0.1082 - val_loss: 0.0575 - val_mean_absolute_error: 0.1893
# Epoch 29/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0241 - mean_absolute_error: 0.1138 - val_loss: 0.0584 - val_mean_absolute_error: 0.1909
# Epoch 30/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0218 - mean_absolute_error: 0.1074 - val_loss: 0.0566 - val_mean_absolute_error: 0.1908
# Epoch 31/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0214 - mean_absolute_error: 0.1048 - val_loss: 0.0541 - val_mean_absolute_error: 0.1867
# Epoch 32/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0207 - mean_absolute_error: 0.1062 - val_loss: 0.0591 - val_mean_absolute_error: 0.1900
# Epoch 33/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0219 - mean_absolute_error: 0.1051 - val_loss: 0.0515 - val_mean_absolute_error: 0.1829
# Epoch 34/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0208 - mean_absolute_error: 0.1050 - val_loss: 0.0513 - val_mean_absolute_error: 0.1835
# Epoch 35/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0199 - mean_absolute_error: 0.1036 - val_loss: 0.0520 - val_mean_absolute_error: 0.1837
# Epoch 36/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0190 - mean_absolute_error: 0.0996 - val_loss: 0.0499 - val_mean_absolute_error: 0.1812
# Epoch 37/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0185 - mean_absolute_error: 0.0986 - val_loss: 0.0498 - val_mean_absolute_error: 0.1778
# Epoch 38/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0205 - mean_absolute_error: 0.1032 - val_loss: 0.0487 - val_mean_absolute_error: 0.1748
# Epoch 39/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0188 - mean_absolute_error: 0.1000 - val_loss: 0.0459 - val_mean_absolute_error: 0.1733
# Epoch 40/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0201 - mean_absolute_error: 0.1015 - val_loss: 0.0526 - val_mean_absolute_error: 0.1799
# Epoch 41/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0191 - mean_absolute_error: 0.0993 - val_loss: 0.0458 - val_mean_absolute_error: 0.1714
# Epoch 42/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0182 - mean_absolute_error: 0.0975 - val_loss: 0.0471 - val_mean_absolute_error: 0.1721
# Epoch 43/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0188 - mean_absolute_error: 0.0977 - val_loss: 0.0496 - val_mean_absolute_error: 0.1735
# Epoch 44/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0191 - mean_absolute_error: 0.0994 - val_loss: 0.0447 - val_mean_absolute_error: 0.1709
# Epoch 45/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0173 - mean_absolute_error: 0.0964 - val_loss: 0.0556 - val_mean_absolute_error: 0.1789
# Epoch 46/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0198 - mean_absolute_error: 0.1050 - val_loss: 0.0437 - val_mean_absolute_error: 0.1647
# Epoch 47/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0170 - mean_absolute_error: 0.0945 - val_loss: 0.0417 - val_mean_absolute_error: 0.1636
# Epoch 48/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0170 - mean_absolute_error: 0.0950 - val_loss: 0.0413 - val_mean_absolute_error: 0.1649
# Epoch 49/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0174 - mean_absolute_error: 0.0950 - val_loss: 0.0513 - val_mean_absolute_error: 0.1731
# Epoch 50/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0190 - mean_absolute_error: 0.1024 - val_loss: 0.0430 - val_mean_absolute_error: 0.1677
# Epoch 51/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0161 - mean_absolute_error: 0.0919 - val_loss: 0.0393 - val_mean_absolute_error: 0.1596
# Epoch 52/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0162 - mean_absolute_error: 0.0904 - val_loss: 0.0403 - val_mean_absolute_error: 0.1631
# Epoch 53/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0154 - mean_absolute_error: 0.0888 - val_loss: 0.0395 - val_mean_absolute_error: 0.1617
# Epoch 54/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0165 - mean_absolute_error: 0.0921 - val_loss: 0.0401 - val_mean_absolute_error: 0.1570
# Epoch 55/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0167 - mean_absolute_error: 0.0946 - val_loss: 0.0426 - val_mean_absolute_error: 0.1619
# Epoch 56/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0167 - mean_absolute_error: 0.0925 - val_loss: 0.0390 - val_mean_absolute_error: 0.1598
# Epoch 57/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0164 - mean_absolute_error: 0.0910 - val_loss: 0.0385 - val_mean_absolute_error: 0.1550
# Epoch 58/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0152 - mean_absolute_error: 0.0898 - val_loss: 0.0420 - val_mean_absolute_error: 0.1562
# Epoch 59/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0183 - mean_absolute_error: 0.0956 - val_loss: 0.0445 - val_mean_absolute_error: 0.1609
# Epoch 60/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0176 - mean_absolute_error: 0.0946 - val_loss: 0.0385 - val_mean_absolute_error: 0.1569
# Epoch 61/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0175 - mean_absolute_error: 0.0941 - val_loss: 0.0377 - val_mean_absolute_error: 0.1546
# Epoch 62/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0152 - mean_absolute_error: 0.0880 - val_loss: 0.0380 - val_mean_absolute_error: 0.1501
# Epoch 63/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0165 - mean_absolute_error: 0.0917 - val_loss: 0.0433 - val_mean_absolute_error: 0.1577
# Epoch 64/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0142 - mean_absolute_error: 0.0852 - val_loss: 0.0358 - val_mean_absolute_error: 0.1551
# Epoch 65/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0145 - mean_absolute_error: 0.0847 - val_loss: 0.0356 - val_mean_absolute_error: 0.1514
# Epoch 66/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0176 - mean_absolute_error: 0.0933 - val_loss: 0.0604 - val_mean_absolute_error: 0.1779
# Epoch 67/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0256 - mean_absolute_error: 0.1131 - val_loss: 0.0634 - val_mean_absolute_error: 0.1833
# Epoch 68/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0257 - mean_absolute_error: 0.1173 - val_loss: 0.0409 - val_mean_absolute_error: 0.1624
# Epoch 69/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0149 - mean_absolute_error: 0.0888 - val_loss: 0.0416 - val_mean_absolute_error: 0.1621
# Epoch 70/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0149 - mean_absolute_error: 0.0855 - val_loss: 0.0410 - val_mean_absolute_error: 0.1608
# Epoch 71/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0159 - mean_absolute_error: 0.0911 - val_loss: 0.0361 - val_mean_absolute_error: 0.1557
# Epoch 72/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0146 - mean_absolute_error: 0.0871 - val_loss: 0.0362 - val_mean_absolute_error: 0.1552
# Epoch 73/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0138 - mean_absolute_error: 0.0863 - val_loss: 0.0392 - val_mean_absolute_error: 0.1544
# Epoch 74/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0147 - mean_absolute_error: 0.0870 - val_loss: 0.0358 - val_mean_absolute_error: 0.1527
# Epoch 75/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0139 - mean_absolute_error: 0.0849 - val_loss: 0.0352 - val_mean_absolute_error: 0.1485
# Epoch 76/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0128 - mean_absolute_error: 0.0809 - val_loss: 0.0348 - val_mean_absolute_error: 0.1474
# Epoch 77/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0128 - mean_absolute_error: 0.0806 - val_loss: 0.0341 - val_mean_absolute_error: 0.1451
# Epoch 78/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0133 - mean_absolute_error: 0.0823 - val_loss: 0.0326 - val_mean_absolute_error: 0.1447
# Epoch 79/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0124 - mean_absolute_error: 0.0784 - val_loss: 0.0350 - val_mean_absolute_error: 0.1445
# Epoch 80/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0130 - mean_absolute_error: 0.0805 - val_loss: 0.0336 - val_mean_absolute_error: 0.1418
# Epoch 81/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0131 - mean_absolute_error: 0.0802 - val_loss: 0.0318 - val_mean_absolute_error: 0.1428
# Epoch 82/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0134 - mean_absolute_error: 0.0804 - val_loss: 0.0352 - val_mean_absolute_error: 0.1468
# Epoch 83/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0120 - mean_absolute_error: 0.0785 - val_loss: 0.0349 - val_mean_absolute_error: 0.1437
# Epoch 84/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0121 - mean_absolute_error: 0.0787 - val_loss: 0.0305 - val_mean_absolute_error: 0.1390
# Epoch 85/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0117 - mean_absolute_error: 0.0757 - val_loss: 0.0369 - val_mean_absolute_error: 0.1505
# Epoch 86/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0120 - mean_absolute_error: 0.0775 - val_loss: 0.0311 - val_mean_absolute_error: 0.1373
# Epoch 87/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0116 - mean_absolute_error: 0.0772 - val_loss: 0.0363 - val_mean_absolute_error: 0.1460
# Epoch 88/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0123 - mean_absolute_error: 0.0799 - val_loss: 0.0392 - val_mean_absolute_error: 0.1519
# Epoch 89/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0131 - mean_absolute_error: 0.0826 - val_loss: 0.0354 - val_mean_absolute_error: 0.1459
# Epoch 90/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0159 - mean_absolute_error: 0.0915 - val_loss: 0.0295 - val_mean_absolute_error: 0.1333
# Epoch 91/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0153 - mean_absolute_error: 0.0844 - val_loss: 0.0314 - val_mean_absolute_error: 0.1403
# Epoch 92/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0138 - mean_absolute_error: 0.0844 - val_loss: 0.0318 - val_mean_absolute_error: 0.1380
# Epoch 93/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0150 - mean_absolute_error: 0.0865 - val_loss: 0.0377 - val_mean_absolute_error: 0.1500
# Epoch 94/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0132 - mean_absolute_error: 0.0824 - val_loss: 0.0411 - val_mean_absolute_error: 0.1571
# Epoch 95/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0122 - mean_absolute_error: 0.0788 - val_loss: 0.0312 - val_mean_absolute_error: 0.1412
# Epoch 96/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0123 - mean_absolute_error: 0.0784 - val_loss: 0.0305 - val_mean_absolute_error: 0.1388
# Epoch 97/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0131 - mean_absolute_error: 0.0807 - val_loss: 0.0307 - val_mean_absolute_error: 0.1397
# Epoch 98/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0112 - mean_absolute_error: 0.0745 - val_loss: 0.0328 - val_mean_absolute_error: 0.1415
# Epoch 99/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0116 - mean_absolute_error: 0.0770 - val_loss: 0.0335 - val_mean_absolute_error: 0.1438
# Epoch 100/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0123 - mean_absolute_error: 0.0763 - val_loss: 0.0299 - val_mean_absolute_error: 0.1369
# Epoch 101/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0135 - mean_absolute_error: 0.0820 - val_loss: 0.0302 - val_mean_absolute_error: 0.1374
# Epoch 102/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0122 - mean_absolute_error: 0.0771 - val_loss: 0.0335 - val_mean_absolute_error: 0.1443
# Epoch 103/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0114 - mean_absolute_error: 0.0768 - val_loss: 0.0389 - val_mean_absolute_error: 0.1526
# Epoch 104/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0121 - mean_absolute_error: 0.0783 - val_loss: 0.0322 - val_mean_absolute_error: 0.1415
# Epoch 105/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0114 - mean_absolute_error: 0.0767 - val_loss: 0.0382 - val_mean_absolute_error: 0.1506
# Epoch 106/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0118 - mean_absolute_error: 0.0779 - val_loss: 0.0307 - val_mean_absolute_error: 0.1348
# Epoch 107/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0141 - mean_absolute_error: 0.0832 - val_loss: 0.0299 - val_mean_absolute_error: 0.1364
# Epoch 108/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0146 - mean_absolute_error: 0.0879 - val_loss: 0.0299 - val_mean_absolute_error: 0.1356
# Epoch 109/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0118 - mean_absolute_error: 0.0758 - val_loss: 0.0312 - val_mean_absolute_error: 0.1406
# Epoch 110/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0114 - mean_absolute_error: 0.0748 - val_loss: 0.0321 - val_mean_absolute_error: 0.1408
# Epoch 111/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0110 - mean_absolute_error: 0.0740 - val_loss: 0.0310 - val_mean_absolute_error: 0.1387
# Epoch 112/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0109 - mean_absolute_error: 0.0732 - val_loss: 0.0291 - val_mean_absolute_error: 0.1339
# Epoch 113/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0113 - mean_absolute_error: 0.0753 - val_loss: 0.0309 - val_mean_absolute_error: 0.1384
# Epoch 114/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0108 - mean_absolute_error: 0.0739 - val_loss: 0.0348 - val_mean_absolute_error: 0.1460
# Epoch 115/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0108 - mean_absolute_error: 0.0741 - val_loss: 0.0292 - val_mean_absolute_error: 0.1349
# Epoch 116/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0111 - mean_absolute_error: 0.0746 - val_loss: 0.0384 - val_mean_absolute_error: 0.1521
# Epoch 117/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0132 - mean_absolute_error: 0.0800 - val_loss: 0.0366 - val_mean_absolute_error: 0.1497
# Epoch 118/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0116 - mean_absolute_error: 0.0775 - val_loss: 0.0351 - val_mean_absolute_error: 0.1450
# Epoch 119/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0118 - mean_absolute_error: 0.0769 - val_loss: 0.0305 - val_mean_absolute_error: 0.1390
# Epoch 120/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0109 - mean_absolute_error: 0.0737 - val_loss: 0.0293 - val_mean_absolute_error: 0.1346
# Epoch 121/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0119 - mean_absolute_error: 0.0773 - val_loss: 0.0324 - val_mean_absolute_error: 0.1402
# Epoch 122/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0108 - mean_absolute_error: 0.0740 - val_loss: 0.0402 - val_mean_absolute_error: 0.1572
# Epoch 123/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0123 - mean_absolute_error: 0.0803 - val_loss: 0.0321 - val_mean_absolute_error: 0.1395
# Epoch 124/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0107 - mean_absolute_error: 0.0745 - val_loss: 0.0291 - val_mean_absolute_error: 0.1346
# Epoch 125/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0117 - mean_absolute_error: 0.0763 - val_loss: 0.0307 - val_mean_absolute_error: 0.1379
# Epoch 126/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0112 - mean_absolute_error: 0.0757 - val_loss: 0.0300 - val_mean_absolute_error: 0.1347
# Epoch 127/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0106 - mean_absolute_error: 0.0733 - val_loss: 0.0377 - val_mean_absolute_error: 0.1518
# Epoch 128/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0114 - mean_absolute_error: 0.0753 - val_loss: 0.0340 - val_mean_absolute_error: 0.1422
# Epoch 129/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0107 - mean_absolute_error: 0.0721 - val_loss: 0.0284 - val_mean_absolute_error: 0.1308
# Epoch 130/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0132 - mean_absolute_error: 0.0821 - val_loss: 0.0546 - val_mean_absolute_error: 0.1744
# Epoch 131/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0155 - mean_absolute_error: 0.0878 - val_loss: 0.0413 - val_mean_absolute_error: 0.1543
# Epoch 132/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0146 - mean_absolute_error: 0.0851 - val_loss: 0.0522 - val_mean_absolute_error: 0.1727
# Epoch 133/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0177 - mean_absolute_error: 0.0965 - val_loss: 0.0321 - val_mean_absolute_error: 0.1366
# Epoch 134/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0147 - mean_absolute_error: 0.0845 - val_loss: 0.0321 - val_mean_absolute_error: 0.1453
# Epoch 135/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0152 - mean_absolute_error: 0.0863 - val_loss: 0.0531 - val_mean_absolute_error: 0.1708
# Epoch 136/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0164 - mean_absolute_error: 0.0895 - val_loss: 0.0305 - val_mean_absolute_error: 0.1380
# Epoch 137/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0127 - mean_absolute_error: 0.0788 - val_loss: 0.0309 - val_mean_absolute_error: 0.1409
# Epoch 138/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0114 - mean_absolute_error: 0.0751 - val_loss: 0.0338 - val_mean_absolute_error: 0.1429
# Epoch 139/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0109 - mean_absolute_error: 0.0736 - val_loss: 0.0314 - val_mean_absolute_error: 0.1387
# Epoch 140/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0107 - mean_absolute_error: 0.0728 - val_loss: 0.0307 - val_mean_absolute_error: 0.1361
# Epoch 141/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0107 - mean_absolute_error: 0.0731 - val_loss: 0.0370 - val_mean_absolute_error: 0.1483
# Epoch 142/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0130 - mean_absolute_error: 0.0799 - val_loss: 0.0291 - val_mean_absolute_error: 0.1310
# Epoch 143/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0128 - mean_absolute_error: 0.0780 - val_loss: 0.0289 - val_mean_absolute_error: 0.1325
# Epoch 144/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0158 - mean_absolute_error: 0.0871 - val_loss: 0.0415 - val_mean_absolute_error: 0.1534
# Epoch 145/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0116 - mean_absolute_error: 0.0787 - val_loss: 0.0313 - val_mean_absolute_error: 0.1402
# Epoch 146/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0111 - mean_absolute_error: 0.0740 - val_loss: 0.0301 - val_mean_absolute_error: 0.1368
# Epoch 147/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0125 - mean_absolute_error: 0.0770 - val_loss: 0.0358 - val_mean_absolute_error: 0.1445
# Epoch 148/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0119 - mean_absolute_error: 0.0768 - val_loss: 0.0399 - val_mean_absolute_error: 0.1512
# Epoch 149/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0133 - mean_absolute_error: 0.0805 - val_loss: 0.0296 - val_mean_absolute_error: 0.1330
# Epoch 150/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0126 - mean_absolute_error: 0.0821 - val_loss: 0.0385 - val_mean_absolute_error: 0.1491
# Epoch 151/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0113 - mean_absolute_error: 0.0756 - val_loss: 0.0317 - val_mean_absolute_error: 0.1370
# Epoch 152/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0106 - mean_absolute_error: 0.0721 - val_loss: 0.0304 - val_mean_absolute_error: 0.1395
# Epoch 153/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0118 - mean_absolute_error: 0.0760 - val_loss: 0.0301 - val_mean_absolute_error: 0.1334
# Epoch 154/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0117 - mean_absolute_error: 0.0779 - val_loss: 0.0335 - val_mean_absolute_error: 0.1424
# Epoch 155/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0126 - mean_absolute_error: 0.0784 - val_loss: 0.0419 - val_mean_absolute_error: 0.1535
# Epoch 156/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0126 - mean_absolute_error: 0.0810 - val_loss: 0.0290 - val_mean_absolute_error: 0.1318
# Epoch 157/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0119 - mean_absolute_error: 0.0755 - val_loss: 0.0305 - val_mean_absolute_error: 0.1390
# Epoch 158/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0124 - mean_absolute_error: 0.0797 - val_loss: 0.0381 - val_mean_absolute_error: 0.1471
# Epoch 159/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0116 - mean_absolute_error: 0.0767 - val_loss: 0.0345 - val_mean_absolute_error: 0.1453
# Epoch 160/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0107 - mean_absolute_error: 0.0723 - val_loss: 0.0318 - val_mean_absolute_error: 0.1393
# Epoch 161/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0102 - mean_absolute_error: 0.0733 - val_loss: 0.0324 - val_mean_absolute_error: 0.1384
# Epoch 162/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0101 - mean_absolute_error: 0.0714 - val_loss: 0.0310 - val_mean_absolute_error: 0.1377
# Epoch 163/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0101 - mean_absolute_error: 0.0716 - val_loss: 0.0344 - val_mean_absolute_error: 0.1431
# Epoch 164/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0106 - mean_absolute_error: 0.0749 - val_loss: 0.0292 - val_mean_absolute_error: 0.1316
# Epoch 165/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0105 - mean_absolute_error: 0.0718 - val_loss: 0.0309 - val_mean_absolute_error: 0.1378
# Epoch 166/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0099 - mean_absolute_error: 0.0714 - val_loss: 0.0349 - val_mean_absolute_error: 0.1425
# Epoch 167/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0118 - mean_absolute_error: 0.0774 - val_loss: 0.0350 - val_mean_absolute_error: 0.1430
# Epoch 168/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0140 - mean_absolute_error: 0.0831 - val_loss: 0.0302 - val_mean_absolute_error: 0.1343
# Epoch 169/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0129 - mean_absolute_error: 0.0790 - val_loss: 0.0312 - val_mean_absolute_error: 0.1377
# Epoch 170/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0102 - mean_absolute_error: 0.0725 - val_loss: 0.0341 - val_mean_absolute_error: 0.1400
# Epoch 171/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0100 - mean_absolute_error: 0.0716 - val_loss: 0.0307 - val_mean_absolute_error: 0.1363
# Epoch 172/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0104 - mean_absolute_error: 0.0732 - val_loss: 0.0443 - val_mean_absolute_error: 0.1554
# Epoch 173/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0139 - mean_absolute_error: 0.0842 - val_loss: 0.0291 - val_mean_absolute_error: 0.1314
# Epoch 174/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0136 - mean_absolute_error: 0.0817 - val_loss: 0.0293 - val_mean_absolute_error: 0.1321
# Epoch 175/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0115 - mean_absolute_error: 0.0762 - val_loss: 0.0470 - val_mean_absolute_error: 0.1605
# Epoch 176/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0142 - mean_absolute_error: 0.0848 - val_loss: 0.0346 - val_mean_absolute_error: 0.1455
# Epoch 177/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0112 - mean_absolute_error: 0.0760 - val_loss: 0.0429 - val_mean_absolute_error: 0.1545
# Epoch 178/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0114 - mean_absolute_error: 0.0753 - val_loss: 0.0320 - val_mean_absolute_error: 0.1398
# Epoch 179/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0100 - mean_absolute_error: 0.0708 - val_loss: 0.0340 - val_mean_absolute_error: 0.1415
# Epoch 180/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0103 - mean_absolute_error: 0.0708 - val_loss: 0.0291 - val_mean_absolute_error: 0.1323
# Epoch 181/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0114 - mean_absolute_error: 0.0761 - val_loss: 0.0314 - val_mean_absolute_error: 0.1357
# Epoch 182/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0114 - mean_absolute_error: 0.0755 - val_loss: 0.0365 - val_mean_absolute_error: 0.1442
# Epoch 183/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0104 - mean_absolute_error: 0.0720 - val_loss: 0.0309 - val_mean_absolute_error: 0.1350
# Epoch 184/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0107 - mean_absolute_error: 0.0736 - val_loss: 0.0296 - val_mean_absolute_error: 0.1335
# Epoch 185/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0097 - mean_absolute_error: 0.0692 - val_loss: 0.0323 - val_mean_absolute_error: 0.1380
# Epoch 186/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0101 - mean_absolute_error: 0.0708 - val_loss: 0.0335 - val_mean_absolute_error: 0.1379
# Epoch 187/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0102 - mean_absolute_error: 0.0712 - val_loss: 0.0293 - val_mean_absolute_error: 0.1325
# Epoch 188/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0112 - mean_absolute_error: 0.0752 - val_loss: 0.0311 - val_mean_absolute_error: 0.1343
# Epoch 189/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0096 - mean_absolute_error: 0.0707 - val_loss: 0.0327 - val_mean_absolute_error: 0.1390
# Epoch 190/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0099 - mean_absolute_error: 0.0702 - val_loss: 0.0317 - val_mean_absolute_error: 0.1357
# Epoch 191/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0107 - mean_absolute_error: 0.0742 - val_loss: 0.0308 - val_mean_absolute_error: 0.1368
# Epoch 192/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0102 - mean_absolute_error: 0.0732 - val_loss: 0.0305 - val_mean_absolute_error: 0.1331
# Epoch 193/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0100 - mean_absolute_error: 0.0717 - val_loss: 0.0307 - val_mean_absolute_error: 0.1370
# Epoch 194/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0099 - mean_absolute_error: 0.0727 - val_loss: 0.0391 - val_mean_absolute_error: 0.1457
# Epoch 195/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0115 - mean_absolute_error: 0.0781 - val_loss: 0.0309 - val_mean_absolute_error: 0.1371
# Epoch 196/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0100 - mean_absolute_error: 0.0703 - val_loss: 0.0310 - val_mean_absolute_error: 0.1329
# Epoch 197/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0100 - mean_absolute_error: 0.0713 - val_loss: 0.0361 - val_mean_absolute_error: 0.1440
# Epoch 198/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0101 - mean_absolute_error: 0.0701 - val_loss: 0.0328 - val_mean_absolute_error: 0.1365
# Epoch 199/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0110 - mean_absolute_error: 0.0731 - val_loss: 0.0314 - val_mean_absolute_error: 0.1368
# Epoch 200/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0097 - mean_absolute_error: 0.0693 - val_loss: 0.0341 - val_mean_absolute_error: 0.1372

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_3 (LSTM)               (None, 64)                16896
#
#  dense_6 (Dense)             (None, 64)                4160
#
#  dense_7 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 21121 (82.50 KB)
# Trainable params: 21121 (82.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
plt.plot(x.history['loss'])

# %%
# Evaluate the model
train_loss = model.evaluate(X_train, y_train, verbose=0)
print(f'Training Loss: {train_loss}')

test_loss = model.evaluate(X_test, y_test, verbose=0)
print(f'Testing Loss: {test_loss}')
# Out:
# Training Loss: [0.009780551306903362, 0.07091256231069565]
# Testing Loss: [0.011443903669714928, 0.07996901124715805]

# %%
train_predictions = model.predict(X_train)

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)

#plt.plot(train_predictions)
#plt.plot(y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 7/7 [==============================] - 0s 1ms/step

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 1/1 [==============================] - 0s 142ms/step

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 1/1 [==============================] - 0s 11ms/step

# %%
n = 50  # Change this value to forecast more or fewer values
forecast = []
last_data = X[-1]  # Last X data point
for i in range(n):
    next_y = model.predict(last_data.reshape(1, X.shape[1], X.shape[2]))  # Predict next y
    forecast.append(next_y)
    last_data = np.append(last_data[1:], next_y)  # Shift data by 1 and append next_y
forecast = scaler.inverse_transform(np.array(forecast).reshape(-1, 1))
print("Forecasted next", n, "y values:")
print(forecast)
# Out:
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# Forecasted next 50 y values:
# [[ 0.7348345 ]
#  [ 0.6948703 ]
#  [ 0.4256973 ]
#  [ 0.17692205]
#  [ 0.11987503]
#  [ 0.55770534]
#  [ 0.7163394 ]
#  [ 0.36750948]
#  [ 0.03106105]
#  [ 0.03291207]
#  [ 0.4425243 ]
#  [ 0.7487912 ]
#  [ 0.2824374 ]
#  [-0.02315838]
#  [-0.01152202]
#  [ 0.3806405 ]
#  [ 0.777413  ]
#  [ 0.17154992]
#  [-0.0348932 ]
#  [-0.02417457]
#  [ 0.36505187]
#  [ 0.79914254]
#  [ 0.10220627]
#  [-0.04161338]
#  [-0.02516774]
#  [ 0.37069657]
#  [ 0.81499743]
#  [ 0.0540553 ]
#  [-0.0451302 ]
#  [-0.02236177]
#  [ 0.38550895]
#  [ 0.82742435]
#  [ 0.01545784]
#  [-0.04701703]
#  [-0.01848408]
#  [ 0.40524888]
#  [ 0.8376757 ]
#  [-0.0140968 ]
#  [-0.04827417]
#  [-0.01493244]
#  [ 0.42604557]
#  [ 0.8466949 ]
#  [-0.03538602]
#  [-0.04947541]
#  [-0.01239669]
#  [ 0.4452402 ]
#  [ 0.8551969 ]
#  [-0.04976529]
#  [-0.05099485]
#  [-0.01117783]]

# %%
plt.figure(figsize=(10, 6))
plt.plot(dates, y, label='Original Data')
plt.xlabel('Time')
plt.ylabel('Value')
plt.title('Original Data and Forecast')
plt.xticks(rotation=45)
plt.legend()

# Plot forecast
forecast_dates = np.arange(len(y), len(y) + n)
plt.plot(forecast_dates, forecast, label='Forecast', color='red')
plt.legend()

plt.show()

# %%
# Inverse transform to get actual prices
y_train_actual = scaler.inverse_transform(y_train.reshape(-1, 1))
y_test_actual = scaler.inverse_transform(y_test.reshape(-1, 1))
y_train_pred_actual = scaler.inverse_transform(train_predictions.reshape(-1,1))
y_test_pred_actual = scaler.inverse_transform(test_predictions.reshape(-1,1))
y_val_pred_actual = scaler.inverse_transform(val_predictions.reshape(-1,1))
y_val_actual = scaler.inverse_transform(y_val.reshape(-1,1))

# %%
# Calculate evaluation metrics
train_mae = mean_absolute_error(y_train_actual, y_train_pred_actual)
train_mse = mean_squared_error(y_train_actual, y_train_pred_actual)
val_mae = mean_absolute_error(y_val_actual, y_val_pred_actual)
test_mae = mean_absolute_error(y_test_actual, y_test_pred_actual)
test_mse = mean_squared_error(y_test_actual, y_test_pred_actual)
val_mse = mean_squared_error(y_val_actual, y_val_pred_actual)

print(f'Training MAE: {train_mae}')
print(f'Training MSE: {train_mse}')
print(f'Val MAE: {val_mae}')
print(f'Val MSE: {val_mse}')
print(f'Testing MAE: {test_mae}')
print(f'Testing MSE: {test_mse}')


train_r = np.sqrt(train_mse)
train_r2 = r2_score(y_train_actual, y_train_pred_actual)
test_r = np.sqrt(test_mse)
test_r2 = r2_score(y_test_actual, y_test_pred_actual)
val_r = np.sqrt(val_mse)
val_r2 = r2_score(y_val_actual, y_val_pred_actual)


print(train_r)
print(train_r2)
print(val_r)
print(val_r2)
print(test_r)
print(test_r2)
# Out:
# Training MAE: 0.07091256231069565
# Training MSE: 0.009780549444258213
# Val MAE: 0.13716647028923035
# Val MSE: 0.03410765156149864
# Testing MAE: 0.07996901124715805
# Testing MSE: 0.011443904601037502
# 0.09889666
# 0.8731552836460942
# 0.18468256
# 0.6490641099313923
# 0.10697619
# 0.7630082612399169

# %%
# Calculate evaluation metrics
train_mae = mean_absolute_error(y_train, train_predictions)
train_mse = mean_squared_error(y_train, train_predictions)
val_mae = mean_absolute_error(y_val, val_predictions)
test_mae = mean_absolute_error(y_test, test_predictions)
test_mse = mean_squared_error(y_test, test_predictions)
val_mse = mean_squared_error(y_val, val_predictions)

print(f'Training MAE: {train_mae}')
print(f'Training MSE: {train_mse}')
print(f'Testing MAE: {test_mae}')
print(f'Testing MSE: {test_mse}')
print(f'Testing MAE: {val_mae}')
print(f'Testing MSE: {val_mse}')

train_r = np.sqrt(train_mse)
train_r2 = r2_score(y_train_actual, y_train_pred_actual)
test_r = np.sqrt(test_mse)
test_r2 = r2_score(y_test_actual, y_test_pred_actual)
val_r = np.sqrt(val_mse)
val_r2 = r2_score(y_val_actual, y_val_pred_actual)


print(train_r)
print(val_r)
print(test_r)
print(train_r2)
print(val_r2)
print(test_r2)
# Out:
# Training MAE: 0.03931098058819771
# Training MSE: 0.0032352623529732227
# Testing MAE: 0.03548557311296463
# Testing MSE: 0.0023003045935183764
# Testing MAE: 0.056559350341558456
# Testing MSE: 0.007438889238983393
# 0.056879368
# 0.086248994
# 0.047961492
# 0.9026494483238845
# 0.8178772464656185
# 0.821485557583796

# %%
model.save('onion_cnn')
# Out:
# INFO:tensorflow:Assets written to: onion_cnn/assets
# INFO:tensorflow:Assets written to: onion_cnn/assets

# %%
import tensorflow as tf
m1=tf.keras.models.load_model('onion_gru')
m1.layers[0].input_shape
# Out:
# (None, 3, 1)

# %%
test_predictions = m1.predict(X_test).flatten()

y_test_actual = scaler.inverse_transform(y_test.reshape(-1, 1))
y_test_pred_actual = scaler.inverse_transform(test_predictions.reshape(-1,1))

test_r2 = r2_score(y_test_actual, y_test_pred_actual)
print(test_r2)
#plt.plot(dates_test, test_predictions)
#plt.plot(dates_test, y_test)
#plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 1/1 [==============================] - 0s 144ms/step
# 0.6569322096157718

# %%
plt.plot(figsize=(100,100))
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations'])

# %%
from copy import deepcopy

recursive_predictions = []
recursive_dates = np.concatenate([dates_val, dates_test])

for target_date in recursive_dates:
    last_window = deepcopy(X_train[-1])
    next_prediction = model.predict(np.array([last_window])).flatten()
    recursive_predictions.append(next_prediction)
    last_window[-1] = next_prediction
# Out:
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.plot(recursive_dates, recursive_predictions)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations',
            'Recursive Predictions'])

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import EarlyStopping
# Sample DataFrame
#data = {'date': pd.date_range(start='2024-01-01', periods=100),
#        'price': np.random.rand(100)}
#df = pd.DataFrame(data)

# %%
# Normalize the price data
scaler = MinMaxScaler(feature_range=(0, 1))
d['price'] = scaler.fit_transform(d['Rice'].values.reshape(-1,1))

# %%
x=d.pop('Rice')
d
# Out:
#           date     price
# 0   2000-02-01  0.053404
# 1   2000-03-01  0.043292
# 2   2000-04-01  0.049974
# 3   2000-05-01  0.049490
# 4   2000-06-01  0.049135
# ..         ...       ...
# 235 2019-09-01  0.058386
# 236 2019-10-01  0.056683
# 237 2019-11-01  0.075554
# 238 2019-12-01  0.081035
# 239 2020-01-01  0.089746
#
# [240 rows x 2 columns]

# %%
# Function to create sequences for LSTM
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i + seq_length])
        y.append(data[i + seq_length])
    return np.array(X), np.array(y)

# Hyperparameters
sequence_length = 10  # Adjust according to your choice
batch_size = 64
epochs = 100

# Create sequences
X, y = create_sequences(d['price'].values, sequence_length)

# Split the data into training and testing sets
split = int(0.8 * len(X))
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

# Reshape input data for LSTM [samples, time steps, features]
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# %%
# Define the LSTM model
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(sequence_length, 1)))
model.add(LSTM(units=50))
model.add(Dense(units=1))

# %%
# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
# Train the model
model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, verbose=1)
# Define Early Stopping Callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5, verbose=1, restore_best_weights=True)
# Out:
# Epoch 1/100
# 3/3 [==============================] - 1s 6ms/step - loss: 0.0041
# Epoch 2/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0026
# Epoch 3/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0027
# Epoch 4/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0023
# Epoch 5/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0023
# Epoch 6/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 7/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0021
# Epoch 8/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0020
# Epoch 9/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0021
# Epoch 10/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0020
# Epoch 11/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0019
# Epoch 12/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0019
# Epoch 13/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0019
# Epoch 14/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0018
# Epoch 15/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0018
# Epoch 16/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0018
# Epoch 17/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0017
# Epoch 18/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0017
# Epoch 19/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0016
# Epoch 20/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0016
# Epoch 21/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0016
# Epoch 22/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0015
# Epoch 23/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0015
# Epoch 24/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0014
# Epoch 25/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0014
# Epoch 26/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0013
# Epoch 27/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0013
# Epoch 28/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0013
# Epoch 29/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0012
# Epoch 30/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0012
# Epoch 31/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0012
# Epoch 32/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0012
# Epoch 33/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0012
# Epoch 34/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0012
# Epoch 35/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0012
# Epoch 36/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0012
# Epoch 37/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0011
# Epoch 38/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0011
# Epoch 39/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0011
# Epoch 40/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0011
# Epoch 41/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0011
# Epoch 42/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0011
# Epoch 43/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0011
# Epoch 44/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0011
# Epoch 45/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0010
# Epoch 46/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0010
# Epoch 47/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0010
# Epoch 48/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0010
# Epoch 49/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0010
# Epoch 50/100
# 3/3 [==============================] - 0s 6ms/step - loss: 9.9526e-04
# Epoch 51/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0010
# Epoch 52/100
# 3/3 [==============================] - 0s 6ms/step - loss: 9.7158e-04
# Epoch 53/100
# 3/3 [==============================] - 0s 6ms/step - loss: 9.6520e-04
# Epoch 54/100
# 3/3 [==============================] - 0s 6ms/step - loss: 9.5791e-04
# Epoch 55/100
# 3/3 [==============================] - 0s 5ms/step - loss: 9.5454e-04
# Epoch 56/100
# 3/3 [==============================] - 0s 6ms/step - loss: 9.4484e-04
# Epoch 57/100
# 3/3 [==============================] - 0s 6ms/step - loss: 9.3222e-04
# Epoch 58/100
# 3/3 [==============================] - 0s 6ms/step - loss: 9.2266e-04
# Epoch 59/100
# 3/3 [==============================] - 0s 6ms/step - loss: 9.0965e-04
# Epoch 60/100
# 3/3 [==============================] - 0s 5ms/step - loss: 9.0117e-04
# Epoch 61/100
# 3/3 [==============================] - 0s 6ms/step - loss: 8.9130e-04
# Epoch 62/100
# 3/3 [==============================] - 0s 6ms/step - loss: 8.8937e-04
# Epoch 63/100
# 3/3 [==============================] - 0s 5ms/step - loss: 8.7434e-04
# Epoch 64/100
# 3/3 [==============================] - 0s 5ms/step - loss: 8.6231e-04
# Epoch 65/100
# 3/3 [==============================] - 0s 6ms/step - loss: 8.8836e-04
# Epoch 66/100
# 3/3 [==============================] - 0s 5ms/step - loss: 8.4441e-04
# Epoch 67/100
# 3/3 [==============================] - 0s 6ms/step - loss: 8.4663e-04
# Epoch 68/100
# 3/3 [==============================] - 0s 5ms/step - loss: 8.2159e-04
# Epoch 69/100
# 3/3 [==============================] - 0s 5ms/step - loss: 8.1547e-04
# Epoch 70/100
# 3/3 [==============================] - 0s 5ms/step - loss: 8.0546e-04
# Epoch 71/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.9839e-04
# Epoch 72/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.9681e-04
# Epoch 73/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.8139e-04
# Epoch 74/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.7697e-04
# Epoch 75/100
# 3/3 [==============================] - 0s 6ms/step - loss: 7.7261e-04
# Epoch 76/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.6035e-04
# Epoch 77/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.4825e-04
# Epoch 78/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.4420e-04
# Epoch 79/100
# 3/3 [==============================] - 0s 6ms/step - loss: 7.4013e-04
# Epoch 80/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.3297e-04
# Epoch 81/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.3705e-04
# Epoch 82/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.2424e-04
# Epoch 83/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.3513e-04
# Epoch 84/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.0972e-04
# Epoch 85/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.0489e-04
# Epoch 86/100
# 3/3 [==============================] - 0s 5ms/step - loss: 6.9739e-04
# Epoch 87/100
# 3/3 [==============================] - 0s 5ms/step - loss: 6.9600e-04
# Epoch 88/100
# 3/3 [==============================] - 0s 5ms/step - loss: 6.8829e-04
# Epoch 89/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.0131e-04
# Epoch 90/100
# 3/3 [==============================] - 0s 5ms/step - loss: 6.7832e-04
# Epoch 91/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.0200e-04
# Epoch 92/100
# 3/3 [==============================] - 0s 5ms/step - loss: 6.8064e-04
# Epoch 93/100
# 3/3 [==============================] - 0s 6ms/step - loss: 6.7383e-04
# Epoch 94/100
# 3/3 [==============================] - 0s 6ms/step - loss: 6.7962e-04
# Epoch 95/100
# 3/3 [==============================] - 0s 5ms/step - loss: 6.8475e-04
# Epoch 96/100
# 3/3 [==============================] - 0s 5ms/step - loss: 6.8147e-04
# Epoch 97/100
# 3/3 [==============================] - 0s 5ms/step - loss: 6.7189e-04
# Epoch 98/100
# 3/3 [==============================] - 0s 5ms/step - loss: 6.7507e-04
# Epoch 99/100
# 3/3 [==============================] - 0s 5ms/step - loss: 6.7166e-04
# Epoch 100/100
# 3/3 [==============================] - 0s 6ms/step - loss: 7.0050e-04

# %%
# Evaluate the model
train_loss = model.evaluate(X_train, y_train, verbose=0)
print(f'Training Loss: {train_loss}')

test_loss = model.evaluate(X_test, y_test, verbose=0)
print(f'Testing Loss: {test_loss}')
# Out:
# Training Loss: 0.0006569024408236146
# Testing Loss: 0.04776032641530037

# %%
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

# Inverse transform to get actual prices
y_train_actual = scaler.inverse_transform(y_train.reshape(-1, 1))
y_test_actual = scaler.inverse_transform(y_test.reshape(-1, 1))
y_train_pred_actual = scaler.inverse_transform(y_train_pred)
y_test_pred_actual = scaler.inverse_transform(y_test_pred)

# Calculate evaluation metrics
train_mae = mean_absolute_error(y_train_actual, y_train_pred_actual)
train_mse = mean_squared_error(y_train_actual, y_train_pred_actual)
test_mae = mean_absolute_error(y_test_actual, y_test_pred_actual)
test_mse = mean_squared_error(y_test_actual, y_test_pred_actual)
#
train_r = np.sqrt(train_mse)
train_r2 = r2_score(y_train_actual, y_train_pred_actual)
test_r = np.sqrt(test_mse)
test_r2 = r2_score(y_test_actual, y_test_pred_actual)

print(f'Training MAE: {train_mae}')
print(f'Training MSE: {train_mse}')
print(f'Testing MAE: {test_mae}')
print(f'Testing MSE: {test_mse}')
print(train_r)
print(test_r)
print(train_r2)
print(test_r2)
# Out:
# 6/6 [==============================] - 0s 857us/step
# 1/1 [==============================] - 0s 8ms/step
# Training MAE: 15.197800636291504
# Training MSE: 980.4922485351562
# Testing MAE: 217.68800354003906
# Testing MSE: 190393.921875
# 31.312813
# 436.34152
# 0.80162733858064
# 0.20735048207608497

# %%
import matplotlib.pyplot as plt

# Plot actual vs predicted for training set
plt.figure(figsize=(12, 6))
plt.plot(y_train_actual, label='Actual')
plt.plot(y_train_pred_actual, label='Predicted')
plt.title('Actual vs Predicted Prices - Training Set')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()

# Plot actual vs predicted for testing set
plt.figure(figsize=(12, 6))
plt.plot(y_test_actual, label='Actual')
plt.plot(y_test_pred_actual, label='Predicted')
plt.title('Actual vs Predicted Prices - Testing Set')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
d
# Out:
#           date     price
# 0   2000-02-01  0.053404
# 1   2000-03-01  0.043292
# 2   2000-04-01  0.049974
# 3   2000-05-01  0.049490
# 4   2000-06-01  0.049135
# ..         ...       ...
# 235 2019-09-01  0.058386
# 236 2019-10-01  0.056683
# 237 2019-11-01  0.075554
# 238 2019-12-01  0.081035
# 239 2020-01-01  0.089746
#
# [240 rows x 2 columns]
