# %%
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.preprocessing import MinMaxScaler
from statsmodels.tsa.stattools import kpss

# %%
df=pd.read_csv("DATA/maize.csv")

df
# Out:
#                     Date  price
# 0    2000-01-01 00:00:00  189.0
# 1    2000-02-01 00:00:00  188.3
# 2    2000-03-01 00:00:00  192.4
# 3    2000-04-01 00:00:00  191.2
# 4    2000-05-01 00:00:00  186.9
# ..                   ...    ...
# 277  2023-02-01 00:00:00  193.1
# 278  2023-03-01 00:00:00  193.7
# 279  2023-04-01 00:00:00  189.8
# 280  2023-05-01 00:00:00  184.5
# 281  2023-06-01 00:00:00  181.9
#
# [282 rows x 2 columns]

# %%
df.plot()
# Out:
# <Axes: >

# %%
sn.boxplot(df['price'])
# Out:
# <Axes: >

# %%
t=kpss(df['price'],'ct')
t
# Out:
# /var/folders/35/vcbg9sn9479dqrdl_3fgrrkh0000gn/T/ipykernel_97300/1514378212.py:1: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   t=kpss(df['price'],'ct')
# (0.37914469773592036,
#  0.01,
#  10,
#  {'10%': 0.119, '5%': 0.146, '2.5%': 0.176, '1%': 0.216})

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose

# Assuming df is your DataFrame with a 'date' column and a 'value' column representing the time series
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)

# Perform seasonal decomposition
decomposition = seasonal_decompose(df['price'], model='additive')

# Plot the original time series
plt.figure(figsize=(10, 6))
plt.subplot(411)
plt.plot(df['price'], label='Original', color='blue')
plt.legend(loc='upper left')

# Plot the trend component
plt.subplot(412)
plt.plot(decomposition.trend, label='Trend', color='green')
plt.legend(loc='upper left')

# Plot the seasonal component
plt.subplot(413)
plt.plot(decomposition.seasonal, label='Seasonal', color='red')
plt.legend(loc='upper left')

# Plot the residual component
plt.subplot(414)
plt.plot(decomposition.resid, label='Residual', color='purple')
plt.legend(loc='upper left')

plt.tight_layout()
plt.show()

# %%
df=pd.read_csv("DATA/Backup/maize.csv")
scaler = MinMaxScaler(feature_range=(0, 1))
df['price'] = scaler.fit_transform(df['price'].values.reshape(-1,1))
import matplotlib.pyplot as plt
plt.plot(df['Date'],df['price'])

# %%
# Convert 'date' column to datetime if it's not already
# Shift the 'price' column to create new columns
df['target-1'] = df['price'].shift(1)
df['target-2'] = df['price'].shift(2)
df['target-3'] = df['price'].shift(3)
#df['target-4'] = df['price'].shift(4)
#df['target-5'] = df['price'].shift(5)
#df['target-6'] = df['price'].shift(6)
#df['target-7'] = df['price'].shift(7)
#df['target-8'] = df['price'].shift(8)
#df['target-9'] = df['price'].shift(9)
#df['target-10'] = df['price'].shift(10)

# %%
d=df[3:]
d
# Out:
#                     Date     price  target-1  target-2  target-3
# 3    2000-04-01 00:00:00  0.365413  0.371275  0.351246  0.354665
# 4    2000-05-01 00:00:00  0.344406  0.365413  0.371275  0.351246
# 5    2000-06-01 00:00:00  0.351246  0.344406  0.365413  0.371275
# 6    2000-07-01 00:00:00  0.334636  0.351246  0.344406  0.365413
# 7    2000-08-01 00:00:00  0.326820  0.334636  0.351246  0.344406
# ..                   ...       ...       ...       ...       ...
# 283  2023-08-01 00:00:00  0.344406  0.340010  0.319980  0.332682
# 284  2023-09-01 00:00:00  0.329751  0.344406  0.340010  0.319980
# 285  2023-10-01 00:00:00  0.327797  0.329751  0.344406  0.340010
# 286  2023-11-01 00:00:00  0.327797  0.327797  0.329751  0.344406
# 287  2023-12-01 00:00:00  0.349780  0.327797  0.327797  0.329751
#
# [285 rows x 5 columns]

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
    df_as_np = windowed_dataframe.to_numpy()
    dates = df_as_np[:, 0]
    middle_matrix = df_as_np[:, 1:-1]
    X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))
    Y = df_as_np[:, -1]
    return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(d)

dates.shape, X.shape, y.shape
# Out:
# ((285,), (285, 3, 1), (285,))

# %%
#y

# %%
#dates
#X
#y

# %%
q_80 = int(len(dates) * .8)
q_90 = int(len(dates) * .9)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %%
X_train.shape,
# Out:
# ((228, 3, 1),)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers.legacy import Adam
from tensorflow.keras import layers
from keras.callbacks import EarlyStopping
from keras.regularizers import l2

#early_stopping = EarlyStopping(monitor='val_loss', patience=10, mode='min')

model = Sequential([layers.Input((3, 1)),
                    #layers.GRU(64),
                    #layers.LSTM(64),
                    #layers.LSTM(64, return_sequences=True),
                    #layers.LSTM(64),
                    #layers.Bidirectional(layers.LSTM(64)),
                    layers.Conv1D(filters=64, kernel_size=3, activation='relu'),
                    layers.Flatten(),
                    #layers.Dense(32, activation='relu'),
                    #layers.Dense(32, activation='relu'),
                    layers.Dense(1)
                   ])

model.compile(loss='mse', 
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=250)
# Out:
# Epoch 1/250
# 8/8 [==============================] - 0s 8ms/step - loss: 0.1200 - mean_absolute_error: 0.3043 - val_loss: 0.0085 - val_mean_absolute_error: 0.0760
# Epoch 2/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0552 - mean_absolute_error: 0.1969 - val_loss: 0.0020 - val_mean_absolute_error: 0.0361
# Epoch 3/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0206 - mean_absolute_error: 0.1052 - val_loss: 0.0047 - val_mean_absolute_error: 0.0600
# Epoch 4/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0102 - mean_absolute_error: 0.0633 - val_loss: 0.0097 - val_mean_absolute_error: 0.0917
# Epoch 5/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0104 - mean_absolute_error: 0.0705 - val_loss: 0.0099 - val_mean_absolute_error: 0.0930
# Epoch 6/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0098 - mean_absolute_error: 0.0671 - val_loss: 0.0074 - val_mean_absolute_error: 0.0787
# Epoch 7/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0090 - mean_absolute_error: 0.0587 - val_loss: 0.0051 - val_mean_absolute_error: 0.0636
# Epoch 8/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0087 - mean_absolute_error: 0.0558 - val_loss: 0.0044 - val_mean_absolute_error: 0.0578
# Epoch 9/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0086 - mean_absolute_error: 0.0545 - val_loss: 0.0043 - val_mean_absolute_error: 0.0572
# Epoch 10/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0082 - mean_absolute_error: 0.0525 - val_loss: 0.0044 - val_mean_absolute_error: 0.0584
# Epoch 11/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0081 - mean_absolute_error: 0.0527 - val_loss: 0.0050 - val_mean_absolute_error: 0.0632
# Epoch 12/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0080 - mean_absolute_error: 0.0528 - val_loss: 0.0044 - val_mean_absolute_error: 0.0585
# Epoch 13/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0078 - mean_absolute_error: 0.0506 - val_loss: 0.0039 - val_mean_absolute_error: 0.0543
# Epoch 14/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0076 - mean_absolute_error: 0.0488 - val_loss: 0.0033 - val_mean_absolute_error: 0.0498
# Epoch 15/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0074 - mean_absolute_error: 0.0472 - val_loss: 0.0031 - val_mean_absolute_error: 0.0477
# Epoch 16/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0073 - mean_absolute_error: 0.0460 - val_loss: 0.0028 - val_mean_absolute_error: 0.0458
# Epoch 17/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0071 - mean_absolute_error: 0.0444 - val_loss: 0.0024 - val_mean_absolute_error: 0.0418
# Epoch 18/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0070 - mean_absolute_error: 0.0432 - val_loss: 0.0023 - val_mean_absolute_error: 0.0410
# Epoch 19/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0069 - mean_absolute_error: 0.0427 - val_loss: 0.0022 - val_mean_absolute_error: 0.0396
# Epoch 20/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0068 - mean_absolute_error: 0.0411 - val_loss: 0.0017 - val_mean_absolute_error: 0.0347
# Epoch 21/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0066 - mean_absolute_error: 0.0396 - val_loss: 0.0017 - val_mean_absolute_error: 0.0346
# Epoch 22/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0065 - mean_absolute_error: 0.0402 - val_loss: 0.0020 - val_mean_absolute_error: 0.0371
# Epoch 23/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0065 - mean_absolute_error: 0.0405 - val_loss: 0.0017 - val_mean_absolute_error: 0.0338
# Epoch 24/250
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0064 - mean_absolute_error: 0.0403 - val_loss: 0.0017 - val_mean_absolute_error: 0.0342
# Epoch 25/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0063 - mean_absolute_error: 0.0374 - val_loss: 0.0013 - val_mean_absolute_error: 0.0287
# Epoch 26/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0062 - mean_absolute_error: 0.0366 - val_loss: 0.0014 - val_mean_absolute_error: 0.0306
# Epoch 27/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0061 - mean_absolute_error: 0.0373 - val_loss: 0.0014 - val_mean_absolute_error: 0.0303
# Epoch 28/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0061 - mean_absolute_error: 0.0362 - val_loss: 0.0012 - val_mean_absolute_error: 0.0274
# Epoch 29/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0060 - mean_absolute_error: 0.0353 - val_loss: 0.0012 - val_mean_absolute_error: 0.0278
# Epoch 30/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0060 - mean_absolute_error: 0.0353 - val_loss: 0.0013 - val_mean_absolute_error: 0.0281
# Epoch 31/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0059 - mean_absolute_error: 0.0350 - val_loss: 0.0012 - val_mean_absolute_error: 0.0272
# Epoch 32/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0059 - mean_absolute_error: 0.0352 - val_loss: 0.0013 - val_mean_absolute_error: 0.0282
# Epoch 33/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0059 - mean_absolute_error: 0.0343 - val_loss: 0.0011 - val_mean_absolute_error: 0.0256
# Epoch 34/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0058 - mean_absolute_error: 0.0339 - val_loss: 0.0012 - val_mean_absolute_error: 0.0274
# Epoch 35/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0058 - mean_absolute_error: 0.0345 - val_loss: 0.0011 - val_mean_absolute_error: 0.0265
# Epoch 36/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0057 - mean_absolute_error: 0.0336 - val_loss: 0.0011 - val_mean_absolute_error: 0.0253
# Epoch 37/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0057 - mean_absolute_error: 0.0329 - val_loss: 0.0011 - val_mean_absolute_error: 0.0253
# Epoch 38/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0057 - mean_absolute_error: 0.0329 - val_loss: 0.0011 - val_mean_absolute_error: 0.0254
# Epoch 39/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0056 - mean_absolute_error: 0.0328 - val_loss: 0.0011 - val_mean_absolute_error: 0.0257
# Epoch 40/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0056 - mean_absolute_error: 0.0329 - val_loss: 9.9072e-04 - val_mean_absolute_error: 0.0245
# Epoch 41/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0056 - mean_absolute_error: 0.0320 - val_loss: 9.6604e-04 - val_mean_absolute_error: 0.0242
# Epoch 42/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0056 - mean_absolute_error: 0.0332 - val_loss: 0.0011 - val_mean_absolute_error: 0.0266
# Epoch 43/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0055 - mean_absolute_error: 0.0322 - val_loss: 9.1558e-04 - val_mean_absolute_error: 0.0235
# Epoch 44/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0055 - mean_absolute_error: 0.0315 - val_loss: 9.3777e-04 - val_mean_absolute_error: 0.0239
# Epoch 45/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0055 - mean_absolute_error: 0.0322 - val_loss: 0.0011 - val_mean_absolute_error: 0.0263
# Epoch 46/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0055 - mean_absolute_error: 0.0316 - val_loss: 8.8341e-04 - val_mean_absolute_error: 0.0232
# Epoch 47/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0054 - mean_absolute_error: 0.0317 - val_loss: 0.0010 - val_mean_absolute_error: 0.0251
# Epoch 48/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0053 - mean_absolute_error: 0.0312 - val_loss: 9.1092e-04 - val_mean_absolute_error: 0.0237
# Epoch 49/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0053 - mean_absolute_error: 0.0308 - val_loss: 0.0010 - val_mean_absolute_error: 0.0256
# Epoch 50/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0053 - mean_absolute_error: 0.0314 - val_loss: 9.5594e-04 - val_mean_absolute_error: 0.0244
# Epoch 51/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0054 - mean_absolute_error: 0.0311 - val_loss: 9.1823e-04 - val_mean_absolute_error: 0.0239
# Epoch 52/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0053 - mean_absolute_error: 0.0319 - val_loss: 0.0011 - val_mean_absolute_error: 0.0264
# Epoch 53/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0052 - mean_absolute_error: 0.0313 - val_loss: 8.5841e-04 - val_mean_absolute_error: 0.0230
# Epoch 54/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0053 - mean_absolute_error: 0.0305 - val_loss: 8.8967e-04 - val_mean_absolute_error: 0.0236
# Epoch 55/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0052 - mean_absolute_error: 0.0301 - val_loss: 9.2068e-04 - val_mean_absolute_error: 0.0240
# Epoch 56/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0052 - mean_absolute_error: 0.0302 - val_loss: 9.8169e-04 - val_mean_absolute_error: 0.0248
# Epoch 57/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0052 - mean_absolute_error: 0.0307 - val_loss: 8.7260e-04 - val_mean_absolute_error: 0.0234
# Epoch 58/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0052 - mean_absolute_error: 0.0296 - val_loss: 8.8176e-04 - val_mean_absolute_error: 0.0235
# Epoch 59/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0052 - mean_absolute_error: 0.0297 - val_loss: 8.9103e-04 - val_mean_absolute_error: 0.0237
# Epoch 60/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0051 - mean_absolute_error: 0.0300 - val_loss: 8.7242e-04 - val_mean_absolute_error: 0.0234
# Epoch 61/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0051 - mean_absolute_error: 0.0292 - val_loss: 8.1666e-04 - val_mean_absolute_error: 0.0227
# Epoch 62/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0051 - mean_absolute_error: 0.0298 - val_loss: 8.9500e-04 - val_mean_absolute_error: 0.0238
# Epoch 63/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0051 - mean_absolute_error: 0.0294 - val_loss: 8.5188e-04 - val_mean_absolute_error: 0.0232
# Epoch 64/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0051 - mean_absolute_error: 0.0293 - val_loss: 8.7528e-04 - val_mean_absolute_error: 0.0235
# Epoch 65/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0051 - mean_absolute_error: 0.0299 - val_loss: 8.7574e-04 - val_mean_absolute_error: 0.0236
# Epoch 66/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0051 - mean_absolute_error: 0.0292 - val_loss: 8.2971e-04 - val_mean_absolute_error: 0.0229
# Epoch 67/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0051 - mean_absolute_error: 0.0295 - val_loss: 9.3148e-04 - val_mean_absolute_error: 0.0244
# Epoch 68/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0050 - mean_absolute_error: 0.0296 - val_loss: 8.5616e-04 - val_mean_absolute_error: 0.0233
# Epoch 69/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0050 - mean_absolute_error: 0.0290 - val_loss: 8.9135e-04 - val_mean_absolute_error: 0.0238
# Epoch 70/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0050 - mean_absolute_error: 0.0295 - val_loss: 8.8317e-04 - val_mean_absolute_error: 0.0237
# Epoch 71/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0050 - mean_absolute_error: 0.0291 - val_loss: 8.2625e-04 - val_mean_absolute_error: 0.0229
# Epoch 72/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0050 - mean_absolute_error: 0.0290 - val_loss: 9.1954e-04 - val_mean_absolute_error: 0.0243
# Epoch 73/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0050 - mean_absolute_error: 0.0291 - val_loss: 8.5585e-04 - val_mean_absolute_error: 0.0233
# Epoch 74/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0050 - mean_absolute_error: 0.0290 - val_loss: 8.6931e-04 - val_mean_absolute_error: 0.0235
# Epoch 75/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0050 - mean_absolute_error: 0.0302 - val_loss: 0.0010 - val_mean_absolute_error: 0.0263
# Epoch 76/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0050 - mean_absolute_error: 0.0292 - val_loss: 8.7563e-04 - val_mean_absolute_error: 0.0238
# Epoch 77/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0050 - mean_absolute_error: 0.0294 - val_loss: 9.5178e-04 - val_mean_absolute_error: 0.0252
# Epoch 78/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0050 - mean_absolute_error: 0.0291 - val_loss: 8.6041e-04 - val_mean_absolute_error: 0.0235
# Epoch 79/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0289 - val_loss: 9.3375e-04 - val_mean_absolute_error: 0.0248
# Epoch 80/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0289 - val_loss: 8.5365e-04 - val_mean_absolute_error: 0.0234
# Epoch 81/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0285 - val_loss: 8.7015e-04 - val_mean_absolute_error: 0.0237
# Epoch 82/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0290 - val_loss: 8.9241e-04 - val_mean_absolute_error: 0.0241
# Epoch 83/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0287 - val_loss: 8.0885e-04 - val_mean_absolute_error: 0.0227
# Epoch 84/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0279 - val_loss: 8.3690e-04 - val_mean_absolute_error: 0.0231
# Epoch 85/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0281 - val_loss: 7.8340e-04 - val_mean_absolute_error: 0.0223
# Epoch 86/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0050 - mean_absolute_error: 0.0283 - val_loss: 7.7630e-04 - val_mean_absolute_error: 0.0222
# Epoch 87/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0050 - mean_absolute_error: 0.0295 - val_loss: 9.0894e-04 - val_mean_absolute_error: 0.0244
# Epoch 88/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0050 - mean_absolute_error: 0.0286 - val_loss: 7.3897e-04 - val_mean_absolute_error: 0.0216
# Epoch 89/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0294 - val_loss: 0.0010 - val_mean_absolute_error: 0.0261
# Epoch 90/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0291 - val_loss: 7.9519e-04 - val_mean_absolute_error: 0.0225
# Epoch 91/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0283 - val_loss: 8.2418e-04 - val_mean_absolute_error: 0.0230
# Epoch 92/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0281 - val_loss: 7.7725e-04 - val_mean_absolute_error: 0.0222
# Epoch 93/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0050 - mean_absolute_error: 0.0283 - val_loss: 8.3829e-04 - val_mean_absolute_error: 0.0232
# Epoch 94/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0285 - val_loss: 8.4010e-04 - val_mean_absolute_error: 0.0232
# Epoch 95/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0277 - val_loss: 7.1487e-04 - val_mean_absolute_error: 0.0212
# Epoch 96/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0277 - val_loss: 8.6016e-04 - val_mean_absolute_error: 0.0236
# Epoch 97/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0281 - val_loss: 8.1937e-04 - val_mean_absolute_error: 0.0229
# Epoch 98/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0278 - val_loss: 8.1181e-04 - val_mean_absolute_error: 0.0228
# Epoch 99/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0278 - val_loss: 8.8494e-04 - val_mean_absolute_error: 0.0241
# Epoch 100/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0283 - val_loss: 8.2175e-04 - val_mean_absolute_error: 0.0230
# Epoch 101/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0281 - val_loss: 8.6470e-04 - val_mean_absolute_error: 0.0238
# Epoch 102/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0279 - val_loss: 7.8820e-04 - val_mean_absolute_error: 0.0224
# Epoch 103/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0277 - val_loss: 7.5230e-04 - val_mean_absolute_error: 0.0218
# Epoch 104/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0277 - val_loss: 8.1057e-04 - val_mean_absolute_error: 0.0227
# Epoch 105/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0276 - val_loss: 7.8585e-04 - val_mean_absolute_error: 0.0224
# Epoch 106/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0284 - val_loss: 8.4657e-04 - val_mean_absolute_error: 0.0235
# Epoch 107/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0278 - val_loss: 7.5622e-04 - val_mean_absolute_error: 0.0219
# Epoch 108/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0279 - val_loss: 8.2016e-04 - val_mean_absolute_error: 0.0230
# Epoch 109/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0276 - val_loss: 7.9844e-04 - val_mean_absolute_error: 0.0225
# Epoch 110/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0277 - val_loss: 7.8712e-04 - val_mean_absolute_error: 0.0224
# Epoch 111/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0276 - val_loss: 8.1003e-04 - val_mean_absolute_error: 0.0228
# Epoch 112/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0278 - val_loss: 7.5995e-04 - val_mean_absolute_error: 0.0219
# Epoch 113/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0283 - val_loss: 8.2532e-04 - val_mean_absolute_error: 0.0231
# Epoch 114/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0287 - val_loss: 8.7982e-04 - val_mean_absolute_error: 0.0241
# Epoch 115/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0280 - val_loss: 7.6700e-04 - val_mean_absolute_error: 0.0220
# Epoch 116/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0280 - val_loss: 8.6390e-04 - val_mean_absolute_error: 0.0238
# Epoch 117/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0276 - val_loss: 8.0832e-04 - val_mean_absolute_error: 0.0228
# Epoch 118/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0276 - val_loss: 8.1636e-04 - val_mean_absolute_error: 0.0229
# Epoch 119/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0281 - val_loss: 8.0921e-04 - val_mean_absolute_error: 0.0228
# Epoch 120/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0276 - val_loss: 8.0715e-04 - val_mean_absolute_error: 0.0228
# Epoch 121/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0278 - val_loss: 8.2343e-04 - val_mean_absolute_error: 0.0231
# Epoch 122/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0278 - val_loss: 9.6242e-04 - val_mean_absolute_error: 0.0258
# Epoch 123/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0052 - mean_absolute_error: 0.0345 - val_loss: 0.0013 - val_mean_absolute_error: 0.0327
# Epoch 124/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0052 - mean_absolute_error: 0.0334 - val_loss: 0.0013 - val_mean_absolute_error: 0.0327
# Epoch 125/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0050 - mean_absolute_error: 0.0325 - val_loss: 0.0014 - val_mean_absolute_error: 0.0335
# Epoch 126/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0302 - val_loss: 9.3150e-04 - val_mean_absolute_error: 0.0257
# Epoch 127/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0292 - val_loss: 0.0011 - val_mean_absolute_error: 0.0287
# Epoch 128/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0295 - val_loss: 8.3487e-04 - val_mean_absolute_error: 0.0234
# Epoch 129/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0288 - val_loss: 8.6098e-04 - val_mean_absolute_error: 0.0238
# Epoch 130/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0287 - val_loss: 8.1908e-04 - val_mean_absolute_error: 0.0229
# Epoch 131/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0278 - val_loss: 7.2229e-04 - val_mean_absolute_error: 0.0213
# Epoch 132/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0288 - val_loss: 7.9598e-04 - val_mean_absolute_error: 0.0225
# Epoch 133/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0050 - mean_absolute_error: 0.0288 - val_loss: 7.0336e-04 - val_mean_absolute_error: 0.0210
# Epoch 134/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0269 - val_loss: 8.9246e-04 - val_mean_absolute_error: 0.0243
# Epoch 135/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0279 - val_loss: 7.2725e-04 - val_mean_absolute_error: 0.0214
# Epoch 136/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0277 - val_loss: 7.5232e-04 - val_mean_absolute_error: 0.0218
# Epoch 137/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0050 - mean_absolute_error: 0.0287 - val_loss: 8.2653e-04 - val_mean_absolute_error: 0.0231
# Epoch 138/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0283 - val_loss: 8.6809e-04 - val_mean_absolute_error: 0.0239
# Epoch 139/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0281 - val_loss: 8.0447e-04 - val_mean_absolute_error: 0.0228
# Epoch 140/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0283 - val_loss: 8.9546e-04 - val_mean_absolute_error: 0.0245
# Epoch 141/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0276 - val_loss: 7.4383e-04 - val_mean_absolute_error: 0.0217
# Epoch 142/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0273 - val_loss: 8.1653e-04 - val_mean_absolute_error: 0.0229
# Epoch 143/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0273 - val_loss: 7.4667e-04 - val_mean_absolute_error: 0.0217
# Epoch 144/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0274 - val_loss: 7.5481e-04 - val_mean_absolute_error: 0.0218
# Epoch 145/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0281 - val_loss: 6.8039e-04 - val_mean_absolute_error: 0.0206
# Epoch 146/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0275 - val_loss: 7.3162e-04 - val_mean_absolute_error: 0.0215
# Epoch 147/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0279 - val_loss: 7.2385e-04 - val_mean_absolute_error: 0.0213
# Epoch 148/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0050 - mean_absolute_error: 0.0275 - val_loss: 6.6973e-04 - val_mean_absolute_error: 0.0204
# Epoch 149/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0271 - val_loss: 8.4734e-04 - val_mean_absolute_error: 0.0234
# Epoch 150/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0277 - val_loss: 6.9791e-04 - val_mean_absolute_error: 0.0209
# Epoch 151/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0275 - val_loss: 8.1254e-04 - val_mean_absolute_error: 0.0228
# Epoch 152/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0274 - val_loss: 7.4425e-04 - val_mean_absolute_error: 0.0217
# Epoch 153/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0272 - val_loss: 8.4690e-04 - val_mean_absolute_error: 0.0235
# Epoch 154/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0274 - val_loss: 7.0980e-04 - val_mean_absolute_error: 0.0211
# Epoch 155/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0273 - val_loss: 8.9431e-04 - val_mean_absolute_error: 0.0244
# Epoch 156/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0287 - val_loss: 7.2107e-04 - val_mean_absolute_error: 0.0213
# Epoch 157/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0050 - mean_absolute_error: 0.0286 - val_loss: 8.0617e-04 - val_mean_absolute_error: 0.0227
# Epoch 158/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0278 - val_loss: 9.0712e-04 - val_mean_absolute_error: 0.0248
# Epoch 159/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0275 - val_loss: 7.5057e-04 - val_mean_absolute_error: 0.0217
# Epoch 160/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0279 - val_loss: 9.1314e-04 - val_mean_absolute_error: 0.0250
# Epoch 161/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0279 - val_loss: 7.8482e-04 - val_mean_absolute_error: 0.0224
# Epoch 162/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0277 - val_loss: 8.4135e-04 - val_mean_absolute_error: 0.0234
# Epoch 163/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0275 - val_loss: 0.0012 - val_mean_absolute_error: 0.0296
# Epoch 164/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0054 - mean_absolute_error: 0.0377 - val_loss: 0.0011 - val_mean_absolute_error: 0.0281
# Epoch 165/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0051 - mean_absolute_error: 0.0317 - val_loss: 9.7830e-04 - val_mean_absolute_error: 0.0267
# Epoch 166/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0304 - val_loss: 0.0013 - val_mean_absolute_error: 0.0319
# Epoch 167/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0298 - val_loss: 9.0454e-04 - val_mean_absolute_error: 0.0251
# Epoch 168/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0289 - val_loss: 0.0010 - val_mean_absolute_error: 0.0272
# Epoch 169/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0283 - val_loss: 8.0215e-04 - val_mean_absolute_error: 0.0227
# Epoch 170/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0281 - val_loss: 8.6786e-04 - val_mean_absolute_error: 0.0241
# Epoch 171/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0278 - val_loss: 7.4707e-04 - val_mean_absolute_error: 0.0217
# Epoch 172/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0275 - val_loss: 7.6720e-04 - val_mean_absolute_error: 0.0220
# Epoch 173/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0282 - val_loss: 7.4511e-04 - val_mean_absolute_error: 0.0216
# Epoch 174/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0269 - val_loss: 7.4973e-04 - val_mean_absolute_error: 0.0217
# Epoch 175/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0271 - val_loss: 7.4465e-04 - val_mean_absolute_error: 0.0216
# Epoch 176/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0269 - val_loss: 7.6967e-04 - val_mean_absolute_error: 0.0220
# Epoch 177/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0275 - val_loss: 7.4439e-04 - val_mean_absolute_error: 0.0216
# Epoch 178/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0272 - val_loss: 7.9679e-04 - val_mean_absolute_error: 0.0226
# Epoch 179/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0277 - val_loss: 7.9484e-04 - val_mean_absolute_error: 0.0225
# Epoch 180/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0275 - val_loss: 8.8546e-04 - val_mean_absolute_error: 0.0244
# Epoch 181/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0278 - val_loss: 8.1786e-04 - val_mean_absolute_error: 0.0230
# Epoch 182/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0275 - val_loss: 8.4429e-04 - val_mean_absolute_error: 0.0235
# Epoch 183/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0279 - val_loss: 8.4052e-04 - val_mean_absolute_error: 0.0235
# Epoch 184/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0275 - val_loss: 8.4060e-04 - val_mean_absolute_error: 0.0235
# Epoch 185/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0280 - val_loss: 9.0459e-04 - val_mean_absolute_error: 0.0249
# Epoch 186/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0278 - val_loss: 8.0632e-04 - val_mean_absolute_error: 0.0228
# Epoch 187/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0275 - val_loss: 7.9596e-04 - val_mean_absolute_error: 0.0226
# Epoch 188/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0278 - val_loss: 8.1239e-04 - val_mean_absolute_error: 0.0229
# Epoch 189/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0278 - val_loss: 7.3892e-04 - val_mean_absolute_error: 0.0215
# Epoch 190/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0279 - val_loss: 8.9095e-04 - val_mean_absolute_error: 0.0246
# Epoch 191/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0289 - val_loss: 7.5645e-04 - val_mean_absolute_error: 0.0218
# Epoch 192/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0280 - val_loss: 8.3982e-04 - val_mean_absolute_error: 0.0235
# Epoch 193/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0276 - val_loss: 8.1380e-04 - val_mean_absolute_error: 0.0229
# Epoch 194/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0274 - val_loss: 7.6654e-04 - val_mean_absolute_error: 0.0219
# Epoch 195/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0272 - val_loss: 7.7828e-04 - val_mean_absolute_error: 0.0222
# Epoch 196/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0272 - val_loss: 9.1430e-04 - val_mean_absolute_error: 0.0250
# Epoch 197/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0278 - val_loss: 7.7850e-04 - val_mean_absolute_error: 0.0221
# Epoch 198/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0274 - val_loss: 7.3278e-04 - val_mean_absolute_error: 0.0214
# Epoch 199/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0275 - val_loss: 7.9596e-04 - val_mean_absolute_error: 0.0225
# Epoch 200/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0287 - val_loss: 8.6527e-04 - val_mean_absolute_error: 0.0240
# Epoch 201/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0279 - val_loss: 8.5981e-04 - val_mean_absolute_error: 0.0240
# Epoch 202/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0285 - val_loss: 9.1752e-04 - val_mean_absolute_error: 0.0252
# Epoch 203/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0280 - val_loss: 9.9134e-04 - val_mean_absolute_error: 0.0268
# Epoch 204/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0052 - mean_absolute_error: 0.0344 - val_loss: 0.0013 - val_mean_absolute_error: 0.0317
# Epoch 205/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0050 - mean_absolute_error: 0.0324 - val_loss: 0.0014 - val_mean_absolute_error: 0.0340
# Epoch 206/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0314 - val_loss: 0.0013 - val_mean_absolute_error: 0.0322
# Epoch 207/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0299 - val_loss: 9.0638e-04 - val_mean_absolute_error: 0.0253
# Epoch 208/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0293 - val_loss: 9.7634e-04 - val_mean_absolute_error: 0.0266
# Epoch 209/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0284 - val_loss: 8.5528e-04 - val_mean_absolute_error: 0.0239
# Epoch 210/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0276 - val_loss: 7.8262e-04 - val_mean_absolute_error: 0.0223
# Epoch 211/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0274 - val_loss: 7.5353e-04 - val_mean_absolute_error: 0.0217
# Epoch 212/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0271 - val_loss: 7.9142e-04 - val_mean_absolute_error: 0.0225
# Epoch 213/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0273 - val_loss: 8.5273e-04 - val_mean_absolute_error: 0.0238
# Epoch 214/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0275 - val_loss: 7.2415e-04 - val_mean_absolute_error: 0.0213
# Epoch 215/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0277 - val_loss: 8.3641e-04 - val_mean_absolute_error: 0.0234
# Epoch 216/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0275 - val_loss: 7.8313e-04 - val_mean_absolute_error: 0.0223
# Epoch 217/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0271 - val_loss: 8.0802e-04 - val_mean_absolute_error: 0.0228
# Epoch 218/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0272 - val_loss: 7.5413e-04 - val_mean_absolute_error: 0.0217
# Epoch 219/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0268 - val_loss: 7.5813e-04 - val_mean_absolute_error: 0.0218
# Epoch 220/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0272 - val_loss: 7.5978e-04 - val_mean_absolute_error: 0.0218
# Epoch 221/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0270 - val_loss: 7.6507e-04 - val_mean_absolute_error: 0.0219
# Epoch 222/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0277 - val_loss: 7.6062e-04 - val_mean_absolute_error: 0.0219
# Epoch 223/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0271 - val_loss: 7.5384e-04 - val_mean_absolute_error: 0.0217
# Epoch 224/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0273 - val_loss: 8.1891e-04 - val_mean_absolute_error: 0.0231
# Epoch 225/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0275 - val_loss: 8.4299e-04 - val_mean_absolute_error: 0.0237
# Epoch 226/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0274 - val_loss: 7.9082e-04 - val_mean_absolute_error: 0.0225
# Epoch 227/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0274 - val_loss: 7.4846e-04 - val_mean_absolute_error: 0.0216
# Epoch 228/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0279 - val_loss: 7.4325e-04 - val_mean_absolute_error: 0.0215
# Epoch 229/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0270 - val_loss: 7.8132e-04 - val_mean_absolute_error: 0.0223
# Epoch 230/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0271 - val_loss: 8.4365e-04 - val_mean_absolute_error: 0.0236
# Epoch 231/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0277 - val_loss: 6.7425e-04 - val_mean_absolute_error: 0.0204
# Epoch 232/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0279 - val_loss: 7.6164e-04 - val_mean_absolute_error: 0.0219
# Epoch 233/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0286 - val_loss: 7.0922e-04 - val_mean_absolute_error: 0.0210
# Epoch 234/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0050 - mean_absolute_error: 0.0281 - val_loss: 8.6115e-04 - val_mean_absolute_error: 0.0240
# Epoch 235/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0292 - val_loss: 6.7955e-04 - val_mean_absolute_error: 0.0205
# Epoch 236/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0277 - val_loss: 7.8212e-04 - val_mean_absolute_error: 0.0223
# Epoch 237/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0276 - val_loss: 6.7054e-04 - val_mean_absolute_error: 0.0203
# Epoch 238/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0275 - val_loss: 9.5201e-04 - val_mean_absolute_error: 0.0258
# Epoch 239/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0293 - val_loss: 7.8231e-04 - val_mean_absolute_error: 0.0224
# Epoch 240/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0278 - val_loss: 8.2008e-04 - val_mean_absolute_error: 0.0232
# Epoch 241/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0278 - val_loss: 8.7792e-04 - val_mean_absolute_error: 0.0244
# Epoch 242/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0277 - val_loss: 7.5787e-04 - val_mean_absolute_error: 0.0218
# Epoch 243/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0050 - mean_absolute_error: 0.0285 - val_loss: 8.3859e-04 - val_mean_absolute_error: 0.0235
# Epoch 244/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0273 - val_loss: 7.4415e-04 - val_mean_absolute_error: 0.0216
# Epoch 245/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0269 - val_loss: 7.5886e-04 - val_mean_absolute_error: 0.0218
# Epoch 246/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0271 - val_loss: 7.4776e-04 - val_mean_absolute_error: 0.0216
# Epoch 247/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0274 - val_loss: 8.3157e-04 - val_mean_absolute_error: 0.0233
# Epoch 248/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0272 - val_loss: 7.6831e-04 - val_mean_absolute_error: 0.0220
# Epoch 249/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0270 - val_loss: 8.2244e-04 - val_mean_absolute_error: 0.0231
# Epoch 250/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0276 - val_loss: 6.9651e-04 - val_mean_absolute_error: 0.0208

# %%
# Evaluate the model
train_loss = model.evaluate(X_train, y_train, verbose=0)
print(f'Training Loss: {train_loss}')

test_loss = model.evaluate(X_test, y_test, verbose=0)
print(f'Testing Loss: {test_loss}')
# Out:
# Training Loss: [0.004815807566046715, 0.02671213075518608]
# Testing Loss: [0.0006510484963655472, 0.02153308317065239]

# %%
train_predictions = model.predict(X_train)

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)

#plt.plot(train_predictions)
#plt.plot(y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 8/8 [==============================] - 0s 507us/step

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 1/1 [==============================] - 0s 11ms/step

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 1/1 [==============================] - 0s 11ms/step

# %%
#test_predictions

# %%
# Inverse transform to get actual prices
y_train_actual = scaler.inverse_transform(y_train.reshape(-1, 1))
y_test_actual = scaler.inverse_transform(y_test.reshape(-1, 1))
y_train_pred_actual = scaler.inverse_transform(train_predictions.reshape(-1,1))
y_test_pred_actual = scaler.inverse_transform(test_predictions.reshape(-1,1))
y_val_pred_actual = scaler.inverse_transform(val_predictions.reshape(-1,1))
y_val_actual = scaler.inverse_transform(y_val.reshape(-1,1))

# %%
# Calculate evaluation metrics
train_mae = mean_absolute_error(y_train_actual, y_train_pred_actual)
train_mse = mean_squared_error(y_train_actual, y_train_pred_actual)
val_mae = mean_absolute_error(y_val_actual, y_val_pred_actual)
test_mae = mean_absolute_error(y_test_actual, y_test_pred_actual)
test_mse = mean_squared_error(y_test_actual, y_test_pred_actual)
val_mse = mean_squared_error(y_val_actual, y_val_pred_actual)

print(f'Training MAE: {train_mae}')
print(f'Training MSE: {train_mse}')
print(f'Val MAE: {val_mae}')
print(f'Val MSE: {val_mse}')
print(f'Testing MAE: {test_mae}')
print(f'Testing MSE: {test_mse}')


train_r = np.sqrt(train_mse)
train_r2 = r2_score(y_train_actual, y_train_pred_actual)
test_r = np.sqrt(test_mse)
test_r2 = r2_score(y_test_actual, y_test_pred_actual)
val_r = np.sqrt(val_mse)
val_r2 = r2_score(y_val_actual, y_val_pred_actual)


print(train_r)
print(train_r2)
print(val_r)
print(val_r2)
print(test_r)
print(test_r2)
# Out:
# Training MAE: 5.46797513961792
# Training MSE: 201.79254150390625
# Val MAE: 4.253499507904053
# Val MSE: 29.185327529907227
# Testing MAE: 4.407820701599121
# Testing MSE: 27.280277252197266
# 14.20537
# 0.9088528540315013
# 5.4023447
# 0.8962814594086727
# 5.2230525
# 0.9085310916517019

# %%
# Calculate evaluation metrics
train_mae = mean_absolute_error(y_train, train_predictions)
train_mse = mean_squared_error(y_train, train_predictions)
val_mae = mean_absolute_error(y_val, val_predictions)
test_mae = mean_absolute_error(y_test, test_predictions)
test_mse = mean_squared_error(y_test, test_predictions)
val_mse = mean_squared_error(y_val, val_predictions)

print(f'Training MAE: {train_mae}')
print(f'Training MSE: {train_mse}')
print(f'Testing MAE: {test_mae}')
print(f'Testing MSE: {test_mse}')
print(f'Testing MAE: {val_mae}')
print(f'Testing MSE: {val_mse}')

train_r = np.sqrt(train_mse)
train_r2 = r2_score(y_train_actual, y_train_pred_actual)
test_r = np.sqrt(test_mse)
test_r2 = r2_score(y_test_actual, y_test_pred_actual)
val_r = np.sqrt(val_mse)
val_r2 = r2_score(y_val_actual, y_val_pred_actual)


print(train_r)
print(val_r)
print(test_r)
print(train_r2)
print(val_r2)
print(test_r2)
# Out:
# Training MAE: 0.02679029293358326
# Training MSE: 0.004798106849193573
# Testing MAE: 0.02068977989256382
# Testing MSE: 0.000586901733186096
# Testing MAE: 0.020150525495409966
# Testing MSE: 0.0006688120774924755
# 0.06926837
# 0.025861401
# 0.024226055
# 0.9091879044681623
# 0.9004063212501987
# 0.9175432923386182

# %%
model.save('maize_cnn')
# Out:
# INFO:tensorflow:Assets written to: maize_cnn/assets
# INFO:tensorflow:Assets written to: maize_cnn/assets

# %%
import tensorflow as tf
m1=tf.keras.models.load_model('maize_cnn')
m1.layers[0].input_shape
# Out:
# (None, 3, 1)

# %%
test_predictions = m1.predict(X_test).flatten()

y_test_actual = scaler.inverse_transform(y_test.reshape(-1, 1))
y_test_pred_actual = scaler.inverse_transform(test_predictions.reshape(-1,1))

test_r2 = r2_score(y_test_actual, y_test_pred_actual)
print(test_r2)
#plt.plot(dates_test, test_predictions)
#plt.plot(dates_test, y_test)
#plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 1/1 [==============================] - 0s 27ms/step
# 0.9085310916517019

# %%
plt.plot(figsize=(100,100))
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations'])

# %%
from copy import deepcopy

recursive_predictions = []
recursive_dates = np.concatenate([dates_val, dates_test])

for target_date in recursive_dates:
    last_window = deepcopy(X_train[-1])
    next_prediction = model.predict(np.array([last_window])).flatten()
    recursive_predictions.append(next_prediction)
    last_window[-1] = next_prediction
# Out:
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.plot(recursive_dates, recursive_predictions)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations',
            'Recursive Predictions'])

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import EarlyStopping
# Sample DataFrame
#data = {'date': pd.date_range(start='2024-01-01', periods=100),
#        'price': np.random.rand(100)}
#df = pd.DataFrame(data)

# %%
# Normalize the price data
scaler = MinMaxScaler(feature_range=(0, 1))
d['price'] = scaler.fit_transform(d['Rice'].values.reshape(-1,1))

# %%
x=d.pop('Rice')
d
# Out:
#           date     price
# 0   2000-02-01  0.053404
# 1   2000-03-01  0.043292
# 2   2000-04-01  0.049974
# 3   2000-05-01  0.049490
# 4   2000-06-01  0.049135
# ..         ...       ...
# 235 2019-09-01  0.058386
# 236 2019-10-01  0.056683
# 237 2019-11-01  0.075554
# 238 2019-12-01  0.081035
# 239 2020-01-01  0.089746
#
# [240 rows x 2 columns]

# %%
# Function to create sequences for LSTM
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i + seq_length])
        y.append(data[i + seq_length])
    return np.array(X), np.array(y)

# Hyperparameters
sequence_length = 10  # Adjust according to your choice
batch_size = 64
epochs = 100

# Create sequences
X, y = create_sequences(d['price'].values, sequence_length)

# Split the data into training and testing sets
split = int(0.8 * len(X))
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

# Reshape input data for LSTM [samples, time steps, features]
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# %%
# Define the LSTM model
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(sequence_length, 1)))
model.add(LSTM(units=50))
model.add(Dense(units=1))

# %%
# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
# Train the model
model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, verbose=1)
# Define Early Stopping Callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5, verbose=1, restore_best_weights=True)
# Out:
# Epoch 1/100
# 3/3 [==============================] - 1s 6ms/step - loss: 0.0041
# Epoch 2/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0026
# Epoch 3/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0027
# Epoch 4/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0023
# Epoch 5/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0023
# Epoch 6/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 7/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0021
# Epoch 8/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0020
# Epoch 9/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0021
# Epoch 10/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0020
# Epoch 11/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0019
# Epoch 12/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0019
# Epoch 13/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0019
# Epoch 14/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0018
# Epoch 15/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0018
# Epoch 16/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0018
# Epoch 17/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0017
# Epoch 18/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0017
# Epoch 19/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0016
# Epoch 20/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0016
# Epoch 21/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0016
# Epoch 22/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0015
# Epoch 23/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0015
# Epoch 24/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0014
# Epoch 25/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0014
# Epoch 26/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0013
# Epoch 27/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0013
# Epoch 28/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0013
# Epoch 29/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0012
# Epoch 30/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0012
# Epoch 31/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0012
# Epoch 32/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0012
# Epoch 33/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0012
# Epoch 34/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0012
# Epoch 35/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0012
# Epoch 36/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0012
# Epoch 37/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0011
# Epoch 38/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0011
# Epoch 39/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0011
# Epoch 40/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0011
# Epoch 41/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0011
# Epoch 42/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0011
# Epoch 43/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0011
# Epoch 44/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0011
# Epoch 45/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0010
# Epoch 46/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0010
# Epoch 47/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0010
# Epoch 48/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0010
# Epoch 49/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0010
# Epoch 50/100
# 3/3 [==============================] - 0s 6ms/step - loss: 9.9526e-04
# Epoch 51/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0010
# Epoch 52/100
# 3/3 [==============================] - 0s 6ms/step - loss: 9.7158e-04
# Epoch 53/100
# 3/3 [==============================] - 0s 6ms/step - loss: 9.6520e-04
# Epoch 54/100
# 3/3 [==============================] - 0s 6ms/step - loss: 9.5791e-04
# Epoch 55/100
# 3/3 [==============================] - 0s 5ms/step - loss: 9.5454e-04
# Epoch 56/100
# 3/3 [==============================] - 0s 6ms/step - loss: 9.4484e-04
# Epoch 57/100
# 3/3 [==============================] - 0s 6ms/step - loss: 9.3222e-04
# Epoch 58/100
# 3/3 [==============================] - 0s 6ms/step - loss: 9.2266e-04
# Epoch 59/100
# 3/3 [==============================] - 0s 6ms/step - loss: 9.0965e-04
# Epoch 60/100
# 3/3 [==============================] - 0s 5ms/step - loss: 9.0117e-04
# Epoch 61/100
# 3/3 [==============================] - 0s 6ms/step - loss: 8.9130e-04
# Epoch 62/100
# 3/3 [==============================] - 0s 6ms/step - loss: 8.8937e-04
# Epoch 63/100
# 3/3 [==============================] - 0s 5ms/step - loss: 8.7434e-04
# Epoch 64/100
# 3/3 [==============================] - 0s 5ms/step - loss: 8.6231e-04
# Epoch 65/100
# 3/3 [==============================] - 0s 6ms/step - loss: 8.8836e-04
# Epoch 66/100
# 3/3 [==============================] - 0s 5ms/step - loss: 8.4441e-04
# Epoch 67/100
# 3/3 [==============================] - 0s 6ms/step - loss: 8.4663e-04
# Epoch 68/100
# 3/3 [==============================] - 0s 5ms/step - loss: 8.2159e-04
# Epoch 69/100
# 3/3 [==============================] - 0s 5ms/step - loss: 8.1547e-04
# Epoch 70/100
# 3/3 [==============================] - 0s 5ms/step - loss: 8.0546e-04
# Epoch 71/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.9839e-04
# Epoch 72/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.9681e-04
# Epoch 73/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.8139e-04
# Epoch 74/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.7697e-04
# Epoch 75/100
# 3/3 [==============================] - 0s 6ms/step - loss: 7.7261e-04
# Epoch 76/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.6035e-04
# Epoch 77/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.4825e-04
# Epoch 78/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.4420e-04
# Epoch 79/100
# 3/3 [==============================] - 0s 6ms/step - loss: 7.4013e-04
# Epoch 80/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.3297e-04
# Epoch 81/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.3705e-04
# Epoch 82/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.2424e-04
# Epoch 83/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.3513e-04
# Epoch 84/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.0972e-04
# Epoch 85/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.0489e-04
# Epoch 86/100
# 3/3 [==============================] - 0s 5ms/step - loss: 6.9739e-04
# Epoch 87/100
# 3/3 [==============================] - 0s 5ms/step - loss: 6.9600e-04
# Epoch 88/100
# 3/3 [==============================] - 0s 5ms/step - loss: 6.8829e-04
# Epoch 89/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.0131e-04
# Epoch 90/100
# 3/3 [==============================] - 0s 5ms/step - loss: 6.7832e-04
# Epoch 91/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.0200e-04
# Epoch 92/100
# 3/3 [==============================] - 0s 5ms/step - loss: 6.8064e-04
# Epoch 93/100
# 3/3 [==============================] - 0s 6ms/step - loss: 6.7383e-04
# Epoch 94/100
# 3/3 [==============================] - 0s 6ms/step - loss: 6.7962e-04
# Epoch 95/100
# 3/3 [==============================] - 0s 5ms/step - loss: 6.8475e-04
# Epoch 96/100
# 3/3 [==============================] - 0s 5ms/step - loss: 6.8147e-04
# Epoch 97/100
# 3/3 [==============================] - 0s 5ms/step - loss: 6.7189e-04
# Epoch 98/100
# 3/3 [==============================] - 0s 5ms/step - loss: 6.7507e-04
# Epoch 99/100
# 3/3 [==============================] - 0s 5ms/step - loss: 6.7166e-04
# Epoch 100/100
# 3/3 [==============================] - 0s 6ms/step - loss: 7.0050e-04

# %%
# Evaluate the model
train_loss = model.evaluate(X_train, y_train, verbose=0)
print(f'Training Loss: {train_loss}')

test_loss = model.evaluate(X_test, y_test, verbose=0)
print(f'Testing Loss: {test_loss}')
# Out:
# Training Loss: 0.0006569024408236146
# Testing Loss: 0.04776032641530037

# %%
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

# Inverse transform to get actual prices
y_train_actual = scaler.inverse_transform(y_train.reshape(-1, 1))
y_test_actual = scaler.inverse_transform(y_test.reshape(-1, 1))
y_train_pred_actual = scaler.inverse_transform(y_train_pred)
y_test_pred_actual = scaler.inverse_transform(y_test_pred)

# Calculate evaluation metrics
train_mae = mean_absolute_error(y_train_actual, y_train_pred_actual)
train_mse = mean_squared_error(y_train_actual, y_train_pred_actual)
test_mae = mean_absolute_error(y_test_actual, y_test_pred_actual)
test_mse = mean_squared_error(y_test_actual, y_test_pred_actual)
#
train_r = np.sqrt(train_mse)
train_r2 = r2_score(y_train_actual, y_train_pred_actual)
test_r = np.sqrt(test_mse)
test_r2 = r2_score(y_test_actual, y_test_pred_actual)

print(f'Training MAE: {train_mae}')
print(f'Training MSE: {train_mse}')
print(f'Testing MAE: {test_mae}')
print(f'Testing MSE: {test_mse}')
print(train_r)
print(test_r)
print(train_r2)
print(test_r2)
# Out:
# 6/6 [==============================] - 0s 857us/step
# 1/1 [==============================] - 0s 8ms/step
# Training MAE: 15.197800636291504
# Training MSE: 980.4922485351562
# Testing MAE: 217.68800354003906
# Testing MSE: 190393.921875
# 31.312813
# 436.34152
# 0.80162733858064
# 0.20735048207608497

# %%
import matplotlib.pyplot as plt

# Plot actual vs predicted for training set
plt.figure(figsize=(12, 6))
plt.plot(y_train_actual, label='Actual')
plt.plot(y_train_pred_actual, label='Predicted')
plt.title('Actual vs Predicted Prices - Training Set')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()

# Plot actual vs predicted for testing set
plt.figure(figsize=(12, 6))
plt.plot(y_test_actual, label='Actual')
plt.plot(y_test_pred_actual, label='Predicted')
plt.title('Actual vs Predicted Prices - Testing Set')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
d
# Out:
#           date     price
# 0   2000-02-01  0.053404
# 1   2000-03-01  0.043292
# 2   2000-04-01  0.049974
# 3   2000-05-01  0.049490
# 4   2000-06-01  0.049135
# ..         ...       ...
# 235 2019-09-01  0.058386
# 236 2019-10-01  0.056683
# 237 2019-11-01  0.075554
# 238 2019-12-01  0.081035
# 239 2020-01-01  0.089746
#
# [240 rows x 2 columns]
