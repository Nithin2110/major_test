# %%
com = {
    'rice': {
        'LSTM': {
            'lstm_units': 195,
            'dense_units': 73,
            'learning_rate': 0.001
        },
        'Bi-LSTM': {
            'lstm_units': 195,
            'dense_units': 88,
            'learning_rate': 0.001
        },
        'Stacked-LSTM': {
            'lstm_units': 176,
            'dense_units': 46,
            'num_lstm_layers': 3,
            'learning_rate': 0.001
        },
        'GRU': {
            'gru_units': 64,
            'dense_units': 32,
            'learning_rate': 0.001
        },
        '1D-CNN': {
            'num_filters': 78,
            'kernel_size': 4,
            'dense_units': 40,
            'learning_rate': 0.001
        }
    }
}


print(com['rice'])
# Out:
# {'LSTM': {'lstm_units': 195, 'dense_units': 73, 'learning_rate': 0.001}, 'Bi-LSTM': {'lstm_units': 195, 'dense_units': 88, 'learning_rate': 0.001}, 'Stacked-LSTM': {'lstm_units': 176, 'dense_units': 46, 'num_lstm_layers': 3, 'learning_rate': 0.001}, 'GRU': {'gru_units': 64, 'dense_units': 32, 'learning_rate': 0.001}, '1D-CNN': {'num_filters': 78, 'kernel_size': 4, 'dense_units': 40, 'learning_rate': 0.001}}
