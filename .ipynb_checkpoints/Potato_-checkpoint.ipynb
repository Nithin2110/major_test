# %%
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.preprocessing import MinMaxScaler
from statsmodels.tsa.stattools import kpss

# %%
df=pd.read_csv("DATA/potato.csv")

df
# Out:
#                     Date  price
# 0    2000-01-01 00:00:00   70.7
# 1    2000-02-01 00:00:00   58.6
# 2    2000-03-01 00:00:00   67.0
# 3    2000-04-01 00:00:00   68.7
# 4    2000-05-01 00:00:00   77.8
# ..                   ...    ...
# 277  2023-02-01 00:00:00  146.0
# 278  2023-03-01 00:00:00  135.2
# 279  2023-04-01 00:00:00  157.0
# 280  2023-05-01 00:00:00  190.0
# 281  2023-06-01 00:00:00  204.3
#
# [282 rows x 2 columns]

# %%
df.plot()
# Out:
# <Axes: >

# %%
sn.boxplot(df['price'])
# Out:
# <Axes: >

# %%
t=kpss(df['price'],'ct')
t
# Out:
# (0.13325745998218122,
#  0.07359729632929403,
#  9,
#  {'10%': 0.119, '5%': 0.146, '2.5%': 0.176, '1%': 0.216})

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose

# Assuming df is your DataFrame with a 'date' column and a 'value' column representing the time series
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)

# Perform seasonal decomposition
decomposition = seasonal_decompose(df['price'], model='additive')

# Plot the original time series
plt.figure(figsize=(10, 6))
plt.subplot(411)
plt.plot(df['price'], label='Original', color='blue')
plt.legend(loc='upper left')

# Plot the trend component
plt.subplot(412)
plt.plot(decomposition.trend, label='Trend', color='green')
plt.legend(loc='upper left')

# Plot the seasonal component
plt.subplot(413)
plt.plot(decomposition.seasonal, label='Seasonal', color='red')
plt.legend(loc='upper left')

# Plot the residual component
plt.subplot(414)
plt.plot(decomposition.resid, label='Residual', color='purple')
plt.legend(loc='upper left')

plt.tight_layout()
plt.show()

# %%
df=pd.read_csv("DATA/Backup/potato.csv")
scaler = MinMaxScaler(feature_range=(0, 1))
df['price'] = scaler.fit_transform(df['price'].values.reshape(-1,1))
import matplotlib.pyplot as plt
plt.plot(df['Date'],df['price'])

# %%
# Convert 'date' column to datetime if it's not already
# Shift the 'price' column to create new columns
df['target-1'] = df['price'].shift(1)
df['target-2'] = df['price'].shift(2)
df['target-3'] = df['price'].shift(3)
#df['target-4'] = df['price'].shift(4)
#df['target-5'] = df['price'].shift(5)
#df['target-6'] = df['price'].shift(6)
#df['target-7'] = df['price'].shift(7)
#df['target-8'] = df['price'].shift(8)
#df['target-9'] = df['price'].shift(9)
#df['target-10'] = df['price'].shift(10)

# %%
d=df[3:]
d
# Out:
#                     Date     price  target-1  target-2  target-3
# 3    2000-04-01 00:00:00  0.023353  0.019422  0.000000  0.027977
# 4    2000-05-01 00:00:00  0.044393  0.023353  0.019422  0.000000
# 5    2000-06-01 00:00:00  0.093642  0.044393  0.023353  0.019422
# 6    2000-07-01 00:00:00  0.101734  0.093642  0.044393  0.023353
# 7    2000-08-01 00:00:00  0.092948  0.101734  0.093642  0.044393
# ..                   ...       ...       ...       ...       ...
# 283  2023-08-01 00:00:00  0.376416  0.376185  0.336879  0.303815
# 284  2023-09-01 00:00:00  0.355145  0.376416  0.376185  0.336879
# 285  2023-10-01 00:00:00  0.349364  0.355145  0.376416  0.376185
# 286  2023-11-01 00:00:00  0.351676  0.349364  0.355145  0.376416
# 287  2023-12-01 00:00:00  0.306358  0.351676  0.349364  0.355145
#
# [285 rows x 5 columns]

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
    df_as_np = windowed_dataframe.to_numpy()
    dates = df_as_np[:, 0]
    middle_matrix = df_as_np[:, 1:-1]
    X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))
    Y = df_as_np[:, -1]
    return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(d)

dates.shape, X.shape, y.shape
# Out:
# ((285,), (285, 3, 1), (285,))

# %%
#y

# %%
#dates
#X
#y

# %%
q_80 = int(len(dates) * .8)
q_90 = int(len(dates) * .9)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %%
X_train.shape,
# Out:
# ((228, 3, 1),)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers.legacy import Adam
from tensorflow.keras import layers
from keras.callbacks import EarlyStopping
from keras.regularizers import l2

#early_stopping = EarlyStopping(monitor='val_loss', patience=10, mode='min')

model = Sequential([layers.Input((3, 1)),
                    #layers.GRU(64),
                    #layers.LSTM(64),
                    #layers.LSTM(32, return_sequences=True),
                    #layers.LSTM(32),
                    #layers.Bidirectional(layers.LSTM(64)),
                    layers.Conv1D(filters=64, kernel_size=3, activation='relu'),
                    layers.Flatten(),
                    layers.Dense(64, activation='relu'),
                    #layers.Dense(32, activation='relu'),
                    layers.Dense(1)
                   ])

model.compile(loss='mse', 
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=250)
# Out:
# Epoch 1/250
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0677 - mean_absolute_error: 0.2105 - val_loss: 0.0456 - val_mean_absolute_error: 0.1275
# Epoch 2/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0171 - mean_absolute_error: 0.0921 - val_loss: 0.0296 - val_mean_absolute_error: 0.1342
# Epoch 3/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0169 - mean_absolute_error: 0.1089 - val_loss: 0.0270 - val_mean_absolute_error: 0.1272
# Epoch 4/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0127 - mean_absolute_error: 0.0859 - val_loss: 0.0233 - val_mean_absolute_error: 0.0829
# Epoch 5/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0108 - mean_absolute_error: 0.0731 - val_loss: 0.0210 - val_mean_absolute_error: 0.0820
# Epoch 6/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0096 - mean_absolute_error: 0.0691 - val_loss: 0.0194 - val_mean_absolute_error: 0.0774
# Epoch 7/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0086 - mean_absolute_error: 0.0644 - val_loss: 0.0176 - val_mean_absolute_error: 0.0729
# Epoch 8/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0078 - mean_absolute_error: 0.0650 - val_loss: 0.0161 - val_mean_absolute_error: 0.0770
# Epoch 9/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0069 - mean_absolute_error: 0.0583 - val_loss: 0.0152 - val_mean_absolute_error: 0.0585
# Epoch 10/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0062 - mean_absolute_error: 0.0541 - val_loss: 0.0140 - val_mean_absolute_error: 0.0650
# Epoch 11/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0058 - mean_absolute_error: 0.0546 - val_loss: 0.0132 - val_mean_absolute_error: 0.0585
# Epoch 12/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0054 - mean_absolute_error: 0.0482 - val_loss: 0.0125 - val_mean_absolute_error: 0.0594
# Epoch 13/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0050 - mean_absolute_error: 0.0488 - val_loss: 0.0121 - val_mean_absolute_error: 0.0583
# Epoch 14/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0455 - val_loss: 0.0115 - val_mean_absolute_error: 0.0594
# Epoch 15/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0045 - mean_absolute_error: 0.0455 - val_loss: 0.0113 - val_mean_absolute_error: 0.0594
# Epoch 16/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0045 - mean_absolute_error: 0.0452 - val_loss: 0.0108 - val_mean_absolute_error: 0.0610
# Epoch 17/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0043 - mean_absolute_error: 0.0457 - val_loss: 0.0112 - val_mean_absolute_error: 0.0620
# Epoch 18/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0044 - mean_absolute_error: 0.0446 - val_loss: 0.0104 - val_mean_absolute_error: 0.0597
# Epoch 19/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0042 - mean_absolute_error: 0.0436 - val_loss: 0.0107 - val_mean_absolute_error: 0.0603
# Epoch 20/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0042 - mean_absolute_error: 0.0438 - val_loss: 0.0104 - val_mean_absolute_error: 0.0582
# Epoch 21/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0041 - mean_absolute_error: 0.0433 - val_loss: 0.0103 - val_mean_absolute_error: 0.0587
# Epoch 22/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0041 - mean_absolute_error: 0.0442 - val_loss: 0.0106 - val_mean_absolute_error: 0.0607
# Epoch 23/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0043 - mean_absolute_error: 0.0434 - val_loss: 0.0101 - val_mean_absolute_error: 0.0641
# Epoch 24/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0042 - mean_absolute_error: 0.0452 - val_loss: 0.0103 - val_mean_absolute_error: 0.0580
# Epoch 25/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0040 - mean_absolute_error: 0.0418 - val_loss: 0.0099 - val_mean_absolute_error: 0.0622
# Epoch 26/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0040 - mean_absolute_error: 0.0430 - val_loss: 0.0102 - val_mean_absolute_error: 0.0569
# Epoch 27/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0039 - mean_absolute_error: 0.0417 - val_loss: 0.0100 - val_mean_absolute_error: 0.0669
# Epoch 28/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0044 - mean_absolute_error: 0.0478 - val_loss: 0.0101 - val_mean_absolute_error: 0.0610
# Epoch 29/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0040 - mean_absolute_error: 0.0449 - val_loss: 0.0095 - val_mean_absolute_error: 0.0583
# Epoch 30/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0040 - mean_absolute_error: 0.0435 - val_loss: 0.0094 - val_mean_absolute_error: 0.0618
# Epoch 31/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0040 - mean_absolute_error: 0.0465 - val_loss: 0.0094 - val_mean_absolute_error: 0.0583
# Epoch 32/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0039 - mean_absolute_error: 0.0453 - val_loss: 0.0095 - val_mean_absolute_error: 0.0607
# Epoch 33/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0038 - mean_absolute_error: 0.0432 - val_loss: 0.0092 - val_mean_absolute_error: 0.0576
# Epoch 34/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0037 - mean_absolute_error: 0.0417 - val_loss: 0.0092 - val_mean_absolute_error: 0.0570
# Epoch 35/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0038 - mean_absolute_error: 0.0433 - val_loss: 0.0093 - val_mean_absolute_error: 0.0553
# Epoch 36/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0036 - mean_absolute_error: 0.0407 - val_loss: 0.0093 - val_mean_absolute_error: 0.0562
# Epoch 37/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0036 - mean_absolute_error: 0.0404 - val_loss: 0.0091 - val_mean_absolute_error: 0.0565
# Epoch 38/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0036 - mean_absolute_error: 0.0427 - val_loss: 0.0093 - val_mean_absolute_error: 0.0578
# Epoch 39/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0036 - mean_absolute_error: 0.0416 - val_loss: 0.0088 - val_mean_absolute_error: 0.0595
# Epoch 40/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0039 - mean_absolute_error: 0.0452 - val_loss: 0.0094 - val_mean_absolute_error: 0.0592
# Epoch 41/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0037 - mean_absolute_error: 0.0434 - val_loss: 0.0089 - val_mean_absolute_error: 0.0562
# Epoch 42/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0037 - mean_absolute_error: 0.0404 - val_loss: 0.0091 - val_mean_absolute_error: 0.0604
# Epoch 43/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0039 - mean_absolute_error: 0.0449 - val_loss: 0.0094 - val_mean_absolute_error: 0.0571
# Epoch 44/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0037 - mean_absolute_error: 0.0408 - val_loss: 0.0090 - val_mean_absolute_error: 0.0612
# Epoch 45/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0037 - mean_absolute_error: 0.0431 - val_loss: 0.0100 - val_mean_absolute_error: 0.0621
# Epoch 46/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0037 - mean_absolute_error: 0.0431 - val_loss: 0.0088 - val_mean_absolute_error: 0.0609
# Epoch 47/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0035 - mean_absolute_error: 0.0416 - val_loss: 0.0092 - val_mean_absolute_error: 0.0580
# Epoch 48/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0034 - mean_absolute_error: 0.0393 - val_loss: 0.0087 - val_mean_absolute_error: 0.0605
# Epoch 49/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0036 - mean_absolute_error: 0.0429 - val_loss: 0.0095 - val_mean_absolute_error: 0.0604
# Epoch 50/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0037 - mean_absolute_error: 0.0428 - val_loss: 0.0088 - val_mean_absolute_error: 0.0613
# Epoch 51/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0035 - mean_absolute_error: 0.0413 - val_loss: 0.0097 - val_mean_absolute_error: 0.0622
# Epoch 52/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0037 - mean_absolute_error: 0.0423 - val_loss: 0.0085 - val_mean_absolute_error: 0.0571
# Epoch 53/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0034 - mean_absolute_error: 0.0390 - val_loss: 0.0087 - val_mean_absolute_error: 0.0561
# Epoch 54/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0034 - mean_absolute_error: 0.0393 - val_loss: 0.0088 - val_mean_absolute_error: 0.0557
# Epoch 55/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0036 - mean_absolute_error: 0.0403 - val_loss: 0.0085 - val_mean_absolute_error: 0.0579
# Epoch 56/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0035 - mean_absolute_error: 0.0396 - val_loss: 0.0086 - val_mean_absolute_error: 0.0560
# Epoch 57/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0034 - mean_absolute_error: 0.0396 - val_loss: 0.0088 - val_mean_absolute_error: 0.0556
# Epoch 58/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0035 - mean_absolute_error: 0.0400 - val_loss: 0.0084 - val_mean_absolute_error: 0.0584
# Epoch 59/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0034 - mean_absolute_error: 0.0404 - val_loss: 0.0089 - val_mean_absolute_error: 0.0567
# Epoch 60/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0036 - mean_absolute_error: 0.0412 - val_loss: 0.0084 - val_mean_absolute_error: 0.0578
# Epoch 61/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0035 - mean_absolute_error: 0.0402 - val_loss: 0.0084 - val_mean_absolute_error: 0.0569
# Epoch 62/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_error: 0.0386 - val_loss: 0.0083 - val_mean_absolute_error: 0.0583
# Epoch 63/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0035 - mean_absolute_error: 0.0429 - val_loss: 0.0091 - val_mean_absolute_error: 0.0610
# Epoch 64/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0035 - mean_absolute_error: 0.0417 - val_loss: 0.0082 - val_mean_absolute_error: 0.0588
# Epoch 65/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0037 - mean_absolute_error: 0.0413 - val_loss: 0.0085 - val_mean_absolute_error: 0.0612
# Epoch 66/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0043 - mean_absolute_error: 0.0507 - val_loss: 0.0110 - val_mean_absolute_error: 0.0719
# Epoch 67/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0042 - mean_absolute_error: 0.0463 - val_loss: 0.0085 - val_mean_absolute_error: 0.0653
# Epoch 68/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0038 - mean_absolute_error: 0.0444 - val_loss: 0.0087 - val_mean_absolute_error: 0.0575
# Epoch 69/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0035 - mean_absolute_error: 0.0415 - val_loss: 0.0081 - val_mean_absolute_error: 0.0550
# Epoch 70/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0034 - mean_absolute_error: 0.0389 - val_loss: 0.0081 - val_mean_absolute_error: 0.0552
# Epoch 71/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_error: 0.0384 - val_loss: 0.0081 - val_mean_absolute_error: 0.0556
# Epoch 72/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_error: 0.0392 - val_loss: 0.0084 - val_mean_absolute_error: 0.0555
# Epoch 73/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_error: 0.0388 - val_loss: 0.0081 - val_mean_absolute_error: 0.0576
# Epoch 74/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0034 - mean_absolute_error: 0.0397 - val_loss: 0.0083 - val_mean_absolute_error: 0.0549
# Epoch 75/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_error: 0.0390 - val_loss: 0.0081 - val_mean_absolute_error: 0.0562
# Epoch 76/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_error: 0.0390 - val_loss: 0.0081 - val_mean_absolute_error: 0.0575
# Epoch 77/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0034 - mean_absolute_error: 0.0396 - val_loss: 0.0081 - val_mean_absolute_error: 0.0562
# Epoch 78/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_error: 0.0402 - val_loss: 0.0086 - val_mean_absolute_error: 0.0562
# Epoch 79/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0034 - mean_absolute_error: 0.0395 - val_loss: 0.0080 - val_mean_absolute_error: 0.0557
# Epoch 80/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_error: 0.0386 - val_loss: 0.0081 - val_mean_absolute_error: 0.0551
# Epoch 81/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0034 - mean_absolute_error: 0.0393 - val_loss: 0.0082 - val_mean_absolute_error: 0.0551
# Epoch 82/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0034 - mean_absolute_error: 0.0394 - val_loss: 0.0080 - val_mean_absolute_error: 0.0566
# Epoch 83/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_error: 0.0392 - val_loss: 0.0079 - val_mean_absolute_error: 0.0582
# Epoch 84/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0035 - mean_absolute_error: 0.0422 - val_loss: 0.0080 - val_mean_absolute_error: 0.0570
# Epoch 85/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_error: 0.0402 - val_loss: 0.0078 - val_mean_absolute_error: 0.0553
# Epoch 86/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_error: 0.0386 - val_loss: 0.0081 - val_mean_absolute_error: 0.0609
# Epoch 87/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0037 - mean_absolute_error: 0.0446 - val_loss: 0.0092 - val_mean_absolute_error: 0.0626
# Epoch 88/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0035 - mean_absolute_error: 0.0423 - val_loss: 0.0078 - val_mean_absolute_error: 0.0572
# Epoch 89/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0034 - mean_absolute_error: 0.0403 - val_loss: 0.0079 - val_mean_absolute_error: 0.0561
# Epoch 90/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0381 - val_loss: 0.0080 - val_mean_absolute_error: 0.0557
# Epoch 91/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0381 - val_loss: 0.0081 - val_mean_absolute_error: 0.0552
# Epoch 92/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0035 - mean_absolute_error: 0.0395 - val_loss: 0.0080 - val_mean_absolute_error: 0.0577
# Epoch 93/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0037 - mean_absolute_error: 0.0401 - val_loss: 0.0081 - val_mean_absolute_error: 0.0571
# Epoch 94/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_error: 0.0391 - val_loss: 0.0078 - val_mean_absolute_error: 0.0571
# Epoch 95/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0391 - val_loss: 0.0080 - val_mean_absolute_error: 0.0561
# Epoch 96/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_error: 0.0399 - val_loss: 0.0077 - val_mean_absolute_error: 0.0562
# Epoch 97/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0034 - mean_absolute_error: 0.0392 - val_loss: 0.0077 - val_mean_absolute_error: 0.0560
# Epoch 98/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0382 - val_loss: 0.0077 - val_mean_absolute_error: 0.0556
# Epoch 99/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0390 - val_loss: 0.0077 - val_mean_absolute_error: 0.0559
# Epoch 100/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0392 - val_loss: 0.0079 - val_mean_absolute_error: 0.0553
# Epoch 101/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0388 - val_loss: 0.0076 - val_mean_absolute_error: 0.0589
# Epoch 102/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_error: 0.0402 - val_loss: 0.0080 - val_mean_absolute_error: 0.0559
# Epoch 103/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0391 - val_loss: 0.0078 - val_mean_absolute_error: 0.0557
# Epoch 104/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0034 - mean_absolute_error: 0.0409 - val_loss: 0.0085 - val_mean_absolute_error: 0.0673
# Epoch 105/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0039 - mean_absolute_error: 0.0460 - val_loss: 0.0082 - val_mean_absolute_error: 0.0557
# Epoch 106/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_error: 0.0402 - val_loss: 0.0077 - val_mean_absolute_error: 0.0556
# Epoch 107/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_error: 0.0389 - val_loss: 0.0076 - val_mean_absolute_error: 0.0576
# Epoch 108/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_error: 0.0409 - val_loss: 0.0090 - val_mean_absolute_error: 0.0588
# Epoch 109/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0038 - mean_absolute_error: 0.0432 - val_loss: 0.0078 - val_mean_absolute_error: 0.0551
# Epoch 110/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0038 - mean_absolute_error: 0.0433 - val_loss: 0.0080 - val_mean_absolute_error: 0.0621
# Epoch 111/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0035 - mean_absolute_error: 0.0418 - val_loss: 0.0080 - val_mean_absolute_error: 0.0546
# Epoch 112/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_error: 0.0392 - val_loss: 0.0077 - val_mean_absolute_error: 0.0549
# Epoch 113/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_error: 0.0388 - val_loss: 0.0080 - val_mean_absolute_error: 0.0630
# Epoch 114/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0038 - mean_absolute_error: 0.0443 - val_loss: 0.0076 - val_mean_absolute_error: 0.0543
# Epoch 115/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0034 - mean_absolute_error: 0.0422 - val_loss: 0.0077 - val_mean_absolute_error: 0.0568
# Epoch 116/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0034 - mean_absolute_error: 0.0395 - val_loss: 0.0073 - val_mean_absolute_error: 0.0551
# Epoch 117/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_error: 0.0392 - val_loss: 0.0074 - val_mean_absolute_error: 0.0577
# Epoch 118/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_error: 0.0410 - val_loss: 0.0075 - val_mean_absolute_error: 0.0549
# Epoch 119/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0036 - mean_absolute_error: 0.0433 - val_loss: 0.0081 - val_mean_absolute_error: 0.0569
# Epoch 120/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_error: 0.0389 - val_loss: 0.0075 - val_mean_absolute_error: 0.0578
# Epoch 121/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_error: 0.0402 - val_loss: 0.0075 - val_mean_absolute_error: 0.0551
# Epoch 122/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0031 - mean_absolute_error: 0.0387 - val_loss: 0.0081 - val_mean_absolute_error: 0.0558
# Epoch 123/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0036 - mean_absolute_error: 0.0417 - val_loss: 0.0080 - val_mean_absolute_error: 0.0585
# Epoch 124/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0037 - mean_absolute_error: 0.0410 - val_loss: 0.0079 - val_mean_absolute_error: 0.0560
# Epoch 125/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0386 - val_loss: 0.0076 - val_mean_absolute_error: 0.0557
# Epoch 126/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0389 - val_loss: 0.0075 - val_mean_absolute_error: 0.0562
# Epoch 127/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0381 - val_loss: 0.0075 - val_mean_absolute_error: 0.0561
# Epoch 128/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0390 - val_loss: 0.0076 - val_mean_absolute_error: 0.0564
# Epoch 129/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_error: 0.0405 - val_loss: 0.0076 - val_mean_absolute_error: 0.0550
# Epoch 130/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_error: 0.0405 - val_loss: 0.0079 - val_mean_absolute_error: 0.0557
# Epoch 131/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0396 - val_loss: 0.0076 - val_mean_absolute_error: 0.0577
# Epoch 132/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_error: 0.0391 - val_loss: 0.0075 - val_mean_absolute_error: 0.0558
# Epoch 133/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0401 - val_loss: 0.0078 - val_mean_absolute_error: 0.0554
# Epoch 134/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0031 - mean_absolute_error: 0.0381 - val_loss: 0.0077 - val_mean_absolute_error: 0.0598
# Epoch 135/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0034 - mean_absolute_error: 0.0404 - val_loss: 0.0079 - val_mean_absolute_error: 0.0536
# Epoch 136/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0387 - val_loss: 0.0075 - val_mean_absolute_error: 0.0564
# Epoch 137/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_error: 0.0411 - val_loss: 0.0077 - val_mean_absolute_error: 0.0544
# Epoch 138/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0037 - mean_absolute_error: 0.0446 - val_loss: 0.0078 - val_mean_absolute_error: 0.0558
# Epoch 139/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_error: 0.0406 - val_loss: 0.0076 - val_mean_absolute_error: 0.0567
# Epoch 140/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_error: 0.0406 - val_loss: 0.0074 - val_mean_absolute_error: 0.0583
# Epoch 141/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0036 - mean_absolute_error: 0.0426 - val_loss: 0.0080 - val_mean_absolute_error: 0.0580
# Epoch 142/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0394 - val_loss: 0.0074 - val_mean_absolute_error: 0.0579
# Epoch 143/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0390 - val_loss: 0.0074 - val_mean_absolute_error: 0.0546
# Epoch 144/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0389 - val_loss: 0.0074 - val_mean_absolute_error: 0.0549
# Epoch 145/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0386 - val_loss: 0.0075 - val_mean_absolute_error: 0.0545
# Epoch 146/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0380 - val_loss: 0.0073 - val_mean_absolute_error: 0.0558
# Epoch 147/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0392 - val_loss: 0.0074 - val_mean_absolute_error: 0.0548
# Epoch 148/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_error: 0.0396 - val_loss: 0.0073 - val_mean_absolute_error: 0.0566
# Epoch 149/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_error: 0.0393 - val_loss: 0.0074 - val_mean_absolute_error: 0.0566
# Epoch 150/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0031 - mean_absolute_error: 0.0382 - val_loss: 0.0078 - val_mean_absolute_error: 0.0542
# Epoch 151/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_error: 0.0388 - val_loss: 0.0076 - val_mean_absolute_error: 0.0583
# Epoch 152/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_error: 0.0407 - val_loss: 0.0076 - val_mean_absolute_error: 0.0543
# Epoch 153/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_error: 0.0412 - val_loss: 0.0074 - val_mean_absolute_error: 0.0556
# Epoch 154/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_error: 0.0402 - val_loss: 0.0073 - val_mean_absolute_error: 0.0547
# Epoch 155/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0034 - mean_absolute_error: 0.0393 - val_loss: 0.0078 - val_mean_absolute_error: 0.0567
# Epoch 156/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0395 - val_loss: 0.0077 - val_mean_absolute_error: 0.0540
# Epoch 157/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0034 - mean_absolute_error: 0.0412 - val_loss: 0.0076 - val_mean_absolute_error: 0.0548
# Epoch 158/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0035 - mean_absolute_error: 0.0416 - val_loss: 0.0079 - val_mean_absolute_error: 0.0561
# Epoch 159/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_error: 0.0388 - val_loss: 0.0073 - val_mean_absolute_error: 0.0561
# Epoch 160/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0383 - val_loss: 0.0074 - val_mean_absolute_error: 0.0567
# Epoch 161/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_error: 0.0406 - val_loss: 0.0074 - val_mean_absolute_error: 0.0551
# Epoch 162/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0034 - mean_absolute_error: 0.0431 - val_loss: 0.0080 - val_mean_absolute_error: 0.0591
# Epoch 163/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_error: 0.0408 - val_loss: 0.0074 - val_mean_absolute_error: 0.0602
# Epoch 164/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0038 - mean_absolute_error: 0.0469 - val_loss: 0.0083 - val_mean_absolute_error: 0.0587
# Epoch 165/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0034 - mean_absolute_error: 0.0418 - val_loss: 0.0073 - val_mean_absolute_error: 0.0546
# Epoch 166/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_error: 0.0395 - val_loss: 0.0073 - val_mean_absolute_error: 0.0573
# Epoch 167/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0037 - mean_absolute_error: 0.0451 - val_loss: 0.0083 - val_mean_absolute_error: 0.0548
# Epoch 168/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0035 - mean_absolute_error: 0.0410 - val_loss: 0.0073 - val_mean_absolute_error: 0.0560
# Epoch 169/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0385 - val_loss: 0.0072 - val_mean_absolute_error: 0.0552
# Epoch 170/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0034 - mean_absolute_error: 0.0429 - val_loss: 0.0078 - val_mean_absolute_error: 0.0532
# Epoch 171/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0395 - val_loss: 0.0076 - val_mean_absolute_error: 0.0574
# Epoch 172/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0398 - val_loss: 0.0081 - val_mean_absolute_error: 0.0539
# Epoch 173/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0385 - val_loss: 0.0075 - val_mean_absolute_error: 0.0576
# Epoch 174/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0403 - val_loss: 0.0083 - val_mean_absolute_error: 0.0569
# Epoch 175/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0036 - mean_absolute_error: 0.0444 - val_loss: 0.0071 - val_mean_absolute_error: 0.0542
# Epoch 176/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0035 - mean_absolute_error: 0.0409 - val_loss: 0.0070 - val_mean_absolute_error: 0.0573
# Epoch 177/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0394 - val_loss: 0.0071 - val_mean_absolute_error: 0.0551
# Epoch 178/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0402 - val_loss: 0.0079 - val_mean_absolute_error: 0.0543
# Epoch 179/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_error: 0.0397 - val_loss: 0.0080 - val_mean_absolute_error: 0.0644
# Epoch 180/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0036 - mean_absolute_error: 0.0426 - val_loss: 0.0080 - val_mean_absolute_error: 0.0568
# Epoch 181/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0034 - mean_absolute_error: 0.0420 - val_loss: 0.0071 - val_mean_absolute_error: 0.0555
# Epoch 182/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0392 - val_loss: 0.0072 - val_mean_absolute_error: 0.0572
# Epoch 183/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0034 - mean_absolute_error: 0.0435 - val_loss: 0.0081 - val_mean_absolute_error: 0.0570
# Epoch 184/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0035 - mean_absolute_error: 0.0408 - val_loss: 0.0071 - val_mean_absolute_error: 0.0566
# Epoch 185/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_error: 0.0403 - val_loss: 0.0071 - val_mean_absolute_error: 0.0535
# Epoch 186/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0386 - val_loss: 0.0073 - val_mean_absolute_error: 0.0530
# Epoch 187/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0393 - val_loss: 0.0072 - val_mean_absolute_error: 0.0540
# Epoch 188/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0031 - mean_absolute_error: 0.0383 - val_loss: 0.0072 - val_mean_absolute_error: 0.0557
# Epoch 189/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0404 - val_loss: 0.0071 - val_mean_absolute_error: 0.0547
# Epoch 190/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0034 - mean_absolute_error: 0.0418 - val_loss: 0.0083 - val_mean_absolute_error: 0.0590
# Epoch 191/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0396 - val_loss: 0.0073 - val_mean_absolute_error: 0.0579
# Epoch 192/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0031 - mean_absolute_error: 0.0387 - val_loss: 0.0074 - val_mean_absolute_error: 0.0543
# Epoch 193/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0031 - mean_absolute_error: 0.0388 - val_loss: 0.0073 - val_mean_absolute_error: 0.0542
# Epoch 194/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0031 - mean_absolute_error: 0.0381 - val_loss: 0.0073 - val_mean_absolute_error: 0.0549
# Epoch 195/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0031 - mean_absolute_error: 0.0385 - val_loss: 0.0073 - val_mean_absolute_error: 0.0563
# Epoch 196/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_error: 0.0384 - val_loss: 0.0074 - val_mean_absolute_error: 0.0553
# Epoch 197/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_error: 0.0405 - val_loss: 0.0078 - val_mean_absolute_error: 0.0537
# Epoch 198/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0034 - mean_absolute_error: 0.0407 - val_loss: 0.0078 - val_mean_absolute_error: 0.0545
# Epoch 199/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0034 - mean_absolute_error: 0.0399 - val_loss: 0.0074 - val_mean_absolute_error: 0.0562
# Epoch 200/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0031 - mean_absolute_error: 0.0384 - val_loss: 0.0080 - val_mean_absolute_error: 0.0531
# Epoch 201/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0031 - mean_absolute_error: 0.0385 - val_loss: 0.0075 - val_mean_absolute_error: 0.0565
# Epoch 202/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0388 - val_loss: 0.0077 - val_mean_absolute_error: 0.0606
# Epoch 203/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0043 - mean_absolute_error: 0.0504 - val_loss: 0.0110 - val_mean_absolute_error: 0.0733
# Epoch 204/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0045 - mean_absolute_error: 0.0498 - val_loss: 0.0087 - val_mean_absolute_error: 0.0723
# Epoch 205/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0043 - mean_absolute_error: 0.0457 - val_loss: 0.0085 - val_mean_absolute_error: 0.0520
# Epoch 206/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_error: 0.0413 - val_loss: 0.0079 - val_mean_absolute_error: 0.0539
# Epoch 207/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0382 - val_loss: 0.0076 - val_mean_absolute_error: 0.0551
# Epoch 208/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_error: 0.0410 - val_loss: 0.0078 - val_mean_absolute_error: 0.0528
# Epoch 209/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0031 - mean_absolute_error: 0.0377 - val_loss: 0.0074 - val_mean_absolute_error: 0.0554
# Epoch 210/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0384 - val_loss: 0.0074 - val_mean_absolute_error: 0.0535
# Epoch 211/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0031 - mean_absolute_error: 0.0380 - val_loss: 0.0074 - val_mean_absolute_error: 0.0534
# Epoch 212/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0031 - mean_absolute_error: 0.0381 - val_loss: 0.0072 - val_mean_absolute_error: 0.0542
# Epoch 213/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0031 - mean_absolute_error: 0.0384 - val_loss: 0.0072 - val_mean_absolute_error: 0.0537
# Epoch 214/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_error: 0.0411 - val_loss: 0.0075 - val_mean_absolute_error: 0.0527
# Epoch 215/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0031 - mean_absolute_error: 0.0392 - val_loss: 0.0070 - val_mean_absolute_error: 0.0540
# Epoch 216/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0034 - mean_absolute_error: 0.0404 - val_loss: 0.0071 - val_mean_absolute_error: 0.0562
# Epoch 217/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_error: 0.0397 - val_loss: 0.0071 - val_mean_absolute_error: 0.0533
# Epoch 218/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0384 - val_loss: 0.0071 - val_mean_absolute_error: 0.0547
# Epoch 219/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0402 - val_loss: 0.0078 - val_mean_absolute_error: 0.0540
# Epoch 220/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0034 - mean_absolute_error: 0.0420 - val_loss: 0.0072 - val_mean_absolute_error: 0.0564
# Epoch 221/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0036 - mean_absolute_error: 0.0409 - val_loss: 0.0072 - val_mean_absolute_error: 0.0556
# Epoch 222/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_error: 0.0406 - val_loss: 0.0080 - val_mean_absolute_error: 0.0541
# Epoch 223/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0380 - val_loss: 0.0073 - val_mean_absolute_error: 0.0552
# Epoch 224/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_error: 0.0391 - val_loss: 0.0072 - val_mean_absolute_error: 0.0551
# Epoch 225/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0037 - mean_absolute_error: 0.0438 - val_loss: 0.0082 - val_mean_absolute_error: 0.0553
# Epoch 226/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0034 - mean_absolute_error: 0.0418 - val_loss: 0.0069 - val_mean_absolute_error: 0.0557
# Epoch 227/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0034 - mean_absolute_error: 0.0421 - val_loss: 0.0070 - val_mean_absolute_error: 0.0547
# Epoch 228/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0031 - mean_absolute_error: 0.0386 - val_loss: 0.0074 - val_mean_absolute_error: 0.0522
# Epoch 229/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0386 - val_loss: 0.0073 - val_mean_absolute_error: 0.0526
# Epoch 230/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0035 - mean_absolute_error: 0.0412 - val_loss: 0.0073 - val_mean_absolute_error: 0.0611
# Epoch 231/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0035 - mean_absolute_error: 0.0448 - val_loss: 0.0078 - val_mean_absolute_error: 0.0552
# Epoch 232/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0398 - val_loss: 0.0074 - val_mean_absolute_error: 0.0559
# Epoch 233/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0390 - val_loss: 0.0073 - val_mean_absolute_error: 0.0539
# Epoch 234/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_error: 0.0406 - val_loss: 0.0084 - val_mean_absolute_error: 0.0576
# Epoch 235/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0034 - mean_absolute_error: 0.0413 - val_loss: 0.0071 - val_mean_absolute_error: 0.0558
# Epoch 236/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0031 - mean_absolute_error: 0.0397 - val_loss: 0.0072 - val_mean_absolute_error: 0.0528
# Epoch 237/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_error: 0.0416 - val_loss: 0.0074 - val_mean_absolute_error: 0.0520
# Epoch 238/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0387 - val_loss: 0.0073 - val_mean_absolute_error: 0.0525
# Epoch 239/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0384 - val_loss: 0.0071 - val_mean_absolute_error: 0.0546
# Epoch 240/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0031 - mean_absolute_error: 0.0386 - val_loss: 0.0073 - val_mean_absolute_error: 0.0533
# Epoch 241/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0031 - mean_absolute_error: 0.0391 - val_loss: 0.0076 - val_mean_absolute_error: 0.0531
# Epoch 242/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0394 - val_loss: 0.0074 - val_mean_absolute_error: 0.0589
# Epoch 243/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_error: 0.0406 - val_loss: 0.0074 - val_mean_absolute_error: 0.0533
# Epoch 244/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0030 - mean_absolute_error: 0.0377 - val_loss: 0.0073 - val_mean_absolute_error: 0.0537
# Epoch 245/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0385 - val_loss: 0.0075 - val_mean_absolute_error: 0.0538
# Epoch 246/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0031 - mean_absolute_error: 0.0373 - val_loss: 0.0079 - val_mean_absolute_error: 0.0533
# Epoch 247/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0031 - mean_absolute_error: 0.0374 - val_loss: 0.0077 - val_mean_absolute_error: 0.0540
# Epoch 248/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0383 - val_loss: 0.0073 - val_mean_absolute_error: 0.0558
# Epoch 249/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0391 - val_loss: 0.0074 - val_mean_absolute_error: 0.0540
# Epoch 250/250
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0031 - mean_absolute_error: 0.0372 - val_loss: 0.0074 - val_mean_absolute_error: 0.0529

# %%
# Evaluate the model
train_loss = model.evaluate(X_train, y_train, verbose=0)
print(f'Training Loss: {train_loss}')

test_loss = model.evaluate(X_test, y_test, verbose=0)
print(f'Testing Loss: {test_loss}')
# Out:
# Training Loss: [0.0030461223796010017, 0.03706270456314087]
# Testing Loss: [0.002200337126851082, 0.03385021910071373]

# %%
train_predictions = model.predict(X_train)

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)

#plt.plot(train_predictions)
#plt.plot(y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 8/8 [==============================] - 0s 511us/step

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 1/1 [==============================] - 0s 11ms/step

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 1/1 [==============================] - 0s 11ms/step

# %%
#test_predictions

# %%
# Inverse transform to get actual prices
y_train_actual = scaler.inverse_transform(y_train.reshape(-1, 1))
y_test_actual = scaler.inverse_transform(y_test.reshape(-1, 1))
y_train_pred_actual = scaler.inverse_transform(train_predictions.reshape(-1,1))
y_test_pred_actual = scaler.inverse_transform(test_predictions.reshape(-1,1))
y_val_pred_actual = scaler.inverse_transform(val_predictions.reshape(-1,1))
y_val_actual = scaler.inverse_transform(y_val.reshape(-1,1))

# %%
# Calculate evaluation metrics
train_mae = mean_absolute_error(y_train_actual, y_train_pred_actual)
train_mse = mean_squared_error(y_train_actual, y_train_pred_actual)
val_mae = mean_absolute_error(y_val_actual, y_val_pred_actual)
test_mae = mean_absolute_error(y_test_actual, y_test_pred_actual)
test_mse = mean_squared_error(y_test_actual, y_test_pred_actual)
val_mse = mean_squared_error(y_val_actual, y_val_pred_actual)

print(f'Training MAE: {train_mae}')
print(f'Training MSE: {train_mse}')
print(f'Val MAE: {val_mae}')
print(f'Val MSE: {val_mse}')
print(f'Testing MAE: {test_mae}')
print(f'Testing MSE: {test_mse}')


train_r = np.sqrt(train_mse)
train_r2 = r2_score(y_train_actual, y_train_pred_actual)
test_r = np.sqrt(test_mse)
test_r2 = r2_score(y_test_actual, y_test_pred_actual)
val_r = np.sqrt(val_mse)
val_r2 = r2_score(y_val_actual, y_val_pred_actual)


print(train_r)
print(train_r2)
print(val_r)
print(val_r2)
print(test_r)
print(test_r2)
# Out:
# Training MAE: 16.029621124267578
# Training MSE: 569.7963256835938
# Val MAE: 22.895456314086914
# Val MSE: 1392.8931884765625
# Testing MAE: 14.640216827392578
# Testing MSE: 411.5867919921875
# 23.870407
# 0.9069555309237731
# 37.321484
# 0.8304717003760734
# 20.287601
# 0.7993115813717199

# %%
# Calculate evaluation metrics
train_mae = mean_absolute_error(y_train, train_predictions)
train_mse = mean_squared_error(y_train, train_predictions)
val_mae = mean_absolute_error(y_val, val_predictions)
test_mae = mean_absolute_error(y_test, test_predictions)
test_mse = mean_squared_error(y_test, test_predictions)
val_mse = mean_squared_error(y_val, val_predictions)

print(f'Training MAE: {train_mae}')
print(f'Training MSE: {train_mse}')
print(f'Testing MAE: {test_mae}')
print(f'Testing MSE: {test_mse}')
print(f'Testing MAE: {val_mae}')
print(f'Testing MSE: {val_mse}')

train_r = np.sqrt(train_mse)
train_r2 = r2_score(y_train_actual, y_train_pred_actual)
test_r = np.sqrt(test_mse)
test_r2 = r2_score(y_test_actual, y_test_pred_actual)
val_r = np.sqrt(val_mse)
val_r2 = r2_score(y_val_actual, y_val_pred_actual)


print(train_r)
print(val_r)
print(test_r)
print(train_r2)
print(val_r2)
print(test_r2)
# Out:
# Training MAE: 0.03931098058819771
# Training MSE: 0.0032352623529732227
# Testing MAE: 0.03548557311296463
# Testing MSE: 0.0023003045935183764
# Testing MAE: 0.056559350341558456
# Testing MSE: 0.007438889238983393
# 0.056879368
# 0.086248994
# 0.047961492
# 0.9026494483238845
# 0.8178772464656185
# 0.821485557583796

# %%
model.save('potato_cnn')
# Out:
# INFO:tensorflow:Assets written to: potato_cnn/assets
# INFO:tensorflow:Assets written to: potato_cnn/assets

# %%
import tensorflow as tf
m1=tf.keras.models.load_model('potato_cnn')
m1.layers[0].input_shape
# Out:
# (None, 3, 1)

# %%
test_predictions = m1.predict(X_test).flatten()

y_test_actual = scaler.inverse_transform(y_test.reshape(-1, 1))
y_test_pred_actual = scaler.inverse_transform(test_predictions.reshape(-1,1))

test_r2 = r2_score(y_test_actual, y_test_pred_actual)
print(test_r2)
#plt.plot(dates_test, test_predictions)
#plt.plot(dates_test, y_test)
#plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 1/1 [==============================] - 0s 30ms/step
# 0.7993115813717199

# %%
plt.plot(figsize=(100,100))
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations'])

# %%
from copy import deepcopy

recursive_predictions = []
recursive_dates = np.concatenate([dates_val, dates_test])

for target_date in recursive_dates:
    last_window = deepcopy(X_train[-1])
    next_prediction = model.predict(np.array([last_window])).flatten()
    recursive_predictions.append(next_prediction)
    last_window[-1] = next_prediction
# Out:
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.plot(recursive_dates, recursive_predictions)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations',
            'Recursive Predictions'])

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import EarlyStopping
# Sample DataFrame
#data = {'date': pd.date_range(start='2024-01-01', periods=100),
#        'price': np.random.rand(100)}
#df = pd.DataFrame(data)

# %%
# Normalize the price data
scaler = MinMaxScaler(feature_range=(0, 1))
d['price'] = scaler.fit_transform(d['Rice'].values.reshape(-1,1))

# %%
x=d.pop('Rice')
d
# Out:
#           date     price
# 0   2000-02-01  0.053404
# 1   2000-03-01  0.043292
# 2   2000-04-01  0.049974
# 3   2000-05-01  0.049490
# 4   2000-06-01  0.049135
# ..         ...       ...
# 235 2019-09-01  0.058386
# 236 2019-10-01  0.056683
# 237 2019-11-01  0.075554
# 238 2019-12-01  0.081035
# 239 2020-01-01  0.089746
#
# [240 rows x 2 columns]

# %%
# Function to create sequences for LSTM
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i + seq_length])
        y.append(data[i + seq_length])
    return np.array(X), np.array(y)

# Hyperparameters
sequence_length = 10  # Adjust according to your choice
batch_size = 64
epochs = 100

# Create sequences
X, y = create_sequences(d['price'].values, sequence_length)

# Split the data into training and testing sets
split = int(0.8 * len(X))
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

# Reshape input data for LSTM [samples, time steps, features]
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# %%
# Define the LSTM model
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(sequence_length, 1)))
model.add(LSTM(units=50))
model.add(Dense(units=1))

# %%
# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
# Train the model
model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, verbose=1)
# Define Early Stopping Callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5, verbose=1, restore_best_weights=True)
# Out:
# Epoch 1/100
# 3/3 [==============================] - 1s 6ms/step - loss: 0.0041
# Epoch 2/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0026
# Epoch 3/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0027
# Epoch 4/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0023
# Epoch 5/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0023
# Epoch 6/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 7/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0021
# Epoch 8/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0020
# Epoch 9/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0021
# Epoch 10/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0020
# Epoch 11/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0019
# Epoch 12/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0019
# Epoch 13/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0019
# Epoch 14/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0018
# Epoch 15/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0018
# Epoch 16/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0018
# Epoch 17/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0017
# Epoch 18/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0017
# Epoch 19/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0016
# Epoch 20/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0016
# Epoch 21/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0016
# Epoch 22/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0015
# Epoch 23/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0015
# Epoch 24/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0014
# Epoch 25/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0014
# Epoch 26/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0013
# Epoch 27/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0013
# Epoch 28/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0013
# Epoch 29/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0012
# Epoch 30/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0012
# Epoch 31/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0012
# Epoch 32/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0012
# Epoch 33/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0012
# Epoch 34/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0012
# Epoch 35/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0012
# Epoch 36/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0012
# Epoch 37/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0011
# Epoch 38/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0011
# Epoch 39/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0011
# Epoch 40/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0011
# Epoch 41/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0011
# Epoch 42/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0011
# Epoch 43/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0011
# Epoch 44/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0011
# Epoch 45/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0010
# Epoch 46/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0010
# Epoch 47/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0010
# Epoch 48/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0010
# Epoch 49/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0010
# Epoch 50/100
# 3/3 [==============================] - 0s 6ms/step - loss: 9.9526e-04
# Epoch 51/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0010
# Epoch 52/100
# 3/3 [==============================] - 0s 6ms/step - loss: 9.7158e-04
# Epoch 53/100
# 3/3 [==============================] - 0s 6ms/step - loss: 9.6520e-04
# Epoch 54/100
# 3/3 [==============================] - 0s 6ms/step - loss: 9.5791e-04
# Epoch 55/100
# 3/3 [==============================] - 0s 5ms/step - loss: 9.5454e-04
# Epoch 56/100
# 3/3 [==============================] - 0s 6ms/step - loss: 9.4484e-04
# Epoch 57/100
# 3/3 [==============================] - 0s 6ms/step - loss: 9.3222e-04
# Epoch 58/100
# 3/3 [==============================] - 0s 6ms/step - loss: 9.2266e-04
# Epoch 59/100
# 3/3 [==============================] - 0s 6ms/step - loss: 9.0965e-04
# Epoch 60/100
# 3/3 [==============================] - 0s 5ms/step - loss: 9.0117e-04
# Epoch 61/100
# 3/3 [==============================] - 0s 6ms/step - loss: 8.9130e-04
# Epoch 62/100
# 3/3 [==============================] - 0s 6ms/step - loss: 8.8937e-04
# Epoch 63/100
# 3/3 [==============================] - 0s 5ms/step - loss: 8.7434e-04
# Epoch 64/100
# 3/3 [==============================] - 0s 5ms/step - loss: 8.6231e-04
# Epoch 65/100
# 3/3 [==============================] - 0s 6ms/step - loss: 8.8836e-04
# Epoch 66/100
# 3/3 [==============================] - 0s 5ms/step - loss: 8.4441e-04
# Epoch 67/100
# 3/3 [==============================] - 0s 6ms/step - loss: 8.4663e-04
# Epoch 68/100
# 3/3 [==============================] - 0s 5ms/step - loss: 8.2159e-04
# Epoch 69/100
# 3/3 [==============================] - 0s 5ms/step - loss: 8.1547e-04
# Epoch 70/100
# 3/3 [==============================] - 0s 5ms/step - loss: 8.0546e-04
# Epoch 71/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.9839e-04
# Epoch 72/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.9681e-04
# Epoch 73/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.8139e-04
# Epoch 74/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.7697e-04
# Epoch 75/100
# 3/3 [==============================] - 0s 6ms/step - loss: 7.7261e-04
# Epoch 76/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.6035e-04
# Epoch 77/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.4825e-04
# Epoch 78/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.4420e-04
# Epoch 79/100
# 3/3 [==============================] - 0s 6ms/step - loss: 7.4013e-04
# Epoch 80/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.3297e-04
# Epoch 81/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.3705e-04
# Epoch 82/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.2424e-04
# Epoch 83/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.3513e-04
# Epoch 84/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.0972e-04
# Epoch 85/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.0489e-04
# Epoch 86/100
# 3/3 [==============================] - 0s 5ms/step - loss: 6.9739e-04
# Epoch 87/100
# 3/3 [==============================] - 0s 5ms/step - loss: 6.9600e-04
# Epoch 88/100
# 3/3 [==============================] - 0s 5ms/step - loss: 6.8829e-04
# Epoch 89/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.0131e-04
# Epoch 90/100
# 3/3 [==============================] - 0s 5ms/step - loss: 6.7832e-04
# Epoch 91/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.0200e-04
# Epoch 92/100
# 3/3 [==============================] - 0s 5ms/step - loss: 6.8064e-04
# Epoch 93/100
# 3/3 [==============================] - 0s 6ms/step - loss: 6.7383e-04
# Epoch 94/100
# 3/3 [==============================] - 0s 6ms/step - loss: 6.7962e-04
# Epoch 95/100
# 3/3 [==============================] - 0s 5ms/step - loss: 6.8475e-04
# Epoch 96/100
# 3/3 [==============================] - 0s 5ms/step - loss: 6.8147e-04
# Epoch 97/100
# 3/3 [==============================] - 0s 5ms/step - loss: 6.7189e-04
# Epoch 98/100
# 3/3 [==============================] - 0s 5ms/step - loss: 6.7507e-04
# Epoch 99/100
# 3/3 [==============================] - 0s 5ms/step - loss: 6.7166e-04
# Epoch 100/100
# 3/3 [==============================] - 0s 6ms/step - loss: 7.0050e-04

# %%
# Evaluate the model
train_loss = model.evaluate(X_train, y_train, verbose=0)
print(f'Training Loss: {train_loss}')

test_loss = model.evaluate(X_test, y_test, verbose=0)
print(f'Testing Loss: {test_loss}')
# Out:
# Training Loss: 0.0006569024408236146
# Testing Loss: 0.04776032641530037

# %%
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

# Inverse transform to get actual prices
y_train_actual = scaler.inverse_transform(y_train.reshape(-1, 1))
y_test_actual = scaler.inverse_transform(y_test.reshape(-1, 1))
y_train_pred_actual = scaler.inverse_transform(y_train_pred)
y_test_pred_actual = scaler.inverse_transform(y_test_pred)

# Calculate evaluation metrics
train_mae = mean_absolute_error(y_train_actual, y_train_pred_actual)
train_mse = mean_squared_error(y_train_actual, y_train_pred_actual)
test_mae = mean_absolute_error(y_test_actual, y_test_pred_actual)
test_mse = mean_squared_error(y_test_actual, y_test_pred_actual)
#
train_r = np.sqrt(train_mse)
train_r2 = r2_score(y_train_actual, y_train_pred_actual)
test_r = np.sqrt(test_mse)
test_r2 = r2_score(y_test_actual, y_test_pred_actual)

print(f'Training MAE: {train_mae}')
print(f'Training MSE: {train_mse}')
print(f'Testing MAE: {test_mae}')
print(f'Testing MSE: {test_mse}')
print(train_r)
print(test_r)
print(train_r2)
print(test_r2)
# Out:
# 6/6 [==============================] - 0s 857us/step
# 1/1 [==============================] - 0s 8ms/step
# Training MAE: 15.197800636291504
# Training MSE: 980.4922485351562
# Testing MAE: 217.68800354003906
# Testing MSE: 190393.921875
# 31.312813
# 436.34152
# 0.80162733858064
# 0.20735048207608497

# %%
import matplotlib.pyplot as plt

# Plot actual vs predicted for training set
plt.figure(figsize=(12, 6))
plt.plot(y_train_actual, label='Actual')
plt.plot(y_train_pred_actual, label='Predicted')
plt.title('Actual vs Predicted Prices - Training Set')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()

# Plot actual vs predicted for testing set
plt.figure(figsize=(12, 6))
plt.plot(y_test_actual, label='Actual')
plt.plot(y_test_pred_actual, label='Predicted')
plt.title('Actual vs Predicted Prices - Testing Set')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
d
# Out:
#           date     price
# 0   2000-02-01  0.053404
# 1   2000-03-01  0.043292
# 2   2000-04-01  0.049974
# 3   2000-05-01  0.049490
# 4   2000-06-01  0.049135
# ..         ...       ...
# 235 2019-09-01  0.058386
# 236 2019-10-01  0.056683
# 237 2019-11-01  0.075554
# 238 2019-12-01  0.081035
# 239 2020-01-01  0.089746
#
# [240 rows x 2 columns]
