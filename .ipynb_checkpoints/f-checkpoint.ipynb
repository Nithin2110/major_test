# %%
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.preprocessing import MinMaxScaler
from statsmodels.tsa.stattools import kpss

# %%
df=pd.read_csv("MainD/rice.csv")

# %%
df
# Out:
#                     Date  price
# 0    2000-01-01 00:00:00   89.8
# 1    2000-02-01 00:00:00   77.4
# 2    2000-03-01 00:00:00   83.0
# 3    2000-04-01 00:00:00   81.6
# 4    2000-05-01 00:00:00   88.9
# ..                   ...    ...
# 283  2023-08-01 00:00:00  233.9
# 284  2023-09-01 00:00:00  271.9
# 285  2023-10-01 00:00:00  343.4
# 286  2023-11-01 00:00:00  471.3
# 287  2023-12-01 00:00:00  372.6
#
# [288 rows x 2 columns]

# %%
sn.boxplot(df['price'])
# Out:
# <Axes: >

# %%
t=kpss(df['price'],'ct')
t
# Out:
# /var/folders/35/vcbg9sn9479dqrdl_3fgrrkh0000gn/T/ipykernel_72498/1514378212.py:1: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   t=kpss(df['price'],'ct')
# (0.2919632085948914,
#  0.01,
#  9,
#  {'10%': 0.119, '5%': 0.146, '2.5%': 0.176, '1%': 0.216})

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose

# Assuming df is your DataFrame with a 'date' column and a 'value' column representing the time series
#df['Date'] = pd.to_datetime(df['Date'])
#df.set_index('Date', inplace=True)

# Perform seasonal decomposition
decomposition = seasonal_decompose(df['price'], model='additive')

# Plot the original time series
plt.figure(figsize=(10, 6))
plt.subplot(411)
plt.plot(df['price'], label='Original', color='blue')
plt.legend(loc='upper left')

# Plot the trend component
plt.subplot(412)
plt.plot(decomposition.trend, label='Trend', color='green')
plt.legend(loc='upper left')

# Plot the seasonal component
plt.subplot(413)
plt.plot(decomposition.seasonal, label='Seasonal', color='red')
plt.legend(loc='upper left')

# Plot the residual component
plt.subplot(414)
plt.plot(decomposition.resid, label='Residual', color='purple')
plt.legend(loc='upper left')

plt.tight_layout()
plt.show()

# %%
import statsmodels.api as sm
r=sm.tsa.seasonal_decompose(df['price'],model='additive')
r.plot()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[996], line 2
#       1 import statsmodels.api as sm
# ----> 2 r=sm.tsa.seasonal_decompose(df['Date'],model='additive')
#       3 r.plot()
#
# File ~/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/seasonal.py:149, in seasonal_decompose(x, model, filt, period, two_sided, extrapolate_trend)
#     146 if period is None:
#     147     pfreq = getattr(getattr(x, "index", None), "inferred_freq", None)
# --> 149 x = array_like(x, "x", maxdim=2)
#     150 nobs = len(x)
#     152 if not np.all(np.isfinite(x)):
#
# File ~/anaconda3/lib/python3.11/site-packages/statsmodels/tools/validation/validation.py:143, in array_like(obj, name, dtype, ndim, maxdim, shape, order, contiguous, optional, writeable)
#     141 elif order == "F":
#     142     reqs += ["F"]
# --> 143 arr = np.require(obj, dtype=dtype, requirements=reqs)
#     144 if maxdim is not None:
#     145     if arr.ndim > maxdim:
#
# File ~/anaconda3/lib/python3.11/site-packages/numpy/core/_asarray.py:130, in require(a, dtype, requirements, like)
#     127     order = 'C'
#     128     requirements.remove('C')
# --> 130 arr = array(a, dtype=dtype, order=order, copy=False, subok=subok)
#     132 for prop in requirements:
#     133     if not arr.flags[prop]:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/series.py:893, in Series.__array__(self, dtype)
#     846 def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
#     847     """
#     848     Return the values as a NumPy array.
#     849
#    (...)
#     891           dtype='datetime64[ns]')
#     892     """
# --> 893     return np.asarray(self._values, dtype)
#
# ValueError: could not convert string to float: '2000-01-01 00:00:00'

# %%
#df.drop(239,inplace=True)
#df[df['price']>600]

# %%
df
# Out:
#                     Date  price
# 0    2000-01-01 00:00:00   89.8
# 1    2000-02-01 00:00:00   77.4
# 2    2000-03-01 00:00:00   83.0
# 3    2000-04-01 00:00:00   81.6
# 4    2000-05-01 00:00:00   88.9
# ..                   ...    ...
# 283  2023-08-01 00:00:00  233.9
# 284  2023-09-01 00:00:00  271.9
# 285  2023-10-01 00:00:00  343.4
# 286  2023-11-01 00:00:00  471.3
# 287  2023-12-01 00:00:00  372.6
#
# [279 rows x 2 columns]

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
df['price'] = scaler.fit_transform(df['price'].values.reshape(-1,1))

# %%
import matplotlib.pyplot as plt
plt.plot(df['Date'],df['price'])

# %%
# Convert 'date' column to datetime if it's not already
# Shift the 'price' column to create new columns
df['target-1'] = df['price'].shift(1)
df['target-2'] = df['price'].shift(2)
df['target-3'] = df['price'].shift(3)
#df['target-4'] = df['price'].shift(4)
#df['target-5'] = df['price'].shift(5)

# %%
d=df[3:]
d
# Out:
#                     Date     price  target-1  target-2  target-3
# 3    2000-04-01 00:00:00  0.005467  0.007290  0.000000  0.016142
# 4    2000-05-01 00:00:00  0.014970  0.005467  0.007290  0.000000
# 5    2000-06-01 00:00:00  0.022130  0.014970  0.005467  0.007290
# 6    2000-07-01 00:00:00  0.005858  0.022130  0.014970  0.005467
# 7    2000-08-01 00:00:00  0.007029  0.005858  0.022130  0.014970
# ..                   ...       ...       ...       ...       ...
# 283  2023-08-01 00:00:00  0.203723  0.139156  0.087217  0.067430
# 284  2023-09-01 00:00:00  0.253189  0.203723  0.139156  0.087217
# 285  2023-10-01 00:00:00  0.346264  0.253189  0.203723  0.139156
# 286  2023-11-01 00:00:00  0.512757  0.346264  0.253189  0.203723
# 287  2023-12-01 00:00:00  0.384275  0.512757  0.346264  0.253189
#
# [285 rows x 5 columns]

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
    df_as_np = windowed_dataframe.to_numpy()
    dates = df_as_np[:, 0]
    middle_matrix = df_as_np[:, 1:-1]
    X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))
    Y = df_as_np[:, -1]
    return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(d)

dates.shape, X.shape, y.shape
# Out:
# ((285,), (285, 3, 1), (285,))

# %%
#y

# %%
#dates
#X
#y

# %%
q_80 = int(len(dates) * .8)
q_90 = int(len(dates) * .9)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %%
X_train.shape,
# Out:
# ((228, 3, 1),)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers.legacy import Adam
from tensorflow.keras import layers
from keras.callbacks import EarlyStopping

#early_stopping = EarlyStopping(monitor='val_loss', patience=10, mode='min')

model = Sequential([layers.Input((3, 1)),
                    #layers.GRU(64),
                    #layers.LSTM(32, return_sequences=True),
                    #layers.LSTM(32),
                    #layers.Bidirectional(layers.LSTM(64)),
                    layers.Conv1D(filters=64, kernel_size=3, activation='relu'),  # 1D Convolutional layer
                    #layers.MaxPooling1D(pool_size=2),  # MaxPooling layer
                    layers.Flatten(),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)
                   ])

model.compile(loss='mse', 
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=190)
# Out:
# Epoch 1/190
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0504 - mean_absolute_error: 0.1545 - val_loss: 0.0471 - val_mean_absolute_error: 0.1424
# Epoch 2/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0250 - mean_absolute_error: 0.0964 - val_loss: 0.0289 - val_mean_absolute_error: 0.1277
# Epoch 3/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0166 - mean_absolute_error: 0.0933 - val_loss: 0.0259 - val_mean_absolute_error: 0.1258
# Epoch 4/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0130 - mean_absolute_error: 0.0782 - val_loss: 0.0233 - val_mean_absolute_error: 0.1103
# Epoch 5/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0110 - mean_absolute_error: 0.0649 - val_loss: 0.0203 - val_mean_absolute_error: 0.1008
# Epoch 6/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0088 - mean_absolute_error: 0.0559 - val_loss: 0.0177 - val_mean_absolute_error: 0.0911
# Epoch 7/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0075 - mean_absolute_error: 0.0537 - val_loss: 0.0158 - val_mean_absolute_error: 0.0858
# Epoch 8/190
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0063 - mean_absolute_error: 0.0451 - val_loss: 0.0143 - val_mean_absolute_error: 0.0837
# Epoch 9/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0061 - mean_absolute_error: 0.0509 - val_loss: 0.0137 - val_mean_absolute_error: 0.0778
# Epoch 10/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0051 - mean_absolute_error: 0.0419 - val_loss: 0.0133 - val_mean_absolute_error: 0.0799
# Epoch 11/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0434 - val_loss: 0.0136 - val_mean_absolute_error: 0.0789
# Epoch 12/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0054 - mean_absolute_error: 0.0446 - val_loss: 0.0134 - val_mean_absolute_error: 0.0850
# Epoch 13/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0053 - mean_absolute_error: 0.0490 - val_loss: 0.0133 - val_mean_absolute_error: 0.0774
# Epoch 14/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0047 - mean_absolute_error: 0.0411 - val_loss: 0.0130 - val_mean_absolute_error: 0.0777
# Epoch 15/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0044 - mean_absolute_error: 0.0417 - val_loss: 0.0135 - val_mean_absolute_error: 0.0789
# Epoch 16/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0047 - mean_absolute_error: 0.0411 - val_loss: 0.0130 - val_mean_absolute_error: 0.0791
# Epoch 17/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0045 - mean_absolute_error: 0.0422 - val_loss: 0.0129 - val_mean_absolute_error: 0.0759
# Epoch 18/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0042 - mean_absolute_error: 0.0394 - val_loss: 0.0128 - val_mean_absolute_error: 0.0754
# Epoch 19/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0042 - mean_absolute_error: 0.0400 - val_loss: 0.0129 - val_mean_absolute_error: 0.0756
# Epoch 20/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0044 - mean_absolute_error: 0.0410 - val_loss: 0.0123 - val_mean_absolute_error: 0.0756
# Epoch 21/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0042 - mean_absolute_error: 0.0419 - val_loss: 0.0126 - val_mean_absolute_error: 0.0749
# Epoch 22/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0047 - mean_absolute_error: 0.0473 - val_loss: 0.0130 - val_mean_absolute_error: 0.0756
# Epoch 23/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0043 - mean_absolute_error: 0.0410 - val_loss: 0.0130 - val_mean_absolute_error: 0.0743
# Epoch 24/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0040 - mean_absolute_error: 0.0376 - val_loss: 0.0127 - val_mean_absolute_error: 0.0737
# Epoch 25/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0038 - mean_absolute_error: 0.0374 - val_loss: 0.0125 - val_mean_absolute_error: 0.0734
# Epoch 26/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0039 - mean_absolute_error: 0.0389 - val_loss: 0.0126 - val_mean_absolute_error: 0.0737
# Epoch 27/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0039 - mean_absolute_error: 0.0371 - val_loss: 0.0125 - val_mean_absolute_error: 0.0756
# Epoch 28/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0038 - mean_absolute_error: 0.0387 - val_loss: 0.0125 - val_mean_absolute_error: 0.0738
# Epoch 29/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0038 - mean_absolute_error: 0.0369 - val_loss: 0.0125 - val_mean_absolute_error: 0.0740
# Epoch 30/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0038 - mean_absolute_error: 0.0368 - val_loss: 0.0126 - val_mean_absolute_error: 0.0754
# Epoch 31/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0042 - mean_absolute_error: 0.0442 - val_loss: 0.0127 - val_mean_absolute_error: 0.0766
# Epoch 32/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0041 - mean_absolute_error: 0.0399 - val_loss: 0.0124 - val_mean_absolute_error: 0.0728
# Epoch 33/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0038 - mean_absolute_error: 0.0383 - val_loss: 0.0123 - val_mean_absolute_error: 0.0729
# Epoch 34/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0036 - mean_absolute_error: 0.0364 - val_loss: 0.0131 - val_mean_absolute_error: 0.0749
# Epoch 35/190
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0042 - mean_absolute_error: 0.0414 - val_loss: 0.0137 - val_mean_absolute_error: 0.0838
# Epoch 36/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0042 - mean_absolute_error: 0.0428 - val_loss: 0.0130 - val_mean_absolute_error: 0.0768
# Epoch 37/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0040 - mean_absolute_error: 0.0419 - val_loss: 0.0128 - val_mean_absolute_error: 0.0773
# Epoch 38/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0036 - mean_absolute_error: 0.0365 - val_loss: 0.0124 - val_mean_absolute_error: 0.0740
# Epoch 39/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0036 - mean_absolute_error: 0.0360 - val_loss: 0.0123 - val_mean_absolute_error: 0.0741
# Epoch 40/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0036 - mean_absolute_error: 0.0374 - val_loss: 0.0127 - val_mean_absolute_error: 0.0743
# Epoch 41/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0035 - mean_absolute_error: 0.0353 - val_loss: 0.0125 - val_mean_absolute_error: 0.0742
# Epoch 42/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0034 - mean_absolute_error: 0.0359 - val_loss: 0.0120 - val_mean_absolute_error: 0.0740
# Epoch 43/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0035 - mean_absolute_error: 0.0366 - val_loss: 0.0117 - val_mean_absolute_error: 0.0741
# Epoch 44/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0035 - mean_absolute_error: 0.0358 - val_loss: 0.0117 - val_mean_absolute_error: 0.0735
# Epoch 45/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0034 - mean_absolute_error: 0.0357 - val_loss: 0.0119 - val_mean_absolute_error: 0.0729
# Epoch 46/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0034 - mean_absolute_error: 0.0355 - val_loss: 0.0124 - val_mean_absolute_error: 0.0741
# Epoch 47/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0034 - mean_absolute_error: 0.0359 - val_loss: 0.0125 - val_mean_absolute_error: 0.0771
# Epoch 48/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0036 - mean_absolute_error: 0.0372 - val_loss: 0.0124 - val_mean_absolute_error: 0.0769
# Epoch 49/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0036 - mean_absolute_error: 0.0393 - val_loss: 0.0124 - val_mean_absolute_error: 0.0767
# Epoch 50/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0036 - mean_absolute_error: 0.0366 - val_loss: 0.0123 - val_mean_absolute_error: 0.0774
# Epoch 51/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0036 - mean_absolute_error: 0.0374 - val_loss: 0.0120 - val_mean_absolute_error: 0.0742
# Epoch 52/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0036 - mean_absolute_error: 0.0382 - val_loss: 0.0120 - val_mean_absolute_error: 0.0737
# Epoch 53/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_error: 0.0345 - val_loss: 0.0124 - val_mean_absolute_error: 0.0742
# Epoch 54/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_error: 0.0346 - val_loss: 0.0125 - val_mean_absolute_error: 0.0756
# Epoch 55/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0039 - mean_absolute_error: 0.0384 - val_loss: 0.0125 - val_mean_absolute_error: 0.0826
# Epoch 56/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0036 - mean_absolute_error: 0.0412 - val_loss: 0.0123 - val_mean_absolute_error: 0.0757
# Epoch 57/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0036 - mean_absolute_error: 0.0369 - val_loss: 0.0125 - val_mean_absolute_error: 0.0752
# Epoch 58/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_error: 0.0354 - val_loss: 0.0127 - val_mean_absolute_error: 0.0783
# Epoch 59/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0036 - mean_absolute_error: 0.0376 - val_loss: 0.0123 - val_mean_absolute_error: 0.0778
# Epoch 60/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0039 - mean_absolute_error: 0.0393 - val_loss: 0.0119 - val_mean_absolute_error: 0.0752
# Epoch 61/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0035 - mean_absolute_error: 0.0398 - val_loss: 0.0121 - val_mean_absolute_error: 0.0752
# Epoch 62/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0034 - mean_absolute_error: 0.0353 - val_loss: 0.0125 - val_mean_absolute_error: 0.0761
# Epoch 63/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_error: 0.0363 - val_loss: 0.0124 - val_mean_absolute_error: 0.0763
# Epoch 64/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0036 - mean_absolute_error: 0.0376 - val_loss: 0.0120 - val_mean_absolute_error: 0.0792
# Epoch 65/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0035 - mean_absolute_error: 0.0386 - val_loss: 0.0120 - val_mean_absolute_error: 0.0759
# Epoch 66/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0359 - val_loss: 0.0123 - val_mean_absolute_error: 0.0762
# Epoch 67/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_error: 0.0352 - val_loss: 0.0126 - val_mean_absolute_error: 0.0798
# Epoch 68/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0348 - val_loss: 0.0122 - val_mean_absolute_error: 0.0765
# Epoch 69/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0031 - mean_absolute_error: 0.0346 - val_loss: 0.0122 - val_mean_absolute_error: 0.0761
# Epoch 70/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0034 - mean_absolute_error: 0.0369 - val_loss: 0.0123 - val_mean_absolute_error: 0.0762
# Epoch 71/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0035 - mean_absolute_error: 0.0382 - val_loss: 0.0121 - val_mean_absolute_error: 0.0759
# Epoch 72/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0034 - mean_absolute_error: 0.0361 - val_loss: 0.0120 - val_mean_absolute_error: 0.0776
# Epoch 73/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0354 - val_loss: 0.0121 - val_mean_absolute_error: 0.0759
# Epoch 74/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0343 - val_loss: 0.0123 - val_mean_absolute_error: 0.0791
# Epoch 75/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_error: 0.0377 - val_loss: 0.0126 - val_mean_absolute_error: 0.0780
# Epoch 76/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0034 - mean_absolute_error: 0.0366 - val_loss: 0.0124 - val_mean_absolute_error: 0.0776
# Epoch 77/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0034 - mean_absolute_error: 0.0361 - val_loss: 0.0123 - val_mean_absolute_error: 0.0769
# Epoch 78/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0354 - val_loss: 0.0121 - val_mean_absolute_error: 0.0776
# Epoch 79/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0036 - mean_absolute_error: 0.0363 - val_loss: 0.0120 - val_mean_absolute_error: 0.0799
# Epoch 80/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0041 - mean_absolute_error: 0.0441 - val_loss: 0.0128 - val_mean_absolute_error: 0.0805
# Epoch 81/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0035 - mean_absolute_error: 0.0381 - val_loss: 0.0122 - val_mean_absolute_error: 0.0784
# Epoch 82/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0366 - val_loss: 0.0125 - val_mean_absolute_error: 0.0777
# Epoch 83/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0034 - mean_absolute_error: 0.0374 - val_loss: 0.0124 - val_mean_absolute_error: 0.0780
# Epoch 84/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0347 - val_loss: 0.0125 - val_mean_absolute_error: 0.0777
# Epoch 85/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0345 - val_loss: 0.0123 - val_mean_absolute_error: 0.0797
# Epoch 86/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0034 - mean_absolute_error: 0.0370 - val_loss: 0.0120 - val_mean_absolute_error: 0.0759
# Epoch 87/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0348 - val_loss: 0.0121 - val_mean_absolute_error: 0.0759
# Epoch 88/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0034 - mean_absolute_error: 0.0351 - val_loss: 0.0123 - val_mean_absolute_error: 0.0814
# Epoch 89/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0042 - mean_absolute_error: 0.0455 - val_loss: 0.0125 - val_mean_absolute_error: 0.0775
# Epoch 90/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0035 - mean_absolute_error: 0.0372 - val_loss: 0.0122 - val_mean_absolute_error: 0.0796
# Epoch 91/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0035 - mean_absolute_error: 0.0371 - val_loss: 0.0120 - val_mean_absolute_error: 0.0771
# Epoch 92/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_error: 0.0367 - val_loss: 0.0122 - val_mean_absolute_error: 0.0774
# Epoch 93/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0031 - mean_absolute_error: 0.0340 - val_loss: 0.0122 - val_mean_absolute_error: 0.0763
# Epoch 94/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0031 - mean_absolute_error: 0.0352 - val_loss: 0.0126 - val_mean_absolute_error: 0.0782
# Epoch 95/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0051 - mean_absolute_error: 0.0448 - val_loss: 0.0119 - val_mean_absolute_error: 0.0859
# Epoch 96/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0526 - val_loss: 0.0118 - val_mean_absolute_error: 0.0745
# Epoch 97/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0040 - mean_absolute_error: 0.0402 - val_loss: 0.0122 - val_mean_absolute_error: 0.0775
# Epoch 98/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0043 - mean_absolute_error: 0.0455 - val_loss: 0.0133 - val_mean_absolute_error: 0.0820
# Epoch 99/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0037 - mean_absolute_error: 0.0378 - val_loss: 0.0134 - val_mean_absolute_error: 0.0786
# Epoch 100/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0037 - mean_absolute_error: 0.0399 - val_loss: 0.0111 - val_mean_absolute_error: 0.0732
# Epoch 101/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0034 - mean_absolute_error: 0.0375 - val_loss: 0.0109 - val_mean_absolute_error: 0.0740
# Epoch 102/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0034 - mean_absolute_error: 0.0355 - val_loss: 0.0115 - val_mean_absolute_error: 0.0746
# Epoch 103/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0031 - mean_absolute_error: 0.0343 - val_loss: 0.0120 - val_mean_absolute_error: 0.0755
# Epoch 104/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0031 - mean_absolute_error: 0.0347 - val_loss: 0.0123 - val_mean_absolute_error: 0.0756
# Epoch 105/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0348 - val_loss: 0.0123 - val_mean_absolute_error: 0.0760
# Epoch 106/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0031 - mean_absolute_error: 0.0347 - val_loss: 0.0122 - val_mean_absolute_error: 0.0770
# Epoch 107/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0030 - mean_absolute_error: 0.0352 - val_loss: 0.0121 - val_mean_absolute_error: 0.0773
# Epoch 108/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0348 - val_loss: 0.0125 - val_mean_absolute_error: 0.0792
# Epoch 109/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_error: 0.0377 - val_loss: 0.0123 - val_mean_absolute_error: 0.0772
# Epoch 110/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0031 - mean_absolute_error: 0.0345 - val_loss: 0.0122 - val_mean_absolute_error: 0.0772
# Epoch 111/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0030 - mean_absolute_error: 0.0355 - val_loss: 0.0122 - val_mean_absolute_error: 0.0769
# Epoch 112/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0034 - mean_absolute_error: 0.0367 - val_loss: 0.0122 - val_mean_absolute_error: 0.0796
# Epoch 113/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0035 - mean_absolute_error: 0.0397 - val_loss: 0.0127 - val_mean_absolute_error: 0.0790
# Epoch 114/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0039 - mean_absolute_error: 0.0407 - val_loss: 0.0127 - val_mean_absolute_error: 0.0831
# Epoch 115/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0038 - mean_absolute_error: 0.0431 - val_loss: 0.0123 - val_mean_absolute_error: 0.0776
# Epoch 116/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0035 - mean_absolute_error: 0.0370 - val_loss: 0.0121 - val_mean_absolute_error: 0.0784
# Epoch 117/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0031 - mean_absolute_error: 0.0351 - val_loss: 0.0123 - val_mean_absolute_error: 0.0774
# Epoch 118/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_error: 0.0350 - val_loss: 0.0123 - val_mean_absolute_error: 0.0774
# Epoch 119/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0031 - mean_absolute_error: 0.0340 - val_loss: 0.0120 - val_mean_absolute_error: 0.0769
# Epoch 120/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0029 - mean_absolute_error: 0.0336 - val_loss: 0.0119 - val_mean_absolute_error: 0.0767
# Epoch 121/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0030 - mean_absolute_error: 0.0339 - val_loss: 0.0119 - val_mean_absolute_error: 0.0763
# Epoch 122/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0031 - mean_absolute_error: 0.0342 - val_loss: 0.0121 - val_mean_absolute_error: 0.0766
# Epoch 123/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0030 - mean_absolute_error: 0.0340 - val_loss: 0.0120 - val_mean_absolute_error: 0.0775
# Epoch 124/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0365 - val_loss: 0.0121 - val_mean_absolute_error: 0.0770
# Epoch 125/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0030 - mean_absolute_error: 0.0335 - val_loss: 0.0122 - val_mean_absolute_error: 0.0776
# Epoch 126/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0029 - mean_absolute_error: 0.0335 - val_loss: 0.0134 - val_mean_absolute_error: 0.0794
# Epoch 127/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0031 - mean_absolute_error: 0.0343 - val_loss: 0.0136 - val_mean_absolute_error: 0.0797
# Epoch 128/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0030 - mean_absolute_error: 0.0331 - val_loss: 0.0130 - val_mean_absolute_error: 0.0799
# Epoch 129/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_error: 0.0379 - val_loss: 0.0128 - val_mean_absolute_error: 0.0771
# Epoch 130/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0030 - mean_absolute_error: 0.0342 - val_loss: 0.0123 - val_mean_absolute_error: 0.0767
# Epoch 131/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0030 - mean_absolute_error: 0.0343 - val_loss: 0.0118 - val_mean_absolute_error: 0.0763
# Epoch 132/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0029 - mean_absolute_error: 0.0334 - val_loss: 0.0120 - val_mean_absolute_error: 0.0761
# Epoch 133/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0339 - val_loss: 0.0136 - val_mean_absolute_error: 0.0791
# Epoch 134/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0346 - val_loss: 0.0133 - val_mean_absolute_error: 0.0779
# Epoch 135/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0031 - mean_absolute_error: 0.0363 - val_loss: 0.0126 - val_mean_absolute_error: 0.0775
# Epoch 136/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0034 - mean_absolute_error: 0.0360 - val_loss: 0.0132 - val_mean_absolute_error: 0.0837
# Epoch 137/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0034 - mean_absolute_error: 0.0387 - val_loss: 0.0127 - val_mean_absolute_error: 0.0782
# Epoch 138/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0030 - mean_absolute_error: 0.0334 - val_loss: 0.0125 - val_mean_absolute_error: 0.0778
# Epoch 139/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0030 - mean_absolute_error: 0.0340 - val_loss: 0.0122 - val_mean_absolute_error: 0.0761
# Epoch 140/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0031 - mean_absolute_error: 0.0369 - val_loss: 0.0118 - val_mean_absolute_error: 0.0762
# Epoch 141/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0031 - mean_absolute_error: 0.0340 - val_loss: 0.0117 - val_mean_absolute_error: 0.0761
# Epoch 142/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0030 - mean_absolute_error: 0.0356 - val_loss: 0.0114 - val_mean_absolute_error: 0.0749
# Epoch 143/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0344 - val_loss: 0.0118 - val_mean_absolute_error: 0.0782
# Epoch 144/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0034 - mean_absolute_error: 0.0395 - val_loss: 0.0126 - val_mean_absolute_error: 0.0774
# Epoch 145/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0030 - mean_absolute_error: 0.0330 - val_loss: 0.0123 - val_mean_absolute_error: 0.0758
# Epoch 146/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0030 - mean_absolute_error: 0.0338 - val_loss: 0.0111 - val_mean_absolute_error: 0.0749
# Epoch 147/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0035 - mean_absolute_error: 0.0399 - val_loss: 0.0122 - val_mean_absolute_error: 0.0764
# Epoch 148/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0363 - val_loss: 0.0125 - val_mean_absolute_error: 0.0765
# Epoch 149/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0030 - mean_absolute_error: 0.0340 - val_loss: 0.0122 - val_mean_absolute_error: 0.0772
# Epoch 150/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0030 - mean_absolute_error: 0.0341 - val_loss: 0.0117 - val_mean_absolute_error: 0.0772
# Epoch 151/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0346 - val_loss: 0.0119 - val_mean_absolute_error: 0.0806
# Epoch 152/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0038 - mean_absolute_error: 0.0434 - val_loss: 0.0134 - val_mean_absolute_error: 0.0811
# Epoch 153/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0036 - mean_absolute_error: 0.0377 - val_loss: 0.0132 - val_mean_absolute_error: 0.0809
# Epoch 154/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0355 - val_loss: 0.0123 - val_mean_absolute_error: 0.0776
# Epoch 155/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0045 - mean_absolute_error: 0.0472 - val_loss: 0.0131 - val_mean_absolute_error: 0.0818
# Epoch 156/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0041 - mean_absolute_error: 0.0441 - val_loss: 0.0116 - val_mean_absolute_error: 0.0752
# Epoch 157/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_error: 0.0385 - val_loss: 0.0116 - val_mean_absolute_error: 0.0753
# Epoch 158/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_error: 0.0365 - val_loss: 0.0116 - val_mean_absolute_error: 0.0759
# Epoch 159/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0030 - mean_absolute_error: 0.0350 - val_loss: 0.0117 - val_mean_absolute_error: 0.0752
# Epoch 160/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0029 - mean_absolute_error: 0.0333 - val_loss: 0.0119 - val_mean_absolute_error: 0.0764
# Epoch 161/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0029 - mean_absolute_error: 0.0330 - val_loss: 0.0122 - val_mean_absolute_error: 0.0770
# Epoch 162/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0029 - mean_absolute_error: 0.0332 - val_loss: 0.0122 - val_mean_absolute_error: 0.0779
# Epoch 163/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0029 - mean_absolute_error: 0.0334 - val_loss: 0.0125 - val_mean_absolute_error: 0.0779
# Epoch 164/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0031 - mean_absolute_error: 0.0336 - val_loss: 0.0127 - val_mean_absolute_error: 0.0805
# Epoch 165/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0369 - val_loss: 0.0124 - val_mean_absolute_error: 0.0777
# Epoch 166/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_error: 0.0362 - val_loss: 0.0120 - val_mean_absolute_error: 0.0772
# Epoch 167/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0029 - mean_absolute_error: 0.0328 - val_loss: 0.0115 - val_mean_absolute_error: 0.0753
# Epoch 168/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0030 - mean_absolute_error: 0.0333 - val_loss: 0.0115 - val_mean_absolute_error: 0.0758
# Epoch 169/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0030 - mean_absolute_error: 0.0331 - val_loss: 0.0116 - val_mean_absolute_error: 0.0767
# Epoch 170/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0029 - mean_absolute_error: 0.0343 - val_loss: 0.0121 - val_mean_absolute_error: 0.0770
# Epoch 171/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0029 - mean_absolute_error: 0.0327 - val_loss: 0.0126 - val_mean_absolute_error: 0.0776
# Epoch 172/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0031 - mean_absolute_error: 0.0355 - val_loss: 0.0123 - val_mean_absolute_error: 0.0768
# Epoch 173/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0030 - mean_absolute_error: 0.0332 - val_loss: 0.0113 - val_mean_absolute_error: 0.0759
# Epoch 174/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0030 - mean_absolute_error: 0.0336 - val_loss: 0.0115 - val_mean_absolute_error: 0.0764
# Epoch 175/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0030 - mean_absolute_error: 0.0348 - val_loss: 0.0120 - val_mean_absolute_error: 0.0763
# Epoch 176/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0028 - mean_absolute_error: 0.0323 - val_loss: 0.0120 - val_mean_absolute_error: 0.0762
# Epoch 177/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0029 - mean_absolute_error: 0.0329 - val_loss: 0.0121 - val_mean_absolute_error: 0.0760
# Epoch 178/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0029 - mean_absolute_error: 0.0340 - val_loss: 0.0118 - val_mean_absolute_error: 0.0763
# Epoch 179/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0028 - mean_absolute_error: 0.0323 - val_loss: 0.0120 - val_mean_absolute_error: 0.0764
# Epoch 180/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0029 - mean_absolute_error: 0.0333 - val_loss: 0.0124 - val_mean_absolute_error: 0.0770
# Epoch 181/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0030 - mean_absolute_error: 0.0339 - val_loss: 0.0126 - val_mean_absolute_error: 0.0790
# Epoch 182/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0030 - mean_absolute_error: 0.0351 - val_loss: 0.0124 - val_mean_absolute_error: 0.0778
# Epoch 183/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0029 - mean_absolute_error: 0.0328 - val_loss: 0.0121 - val_mean_absolute_error: 0.0777
# Epoch 184/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0028 - mean_absolute_error: 0.0320 - val_loss: 0.0117 - val_mean_absolute_error: 0.0761
# Epoch 185/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0029 - mean_absolute_error: 0.0331 - val_loss: 0.0118 - val_mean_absolute_error: 0.0761
# Epoch 186/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0347 - val_loss: 0.0123 - val_mean_absolute_error: 0.0781
# Epoch 187/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0029 - mean_absolute_error: 0.0340 - val_loss: 0.0123 - val_mean_absolute_error: 0.0779
# Epoch 188/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0030 - mean_absolute_error: 0.0333 - val_loss: 0.0123 - val_mean_absolute_error: 0.0783
# Epoch 189/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0028 - mean_absolute_error: 0.0328 - val_loss: 0.0121 - val_mean_absolute_error: 0.0770
# Epoch 190/190
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0028 - mean_absolute_error: 0.0325 - val_loss: 0.0122 - val_mean_absolute_error: 0.0769

# %%
# Evaluate the model
train_loss = model.evaluate(X_train, y_train, verbose=0)
print(f'Training Loss: {train_loss}')

test_loss = model.evaluate(X_test, y_test, verbose=0)
print(f'Testing Loss: {test_loss}')
# Out:
# Training Loss: [0.0027586042415350676, 0.03185956925153732]
# Testing Loss: [0.001415338832885027, 0.028456401079893112]

# %%
train_predictions = model.predict(X_train)

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)

#plt.plot(train_predictions)
#plt.plot(y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 8/8 [==============================] - 0s 603us/step

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 1/1 [==============================] - 0s 11ms/step

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 1/1 [==============================] - 0s 12ms/step

# %%
#test_predictions

# %%
# Inverse transform to get actual prices
y_train_actual = scaler.inverse_transform(y_train.reshape(-1, 1))
y_test_actual = scaler.inverse_transform(y_test.reshape(-1, 1))
y_train_pred_actual = scaler.inverse_transform(train_predictions.reshape(-1,1))
y_test_pred_actual = scaler.inverse_transform(test_predictions.reshape(-1,1))
y_val_pred_actual = scaler.inverse_transform(val_predictions.reshape(-1,1))
y_val_actual = scaler.inverse_transform(y_val.reshape(-1,1))

# %%
# Calculate evaluation metrics
train_mae = mean_absolute_error(y_train_actual, y_train_pred_actual)
train_mse = mean_squared_error(y_train_actual, y_train_pred_actual)
val_mae = mean_absolute_error(y_val_actual, y_val_pred_actual)
test_mae = mean_absolute_error(y_test_actual, y_test_pred_actual)
test_mse = mean_squared_error(y_test_actual, y_test_pred_actual)
val_mse = mean_squared_error(y_val_actual, y_val_pred_actual)

print(f'Training MAE: {train_mae}')
print(f'Training MSE: {train_mse}')
print(f'Testing MAE: {test_mae}')
print(f'Testing MSE: {test_mse}')
print(f'Testing MAE: {val_mae}')
print(f'Testing MSE: {val_mse}')

train_r = np.sqrt(train_mse)
train_r2 = r2_score(y_train_actual, y_train_pred_actual)
test_r = np.sqrt(test_mse)
test_r2 = r2_score(y_test_actual, y_test_pred_actual)
val_r = np.sqrt(val_mse)
val_r2 = r2_score(y_val_actual, y_val_pred_actual)


print(train_r)
print(val_r)
print(test_r)
print(train_r2)
print(val_r2)
print(test_r2)
# Out:
# Training MAE: 24.474519729614258
# Training MSE: 1627.9384765625
# Testing MAE: 21.86020851135254
# Testing MSE: 835.2359008789062
# Testing MAE: 59.10693359375
# Testing MSE: 7180.05859375
# 40.34772
# 84.73523
# 28.900448
# 0.9070695040600518
# 0.6589609973064847
# 0.6554970760327132

# %%
# Calculate evaluation metrics
train_mae = mean_absolute_error(y_train, train_predictions)
train_mse = mean_squared_error(y_train, train_predictions)
val_mae = mean_absolute_error(y_val, val_predictions)
test_mae = mean_absolute_error(y_test, test_predictions)
test_mse = mean_squared_error(y_test, test_predictions)
val_mse = mean_squared_error(y_val, val_predictions)

print(f'Training MAE: {train_mae}')
print(f'Training MSE: {train_mse}')
print(f'Testing MAE: {test_mae}')
print(f'Testing MSE: {test_mse}')
print(f'Testing MAE: {val_mae}')
print(f'Testing MSE: {val_mse}')

train_r = np.sqrt(train_mse)
train_r2 = r2_score(y_train_actual, y_train_pred_actual)
test_r = np.sqrt(test_mse)
test_r2 = r2_score(y_test_actual, y_test_pred_actual)
val_r = np.sqrt(val_mse)
val_r2 = r2_score(y_val_actual, y_val_pred_actual)


print(train_r)
print(val_r)
print(test_r)
print(train_r2)
print(val_r2)
print(test_r2)
# Out:
# Training MAE: 0.03185957297682762
# Training MSE: 0.0027586042415350676
# Testing MAE: 0.02845640666782856
# Testing MSE: 0.001415338832885027
# Testing MAE: 0.0769420936703682
# Testing MSE: 0.012166881002485752
# 0.052522417
# 0.11030359
# 0.037620988
# 0.9070695040600518
# 0.6589609973064847
# 0.6554970760327132

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations'])

# %%
from copy import deepcopy

recursive_predictions = []
recursive_dates = np.concatenate([dates_val, dates_test])

for target_date in recursive_dates:
    last_window = deepcopy(X_train[-1])
    next_prediction = model.predict(np.array([last_window])).flatten()
    recursive_predictions.append(next_prediction)
    last_window[-1] = next_prediction
# Out:
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.plot(recursive_dates, recursive_predictions)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations',
            'Recursive Predictions'])

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import EarlyStopping
# Sample DataFrame
#data = {'date': pd.date_range(start='2024-01-01', periods=100),
#        'price': np.random.rand(100)}
#df = pd.DataFrame(data)

# %%
# Normalize the price data
scaler = MinMaxScaler(feature_range=(0, 1))
d['price'] = scaler.fit_transform(d['Rice'].values.reshape(-1,1))

# %%
x=d.pop('Rice')
d
# Out:
#           date     price
# 0   2000-02-01  0.053404
# 1   2000-03-01  0.043292
# 2   2000-04-01  0.049974
# 3   2000-05-01  0.049490
# 4   2000-06-01  0.049135
# ..         ...       ...
# 235 2019-09-01  0.058386
# 236 2019-10-01  0.056683
# 237 2019-11-01  0.075554
# 238 2019-12-01  0.081035
# 239 2020-01-01  0.089746
#
# [240 rows x 2 columns]

# %%
# Function to create sequences for LSTM
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i + seq_length])
        y.append(data[i + seq_length])
    return np.array(X), np.array(y)

# Hyperparameters
sequence_length = 10  # Adjust according to your choice
batch_size = 64
epochs = 100

# Create sequences
X, y = create_sequences(d['price'].values, sequence_length)

# Split the data into training and testing sets
split = int(0.8 * len(X))
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

# Reshape input data for LSTM [samples, time steps, features]
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# %%
# Define the LSTM model
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(sequence_length, 1)))
model.add(LSTM(units=50))
model.add(Dense(units=1))

# %%
# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
# Train the model
model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, verbose=1)
# Define Early Stopping Callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5, verbose=1, restore_best_weights=True)
# Out:
# Epoch 1/100
# 3/3 [==============================] - 1s 6ms/step - loss: 0.0041
# Epoch 2/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0026
# Epoch 3/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0027
# Epoch 4/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0023
# Epoch 5/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0023
# Epoch 6/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 7/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0021
# Epoch 8/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0020
# Epoch 9/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0021
# Epoch 10/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0020
# Epoch 11/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0019
# Epoch 12/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0019
# Epoch 13/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0019
# Epoch 14/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0018
# Epoch 15/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0018
# Epoch 16/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0018
# Epoch 17/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0017
# Epoch 18/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0017
# Epoch 19/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0016
# Epoch 20/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0016
# Epoch 21/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0016
# Epoch 22/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0015
# Epoch 23/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0015
# Epoch 24/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0014
# Epoch 25/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0014
# Epoch 26/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0013
# Epoch 27/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0013
# Epoch 28/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0013
# Epoch 29/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0012
# Epoch 30/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0012
# Epoch 31/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0012
# Epoch 32/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0012
# Epoch 33/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0012
# Epoch 34/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0012
# Epoch 35/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0012
# Epoch 36/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0012
# Epoch 37/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0011
# Epoch 38/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0011
# Epoch 39/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0011
# Epoch 40/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0011
# Epoch 41/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0011
# Epoch 42/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0011
# Epoch 43/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0011
# Epoch 44/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0011
# Epoch 45/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0010
# Epoch 46/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0010
# Epoch 47/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0010
# Epoch 48/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0010
# Epoch 49/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0010
# Epoch 50/100
# 3/3 [==============================] - 0s 6ms/step - loss: 9.9526e-04
# Epoch 51/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0010
# Epoch 52/100
# 3/3 [==============================] - 0s 6ms/step - loss: 9.7158e-04
# Epoch 53/100
# 3/3 [==============================] - 0s 6ms/step - loss: 9.6520e-04
# Epoch 54/100
# 3/3 [==============================] - 0s 6ms/step - loss: 9.5791e-04
# Epoch 55/100
# 3/3 [==============================] - 0s 5ms/step - loss: 9.5454e-04
# Epoch 56/100
# 3/3 [==============================] - 0s 6ms/step - loss: 9.4484e-04
# Epoch 57/100
# 3/3 [==============================] - 0s 6ms/step - loss: 9.3222e-04
# Epoch 58/100
# 3/3 [==============================] - 0s 6ms/step - loss: 9.2266e-04
# Epoch 59/100
# 3/3 [==============================] - 0s 6ms/step - loss: 9.0965e-04
# Epoch 60/100
# 3/3 [==============================] - 0s 5ms/step - loss: 9.0117e-04
# Epoch 61/100
# 3/3 [==============================] - 0s 6ms/step - loss: 8.9130e-04
# Epoch 62/100
# 3/3 [==============================] - 0s 6ms/step - loss: 8.8937e-04
# Epoch 63/100
# 3/3 [==============================] - 0s 5ms/step - loss: 8.7434e-04
# Epoch 64/100
# 3/3 [==============================] - 0s 5ms/step - loss: 8.6231e-04
# Epoch 65/100
# 3/3 [==============================] - 0s 6ms/step - loss: 8.8836e-04
# Epoch 66/100
# 3/3 [==============================] - 0s 5ms/step - loss: 8.4441e-04
# Epoch 67/100
# 3/3 [==============================] - 0s 6ms/step - loss: 8.4663e-04
# Epoch 68/100
# 3/3 [==============================] - 0s 5ms/step - loss: 8.2159e-04
# Epoch 69/100
# 3/3 [==============================] - 0s 5ms/step - loss: 8.1547e-04
# Epoch 70/100
# 3/3 [==============================] - 0s 5ms/step - loss: 8.0546e-04
# Epoch 71/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.9839e-04
# Epoch 72/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.9681e-04
# Epoch 73/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.8139e-04
# Epoch 74/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.7697e-04
# Epoch 75/100
# 3/3 [==============================] - 0s 6ms/step - loss: 7.7261e-04
# Epoch 76/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.6035e-04
# Epoch 77/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.4825e-04
# Epoch 78/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.4420e-04
# Epoch 79/100
# 3/3 [==============================] - 0s 6ms/step - loss: 7.4013e-04
# Epoch 80/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.3297e-04
# Epoch 81/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.3705e-04
# Epoch 82/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.2424e-04
# Epoch 83/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.3513e-04
# Epoch 84/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.0972e-04
# Epoch 85/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.0489e-04
# Epoch 86/100
# 3/3 [==============================] - 0s 5ms/step - loss: 6.9739e-04
# Epoch 87/100
# 3/3 [==============================] - 0s 5ms/step - loss: 6.9600e-04
# Epoch 88/100
# 3/3 [==============================] - 0s 5ms/step - loss: 6.8829e-04
# Epoch 89/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.0131e-04
# Epoch 90/100
# 3/3 [==============================] - 0s 5ms/step - loss: 6.7832e-04
# Epoch 91/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.0200e-04
# Epoch 92/100
# 3/3 [==============================] - 0s 5ms/step - loss: 6.8064e-04
# Epoch 93/100
# 3/3 [==============================] - 0s 6ms/step - loss: 6.7383e-04
# Epoch 94/100
# 3/3 [==============================] - 0s 6ms/step - loss: 6.7962e-04
# Epoch 95/100
# 3/3 [==============================] - 0s 5ms/step - loss: 6.8475e-04
# Epoch 96/100
# 3/3 [==============================] - 0s 5ms/step - loss: 6.8147e-04
# Epoch 97/100
# 3/3 [==============================] - 0s 5ms/step - loss: 6.7189e-04
# Epoch 98/100
# 3/3 [==============================] - 0s 5ms/step - loss: 6.7507e-04
# Epoch 99/100
# 3/3 [==============================] - 0s 5ms/step - loss: 6.7166e-04
# Epoch 100/100
# 3/3 [==============================] - 0s 6ms/step - loss: 7.0050e-04

# %%
# Evaluate the model
train_loss = model.evaluate(X_train, y_train, verbose=0)
print(f'Training Loss: {train_loss}')

test_loss = model.evaluate(X_test, y_test, verbose=0)
print(f'Testing Loss: {test_loss}')
# Out:
# Training Loss: 0.0006569024408236146
# Testing Loss: 0.04776032641530037

# %%
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

# Inverse transform to get actual prices
y_train_actual = scaler.inverse_transform(y_train.reshape(-1, 1))
y_test_actual = scaler.inverse_transform(y_test.reshape(-1, 1))
y_train_pred_actual = scaler.inverse_transform(y_train_pred)
y_test_pred_actual = scaler.inverse_transform(y_test_pred)

# Calculate evaluation metrics
train_mae = mean_absolute_error(y_train_actual, y_train_pred_actual)
train_mse = mean_squared_error(y_train_actual, y_train_pred_actual)
test_mae = mean_absolute_error(y_test_actual, y_test_pred_actual)
test_mse = mean_squared_error(y_test_actual, y_test_pred_actual)
#
train_r = np.sqrt(train_mse)
train_r2 = r2_score(y_train_actual, y_train_pred_actual)
test_r = np.sqrt(test_mse)
test_r2 = r2_score(y_test_actual, y_test_pred_actual)

print(f'Training MAE: {train_mae}')
print(f'Training MSE: {train_mse}')
print(f'Testing MAE: {test_mae}')
print(f'Testing MSE: {test_mse}')
print(train_r)
print(test_r)
print(train_r2)
print(test_r2)
# Out:
# 6/6 [==============================] - 0s 857us/step
# 1/1 [==============================] - 0s 8ms/step
# Training MAE: 15.197800636291504
# Training MSE: 980.4922485351562
# Testing MAE: 217.68800354003906
# Testing MSE: 190393.921875
# 31.312813
# 436.34152
# 0.80162733858064
# 0.20735048207608497

# %%
import matplotlib.pyplot as plt

# Plot actual vs predicted for training set
plt.figure(figsize=(12, 6))
plt.plot(y_train_actual, label='Actual')
plt.plot(y_train_pred_actual, label='Predicted')
plt.title('Actual vs Predicted Prices - Training Set')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()

# Plot actual vs predicted for testing set
plt.figure(figsize=(12, 6))
plt.plot(y_test_actual, label='Actual')
plt.plot(y_test_pred_actual, label='Predicted')
plt.title('Actual vs Predicted Prices - Testing Set')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
d
# Out:
#           date     price
# 0   2000-02-01  0.053404
# 1   2000-03-01  0.043292
# 2   2000-04-01  0.049974
# 3   2000-05-01  0.049490
# 4   2000-06-01  0.049135
# ..         ...       ...
# 235 2019-09-01  0.058386
# 236 2019-10-01  0.056683
# 237 2019-11-01  0.075554
# 238 2019-12-01  0.081035
# 239 2020-01-01  0.089746
#
# [240 rows x 2 columns]
