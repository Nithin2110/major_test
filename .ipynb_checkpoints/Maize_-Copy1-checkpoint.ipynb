# %%
import optuna
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.preprocessing import MinMaxScaler
from statsmodels.tsa.stattools import kpss

# %%
df=pd.read_csv("DATA/Backup/maize.csv")

df
# Out:
#                     Date  price
# 0    2000-01-01 00:00:00  189.0
# 1    2000-02-01 00:00:00  188.3
# 2    2000-03-01 00:00:00  192.4
# 3    2000-04-01 00:00:00  191.2
# 4    2000-05-01 00:00:00  186.9
# ..                   ...    ...
# 283  2023-08-01 00:00:00  186.9
# 284  2023-09-01 00:00:00  183.9
# 285  2023-10-01 00:00:00  183.5
# 286  2023-11-01 00:00:00  183.5
# 287  2023-12-01 00:00:00  188.0
#
# [288 rows x 2 columns]

# %%
import pandas as pd


# Convert 'Date' column to datetime type
df['Date'] = pd.to_datetime(df['Date'])

# Check for missing values
print("Missing values:")
print(df.isnull().sum())

# Check for duplicates
print("\nDuplicates:")
print(df.duplicated().sum())

# Check basic statistics of the 'Price' column
print("\nBasic statistics of Price:")
print(df['price'].describe())

# Plot the time series data
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(df['Date'], df['price'], marker='o')
plt.title('Time Series Data')
plt.xlabel('Date')
plt.ylabel('Price')
plt.grid(True)
plt.show()
# Out:
# Missing values:
# Date     0
# price    0
# dtype: int64
#
# Duplicates:
# 0
#
# Basic statistics of Price:
# count    288.000000
# mean     205.086111
# std       47.012475
# min      116.400000
# 25%      174.375000
# 50%      194.350000
# 75%      245.625000
# max      321.100000
# Name: price, dtype: float64

# %%
sn.boxplot(df['price'])
# Out:
# <Axes: >

# %%
import pandas as pd
from scipy.stats import mstats
def winsorize_outliers(series, lower_percentile=0.05, upper_percentile=0.95):
    lower_limit = series.quantile(lower_percentile)
    upper_limit = series.quantile(upper_percentile)
    winsorized_values = mstats.winsorize(series, limits=(lower_percentile, 1 - upper_percentile))  # Correcting the upper percentile value
    return winsorized_values


# Winsorize the 'Price' column
#df['Price_winsorized'] = winsorize_outliers(df['price'])
df['price1'] = winsorize_outliers(df['price'], lower_percentile=0.05, upper_percentile=0.95)


# Plot the original and winsorized time series data
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(df['Date'], df['price'], marker='o', label='Original Price')
plt.plot(df['Date'], df['price1'], marker='o', label='Winsorized Price')
plt.title('Original vs. Winsorized Time Series Data')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
plt.show()

# %%
'''from statsmodels.tsa.seasonal import seasonal_decompose

# Seasonal decomposition
result = seasonal_decompose(df['price1'], model='additive', period=12)  # Assuming seasonality period of 12 months
detrended = df['price1'] - result.trend
seasonal = result.seasonal
residual = result.resid'''
# Out:
# "from statsmodels.tsa.seasonal import seasonal_decompose\n\n# Seasonal decomposition\nresult = seasonal_decompose(df['price1'], model='additive', period=12)  # Assuming seasonality period of 12 months\ndetrended = df['price1'] - result.trend\nseasonal = result.seasonal\nresidual = result.resid"

# %%
'''from sklearn.preprocessing import PowerTransformer

# Log transformation
df['Price_log'] = np.log(df['price1'])

# Box-Cox transformation
boxcox_transformer = PowerTransformer(method='box-cox')
df['Price_boxcox'] = boxcox_transformer.fit_transform(df['price1'].values.reshape(-1, 1))

# Quantile transformation (e.g., Gaussian transformation)
quantile_transformer = PowerTransformer(method='yeo-johnson')
df['Price_quantile'] = quantile_transformer.fit_transform(df['price1'].values.reshape(-1, 1))
'''
# Out:
# "from sklearn.preprocessing import PowerTransformer\n\n# Log transformation\ndf['Price_log'] = np.log(df['price1'])\n\n# Box-Cox transformation\nboxcox_transformer = PowerTransformer(method='box-cox')\ndf['Price_boxcox'] = boxcox_transformer.fit_transform(df['price1'].values.reshape(-1, 1))\n\n# Quantile transformation (e.g., Gaussian transformation)\nquantile_transformer = PowerTransformer(method='yeo-johnson')\ndf['Price_quantile'] = quantile_transformer.fit_transform(df['price1'].values.reshape(-1, 1))\n"

# %%
plt.plot(df['Date'],df['price'])

# %%
sn.boxplot(df['price'])
# Out:
# <Axes: >

# %%
t=kpss(df['price'],'ct')
t
# Out:
# /var/folders/35/vcbg9sn9479dqrdl_3fgrrkh0000gn/T/ipykernel_85140/1514378212.py:1: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   t=kpss(df['price'],'ct')
# (0.3404004465342978,
#  0.01,
#  10,
#  {'10%': 0.119, '5%': 0.146, '2.5%': 0.176, '1%': 0.216})

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose

# Assuming df is your DataFrame with a 'date' column and a 'value' column representing the time series
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)

# Perform seasonal decomposition
decomposition = seasonal_decompose(df['price'], model='additive')

# Plot the original time series
plt.figure(figsize=(10, 6))
plt.subplot(411)
plt.plot(df['price'], label='Original', color='blue')
plt.legend(loc='upper left')

# Plot the trend component
plt.subplot(412)
plt.plot(decomposition.trend, label='Trend', color='green')
plt.legend(loc='upper left')

# Plot the seasonal component
plt.subplot(413)
plt.plot(decomposition.seasonal, label='Seasonal', color='red')
plt.legend(loc='upper left')

# Plot the residual component
plt.subplot(414)
plt.plot(decomposition.resid, label='Residual', color='purple')
plt.legend(loc='upper left')

plt.tight_layout()
plt.show()

# %%
from scipy.stats import skew, kurtosis, shapiro

#df=pd.read_csv("DATA/Backup/rice.csv")

# %%
import pandas as pd
from scipy.stats import mstats
def winsorize_outliers(series, lower_percentile=0.05, upper_percentile=0.95):
    lower_limit = series.quantile(lower_percentile)
    upper_limit = series.quantile(upper_percentile)
    winsorized_values = mstats.winsorize(series, limits=(lower_percentile, 1 - upper_percentile))  # Correcting the upper percentile value
    return winsorized_values


# Winsorize the 'Price' column
#df['Price_winsorized'] = winsorize_outliers(df['price'])
df['price1'] = winsorize_outliers(df['price'], lower_percentile=0.05, upper_percentile=0.95)


# Plot the original and winsorized time series data
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(df['Date'], df['price'], marker='o', label='Original Price')
plt.plot(df['Date'], df['price1'], marker='o', label='Winsorized Price')
plt.title('Original vs. Winsorized Time Series Data')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
plt.show()

# %%
df
# Out:
#                     Date  price  price1
# 0    2000-01-01 00:00:00  166.9   166.9
# 1    2000-02-01 00:00:00  166.0   166.0
# 2    2000-03-01 00:00:00  166.6   166.6
# 3    2000-04-01 00:00:00  169.9   169.9
# 4    2000-05-01 00:00:00  171.0   171.0
# ..                   ...    ...     ...
# 283  2023-08-01 00:00:00  184.3   184.3
# 284  2023-09-01 00:00:00  187.0   187.0
# 285  2023-10-01 00:00:00  190.2   190.2
# 286  2023-11-01 00:00:00  191.4   191.4
# 287  2023-12-01 00:00:00  192.0   192.0
#
# [288 rows x 3 columns]

# %%
#df.pop('price')
#df['price']=df.pop('price1')
df1=df
df1
# Out:
#                     Date  price
# 0    2000-01-01 00:00:00  166.9
# 1    2000-02-01 00:00:00  166.0
# 2    2000-03-01 00:00:00  166.6
# 3    2000-04-01 00:00:00  169.9
# 4    2000-05-01 00:00:00  171.0
# ..                   ...    ...
# 283  2023-08-01 00:00:00  184.3
# 284  2023-09-01 00:00:00  187.0
# 285  2023-10-01 00:00:00  190.2
# 286  2023-11-01 00:00:00  191.4
# 287  2023-12-01 00:00:00  192.0
#
# [288 rows x 2 columns]

# %%
skewness = skew(df['price'])
kurt = kurtosis(df['price'])

# Perform Shapiro-Wilk test for normality
shapiro_stat, shapiro_p_value = shapiro(df['price'])

# Print the results
print("Skewness:", skewness)
print("Kurtosis:", kurt)
print("Shapiro-Wilk Statistic:", shapiro_stat)
print("Shapiro-Wilk p-value:", shapiro_p_value)
# Out:
# Skewness: 0.9062133854640201
# Kurtosis: -0.6908483852913809
# Shapiro-Wilk Statistic: 0.8249176740646362
# Shapiro-Wilk p-value: 3.666893971553287e-17

# %%
# Convert 'date' column to datetime if it's not already
# Shift the 'price' column to create new columns

scaler = MinMaxScaler(feature_range=(0, 1))
df['price'] = scaler.fit_transform(df['price'].values.reshape(-1,1))
#import matplotlib.pyplot as plt
#plt.plot(df['Date'],df['price'])


    

#dates_test, X_test, y_test = dates[q_80:], X[q_80:], y[q_80:]

#df['target-1'] = df['price'].shift(1)
#df['target-2'] = df['price'].shift(2)
#df['target-3'] = df['price'].shift(3)
#df['target-4'] = df['price'].shift(4)
#df['target-5'] = df['price'].shift(5)
#df['target-6'] = df['price'].shift(6)
#df['target-7'] = df['price'].shift(7)
#df['target-8'] = df['price'].shift(8)
#df['target-9'] = df['price'].shift(9)
#df['target-10'] = df['price'].shift(10)

# %%
#y

# %%
#dates
#X
#y

# %%
df=pd.read_csv("DATA/Backup/maize.csv")
scaler = MinMaxScaler(feature_range=(0, 1))
df['price'] = scaler.fit_transform(df['price'].values.reshape(-1,1))
shift=3
for i in range(shift,0,-1):
    df['target-'+str(i)] = df['price'].shift(i)
d=df[shift:]

def windowed_df_to_date_X_y(windowed_dataframe):
    df_as_np = windowed_dataframe.to_numpy()
    dates = df_as_np[:, 0]
    middle_matrix = df_as_np[:, 2:]
    X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))
    Y = df_as_np[:, 1:2]
    return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(d)
dates.shape, X.shape, y.shape

q_80 = int(len(dates) * .8)
q_90 = int(len(dates) * .9)
dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]
dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers.legacy import Adam
from tensorflow.keras import layers
from keras.callbacks import EarlyStopping
from keras.regularizers import l2

def objective(trial):
    # Define hyperparameters to tune
    #lstm_units = trial.suggest_int('lstm_units', 32, 256)
    #gru_units = trial.suggest_int('gru_units', 32, 256)
    num_filters = trial.suggest_int('num_filters', 16, 128)
    kernel_size = trial.suggest_int('kernel_size', 3, 7)
    dense_units = trial.suggest_int('dense_units', 16, 128)
    #num_lstm_layers = trial.suggest_int('num_lstm_layers', 1, 3)
    learning_rate = trial.suggest_categorical('learning_rate', [1e-5, 1e-4, 1e-3])

    # Construct the model
    model = Sequential([
        layers.Input((shift, 1)),
        #layers.LSTM(lstm_units),
        #layers.Bidirectional(layers.LSTM(lstm_units)),
        #layers.GRU(gru_units),
        layers.Conv1D(num_filters, kernel_size, activation='relu',padding='same'),
        layers.MaxPooling1D(),
        layers.Flatten(),
        layers.Dense(dense_units, activation='relu'),
        layers.Dense(1)
    ])
    '''
    model = Sequential()
    model.add(layers.Input((shift, 1)))
    for _ in range(num_lstm_layers):
        model.add(layers.LSTM(lstm_units, return_sequences=True))
    model.add(layers.Flatten())
    model.add(layers.Dense(dense_units, activation='relu'))
    model.add(layers.Dense(1))'''
    
    early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
    # Compile the model
    model.compile(loss='mse', 
                  optimizer=Adam(learning_rate=learning_rate),
                  metrics=['mean_absolute_error'])

    # Train the model
    model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=200,callbacks=[early_stopping])

    # Evaluate the model on the validation set and return the validation loss
    loss = model.evaluate(X_val, y_val)[0]
    return loss

# %%
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=100)
best_params = study.best_params
print("Best hyperparameters:", best_params)
# Out:
# [I 2024-03-05 22:13:19,462] A new study created in memory with name: no-name-28efca35-0422-46ad-a1bf-606ef5abb8d6
# Epoch 1/200
# 8/8 [==============================] - 0s 11ms/step - loss: 0.2606 - mean_absolute_error: 0.4580 - val_loss: 0.0402 - val_mean_absolute_error: 0.1832
# Epoch 2/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2491 - mean_absolute_error: 0.4468 - val_loss: 0.0374 - val_mean_absolute_error: 0.1757
# Epoch 3/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2376 - mean_absolute_error: 0.4359 - val_loss: 0.0346 - val_mean_absolute_error: 0.1683
# Epoch 4/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2267 - mean_absolute_error: 0.4250 - val_loss: 0.0320 - val_mean_absolute_error: 0.1610
# Epoch 5/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2159 - mean_absolute_error: 0.4140 - val_loss: 0.0296 - val_mean_absolute_error: 0.1542
# Epoch 6/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2051 - mean_absolute_error: 0.4031 - val_loss: 0.0274 - val_mean_absolute_error: 0.1476
# Epoch 7/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1950 - mean_absolute_error: 0.3925 - val_loss: 0.0253 - val_mean_absolute_error: 0.1411
# Epoch 8/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1854 - mean_absolute_error: 0.3822 - val_loss: 0.0234 - val_mean_absolute_error: 0.1349
# Epoch 9/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1758 - mean_absolute_error: 0.3716 - val_loss: 0.0216 - val_mean_absolute_error: 0.1288
# Epoch 10/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1666 - mean_absolute_error: 0.3615 - val_loss: 0.0199 - val_mean_absolute_error: 0.1227
# Epoch 11/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1580 - mean_absolute_error: 0.3519 - val_loss: 0.0184 - val_mean_absolute_error: 0.1167
# Epoch 12/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1499 - mean_absolute_error: 0.3423 - val_loss: 0.0169 - val_mean_absolute_error: 0.1109
# Epoch 13/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1422 - mean_absolute_error: 0.3332 - val_loss: 0.0155 - val_mean_absolute_error: 0.1049
# Epoch 14/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1347 - mean_absolute_error: 0.3244 - val_loss: 0.0142 - val_mean_absolute_error: 0.0991
# Epoch 15/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1278 - mean_absolute_error: 0.3159 - val_loss: 0.0130 - val_mean_absolute_error: 0.0932
# Epoch 16/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1213 - mean_absolute_error: 0.3075 - val_loss: 0.0118 - val_mean_absolute_error: 0.0873
# Epoch 17/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1150 - mean_absolute_error: 0.2993 - val_loss: 0.0107 - val_mean_absolute_error: 0.0814
# Epoch 18/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1090 - mean_absolute_error: 0.2911 - val_loss: 0.0097 - val_mean_absolute_error: 0.0758
# Epoch 19/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1031 - mean_absolute_error: 0.2831 - val_loss: 0.0088 - val_mean_absolute_error: 0.0710
# Epoch 20/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0978 - mean_absolute_error: 0.2755 - val_loss: 0.0079 - val_mean_absolute_error: 0.0663
# Epoch 21/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0924 - mean_absolute_error: 0.2675 - val_loss: 0.0071 - val_mean_absolute_error: 0.0621
# Epoch 22/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0871 - mean_absolute_error: 0.2596 - val_loss: 0.0064 - val_mean_absolute_error: 0.0581
# Epoch 23/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0823 - mean_absolute_error: 0.2519 - val_loss: 0.0057 - val_mean_absolute_error: 0.0543
# Epoch 24/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0774 - mean_absolute_error: 0.2440 - val_loss: 0.0051 - val_mean_absolute_error: 0.0512
# Epoch 25/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0730 - mean_absolute_error: 0.2365 - val_loss: 0.0046 - val_mean_absolute_error: 0.0481
# Epoch 26/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0686 - mean_absolute_error: 0.2289 - val_loss: 0.0041 - val_mean_absolute_error: 0.0459
# Epoch 27/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0643 - mean_absolute_error: 0.2210 - val_loss: 0.0037 - val_mean_absolute_error: 0.0453
# Epoch 28/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0601 - mean_absolute_error: 0.2132 - val_loss: 0.0034 - val_mean_absolute_error: 0.0454
# Epoch 29/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0562 - mean_absolute_error: 0.2056 - val_loss: 0.0031 - val_mean_absolute_error: 0.0455
# Epoch 30/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0526 - mean_absolute_error: 0.1982 - val_loss: 0.0029 - val_mean_absolute_error: 0.0454
# Epoch 31/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0492 - mean_absolute_error: 0.1910 - val_loss: 0.0027 - val_mean_absolute_error: 0.0456
# Epoch 32/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0460 - mean_absolute_error: 0.1840 - val_loss: 0.0026 - val_mean_absolute_error: 0.0460
# Epoch 33/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0431 - mean_absolute_error: 0.1771 - val_loss: 0.0026 - val_mean_absolute_error: 0.0463
# Epoch 34/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0401 - mean_absolute_error: 0.1700 - val_loss: 0.0026 - val_mean_absolute_error: 0.0468
# Epoch 35/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0373 - mean_absolute_error: 0.1631 - val_loss: 0.0026 - val_mean_absolute_error: 0.0478
# Epoch 36/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0348 - mean_absolute_error: 0.1565 - val_loss: 0.0027 - val_mean_absolute_error: 0.0488
# Epoch 37/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0323 - mean_absolute_error: 0.1502 - val_loss: 0.0028 - val_mean_absolute_error: 0.0497
# Epoch 38/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0302 - mean_absolute_error: 0.1444 - val_loss: 0.0030 - val_mean_absolute_error: 0.0506
# Epoch 39/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0283 - mean_absolute_error: 0.1386 - val_loss: 0.0031 - val_mean_absolute_error: 0.0516
# Epoch 40/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0263 - mean_absolute_error: 0.1326 - val_loss: 0.0033 - val_mean_absolute_error: 0.0527
# Epoch 41/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0246 - mean_absolute_error: 0.1271 - val_loss: 0.0035 - val_mean_absolute_error: 0.0537
# Epoch 42/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0230 - mean_absolute_error: 0.1218 - val_loss: 0.0038 - val_mean_absolute_error: 0.0547
# Epoch 43/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0215 - mean_absolute_error: 0.1170 - val_loss: 0.0040 - val_mean_absolute_error: 0.0557
# Epoch 44/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0201 - mean_absolute_error: 0.1123 - val_loss: 0.0043 - val_mean_absolute_error: 0.0567
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0026 - mean_absolute_error: 0.0468
# [I 2024-03-05 22:13:20,698] Trial 0 finished with value: 0.002587666967883706 and parameters: {'num_filters': 53, 'kernel_size': 5, 'dense_units': 19, 'learning_rate': 0.0001}. Best is trial 0 with value: 0.002587666967883706.
# Epoch 1/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.3117 - mean_absolute_error: 0.5022 - val_loss: 0.0448 - val_mean_absolute_error: 0.1931
# Epoch 2/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2774 - mean_absolute_error: 0.4720 - val_loss: 0.0377 - val_mean_absolute_error: 0.1752
# Epoch 3/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2470 - mean_absolute_error: 0.4434 - val_loss: 0.0313 - val_mean_absolute_error: 0.1576
# Epoch 4/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2186 - mean_absolute_error: 0.4150 - val_loss: 0.0255 - val_mean_absolute_error: 0.1397
# Epoch 5/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1920 - mean_absolute_error: 0.3876 - val_loss: 0.0204 - val_mean_absolute_error: 0.1221
# Epoch 6/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1671 - mean_absolute_error: 0.3603 - val_loss: 0.0158 - val_mean_absolute_error: 0.1042
# Epoch 7/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1429 - mean_absolute_error: 0.3319 - val_loss: 0.0119 - val_mean_absolute_error: 0.0863
# Epoch 8/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1206 - mean_absolute_error: 0.3041 - val_loss: 0.0086 - val_mean_absolute_error: 0.0696
# Epoch 9/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0994 - mean_absolute_error: 0.2755 - val_loss: 0.0060 - val_mean_absolute_error: 0.0564
# Epoch 10/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0811 - mean_absolute_error: 0.2479 - val_loss: 0.0042 - val_mean_absolute_error: 0.0464
# Epoch 11/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0656 - mean_absolute_error: 0.2212 - val_loss: 0.0030 - val_mean_absolute_error: 0.0441
# Epoch 12/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0522 - mean_absolute_error: 0.1954 - val_loss: 0.0025 - val_mean_absolute_error: 0.0441
# Epoch 13/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0410 - mean_absolute_error: 0.1712 - val_loss: 0.0024 - val_mean_absolute_error: 0.0457
# Epoch 14/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0325 - mean_absolute_error: 0.1503 - val_loss: 0.0027 - val_mean_absolute_error: 0.0487
# Epoch 15/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0258 - mean_absolute_error: 0.1315 - val_loss: 0.0033 - val_mean_absolute_error: 0.0519
# Epoch 16/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0208 - mean_absolute_error: 0.1153 - val_loss: 0.0040 - val_mean_absolute_error: 0.0552
# Epoch 17/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0172 - mean_absolute_error: 0.1033 - val_loss: 0.0047 - val_mean_absolute_error: 0.0602
# Epoch 18/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0145 - mean_absolute_error: 0.0928 - val_loss: 0.0052 - val_mean_absolute_error: 0.0630
# Epoch 19/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0126 - mean_absolute_error: 0.0850 - val_loss: 0.0055 - val_mean_absolute_error: 0.0650
# Epoch 20/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0113 - mean_absolute_error: 0.0784 - val_loss: 0.0058 - val_mean_absolute_error: 0.0668
# Epoch 21/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0103 - mean_absolute_error: 0.0728 - val_loss: 0.0060 - val_mean_absolute_error: 0.0681
# Epoch 22/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0096 - mean_absolute_error: 0.0690 - val_loss: 0.0058 - val_mean_absolute_error: 0.0671
# Epoch 23/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0092 - mean_absolute_error: 0.0658 - val_loss: 0.0057 - val_mean_absolute_error: 0.0669
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0024 - mean_absolute_error: 0.0457
# [I 2024-03-05 22:13:21,433] Trial 1 finished with value: 0.002401296515017748 and parameters: {'num_filters': 99, 'kernel_size': 7, 'dense_units': 109, 'learning_rate': 0.0001}. Best is trial 1 with value: 0.002401296515017748.
# Epoch 1/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.3084 - mean_absolute_error: 0.4991 - val_loss: 0.0477 - val_mean_absolute_error: 0.1997
# Epoch 2/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2933 - mean_absolute_error: 0.4857 - val_loss: 0.0440 - val_mean_absolute_error: 0.1908
# Epoch 3/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2780 - mean_absolute_error: 0.4720 - val_loss: 0.0404 - val_mean_absolute_error: 0.1817
# Epoch 4/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2629 - mean_absolute_error: 0.4582 - val_loss: 0.0370 - val_mean_absolute_error: 0.1728
# Epoch 5/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2487 - mean_absolute_error: 0.4446 - val_loss: 0.0338 - val_mean_absolute_error: 0.1642
# Epoch 6/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2348 - mean_absolute_error: 0.4311 - val_loss: 0.0308 - val_mean_absolute_error: 0.1557
# Epoch 7/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2215 - mean_absolute_error: 0.4180 - val_loss: 0.0282 - val_mean_absolute_error: 0.1477
# Epoch 8/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2088 - mean_absolute_error: 0.4055 - val_loss: 0.0257 - val_mean_absolute_error: 0.1399
# Epoch 9/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1968 - mean_absolute_error: 0.3930 - val_loss: 0.0233 - val_mean_absolute_error: 0.1320
# Epoch 10/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1853 - mean_absolute_error: 0.3808 - val_loss: 0.0212 - val_mean_absolute_error: 0.1243
# Epoch 11/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1744 - mean_absolute_error: 0.3692 - val_loss: 0.0192 - val_mean_absolute_error: 0.1168
# Epoch 12/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1642 - mean_absolute_error: 0.3578 - val_loss: 0.0174 - val_mean_absolute_error: 0.1095
# Epoch 13/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1547 - mean_absolute_error: 0.3467 - val_loss: 0.0157 - val_mean_absolute_error: 0.1023
# Epoch 14/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1460 - mean_absolute_error: 0.3363 - val_loss: 0.0142 - val_mean_absolute_error: 0.0953
# Epoch 15/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1376 - mean_absolute_error: 0.3261 - val_loss: 0.0127 - val_mean_absolute_error: 0.0881
# Epoch 16/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1291 - mean_absolute_error: 0.3158 - val_loss: 0.0114 - val_mean_absolute_error: 0.0815
# Epoch 17/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1217 - mean_absolute_error: 0.3064 - val_loss: 0.0102 - val_mean_absolute_error: 0.0757
# Epoch 18/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1143 - mean_absolute_error: 0.2968 - val_loss: 0.0091 - val_mean_absolute_error: 0.0704
# Epoch 19/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1075 - mean_absolute_error: 0.2875 - val_loss: 0.0081 - val_mean_absolute_error: 0.0659
# Epoch 20/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1009 - mean_absolute_error: 0.2782 - val_loss: 0.0073 - val_mean_absolute_error: 0.0617
# Epoch 21/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0947 - mean_absolute_error: 0.2691 - val_loss: 0.0065 - val_mean_absolute_error: 0.0579
# Epoch 22/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0882 - mean_absolute_error: 0.2593 - val_loss: 0.0057 - val_mean_absolute_error: 0.0543
# Epoch 23/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0823 - mean_absolute_error: 0.2502 - val_loss: 0.0051 - val_mean_absolute_error: 0.0517
# Epoch 24/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0770 - mean_absolute_error: 0.2414 - val_loss: 0.0046 - val_mean_absolute_error: 0.0507
# Epoch 25/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0720 - mean_absolute_error: 0.2328 - val_loss: 0.0042 - val_mean_absolute_error: 0.0502
# Epoch 26/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0672 - mean_absolute_error: 0.2245 - val_loss: 0.0038 - val_mean_absolute_error: 0.0497
# Epoch 27/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0626 - mean_absolute_error: 0.2160 - val_loss: 0.0035 - val_mean_absolute_error: 0.0496
# Epoch 28/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0580 - mean_absolute_error: 0.2072 - val_loss: 0.0033 - val_mean_absolute_error: 0.0498
# Epoch 29/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0540 - mean_absolute_error: 0.1991 - val_loss: 0.0031 - val_mean_absolute_error: 0.0500
# Epoch 30/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0503 - mean_absolute_error: 0.1914 - val_loss: 0.0030 - val_mean_absolute_error: 0.0501
# Epoch 31/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0468 - mean_absolute_error: 0.1838 - val_loss: 0.0030 - val_mean_absolute_error: 0.0501
# Epoch 32/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0435 - mean_absolute_error: 0.1764 - val_loss: 0.0029 - val_mean_absolute_error: 0.0503
# Epoch 33/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0405 - mean_absolute_error: 0.1692 - val_loss: 0.0030 - val_mean_absolute_error: 0.0511
# Epoch 34/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0375 - mean_absolute_error: 0.1620 - val_loss: 0.0030 - val_mean_absolute_error: 0.0517
# Epoch 35/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0349 - mean_absolute_error: 0.1556 - val_loss: 0.0031 - val_mean_absolute_error: 0.0522
# Epoch 36/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0326 - mean_absolute_error: 0.1495 - val_loss: 0.0032 - val_mean_absolute_error: 0.0528
# Epoch 37/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0304 - mean_absolute_error: 0.1436 - val_loss: 0.0033 - val_mean_absolute_error: 0.0530
# Epoch 38/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0284 - mean_absolute_error: 0.1379 - val_loss: 0.0035 - val_mean_absolute_error: 0.0537
# Epoch 39/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0267 - mean_absolute_error: 0.1330 - val_loss: 0.0036 - val_mean_absolute_error: 0.0543
# Epoch 40/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0252 - mean_absolute_error: 0.1285 - val_loss: 0.0037 - val_mean_absolute_error: 0.0545
# Epoch 41/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0237 - mean_absolute_error: 0.1241 - val_loss: 0.0038 - val_mean_absolute_error: 0.0552
# Epoch 42/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0223 - mean_absolute_error: 0.1198 - val_loss: 0.0040 - val_mean_absolute_error: 0.0564
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0029 - mean_absolute_error: 0.0503
# [I 2024-03-05 22:13:22,441] Trial 2 finished with value: 0.002949437126517296 and parameters: {'num_filters': 29, 'kernel_size': 4, 'dense_units': 24, 'learning_rate': 0.0001}. Best is trial 1 with value: 0.002401296515017748.
# Epoch 1/200
# 8/8 [==============================] - 0s 12ms/step - loss: 0.1028 - mean_absolute_error: 0.2795 - val_loss: 0.0019 - val_mean_absolute_error: 0.0347
# Epoch 2/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0147 - mean_absolute_error: 0.0880 - val_loss: 0.0104 - val_mean_absolute_error: 0.0970
# Epoch 3/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0145 - mean_absolute_error: 0.0865 - val_loss: 0.0097 - val_mean_absolute_error: 0.0935
# Epoch 4/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0094 - mean_absolute_error: 0.0546 - val_loss: 0.0021 - val_mean_absolute_error: 0.0393
# Epoch 5/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0081 - mean_absolute_error: 0.0591 - val_loss: 0.0017 - val_mean_absolute_error: 0.0342
# Epoch 6/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0071 - mean_absolute_error: 0.0509 - val_loss: 0.0017 - val_mean_absolute_error: 0.0336
# Epoch 7/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0063 - mean_absolute_error: 0.0394 - val_loss: 0.0016 - val_mean_absolute_error: 0.0318
# Epoch 8/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0062 - mean_absolute_error: 0.0349 - val_loss: 9.8449e-04 - val_mean_absolute_error: 0.0253
# Epoch 9/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0060 - mean_absolute_error: 0.0344 - val_loss: 9.4282e-04 - val_mean_absolute_error: 0.0245
# Epoch 10/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0058 - mean_absolute_error: 0.0337 - val_loss: 0.0010 - val_mean_absolute_error: 0.0248
# Epoch 11/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0058 - mean_absolute_error: 0.0329 - val_loss: 9.0571e-04 - val_mean_absolute_error: 0.0236
# Epoch 12/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0057 - mean_absolute_error: 0.0340 - val_loss: 7.8275e-04 - val_mean_absolute_error: 0.0224
# Epoch 13/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0056 - mean_absolute_error: 0.0332 - val_loss: 9.4000e-04 - val_mean_absolute_error: 0.0234
# Epoch 14/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0055 - mean_absolute_error: 0.0321 - val_loss: 7.4712e-04 - val_mean_absolute_error: 0.0215
# Epoch 15/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0054 - mean_absolute_error: 0.0335 - val_loss: 7.8148e-04 - val_mean_absolute_error: 0.0213
# Epoch 16/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0053 - mean_absolute_error: 0.0312 - val_loss: 7.3852e-04 - val_mean_absolute_error: 0.0206
# Epoch 17/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0054 - mean_absolute_error: 0.0319 - val_loss: 6.3117e-04 - val_mean_absolute_error: 0.0202
# Epoch 18/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0065 - mean_absolute_error: 0.0504 - val_loss: 7.1885e-04 - val_mean_absolute_error: 0.0206
# Epoch 19/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0054 - mean_absolute_error: 0.0352 - val_loss: 0.0020 - val_mean_absolute_error: 0.0369
# Epoch 20/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0054 - mean_absolute_error: 0.0348 - val_loss: 7.3037e-04 - val_mean_absolute_error: 0.0207
# Epoch 21/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0054 - mean_absolute_error: 0.0394 - val_loss: 0.0012 - val_mean_absolute_error: 0.0268
# Epoch 22/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0052 - mean_absolute_error: 0.0309 - val_loss: 8.8272e-04 - val_mean_absolute_error: 0.0225
# Epoch 23/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0053 - mean_absolute_error: 0.0338 - val_loss: 8.2191e-04 - val_mean_absolute_error: 0.0213
# Epoch 24/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0052 - mean_absolute_error: 0.0296 - val_loss: 8.2461e-04 - val_mean_absolute_error: 0.0213
# Epoch 25/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0051 - mean_absolute_error: 0.0296 - val_loss: 6.6874e-04 - val_mean_absolute_error: 0.0194
# Epoch 26/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0050 - mean_absolute_error: 0.0311 - val_loss: 6.5631e-04 - val_mean_absolute_error: 0.0192
# Epoch 27/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0051 - mean_absolute_error: 0.0313 - val_loss: 8.5522e-04 - val_mean_absolute_error: 0.0219
# 1/1 [==============================] - 0s 8ms/step - loss: 6.3117e-04 - mean_absolute_error: 0.0202
# [I 2024-03-05 22:13:23,208] Trial 3 finished with value: 0.000631171278655529 and parameters: {'num_filters': 40, 'kernel_size': 4, 'dense_units': 120, 'learning_rate': 0.001}. Best is trial 3 with value: 0.000631171278655529.
# Epoch 1/200
# 8/8 [==============================] - 0s 12ms/step - loss: 0.1875 - mean_absolute_error: 0.3881 - val_loss: 0.0299 - val_mean_absolute_error: 0.1583
# Epoch 2/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1859 - mean_absolute_error: 0.3865 - val_loss: 0.0296 - val_mean_absolute_error: 0.1572
# Epoch 3/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1845 - mean_absolute_error: 0.3848 - val_loss: 0.0292 - val_mean_absolute_error: 0.1561
# Epoch 4/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1830 - mean_absolute_error: 0.3832 - val_loss: 0.0288 - val_mean_absolute_error: 0.1550
# Epoch 5/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1815 - mean_absolute_error: 0.3815 - val_loss: 0.0285 - val_mean_absolute_error: 0.1539
# Epoch 6/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1800 - mean_absolute_error: 0.3799 - val_loss: 0.0281 - val_mean_absolute_error: 0.1528
# Epoch 7/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1786 - mean_absolute_error: 0.3783 - val_loss: 0.0278 - val_mean_absolute_error: 0.1517
# Epoch 8/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1772 - mean_absolute_error: 0.3767 - val_loss: 0.0274 - val_mean_absolute_error: 0.1506
# Epoch 9/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1758 - mean_absolute_error: 0.3751 - val_loss: 0.0271 - val_mean_absolute_error: 0.1495
# Epoch 10/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1744 - mean_absolute_error: 0.3735 - val_loss: 0.0267 - val_mean_absolute_error: 0.1485
# Epoch 11/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1730 - mean_absolute_error: 0.3719 - val_loss: 0.0264 - val_mean_absolute_error: 0.1474
# Epoch 12/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1716 - mean_absolute_error: 0.3703 - val_loss: 0.0261 - val_mean_absolute_error: 0.1463
# Epoch 13/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1702 - mean_absolute_error: 0.3688 - val_loss: 0.0257 - val_mean_absolute_error: 0.1452
# Epoch 14/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1688 - mean_absolute_error: 0.3672 - val_loss: 0.0254 - val_mean_absolute_error: 0.1442
# Epoch 15/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1675 - mean_absolute_error: 0.3657 - val_loss: 0.0251 - val_mean_absolute_error: 0.1431
# Epoch 16/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1661 - mean_absolute_error: 0.3641 - val_loss: 0.0248 - val_mean_absolute_error: 0.1421
# Epoch 17/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1648 - mean_absolute_error: 0.3626 - val_loss: 0.0244 - val_mean_absolute_error: 0.1410
# Epoch 18/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1634 - mean_absolute_error: 0.3610 - val_loss: 0.0241 - val_mean_absolute_error: 0.1399
# Epoch 19/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1621 - mean_absolute_error: 0.3594 - val_loss: 0.0238 - val_mean_absolute_error: 0.1388
# Epoch 20/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1608 - mean_absolute_error: 0.3578 - val_loss: 0.0235 - val_mean_absolute_error: 0.1378
# Epoch 21/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1595 - mean_absolute_error: 0.3563 - val_loss: 0.0232 - val_mean_absolute_error: 0.1368
# Epoch 22/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1582 - mean_absolute_error: 0.3548 - val_loss: 0.0229 - val_mean_absolute_error: 0.1357
# Epoch 23/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1569 - mean_absolute_error: 0.3533 - val_loss: 0.0226 - val_mean_absolute_error: 0.1347
# Epoch 24/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1557 - mean_absolute_error: 0.3518 - val_loss: 0.0223 - val_mean_absolute_error: 0.1337
# Epoch 25/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1544 - mean_absolute_error: 0.3503 - val_loss: 0.0220 - val_mean_absolute_error: 0.1327
# Epoch 26/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1531 - mean_absolute_error: 0.3488 - val_loss: 0.0217 - val_mean_absolute_error: 0.1316
# Epoch 27/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1519 - mean_absolute_error: 0.3472 - val_loss: 0.0214 - val_mean_absolute_error: 0.1306
# Epoch 28/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1506 - mean_absolute_error: 0.3457 - val_loss: 0.0211 - val_mean_absolute_error: 0.1295
# Epoch 29/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1493 - mean_absolute_error: 0.3442 - val_loss: 0.0208 - val_mean_absolute_error: 0.1285
# Epoch 30/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1480 - mean_absolute_error: 0.3426 - val_loss: 0.0206 - val_mean_absolute_error: 0.1274
# Epoch 31/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1468 - mean_absolute_error: 0.3411 - val_loss: 0.0203 - val_mean_absolute_error: 0.1264
# Epoch 32/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1456 - mean_absolute_error: 0.3396 - val_loss: 0.0200 - val_mean_absolute_error: 0.1254
# Epoch 33/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1444 - mean_absolute_error: 0.3382 - val_loss: 0.0197 - val_mean_absolute_error: 0.1243
# Epoch 34/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1432 - mean_absolute_error: 0.3367 - val_loss: 0.0195 - val_mean_absolute_error: 0.1233
# Epoch 35/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1420 - mean_absolute_error: 0.3352 - val_loss: 0.0192 - val_mean_absolute_error: 0.1223
# Epoch 36/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1408 - mean_absolute_error: 0.3337 - val_loss: 0.0189 - val_mean_absolute_error: 0.1213
# Epoch 37/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1396 - mean_absolute_error: 0.3322 - val_loss: 0.0186 - val_mean_absolute_error: 0.1202
# Epoch 38/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1384 - mean_absolute_error: 0.3307 - val_loss: 0.0184 - val_mean_absolute_error: 0.1191
# Epoch 39/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1372 - mean_absolute_error: 0.3292 - val_loss: 0.0181 - val_mean_absolute_error: 0.1181
# Epoch 40/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1360 - mean_absolute_error: 0.3277 - val_loss: 0.0179 - val_mean_absolute_error: 0.1171
# Epoch 41/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1349 - mean_absolute_error: 0.3264 - val_loss: 0.0176 - val_mean_absolute_error: 0.1161
# Epoch 42/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1338 - mean_absolute_error: 0.3249 - val_loss: 0.0174 - val_mean_absolute_error: 0.1151
# Epoch 43/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1326 - mean_absolute_error: 0.3235 - val_loss: 0.0171 - val_mean_absolute_error: 0.1140
# Epoch 44/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1314 - mean_absolute_error: 0.3219 - val_loss: 0.0168 - val_mean_absolute_error: 0.1130
# Epoch 45/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1302 - mean_absolute_error: 0.3204 - val_loss: 0.0166 - val_mean_absolute_error: 0.1119
# Epoch 46/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1290 - mean_absolute_error: 0.3189 - val_loss: 0.0163 - val_mean_absolute_error: 0.1108
# Epoch 47/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1278 - mean_absolute_error: 0.3173 - val_loss: 0.0161 - val_mean_absolute_error: 0.1097
# Epoch 48/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1267 - mean_absolute_error: 0.3158 - val_loss: 0.0158 - val_mean_absolute_error: 0.1087
# Epoch 49/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1255 - mean_absolute_error: 0.3143 - val_loss: 0.0156 - val_mean_absolute_error: 0.1076
# Epoch 50/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1243 - mean_absolute_error: 0.3128 - val_loss: 0.0153 - val_mean_absolute_error: 0.1065
# Epoch 51/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1232 - mean_absolute_error: 0.3113 - val_loss: 0.0151 - val_mean_absolute_error: 0.1055
# Epoch 52/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1221 - mean_absolute_error: 0.3099 - val_loss: 0.0148 - val_mean_absolute_error: 0.1044
# Epoch 53/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1210 - mean_absolute_error: 0.3085 - val_loss: 0.0146 - val_mean_absolute_error: 0.1034
# Epoch 54/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1199 - mean_absolute_error: 0.3070 - val_loss: 0.0144 - val_mean_absolute_error: 0.1023
# Epoch 55/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1188 - mean_absolute_error: 0.3055 - val_loss: 0.0141 - val_mean_absolute_error: 0.1012
# Epoch 56/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1176 - mean_absolute_error: 0.3040 - val_loss: 0.0139 - val_mean_absolute_error: 0.1000
# Epoch 57/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1165 - mean_absolute_error: 0.3025 - val_loss: 0.0136 - val_mean_absolute_error: 0.0990
# Epoch 58/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1154 - mean_absolute_error: 0.3011 - val_loss: 0.0134 - val_mean_absolute_error: 0.0979
# Epoch 59/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1143 - mean_absolute_error: 0.2996 - val_loss: 0.0132 - val_mean_absolute_error: 0.0968
# Epoch 60/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1132 - mean_absolute_error: 0.2981 - val_loss: 0.0129 - val_mean_absolute_error: 0.0956
# Epoch 61/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1121 - mean_absolute_error: 0.2966 - val_loss: 0.0127 - val_mean_absolute_error: 0.0945
# Epoch 62/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1110 - mean_absolute_error: 0.2950 - val_loss: 0.0125 - val_mean_absolute_error: 0.0934
# Epoch 63/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1098 - mean_absolute_error: 0.2935 - val_loss: 0.0123 - val_mean_absolute_error: 0.0923
# Epoch 64/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1087 - mean_absolute_error: 0.2920 - val_loss: 0.0120 - val_mean_absolute_error: 0.0912
# Epoch 65/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1076 - mean_absolute_error: 0.2904 - val_loss: 0.0118 - val_mean_absolute_error: 0.0901
# Epoch 66/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1065 - mean_absolute_error: 0.2889 - val_loss: 0.0116 - val_mean_absolute_error: 0.0890
# Epoch 67/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1054 - mean_absolute_error: 0.2874 - val_loss: 0.0114 - val_mean_absolute_error: 0.0879
# Epoch 68/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1044 - mean_absolute_error: 0.2859 - val_loss: 0.0112 - val_mean_absolute_error: 0.0868
# Epoch 69/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1033 - mean_absolute_error: 0.2844 - val_loss: 0.0110 - val_mean_absolute_error: 0.0858
# Epoch 70/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1023 - mean_absolute_error: 0.2829 - val_loss: 0.0108 - val_mean_absolute_error: 0.0847
# Epoch 71/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1012 - mean_absolute_error: 0.2814 - val_loss: 0.0106 - val_mean_absolute_error: 0.0836
# Epoch 72/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1002 - mean_absolute_error: 0.2799 - val_loss: 0.0104 - val_mean_absolute_error: 0.0825
# Epoch 73/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0991 - mean_absolute_error: 0.2784 - val_loss: 0.0102 - val_mean_absolute_error: 0.0815
# Epoch 74/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0981 - mean_absolute_error: 0.2769 - val_loss: 0.0100 - val_mean_absolute_error: 0.0804
# Epoch 75/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0971 - mean_absolute_error: 0.2754 - val_loss: 0.0098 - val_mean_absolute_error: 0.0793
# Epoch 76/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0960 - mean_absolute_error: 0.2738 - val_loss: 0.0096 - val_mean_absolute_error: 0.0782
# Epoch 77/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0950 - mean_absolute_error: 0.2723 - val_loss: 0.0094 - val_mean_absolute_error: 0.0771
# Epoch 78/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0939 - mean_absolute_error: 0.2708 - val_loss: 0.0093 - val_mean_absolute_error: 0.0761
# Epoch 79/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0929 - mean_absolute_error: 0.2693 - val_loss: 0.0091 - val_mean_absolute_error: 0.0750
# Epoch 80/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0919 - mean_absolute_error: 0.2678 - val_loss: 0.0089 - val_mean_absolute_error: 0.0740
# Epoch 81/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0910 - mean_absolute_error: 0.2664 - val_loss: 0.0088 - val_mean_absolute_error: 0.0730
# Epoch 82/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0901 - mean_absolute_error: 0.2649 - val_loss: 0.0086 - val_mean_absolute_error: 0.0719
# Epoch 83/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0891 - mean_absolute_error: 0.2635 - val_loss: 0.0084 - val_mean_absolute_error: 0.0709
# Epoch 84/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0882 - mean_absolute_error: 0.2621 - val_loss: 0.0083 - val_mean_absolute_error: 0.0700
# Epoch 85/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0872 - mean_absolute_error: 0.2607 - val_loss: 0.0081 - val_mean_absolute_error: 0.0691
# Epoch 86/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0863 - mean_absolute_error: 0.2592 - val_loss: 0.0079 - val_mean_absolute_error: 0.0682
# Epoch 87/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0854 - mean_absolute_error: 0.2578 - val_loss: 0.0078 - val_mean_absolute_error: 0.0673
# Epoch 88/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0844 - mean_absolute_error: 0.2562 - val_loss: 0.0076 - val_mean_absolute_error: 0.0664
# Epoch 89/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0835 - mean_absolute_error: 0.2548 - val_loss: 0.0075 - val_mean_absolute_error: 0.0655
# Epoch 90/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0825 - mean_absolute_error: 0.2533 - val_loss: 0.0073 - val_mean_absolute_error: 0.0646
# Epoch 91/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0816 - mean_absolute_error: 0.2519 - val_loss: 0.0072 - val_mean_absolute_error: 0.0638
# Epoch 92/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0808 - mean_absolute_error: 0.2505 - val_loss: 0.0070 - val_mean_absolute_error: 0.0629
# Epoch 93/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0799 - mean_absolute_error: 0.2490 - val_loss: 0.0069 - val_mean_absolute_error: 0.0621
# Epoch 94/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0790 - mean_absolute_error: 0.2476 - val_loss: 0.0067 - val_mean_absolute_error: 0.0612
# Epoch 95/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0781 - mean_absolute_error: 0.2461 - val_loss: 0.0066 - val_mean_absolute_error: 0.0604
# Epoch 96/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0772 - mean_absolute_error: 0.2447 - val_loss: 0.0065 - val_mean_absolute_error: 0.0596
# Epoch 97/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0763 - mean_absolute_error: 0.2432 - val_loss: 0.0063 - val_mean_absolute_error: 0.0588
# Epoch 98/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0754 - mean_absolute_error: 0.2418 - val_loss: 0.0062 - val_mean_absolute_error: 0.0580
# Epoch 99/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0746 - mean_absolute_error: 0.2404 - val_loss: 0.0061 - val_mean_absolute_error: 0.0572
# Epoch 100/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0738 - mean_absolute_error: 0.2390 - val_loss: 0.0060 - val_mean_absolute_error: 0.0565
# Epoch 101/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0729 - mean_absolute_error: 0.2375 - val_loss: 0.0058 - val_mean_absolute_error: 0.0557
# Epoch 102/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0721 - mean_absolute_error: 0.2361 - val_loss: 0.0057 - val_mean_absolute_error: 0.0550
# Epoch 103/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0713 - mean_absolute_error: 0.2347 - val_loss: 0.0056 - val_mean_absolute_error: 0.0544
# Epoch 104/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0705 - mean_absolute_error: 0.2333 - val_loss: 0.0055 - val_mean_absolute_error: 0.0537
# Epoch 105/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0696 - mean_absolute_error: 0.2319 - val_loss: 0.0054 - val_mean_absolute_error: 0.0530
# Epoch 106/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0688 - mean_absolute_error: 0.2305 - val_loss: 0.0053 - val_mean_absolute_error: 0.0523
# Epoch 107/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0680 - mean_absolute_error: 0.2290 - val_loss: 0.0051 - val_mean_absolute_error: 0.0517
# Epoch 108/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0672 - mean_absolute_error: 0.2276 - val_loss: 0.0050 - val_mean_absolute_error: 0.0510
# Epoch 109/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0665 - mean_absolute_error: 0.2262 - val_loss: 0.0049 - val_mean_absolute_error: 0.0504
# Epoch 110/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0657 - mean_absolute_error: 0.2249 - val_loss: 0.0048 - val_mean_absolute_error: 0.0498
# Epoch 111/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0649 - mean_absolute_error: 0.2235 - val_loss: 0.0047 - val_mean_absolute_error: 0.0491
# Epoch 112/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0641 - mean_absolute_error: 0.2220 - val_loss: 0.0046 - val_mean_absolute_error: 0.0485
# Epoch 113/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0634 - mean_absolute_error: 0.2206 - val_loss: 0.0045 - val_mean_absolute_error: 0.0480
# Epoch 114/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0626 - mean_absolute_error: 0.2193 - val_loss: 0.0044 - val_mean_absolute_error: 0.0474
# Epoch 115/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0619 - mean_absolute_error: 0.2178 - val_loss: 0.0043 - val_mean_absolute_error: 0.0468
# Epoch 116/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0611 - mean_absolute_error: 0.2164 - val_loss: 0.0043 - val_mean_absolute_error: 0.0462
# Epoch 117/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0603 - mean_absolute_error: 0.2149 - val_loss: 0.0042 - val_mean_absolute_error: 0.0456
# Epoch 118/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0596 - mean_absolute_error: 0.2135 - val_loss: 0.0041 - val_mean_absolute_error: 0.0450
# Epoch 119/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0589 - mean_absolute_error: 0.2121 - val_loss: 0.0040 - val_mean_absolute_error: 0.0445
# Epoch 120/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0582 - mean_absolute_error: 0.2108 - val_loss: 0.0039 - val_mean_absolute_error: 0.0440
# Epoch 121/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0575 - mean_absolute_error: 0.2094 - val_loss: 0.0038 - val_mean_absolute_error: 0.0436
# Epoch 122/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0568 - mean_absolute_error: 0.2081 - val_loss: 0.0038 - val_mean_absolute_error: 0.0433
# Epoch 123/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0561 - mean_absolute_error: 0.2067 - val_loss: 0.0037 - val_mean_absolute_error: 0.0430
# Epoch 124/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0554 - mean_absolute_error: 0.2054 - val_loss: 0.0036 - val_mean_absolute_error: 0.0428
# Epoch 125/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0548 - mean_absolute_error: 0.2040 - val_loss: 0.0035 - val_mean_absolute_error: 0.0426
# Epoch 126/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0541 - mean_absolute_error: 0.2026 - val_loss: 0.0035 - val_mean_absolute_error: 0.0424
# Epoch 127/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0534 - mean_absolute_error: 0.2012 - val_loss: 0.0034 - val_mean_absolute_error: 0.0422
# Epoch 128/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0527 - mean_absolute_error: 0.1998 - val_loss: 0.0033 - val_mean_absolute_error: 0.0422
# Epoch 129/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0520 - mean_absolute_error: 0.1985 - val_loss: 0.0033 - val_mean_absolute_error: 0.0421
# Epoch 130/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0514 - mean_absolute_error: 0.1971 - val_loss: 0.0032 - val_mean_absolute_error: 0.0420
# Epoch 131/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0508 - mean_absolute_error: 0.1958 - val_loss: 0.0032 - val_mean_absolute_error: 0.0420
# Epoch 132/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0502 - mean_absolute_error: 0.1945 - val_loss: 0.0031 - val_mean_absolute_error: 0.0420
# Epoch 133/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0495 - mean_absolute_error: 0.1931 - val_loss: 0.0030 - val_mean_absolute_error: 0.0420
# Epoch 134/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0489 - mean_absolute_error: 0.1918 - val_loss: 0.0030 - val_mean_absolute_error: 0.0420
# Epoch 135/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0483 - mean_absolute_error: 0.1905 - val_loss: 0.0029 - val_mean_absolute_error: 0.0420
# Epoch 136/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0477 - mean_absolute_error: 0.1891 - val_loss: 0.0029 - val_mean_absolute_error: 0.0420
# Epoch 137/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0471 - mean_absolute_error: 0.1878 - val_loss: 0.0028 - val_mean_absolute_error: 0.0419
# Epoch 138/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0465 - mean_absolute_error: 0.1864 - val_loss: 0.0028 - val_mean_absolute_error: 0.0419
# Epoch 139/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0459 - mean_absolute_error: 0.1851 - val_loss: 0.0028 - val_mean_absolute_error: 0.0419
# Epoch 140/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0453 - mean_absolute_error: 0.1838 - val_loss: 0.0027 - val_mean_absolute_error: 0.0419
# Epoch 141/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0447 - mean_absolute_error: 0.1825 - val_loss: 0.0027 - val_mean_absolute_error: 0.0419
# Epoch 142/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0441 - mean_absolute_error: 0.1811 - val_loss: 0.0026 - val_mean_absolute_error: 0.0418
# Epoch 143/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0436 - mean_absolute_error: 0.1799 - val_loss: 0.0026 - val_mean_absolute_error: 0.0418
# Epoch 144/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0430 - mean_absolute_error: 0.1786 - val_loss: 0.0026 - val_mean_absolute_error: 0.0418
# Epoch 145/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0425 - mean_absolute_error: 0.1773 - val_loss: 0.0025 - val_mean_absolute_error: 0.0417
# Epoch 146/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0419 - mean_absolute_error: 0.1760 - val_loss: 0.0025 - val_mean_absolute_error: 0.0417
# Epoch 147/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0414 - mean_absolute_error: 0.1748 - val_loss: 0.0025 - val_mean_absolute_error: 0.0417
# Epoch 148/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0409 - mean_absolute_error: 0.1735 - val_loss: 0.0024 - val_mean_absolute_error: 0.0416
# Epoch 149/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0404 - mean_absolute_error: 0.1723 - val_loss: 0.0024 - val_mean_absolute_error: 0.0416
# Epoch 150/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0399 - mean_absolute_error: 0.1711 - val_loss: 0.0024 - val_mean_absolute_error: 0.0415
# Epoch 151/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0393 - mean_absolute_error: 0.1698 - val_loss: 0.0024 - val_mean_absolute_error: 0.0415
# Epoch 152/200
# ...
# Epoch 19/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0051 - mean_absolute_error: 0.0304 - val_loss: 7.4123e-04 - val_mean_absolute_error: 0.0203
# Epoch 20/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0050 - mean_absolute_error: 0.0311 - val_loss: 7.5880e-04 - val_mean_absolute_error: 0.0207
# Epoch 21/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0050 - mean_absolute_error: 0.0314 - val_loss: 8.3839e-04 - val_mean_absolute_error: 0.0220
# Epoch 22/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0051 - mean_absolute_error: 0.0302 - val_loss: 6.7569e-04 - val_mean_absolute_error: 0.0195
# Epoch 23/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0050 - mean_absolute_error: 0.0303 - val_loss: 6.4594e-04 - val_mean_absolute_error: 0.0191
# Epoch 24/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0050 - mean_absolute_error: 0.0291 - val_loss: 6.3489e-04 - val_mean_absolute_error: 0.0189
# Epoch 25/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0050 - mean_absolute_error: 0.0296 - val_loss: 6.1960e-04 - val_mean_absolute_error: 0.0188
# Epoch 26/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0050 - mean_absolute_error: 0.0312 - val_loss: 7.5953e-04 - val_mean_absolute_error: 0.0205
# Epoch 27/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0050 - mean_absolute_error: 0.0312 - val_loss: 6.7971e-04 - val_mean_absolute_error: 0.0194
# Epoch 28/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0299 - val_loss: 6.6505e-04 - val_mean_absolute_error: 0.0191
# Epoch 29/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0302 - val_loss: 7.8041e-04 - val_mean_absolute_error: 0.0208
# Epoch 30/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0299 - val_loss: 6.7016e-04 - val_mean_absolute_error: 0.0193
# Epoch 31/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0292 - val_loss: 5.6821e-04 - val_mean_absolute_error: 0.0182
# Epoch 32/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0291 - val_loss: 7.1714e-04 - val_mean_absolute_error: 0.0201
# Epoch 33/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0298 - val_loss: 9.3486e-04 - val_mean_absolute_error: 0.0234
# Epoch 34/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0281 - val_loss: 5.5230e-04 - val_mean_absolute_error: 0.0188
# Epoch 35/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0052 - mean_absolute_error: 0.0314 - val_loss: 7.7364e-04 - val_mean_absolute_error: 0.0205
# Epoch 36/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0315 - val_loss: 6.3552e-04 - val_mean_absolute_error: 0.0188
# Epoch 37/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0318 - val_loss: 8.8581e-04 - val_mean_absolute_error: 0.0227
# Epoch 38/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0302 - val_loss: 8.4837e-04 - val_mean_absolute_error: 0.0220
# Epoch 39/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0292 - val_loss: 6.3675e-04 - val_mean_absolute_error: 0.0189
# Epoch 40/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0279 - val_loss: 7.5925e-04 - val_mean_absolute_error: 0.0205
# Epoch 41/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0302 - val_loss: 7.7262e-04 - val_mean_absolute_error: 0.0209
# Epoch 42/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0052 - mean_absolute_error: 0.0305 - val_loss: 5.9168e-04 - val_mean_absolute_error: 0.0197
# Epoch 43/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0051 - mean_absolute_error: 0.0362 - val_loss: 0.0015 - val_mean_absolute_error: 0.0305
# Epoch 44/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0051 - mean_absolute_error: 0.0327 - val_loss: 5.5111e-04 - val_mean_absolute_error: 0.0182
# Epoch 45/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0301 - val_loss: 8.5035e-04 - val_mean_absolute_error: 0.0213
# Epoch 46/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0288 - val_loss: 5.7452e-04 - val_mean_absolute_error: 0.0183
# Epoch 47/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0284 - val_loss: 6.1796e-04 - val_mean_absolute_error: 0.0185
# Epoch 48/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0050 - mean_absolute_error: 0.0284 - val_loss: 5.4048e-04 - val_mean_absolute_error: 0.0183
# Epoch 49/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0297 - val_loss: 8.4161e-04 - val_mean_absolute_error: 0.0220
# Epoch 50/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0308 - val_loss: 0.0010 - val_mean_absolute_error: 0.0249
# Epoch 51/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0284 - val_loss: 8.5734e-04 - val_mean_absolute_error: 0.0245
# Epoch 52/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0094 - mean_absolute_error: 0.0687 - val_loss: 0.0046 - val_mean_absolute_error: 0.0633
# Epoch 53/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0067 - mean_absolute_error: 0.0452 - val_loss: 6.4126e-04 - val_mean_absolute_error: 0.0199
# Epoch 54/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0059 - mean_absolute_error: 0.0467 - val_loss: 0.0017 - val_mean_absolute_error: 0.0339
# Epoch 55/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0053 - mean_absolute_error: 0.0330 - val_loss: 6.2799e-04 - val_mean_absolute_error: 0.0191
# Epoch 56/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0053 - mean_absolute_error: 0.0373 - val_loss: 7.7760e-04 - val_mean_absolute_error: 0.0202
# Epoch 57/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0052 - mean_absolute_error: 0.0308 - val_loss: 6.3737e-04 - val_mean_absolute_error: 0.0191
# Epoch 58/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0322 - val_loss: 6.7819e-04 - val_mean_absolute_error: 0.0192
# 1/1 [==============================] - 0s 8ms/step - loss: 5.4048e-04 - mean_absolute_error: 0.0183
# [I 2024-03-05 22:16:51,831] Trial 98 finished with value: 0.0005404843832366168 and parameters: {'num_filters': 79, 'kernel_size': 5, 'dense_units': 108, 'learning_rate': 0.001}. Best is trial 84 with value: 0.000505490810610354.
# Epoch 1/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.1692 - mean_absolute_error: 0.3541 - val_loss: 0.0024 - val_mean_absolute_error: 0.0422
# Epoch 2/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0162 - mean_absolute_error: 0.0942 - val_loss: 0.0164 - val_mean_absolute_error: 0.1229
# Epoch 3/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0209 - mean_absolute_error: 0.1103 - val_loss: 0.0098 - val_mean_absolute_error: 0.0921
# Epoch 4/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0109 - mean_absolute_error: 0.0615 - val_loss: 0.0018 - val_mean_absolute_error: 0.0382
# Epoch 5/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0100 - mean_absolute_error: 0.0666 - val_loss: 0.0034 - val_mean_absolute_error: 0.0503
# Epoch 6/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0084 - mean_absolute_error: 0.0476 - val_loss: 0.0039 - val_mean_absolute_error: 0.0543
# Epoch 7/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0081 - mean_absolute_error: 0.0467 - val_loss: 0.0018 - val_mean_absolute_error: 0.0361
# Epoch 8/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0073 - mean_absolute_error: 0.0456 - val_loss: 0.0017 - val_mean_absolute_error: 0.0337
# Epoch 9/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0070 - mean_absolute_error: 0.0409 - val_loss: 0.0014 - val_mean_absolute_error: 0.0309
# Epoch 10/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0068 - mean_absolute_error: 0.0382 - val_loss: 0.0012 - val_mean_absolute_error: 0.0283
# Epoch 11/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0065 - mean_absolute_error: 0.0382 - val_loss: 0.0010 - val_mean_absolute_error: 0.0270
# Epoch 12/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0073 - mean_absolute_error: 0.0543 - val_loss: 9.5093e-04 - val_mean_absolute_error: 0.0258
# Epoch 13/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0069 - mean_absolute_error: 0.0409 - val_loss: 0.0025 - val_mean_absolute_error: 0.0416
# Epoch 14/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0062 - mean_absolute_error: 0.0376 - val_loss: 9.3040e-04 - val_mean_absolute_error: 0.0250
# Epoch 15/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0062 - mean_absolute_error: 0.0444 - val_loss: 0.0012 - val_mean_absolute_error: 0.0264
# Epoch 16/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0057 - mean_absolute_error: 0.0348 - val_loss: 0.0012 - val_mean_absolute_error: 0.0270
# Epoch 17/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0056 - mean_absolute_error: 0.0337 - val_loss: 9.4197e-04 - val_mean_absolute_error: 0.0237
# Epoch 18/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0055 - mean_absolute_error: 0.0327 - val_loss: 7.9912e-04 - val_mean_absolute_error: 0.0222
# Epoch 19/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0055 - mean_absolute_error: 0.0375 - val_loss: 9.4303e-04 - val_mean_absolute_error: 0.0232
# Epoch 20/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0057 - mean_absolute_error: 0.0326 - val_loss: 8.0468e-04 - val_mean_absolute_error: 0.0214
# Epoch 21/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0057 - mean_absolute_error: 0.0410 - val_loss: 9.4225e-04 - val_mean_absolute_error: 0.0235
# Epoch 22/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0057 - mean_absolute_error: 0.0333 - val_loss: 0.0010 - val_mean_absolute_error: 0.0246
# Epoch 23/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0052 - mean_absolute_error: 0.0353 - val_loss: 7.9276e-04 - val_mean_absolute_error: 0.0212
# Epoch 24/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0053 - mean_absolute_error: 0.0309 - val_loss: 8.9695e-04 - val_mean_absolute_error: 0.0228
# Epoch 25/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0051 - mean_absolute_error: 0.0321 - val_loss: 7.2350e-04 - val_mean_absolute_error: 0.0200
# Epoch 26/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0051 - mean_absolute_error: 0.0299 - val_loss: 8.9050e-04 - val_mean_absolute_error: 0.0229
# Epoch 27/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0051 - mean_absolute_error: 0.0320 - val_loss: 0.0011 - val_mean_absolute_error: 0.0263
# Epoch 28/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0050 - mean_absolute_error: 0.0290 - val_loss: 7.4430e-04 - val_mean_absolute_error: 0.0209
# Epoch 29/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0320 - val_loss: 9.3544e-04 - val_mean_absolute_error: 0.0238
# Epoch 30/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0050 - mean_absolute_error: 0.0291 - val_loss: 8.5050e-04 - val_mean_absolute_error: 0.0227
# Epoch 31/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0303 - val_loss: 0.0010 - val_mean_absolute_error: 0.0247
# Epoch 32/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0050 - mean_absolute_error: 0.0283 - val_loss: 5.8117e-04 - val_mean_absolute_error: 0.0189
# Epoch 33/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0050 - mean_absolute_error: 0.0315 - val_loss: 7.5637e-04 - val_mean_absolute_error: 0.0212
# Epoch 34/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0050 - mean_absolute_error: 0.0315 - val_loss: 0.0011 - val_mean_absolute_error: 0.0254
# Epoch 35/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0051 - mean_absolute_error: 0.0300 - val_loss: 7.0410e-04 - val_mean_absolute_error: 0.0206
# Epoch 36/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0050 - mean_absolute_error: 0.0303 - val_loss: 6.2480e-04 - val_mean_absolute_error: 0.0194
# Epoch 37/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0062 - mean_absolute_error: 0.0493 - val_loss: 0.0013 - val_mean_absolute_error: 0.0290
# Epoch 38/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0055 - mean_absolute_error: 0.0343 - val_loss: 0.0010 - val_mean_absolute_error: 0.0255
# Epoch 39/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0050 - mean_absolute_error: 0.0362 - val_loss: 0.0011 - val_mean_absolute_error: 0.0257
# Epoch 40/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0053 - mean_absolute_error: 0.0308 - val_loss: 7.5923e-04 - val_mean_absolute_error: 0.0210
# Epoch 41/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0051 - mean_absolute_error: 0.0329 - val_loss: 9.4460e-04 - val_mean_absolute_error: 0.0236
# Epoch 42/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0051 - mean_absolute_error: 0.0286 - val_loss: 5.6300e-04 - val_mean_absolute_error: 0.0188
# Epoch 43/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0053 - mean_absolute_error: 0.0394 - val_loss: 0.0015 - val_mean_absolute_error: 0.0317
# Epoch 44/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0056 - mean_absolute_error: 0.0332 - val_loss: 8.5049e-04 - val_mean_absolute_error: 0.0227
# Epoch 45/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0050 - mean_absolute_error: 0.0333 - val_loss: 9.1947e-04 - val_mean_absolute_error: 0.0235
# Epoch 46/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0052 - mean_absolute_error: 0.0293 - val_loss: 5.9667e-04 - val_mean_absolute_error: 0.0186
# Epoch 47/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0306 - val_loss: 6.5186e-04 - val_mean_absolute_error: 0.0194
# Epoch 48/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0285 - val_loss: 8.2922e-04 - val_mean_absolute_error: 0.0223
# Epoch 49/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0283 - val_loss: 7.3546e-04 - val_mean_absolute_error: 0.0212
# Epoch 50/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0308 - val_loss: 9.8440e-04 - val_mean_absolute_error: 0.0245
# Epoch 51/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0051 - mean_absolute_error: 0.0285 - val_loss: 6.2683e-04 - val_mean_absolute_error: 0.0193
# Epoch 52/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0290 - val_loss: 8.1011e-04 - val_mean_absolute_error: 0.0221
# 1/1 [==============================] - 0s 8ms/step - loss: 5.6300e-04 - mean_absolute_error: 0.0188
# [I 2024-03-05 22:16:52,880] Trial 99 finished with value: 0.000563000445254147 and parameters: {'num_filters': 61, 'kernel_size': 5, 'dense_units': 124, 'learning_rate': 0.001}. Best is trial 84 with value: 0.000505490810610354.
# Best hyperparameters: {'num_filters': 112, 'kernel_size': 5, 'dense_units': 124, 'learning_rate': 0.001}

# %%
best_params
# Out:
# {'num_filters': 112,
#  'kernel_size': 5,
#  'dense_units': 124,
#  'learning_rate': 0.001}

# %%
#best_lstm_units = best_params['lstm_units']
#best_gru_units = best_params['gru_units']
num_filters = best_params['num_filters']
kernel_size = best_params['kernel_size']
best_dense_units = best_params['dense_units']
best_learning_rate = best_params['learning_rate']
#best_num_lstm_layers = best_params['num_lstm_layers']
model = Sequential([
    layers.Input((shift, 1)),
    #layers.LSTM(best_lstm_units),
    #layers.Bidirectional(layers.LSTM(best_lstm_units)),
    #layers.GRU(best_gru_units),
    layers.Conv1D(num_filters, kernel_size, activation='relu',padding='same'),
    layers.MaxPooling1D(),
    layers.Flatten(),
    layers.Dense(best_dense_units, activation='relu'),
    layers.Dense(1)
])
'''
model = Sequential()
model.add(layers.Input((shift, 1)))
for _ in range(2):
    model.add(layers.LSTM(best_lstm_units, return_sequences=True))
model.add(layers.Flatten())
model.add(layers.Dense(best_dense_units, activation='relu'))
model.add(layers.Dense(1))'''


# Compile the final model
model.compile(loss='mse', 
                optimizer=Adam(learning_rate=best_learning_rate),
                metrics=['mean_absolute_error'])

# Train the final model on the entire training data
h=model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=200)
# Out:
# Epoch 1/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.1403 - mean_absolute_error: 0.3301 - val_loss: 0.0036 - val_mean_absolute_error: 0.0420
# Epoch 2/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0234 - mean_absolute_error: 0.1206 - val_loss: 0.0096 - val_mean_absolute_error: 0.0922
# Epoch 3/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0141 - mean_absolute_error: 0.0833 - val_loss: 0.0079 - val_mean_absolute_error: 0.0825
# Epoch 4/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0083 - mean_absolute_error: 0.0529 - val_loss: 0.0011 - val_mean_absolute_error: 0.0285
# Epoch 5/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0081 - mean_absolute_error: 0.0544 - val_loss: 0.0031 - val_mean_absolute_error: 0.0481
# Epoch 6/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0070 - mean_absolute_error: 0.0401 - val_loss: 0.0011 - val_mean_absolute_error: 0.0278
# Epoch 7/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0064 - mean_absolute_error: 0.0420 - val_loss: 0.0011 - val_mean_absolute_error: 0.0266
# Epoch 8/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0062 - mean_absolute_error: 0.0354 - val_loss: 9.8285e-04 - val_mean_absolute_error: 0.0252
# Epoch 9/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0061 - mean_absolute_error: 0.0362 - val_loss: 9.3713e-04 - val_mean_absolute_error: 0.0245
# Epoch 10/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0065 - mean_absolute_error: 0.0351 - val_loss: 8.0079e-04 - val_mean_absolute_error: 0.0229
# Epoch 11/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0061 - mean_absolute_error: 0.0445 - val_loss: 9.8951e-04 - val_mean_absolute_error: 0.0243
# Epoch 12/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0061 - mean_absolute_error: 0.0349 - val_loss: 0.0010 - val_mean_absolute_error: 0.0247
# Epoch 13/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0058 - mean_absolute_error: 0.0398 - val_loss: 0.0013 - val_mean_absolute_error: 0.0279
# Epoch 14/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0060 - mean_absolute_error: 0.0345 - val_loss: 7.7646e-04 - val_mean_absolute_error: 0.0219
# Epoch 15/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0055 - mean_absolute_error: 0.0377 - val_loss: 8.8629e-04 - val_mean_absolute_error: 0.0227
# Epoch 16/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0053 - mean_absolute_error: 0.0321 - val_loss: 9.9355e-04 - val_mean_absolute_error: 0.0244
# Epoch 17/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0052 - mean_absolute_error: 0.0326 - val_loss: 6.4620e-04 - val_mean_absolute_error: 0.0204
# Epoch 18/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0052 - mean_absolute_error: 0.0314 - val_loss: 8.5691e-04 - val_mean_absolute_error: 0.0223
# Epoch 19/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0052 - mean_absolute_error: 0.0307 - val_loss: 8.5814e-04 - val_mean_absolute_error: 0.0224
# Epoch 20/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0051 - mean_absolute_error: 0.0311 - val_loss: 8.4177e-04 - val_mean_absolute_error: 0.0222
# Epoch 21/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0052 - mean_absolute_error: 0.0315 - val_loss: 7.8245e-04 - val_mean_absolute_error: 0.0214
# Epoch 22/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0051 - mean_absolute_error: 0.0305 - val_loss: 6.6583e-04 - val_mean_absolute_error: 0.0198
# Epoch 23/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0050 - mean_absolute_error: 0.0324 - val_loss: 7.5392e-04 - val_mean_absolute_error: 0.0208
# Epoch 24/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0050 - mean_absolute_error: 0.0313 - val_loss: 8.0127e-04 - val_mean_absolute_error: 0.0214
# Epoch 25/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0050 - mean_absolute_error: 0.0302 - val_loss: 6.1584e-04 - val_mean_absolute_error: 0.0195
# Epoch 26/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0051 - mean_absolute_error: 0.0293 - val_loss: 6.8846e-04 - val_mean_absolute_error: 0.0200
# Epoch 27/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0050 - mean_absolute_error: 0.0306 - val_loss: 7.2310e-04 - val_mean_absolute_error: 0.0207
# Epoch 28/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0052 - mean_absolute_error: 0.0337 - val_loss: 0.0014 - val_mean_absolute_error: 0.0303
# Epoch 29/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0053 - mean_absolute_error: 0.0340 - val_loss: 0.0010 - val_mean_absolute_error: 0.0246
# Epoch 30/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0050 - mean_absolute_error: 0.0299 - val_loss: 6.6122e-04 - val_mean_absolute_error: 0.0198
# Epoch 31/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0051 - mean_absolute_error: 0.0354 - val_loss: 0.0014 - val_mean_absolute_error: 0.0291
# Epoch 32/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0053 - mean_absolute_error: 0.0317 - val_loss: 5.9867e-04 - val_mean_absolute_error: 0.0196
# Epoch 33/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0315 - val_loss: 0.0011 - val_mean_absolute_error: 0.0252
# Epoch 34/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0051 - mean_absolute_error: 0.0307 - val_loss: 6.0139e-04 - val_mean_absolute_error: 0.0194
# Epoch 35/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0051 - mean_absolute_error: 0.0302 - val_loss: 6.7204e-04 - val_mean_absolute_error: 0.0197
# Epoch 36/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0290 - val_loss: 6.3196e-04 - val_mean_absolute_error: 0.0196
# Epoch 37/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0050 - mean_absolute_error: 0.0313 - val_loss: 7.9546e-04 - val_mean_absolute_error: 0.0218
# Epoch 38/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0290 - val_loss: 8.1078e-04 - val_mean_absolute_error: 0.0221
# Epoch 39/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0306 - val_loss: 0.0012 - val_mean_absolute_error: 0.0270
# Epoch 40/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0285 - val_loss: 7.9896e-04 - val_mean_absolute_error: 0.0231
# Epoch 41/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0081 - mean_absolute_error: 0.0587 - val_loss: 0.0046 - val_mean_absolute_error: 0.0628
# Epoch 42/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0059 - mean_absolute_error: 0.0431 - val_loss: 6.3430e-04 - val_mean_absolute_error: 0.0206
# Epoch 43/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0055 - mean_absolute_error: 0.0356 - val_loss: 0.0014 - val_mean_absolute_error: 0.0296
# Epoch 44/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0312 - val_loss: 5.9986e-04 - val_mean_absolute_error: 0.0197
# Epoch 45/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0051 - mean_absolute_error: 0.0304 - val_loss: 6.4278e-04 - val_mean_absolute_error: 0.0193
# Epoch 46/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0050 - mean_absolute_error: 0.0303 - val_loss: 5.8201e-04 - val_mean_absolute_error: 0.0197
# Epoch 47/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0087 - mean_absolute_error: 0.0668 - val_loss: 0.0040 - val_mean_absolute_error: 0.0585
# Epoch 48/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0088 - mean_absolute_error: 0.0627 - val_loss: 0.0016 - val_mean_absolute_error: 0.0332
# Epoch 49/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0077 - mean_absolute_error: 0.0583 - val_loss: 0.0016 - val_mean_absolute_error: 0.0323
# Epoch 50/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0061 - mean_absolute_error: 0.0403 - val_loss: 9.0411e-04 - val_mean_absolute_error: 0.0222
# Epoch 51/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0054 - mean_absolute_error: 0.0391 - val_loss: 6.7779e-04 - val_mean_absolute_error: 0.0204
# Epoch 52/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0051 - mean_absolute_error: 0.0302 - val_loss: 8.2119e-04 - val_mean_absolute_error: 0.0211
# Epoch 53/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0319 - val_loss: 6.8408e-04 - val_mean_absolute_error: 0.0198
# Epoch 54/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0052 - mean_absolute_error: 0.0300 - val_loss: 7.8504e-04 - val_mean_absolute_error: 0.0209
# Epoch 55/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0052 - mean_absolute_error: 0.0357 - val_loss: 8.0466e-04 - val_mean_absolute_error: 0.0213
# Epoch 56/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0292 - val_loss: 0.0010 - val_mean_absolute_error: 0.0248
# Epoch 57/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0050 - mean_absolute_error: 0.0317 - val_loss: 7.0137e-04 - val_mean_absolute_error: 0.0198
# Epoch 58/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0293 - val_loss: 8.8927e-04 - val_mean_absolute_error: 0.0226
# Epoch 59/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0286 - val_loss: 6.4939e-04 - val_mean_absolute_error: 0.0190
# Epoch 60/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0050 - mean_absolute_error: 0.0285 - val_loss: 5.7276e-04 - val_mean_absolute_error: 0.0185
# Epoch 61/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0050 - mean_absolute_error: 0.0307 - val_loss: 6.9708e-04 - val_mean_absolute_error: 0.0196
# Epoch 62/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0295 - val_loss: 7.4405e-04 - val_mean_absolute_error: 0.0206
# Epoch 63/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0051 - mean_absolute_error: 0.0296 - val_loss: 5.9086e-04 - val_mean_absolute_error: 0.0185
# Epoch 64/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0304 - val_loss: 7.2200e-04 - val_mean_absolute_error: 0.0200
# Epoch 65/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0301 - val_loss: 0.0011 - val_mean_absolute_error: 0.0262
# Epoch 66/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0296 - val_loss: 6.0235e-04 - val_mean_absolute_error: 0.0187
# Epoch 67/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0291 - val_loss: 5.4385e-04 - val_mean_absolute_error: 0.0186
# Epoch 68/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0078 - mean_absolute_error: 0.0632 - val_loss: 0.0024 - val_mean_absolute_error: 0.0433
# Epoch 69/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0061 - mean_absolute_error: 0.0415 - val_loss: 0.0016 - val_mean_absolute_error: 0.0330
# Epoch 70/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0050 - mean_absolute_error: 0.0356 - val_loss: 8.5940e-04 - val_mean_absolute_error: 0.0220
# Epoch 71/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0051 - mean_absolute_error: 0.0299 - val_loss: 7.6002e-04 - val_mean_absolute_error: 0.0201
# Epoch 72/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0321 - val_loss: 6.7892e-04 - val_mean_absolute_error: 0.0194
# Epoch 73/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0286 - val_loss: 6.4953e-04 - val_mean_absolute_error: 0.0192
# Epoch 74/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0050 - mean_absolute_error: 0.0316 - val_loss: 8.8030e-04 - val_mean_absolute_error: 0.0223
# Epoch 75/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0050 - mean_absolute_error: 0.0292 - val_loss: 5.6917e-04 - val_mean_absolute_error: 0.0184
# Epoch 76/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0051 - mean_absolute_error: 0.0312 - val_loss: 8.8919e-04 - val_mean_absolute_error: 0.0227
# Epoch 77/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0306 - val_loss: 8.8046e-04 - val_mean_absolute_error: 0.0227
# Epoch 78/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0050 - mean_absolute_error: 0.0287 - val_loss: 6.1055e-04 - val_mean_absolute_error: 0.0186
# Epoch 79/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0317 - val_loss: 8.4582e-04 - val_mean_absolute_error: 0.0220
# Epoch 80/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0282 - val_loss: 7.7768e-04 - val_mean_absolute_error: 0.0210
# Epoch 81/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0283 - val_loss: 6.8419e-04 - val_mean_absolute_error: 0.0195
# Epoch 82/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0283 - val_loss: 7.4570e-04 - val_mean_absolute_error: 0.0203
# Epoch 83/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0278 - val_loss: 6.5874e-04 - val_mean_absolute_error: 0.0193
# Epoch 84/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0286 - val_loss: 6.8787e-04 - val_mean_absolute_error: 0.0198
# Epoch 85/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0298 - val_loss: 9.9091e-04 - val_mean_absolute_error: 0.0244
# Epoch 86/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0292 - val_loss: 5.8135e-04 - val_mean_absolute_error: 0.0185
# Epoch 87/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0289 - val_loss: 7.6982e-04 - val_mean_absolute_error: 0.0211
# Epoch 88/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0310 - val_loss: 9.6753e-04 - val_mean_absolute_error: 0.0242
# Epoch 89/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0289 - val_loss: 7.6460e-04 - val_mean_absolute_error: 0.0214
# Epoch 90/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0287 - val_loss: 6.8678e-04 - val_mean_absolute_error: 0.0201
# Epoch 91/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0299 - val_loss: 0.0012 - val_mean_absolute_error: 0.0270
# Epoch 92/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0288 - val_loss: 5.4072e-04 - val_mean_absolute_error: 0.0184
# Epoch 93/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0314 - val_loss: 0.0013 - val_mean_absolute_error: 0.0286
# Epoch 94/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0051 - mean_absolute_error: 0.0308 - val_loss: 5.3595e-04 - val_mean_absolute_error: 0.0187
# Epoch 95/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0050 - mean_absolute_error: 0.0324 - val_loss: 0.0012 - val_mean_absolute_error: 0.0272
# Epoch 96/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0047 - mean_absolute_error: 0.0282 - val_loss: 5.4027e-04 - val_mean_absolute_error: 0.0186
# Epoch 97/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0298 - val_loss: 7.7172e-04 - val_mean_absolute_error: 0.0209
# Epoch 98/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0284 - val_loss: 5.7584e-04 - val_mean_absolute_error: 0.0183
# Epoch 99/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0050 - mean_absolute_error: 0.0340 - val_loss: 0.0012 - val_mean_absolute_error: 0.0272
# Epoch 100/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0050 - mean_absolute_error: 0.0294 - val_loss: 5.2956e-04 - val_mean_absolute_error: 0.0184
# Epoch 101/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0330 - val_loss: 0.0012 - val_mean_absolute_error: 0.0272
# Epoch 102/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0286 - val_loss: 5.7195e-04 - val_mean_absolute_error: 0.0181
# Epoch 103/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0279 - val_loss: 5.9461e-04 - val_mean_absolute_error: 0.0184
# Epoch 104/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0290 - val_loss: 6.8219e-04 - val_mean_absolute_error: 0.0199
# Epoch 105/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0279 - val_loss: 5.2630e-04 - val_mean_absolute_error: 0.0180
# Epoch 106/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0339 - val_loss: 0.0010 - val_mean_absolute_error: 0.0253
# Epoch 107/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0292 - val_loss: 6.2192e-04 - val_mean_absolute_error: 0.0190
# Epoch 108/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0047 - mean_absolute_error: 0.0284 - val_loss: 6.6659e-04 - val_mean_absolute_error: 0.0194
# Epoch 109/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0274 - val_loss: 5.7902e-04 - val_mean_absolute_error: 0.0181
# Epoch 110/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0276 - val_loss: 5.9084e-04 - val_mean_absolute_error: 0.0182
# Epoch 111/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0310 - val_loss: 8.6402e-04 - val_mean_absolute_error: 0.0224
# Epoch 112/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0287 - val_loss: 5.3024e-04 - val_mean_absolute_error: 0.0180
# Epoch 113/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0294 - val_loss: 7.8031e-04 - val_mean_absolute_error: 0.0213
# Epoch 114/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0047 - mean_absolute_error: 0.0287 - val_loss: 6.0103e-04 - val_mean_absolute_error: 0.0188
# Epoch 115/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0286 - val_loss: 8.1048e-04 - val_mean_absolute_error: 0.0218
# Epoch 116/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0292 - val_loss: 7.1580e-04 - val_mean_absolute_error: 0.0205
# Epoch 117/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0278 - val_loss: 5.9402e-04 - val_mean_absolute_error: 0.0187
# Epoch 118/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0313 - val_loss: 0.0011 - val_mean_absolute_error: 0.0262
# Epoch 119/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0294 - val_loss: 5.4289e-04 - val_mean_absolute_error: 0.0188
# Epoch 120/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0054 - mean_absolute_error: 0.0357 - val_loss: 0.0012 - val_mean_absolute_error: 0.0275
# Epoch 121/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0305 - val_loss: 5.5025e-04 - val_mean_absolute_error: 0.0187
# Epoch 122/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0293 - val_loss: 7.0339e-04 - val_mean_absolute_error: 0.0200
# Epoch 123/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0311 - val_loss: 9.5642e-04 - val_mean_absolute_error: 0.0238
# Epoch 124/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0279 - val_loss: 5.5378e-04 - val_mean_absolute_error: 0.0191
# Epoch 125/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0050 - mean_absolute_error: 0.0329 - val_loss: 0.0011 - val_mean_absolute_error: 0.0268
# Epoch 126/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0047 - mean_absolute_error: 0.0283 - val_loss: 5.5795e-04 - val_mean_absolute_error: 0.0192
# Epoch 127/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0051 - mean_absolute_error: 0.0325 - val_loss: 8.3829e-04 - val_mean_absolute_error: 0.0218
# Epoch 128/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0301 - val_loss: 7.0753e-04 - val_mean_absolute_error: 0.0202
# Epoch 129/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0285 - val_loss: 5.5284e-04 - val_mean_absolute_error: 0.0184
# Epoch 130/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0050 - mean_absolute_error: 0.0345 - val_loss: 0.0015 - val_mean_absolute_error: 0.0318
# Epoch 131/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0294 - val_loss: 5.3220e-04 - val_mean_absolute_error: 0.0183
# Epoch 132/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0050 - mean_absolute_error: 0.0320 - val_loss: 6.8003e-04 - val_mean_absolute_error: 0.0198
# Epoch 133/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0053 - mean_absolute_error: 0.0353 - val_loss: 0.0016 - val_mean_absolute_error: 0.0338
# Epoch 134/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0304 - val_loss: 5.5132e-04 - val_mean_absolute_error: 0.0183
# Epoch 135/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0309 - val_loss: 0.0011 - val_mean_absolute_error: 0.0260
# Epoch 136/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0293 - val_loss: 5.4560e-04 - val_mean_absolute_error: 0.0189
# Epoch 137/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0047 - mean_absolute_error: 0.0299 - val_loss: 0.0011 - val_mean_absolute_error: 0.0256
# Epoch 138/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0047 - mean_absolute_error: 0.0286 - val_loss: 5.7639e-04 - val_mean_absolute_error: 0.0186
# Epoch 139/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0281 - val_loss: 6.9801e-04 - val_mean_absolute_error: 0.0201
# Epoch 140/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0047 - mean_absolute_error: 0.0280 - val_loss: 6.7885e-04 - val_mean_absolute_error: 0.0199
# Epoch 141/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0281 - val_loss: 5.3580e-04 - val_mean_absolute_error: 0.0180
# Epoch 142/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0300 - val_loss: 7.9001e-04 - val_mean_absolute_error: 0.0215
# Epoch 143/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0047 - mean_absolute_error: 0.0269 - val_loss: 5.3137e-04 - val_mean_absolute_error: 0.0180
# Epoch 144/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0295 - val_loss: 9.3463e-04 - val_mean_absolute_error: 0.0236
# Epoch 145/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0047 - mean_absolute_error: 0.0282 - val_loss: 5.6776e-04 - val_mean_absolute_error: 0.0186
# Epoch 146/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0296 - val_loss: 6.3728e-04 - val_mean_absolute_error: 0.0193
# Epoch 147/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0047 - mean_absolute_error: 0.0290 - val_loss: 9.7530e-04 - val_mean_absolute_error: 0.0243
# Epoch 148/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0050 - mean_absolute_error: 0.0308 - val_loss: 5.3478e-04 - val_mean_absolute_error: 0.0187
# Epoch 149/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0294 - val_loss: 8.3876e-04 - val_mean_absolute_error: 0.0221
# Epoch 150/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0304 - val_loss: 6.0769e-04 - val_mean_absolute_error: 0.0189
# Epoch 151/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0286 - val_loss: 6.0327e-04 - val_mean_absolute_error: 0.0190
# Epoch 152/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0311 - val_loss: 0.0010 - val_mean_absolute_error: 0.0254
# Epoch 153/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0308 - val_loss: 7.6856e-04 - val_mean_absolute_error: 0.0212
# Epoch 154/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0051 - mean_absolute_error: 0.0294 - val_loss: 5.5257e-04 - val_mean_absolute_error: 0.0184
# Epoch 155/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0304 - val_loss: 9.8131e-04 - val_mean_absolute_error: 0.0242
# Epoch 156/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0296 - val_loss: 6.1017e-04 - val_mean_absolute_error: 0.0188
# Epoch 157/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0047 - mean_absolute_error: 0.0283 - val_loss: 6.8431e-04 - val_mean_absolute_error: 0.0202
# Epoch 158/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0283 - val_loss: 5.1417e-04 - val_mean_absolute_error: 0.0182
# Epoch 159/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0051 - mean_absolute_error: 0.0338 - val_loss: 9.6184e-04 - val_mean_absolute_error: 0.0241
# Epoch 160/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0047 - mean_absolute_error: 0.0278 - val_loss: 5.7051e-04 - val_mean_absolute_error: 0.0186
# Epoch 161/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0282 - val_loss: 6.5684e-04 - val_mean_absolute_error: 0.0198
# Epoch 162/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0317 - val_loss: 0.0013 - val_mean_absolute_error: 0.0302
# Epoch 163/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0297 - val_loss: 5.8499e-04 - val_mean_absolute_error: 0.0199
# Epoch 164/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0054 - mean_absolute_error: 0.0337 - val_loss: 0.0010 - val_mean_absolute_error: 0.0250
# Epoch 165/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0302 - val_loss: 5.4400e-04 - val_mean_absolute_error: 0.0181
# Epoch 166/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0051 - mean_absolute_error: 0.0302 - val_loss: 5.5513e-04 - val_mean_absolute_error: 0.0181
# Epoch 167/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0047 - mean_absolute_error: 0.0300 - val_loss: 9.2453e-04 - val_mean_absolute_error: 0.0234
# Epoch 168/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0304 - val_loss: 6.2656e-04 - val_mean_absolute_error: 0.0192
# Epoch 169/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0047 - mean_absolute_error: 0.0284 - val_loss: 6.1298e-04 - val_mean_absolute_error: 0.0189
# Epoch 170/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0316 - val_loss: 9.0942e-04 - val_mean_absolute_error: 0.0230
# Epoch 171/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0050 - mean_absolute_error: 0.0298 - val_loss: 5.2769e-04 - val_mean_absolute_error: 0.0184
# Epoch 172/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0050 - mean_absolute_error: 0.0283 - val_loss: 5.3162e-04 - val_mean_absolute_error: 0.0182
# Epoch 173/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0309 - val_loss: 8.5305e-04 - val_mean_absolute_error: 0.0225
# Epoch 174/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0290 - val_loss: 6.7195e-04 - val_mean_absolute_error: 0.0200
# Epoch 175/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0284 - val_loss: 5.1430e-04 - val_mean_absolute_error: 0.0181
# Epoch 176/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0334 - val_loss: 0.0020 - val_mean_absolute_error: 0.0387
# Epoch 177/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0051 - mean_absolute_error: 0.0319 - val_loss: 5.4448e-04 - val_mean_absolute_error: 0.0181
# Epoch 178/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0053 - mean_absolute_error: 0.0314 - val_loss: 5.3997e-04 - val_mean_absolute_error: 0.0187
# Epoch 179/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0311 - val_loss: 6.6487e-04 - val_mean_absolute_error: 0.0197
# Epoch 180/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0047 - mean_absolute_error: 0.0307 - val_loss: 6.8551e-04 - val_mean_absolute_error: 0.0203
# Epoch 181/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0289 - val_loss: 5.6011e-04 - val_mean_absolute_error: 0.0186
# Epoch 182/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0310 - val_loss: 9.2260e-04 - val_mean_absolute_error: 0.0235
# Epoch 183/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0047 - mean_absolute_error: 0.0299 - val_loss: 7.3919e-04 - val_mean_absolute_error: 0.0206
# Epoch 184/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0047 - mean_absolute_error: 0.0298 - val_loss: 8.3130e-04 - val_mean_absolute_error: 0.0219
# Epoch 185/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0279 - val_loss: 5.2786e-04 - val_mean_absolute_error: 0.0184
# Epoch 186/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0350 - val_loss: 0.0018 - val_mean_absolute_error: 0.0360
# Epoch 187/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0310 - val_loss: 0.0015 - val_mean_absolute_error: 0.0331
# Epoch 188/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0088 - mean_absolute_error: 0.0688 - val_loss: 0.0059 - val_mean_absolute_error: 0.0727
# Epoch 189/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0070 - mean_absolute_error: 0.0528 - val_loss: 0.0012 - val_mean_absolute_error: 0.0271
# Epoch 190/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0055 - mean_absolute_error: 0.0397 - val_loss: 9.3865e-04 - val_mean_absolute_error: 0.0229
# Epoch 191/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0314 - val_loss: 7.9131e-04 - val_mean_absolute_error: 0.0214
# Epoch 192/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0050 - mean_absolute_error: 0.0296 - val_loss: 6.7967e-04 - val_mean_absolute_error: 0.0213
# Epoch 193/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0320 - val_loss: 0.0011 - val_mean_absolute_error: 0.0267
# Epoch 194/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0305 - val_loss: 6.1056e-04 - val_mean_absolute_error: 0.0182
# Epoch 195/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0288 - val_loss: 6.5714e-04 - val_mean_absolute_error: 0.0184
# Epoch 196/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0293 - val_loss: 6.3134e-04 - val_mean_absolute_error: 0.0184
# Epoch 197/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0282 - val_loss: 5.4816e-04 - val_mean_absolute_error: 0.0181
# Epoch 198/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0295 - val_loss: 6.2175e-04 - val_mean_absolute_error: 0.0181
# Epoch 199/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0296 - val_loss: 6.5444e-04 - val_mean_absolute_error: 0.0187
# Epoch 200/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0290 - val_loss: 5.9633e-04 - val_mean_absolute_error: 0.0179

# %%
train_loss = model.evaluate(X_train, y_train, verbose=0)
print(f'Training Loss: {train_loss}')
test_loss = model.evaluate(X_test, y_test, verbose=0)
print(f'Testing Loss: {test_loss}')

plt.plot(h.history['loss'], label='Training Loss')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Training Loss: [0.0046949624083936214, 0.028580669313669205]
# Testing Loss: [0.00046387803740799427, 0.017828384414315224]

# %%
train_predictions = model.predict(X_train)

plt.plot(dates_train, train_predictions,linestyle="-", marker='o', markersize=3)
plt.plot(dates_train, y_train, linestyle="--", marker='x', markersize=3)

##plt.plot(train_predictions)
##plt.plot(y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 8/8 [==============================] - 0s 467us/step

# %%
val_predictions = model.predict(X_val)#.flatten()

plt.plot(dates_val, val_predictions,linestyle="-", marker='o', markersize=3)
plt.plot(dates_val, y_val,linestyle="--", marker='x', markersize=3)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 1/1 [==============================] - 0s 12ms/step

# %%
test_predictions = model.predict(X_test)#.flatten()

plt.plot(dates_test, test_predictions,linestyle="-", marker='o', markersize=3)
plt.plot(dates_test, y_test,linestyle="--", marker='x', markersize=3)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 1/1 [==============================] - 0s 10ms/step

# %%
#test_predictions

# %%
# Inverse transform to get actual prices
y_train_actual = scaler.inverse_transform(y_train.reshape(-1, 1))
y_test_actual = scaler.inverse_transform(y_test.reshape(-1, 1))
y_train_pred_actual = scaler.inverse_transform(train_predictions.reshape(-1,1))
y_test_pred_actual = scaler.inverse_transform(test_predictions.reshape(-1,1))
y_val_pred_actual = scaler.inverse_transform(val_predictions.reshape(-1,1))
y_val_actual = scaler.inverse_transform(y_val.reshape(-1,1))

# %%
# Calculate evaluation metrics
train_mae = mean_absolute_error(y_train_actual, y_train_pred_actual)
train_mse = mean_squared_error(y_train_actual, y_train_pred_actual)
val_mae = mean_absolute_error(y_val_actual, y_val_pred_actual)
test_mae = mean_absolute_error(y_test_actual, y_test_pred_actual)
test_mse = mean_squared_error(y_test_actual, y_test_pred_actual)
val_mse = mean_squared_error(y_val_actual, y_val_pred_actual)

print(f'Training MAE: {train_mae}')
print(f'Training MSE: {train_mse}')
print(f'Val MAE: {val_mae}')
print(f'Val MSE: {val_mse}')
print(f'Testing MAE: {test_mae}')
print(f'Testing MSE: {test_mse}')


train_r = np.sqrt(train_mse)
train_r2 = r2_score(y_train_actual, y_train_pred_actual)
test_r = np.sqrt(test_mse)
test_r2 = r2_score(y_test_actual, y_test_pred_actual)
val_r = np.sqrt(val_mse)
val_r2 = r2_score(y_val_actual, y_val_pred_actual)


print(train_r)
print(train_r2)
print(val_r)
print(val_r2)
print(test_r)
print(test_r2)
# Out:
# Training MAE: 5.850461006164551
# Training MSE: 196.72869873046875
# Val MAE: 3.6588244438171387
# Val MSE: 24.987548828125
# Testing MAE: 3.6494715213775635
# Testing MSE: 19.437480926513672
# 14.026001
# 0.912585681588982
# 4.9987545
# 0.9160737748311767
# 4.408796
# 0.9023198752822621

# %%
model.save('maize_cnn')
# Out:
# INFO:tensorflow:Assets written to: maize_cnn/assets
# INFO:tensorflow:Assets written to: maize_cnn/assets

# %%
import tensorflow as tf
m1=tf.keras.models.load_model('maize_cnn')
m1.layers[0].input_shape
# Out:
# (None, 3, 1)

# %%
test_predictions = m1.predict(X_test)#.flatten()

y_test_actual = scaler.inverse_transform(y_test.reshape(-1, 1))
y_test_pred_actual = scaler.inverse_transform(test_predictions.reshape(-1,1))

test_r2 = r2_score(y_test_actual, y_test_pred_actual)
print(test_r2)
#plt.plot(dates_test, test_predictions)
#plt.plot(dates_test, y_test)
#plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 1/1 [==============================] - 0s 34ms/step
# 0.9023198752822621

# %%
plt.plot(figsize=(100,100))
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations'],loc='upper left')

# %%
n = 12  # Change this value to forecast more or fewer values
forecast = []
last_data = X[-1]  # Last X data point
for i in range(n):
    next_y = model.predict(last_data.reshape(1, X.shape[1], X.shape[2]))  # Predict next y
    forecast.append(next_y)
    last_data = np.append(last_data[1:], next_y)  # Shift data by 1 and append next_y
forecast = scaler.inverse_transform(np.array(forecast).reshape(-1, 1))
y_act=scaler.inverse_transform(np.array(y).reshape(-1, 1))
# Out:
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step

# %%
plt.figure(figsize=(10, 6))
plt.plot(dates, y_act, label='Original Data')
plt.xlabel('Time')
plt.ylabel('Value')
plt.title('Original Data and Forecast')
plt.xticks(rotation=45)
plt.legend()

# Plot forecast
forecast_dates = np.arange(len(y), len(y) + n)
plt.plot(forecast_dates, forecast, label='Forecast', color='red')
plt.legend()

plt.show()
