# %%
import optuna
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.preprocessing import MinMaxScaler
from statsmodels.tsa.stattools import kpss

# %%
df=pd.read_csv("DATA/rice.csv")

df
# Out:
#                     Date  price
# 0    2000-01-01 00:00:00  166.9
# 1    2000-02-01 00:00:00  166.0
# 2    2000-03-01 00:00:00  166.6
# 3    2000-04-01 00:00:00  169.9
# 4    2000-05-01 00:00:00  171.0
# ..                   ...    ...
# 277  2023-02-01 00:00:00  175.6
# 278  2023-03-01 00:00:00  175.4
# 279  2023-04-01 00:00:00  176.2
# 280  2023-05-01 00:00:00  177.2
# 281  2023-06-01 00:00:00  178.2
#
# [282 rows x 2 columns]

# %%
import pandas as pd


# Convert 'Date' column to datetime type
df['Date'] = pd.to_datetime(df['Date'])

# Check for missing values
print("Missing values:")
print(df.isnull().sum())

# Check for duplicates
print("\nDuplicates:")
print(df.duplicated().sum())

# Check basic statistics of the 'Price' column
print("\nBasic statistics of Price:")
print(df['price'].describe())

# Plot the time series data
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(df['Date'], df['price'], marker='o')
plt.title('Time Series Data')
plt.xlabel('Date')
plt.ylabel('Price')
plt.grid(True)
plt.show()
# Out:
# Missing values:
# Date     0
# price    0
# dtype: int64
#
# Duplicates:
# 0
#
# Basic statistics of Price:
# count    282.000000
# mean     187.863475
# std       32.500295
# min      147.600000
# 25%      164.800000
# 50%      172.650000
# 75%      207.250000
# max      256.500000
# Name: price, dtype: float64

# %%
import pandas as pd
from scipy.stats import mstats
def winsorize_outliers(series, lower_percentile=0.05, upper_percentile=0.95):
    lower_limit = series.quantile(lower_percentile)
    upper_limit = series.quantile(upper_percentile)
    winsorized_values = mstats.winsorize(series, limits=(lower_percentile, 1 - upper_percentile))  # Correcting the upper percentile value
    return winsorized_values


# Winsorize the 'Price' column
#df['Price_winsorized'] = winsorize_outliers(df['price'])
df['price1'] = winsorize_outliers(df['price'], lower_percentile=0.05, upper_percentile=0.95)


# Plot the original and winsorized time series data
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(df['Date'], df['price'], marker='o', label='Original Price')
plt.plot(df['Date'], df['price1'], marker='o', label='Winsorized Price')
plt.title('Original vs. Winsorized Time Series Data')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
plt.show()

# %%
'''from statsmodels.tsa.seasonal import seasonal_decompose

# Seasonal decomposition
result = seasonal_decompose(df['price1'], model='additive', period=12)  # Assuming seasonality period of 12 months
detrended = df['price1'] - result.trend
seasonal = result.seasonal
residual = result.resid'''
# Out:
# "from statsmodels.tsa.seasonal import seasonal_decompose\n\n# Seasonal decomposition\nresult = seasonal_decompose(df['price1'], model='additive', period=12)  # Assuming seasonality period of 12 months\ndetrended = df['price1'] - result.trend\nseasonal = result.seasonal\nresidual = result.resid"

# %%
'''from sklearn.preprocessing import PowerTransformer

# Log transformation
df['Price_log'] = np.log(df['price1'])

# Box-Cox transformation
boxcox_transformer = PowerTransformer(method='box-cox')
df['Price_boxcox'] = boxcox_transformer.fit_transform(df['price1'].values.reshape(-1, 1))

# Quantile transformation (e.g., Gaussian transformation)
quantile_transformer = PowerTransformer(method='yeo-johnson')
df['Price_quantile'] = quantile_transformer.fit_transform(df['price1'].values.reshape(-1, 1))
'''
# Out:
# "from sklearn.preprocessing import PowerTransformer\n\n# Log transformation\ndf['Price_log'] = np.log(df['price1'])\n\n# Box-Cox transformation\nboxcox_transformer = PowerTransformer(method='box-cox')\ndf['Price_boxcox'] = boxcox_transformer.fit_transform(df['price1'].values.reshape(-1, 1))\n\n# Quantile transformation (e.g., Gaussian transformation)\nquantile_transformer = PowerTransformer(method='yeo-johnson')\ndf['Price_quantile'] = quantile_transformer.fit_transform(df['price1'].values.reshape(-1, 1))\n"

# %%
plt.plot(df['Date'],df['price'])

# %%
sn.boxplot(df['price'])
# Out:
# <Axes: >

# %%
t=kpss(df['price'],'ct')
t
# Out:
# /var/folders/35/vcbg9sn9479dqrdl_3fgrrkh0000gn/T/ipykernel_85140/1514378212.py:1: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   t=kpss(df['price'],'ct')
# (0.3404004465342978,
#  0.01,
#  10,
#  {'10%': 0.119, '5%': 0.146, '2.5%': 0.176, '1%': 0.216})

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose

# Assuming df is your DataFrame with a 'date' column and a 'value' column representing the time series
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)

# Perform seasonal decomposition
decomposition = seasonal_decompose(df['price'], model='additive')

# Plot the original time series
plt.figure(figsize=(10, 6))
plt.subplot(411)
plt.plot(df['price'], label='Original', color='blue')
plt.legend(loc='upper left')

# Plot the trend component
plt.subplot(412)
plt.plot(decomposition.trend, label='Trend', color='green')
plt.legend(loc='upper left')

# Plot the seasonal component
plt.subplot(413)
plt.plot(decomposition.seasonal, label='Seasonal', color='red')
plt.legend(loc='upper left')

# Plot the residual component
plt.subplot(414)
plt.plot(decomposition.resid, label='Residual', color='purple')
plt.legend(loc='upper left')

plt.tight_layout()
plt.show()

# %%
from scipy.stats import skew, kurtosis, shapiro

#df=pd.read_csv("DATA/Backup/rice.csv")

# %%
import pandas as pd
from scipy.stats import mstats
def winsorize_outliers(series, lower_percentile=0.05, upper_percentile=0.95):
    lower_limit = series.quantile(lower_percentile)
    upper_limit = series.quantile(upper_percentile)
    winsorized_values = mstats.winsorize(series, limits=(lower_percentile, 1 - upper_percentile))  # Correcting the upper percentile value
    return winsorized_values


# Winsorize the 'Price' column
#df['Price_winsorized'] = winsorize_outliers(df['price'])
df['price1'] = winsorize_outliers(df['price'], lower_percentile=0.05, upper_percentile=0.95)


# Plot the original and winsorized time series data
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(df['Date'], df['price'], marker='o', label='Original Price')
plt.plot(df['Date'], df['price1'], marker='o', label='Winsorized Price')
plt.title('Original vs. Winsorized Time Series Data')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
plt.show()

# %%
df
# Out:
#                     Date  price  price1
# 0    2000-01-01 00:00:00  166.9   166.9
# 1    2000-02-01 00:00:00  166.0   166.0
# 2    2000-03-01 00:00:00  166.6   166.6
# 3    2000-04-01 00:00:00  169.9   169.9
# 4    2000-05-01 00:00:00  171.0   171.0
# ..                   ...    ...     ...
# 283  2023-08-01 00:00:00  184.3   184.3
# 284  2023-09-01 00:00:00  187.0   187.0
# 285  2023-10-01 00:00:00  190.2   190.2
# 286  2023-11-01 00:00:00  191.4   191.4
# 287  2023-12-01 00:00:00  192.0   192.0
#
# [288 rows x 3 columns]

# %%
#df.pop('price')
#df['price']=df.pop('price1')
df1=df
df1
# Out:
#                     Date  price
# 0    2000-01-01 00:00:00  166.9
# 1    2000-02-01 00:00:00  166.0
# 2    2000-03-01 00:00:00  166.6
# 3    2000-04-01 00:00:00  169.9
# 4    2000-05-01 00:00:00  171.0
# ..                   ...    ...
# 283  2023-08-01 00:00:00  184.3
# 284  2023-09-01 00:00:00  187.0
# 285  2023-10-01 00:00:00  190.2
# 286  2023-11-01 00:00:00  191.4
# 287  2023-12-01 00:00:00  192.0
#
# [288 rows x 2 columns]

# %%
skewness = skew(df['price'])
kurt = kurtosis(df['price'])

# Perform Shapiro-Wilk test for normality
shapiro_stat, shapiro_p_value = shapiro(df['price'])

# Print the results
print("Skewness:", skewness)
print("Kurtosis:", kurt)
print("Shapiro-Wilk Statistic:", shapiro_stat)
print("Shapiro-Wilk p-value:", shapiro_p_value)
# Out:
# Skewness: 0.9062133854640201
# Kurtosis: -0.6908483852913809
# Shapiro-Wilk Statistic: 0.8249176740646362
# Shapiro-Wilk p-value: 3.666893971553287e-17

# %%
# Convert 'date' column to datetime if it's not already
# Shift the 'price' column to create new columns

scaler = MinMaxScaler(feature_range=(0, 1))
df['price'] = scaler.fit_transform(df['price'].values.reshape(-1,1))
#import matplotlib.pyplot as plt
#plt.plot(df['Date'],df['price'])


    

#dates_test, X_test, y_test = dates[q_80:], X[q_80:], y[q_80:]

#df['target-1'] = df['price'].shift(1)
#df['target-2'] = df['price'].shift(2)
#df['target-3'] = df['price'].shift(3)
#df['target-4'] = df['price'].shift(4)
#df['target-5'] = df['price'].shift(5)
#df['target-6'] = df['price'].shift(6)
#df['target-7'] = df['price'].shift(7)
#df['target-8'] = df['price'].shift(8)
#df['target-9'] = df['price'].shift(9)
#df['target-10'] = df['price'].shift(10)

# %%
#y

# %%
#dates
#X
#y

# %%
df=pd.read_csv("DATA/Backup/rice.csv")
scaler = MinMaxScaler(feature_range=(0, 1))
df['price'] = scaler.fit_transform(df['price'].values.reshape(-1,1))
shift=1
for i in range(shift,0,-1):
    df['target-'+str(i)] = df['price'].shift(i)
d=df[shift:]

def windowed_df_to_date_X_y(windowed_dataframe):
    df_as_np = windowed_dataframe.to_numpy()
    dates = df_as_np[:, 0]
    middle_matrix = df_as_np[:, 2:]
    X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))
    Y = df_as_np[:, 1:2]
    return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(d)
dates.shape, X.shape, y.shape

q_80 = int(len(dates) * .8)
q_90 = int(len(dates) * .9)
dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]
dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers.legacy import Adam
from tensorflow.keras import layers
from keras.callbacks import EarlyStopping
from keras.regularizers import l2

def objective(trial):
    # Define hyperparameters to tune
    lstm_units = trial.suggest_int('lstm_units', 32, 256)
    #gru_units = trial.suggest_int('gru_units', 32, 256)
    #num_filters = trial.suggest_int('num_filters', 16, 128)
    #kernel_size = trial.suggest_int('kernel_size', 3, 7)
    dense_units = trial.suggest_int('dense_units', 16, 128)
    #num_lstm_layers = trial.suggest_int('num_lstm_layers', 1, 3)
    learning_rate = trial.suggest_categorical('learning_rate', [1e-5, 1e-4, 1e-3])

    # Construct the model
    model = Sequential([
        layers.Input((shift, 1)),
        layers.LSTM(lstm_units),
        #layers.Bidirectional(layers.LSTM(lstm_units)),
        #layers.GRU(gru_units),
        #layers.Conv1D(num_filters, kernel_size, activation='relu',padding='same'),
        #layers.MaxPooling1D(),
        layers.Flatten(),
        layers.Dense(dense_units, activation='relu'),
        layers.Dense(1)
    ])
    '''model = Sequential()
    model.add(layers.Input((1, 1)))
    for _ in range(num_lstm_layers):
        model.add(layers.LSTM(lstm_units, return_sequences=True))
    model.add(layers.Flatten())
    model.add(layers.Dense(dense_units, activation='relu'))
    model.add(layers.Dense(1))'''
    
    early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
    # Compile the model
    model.compile(loss='mse', 
                  optimizer=Adam(learning_rate=learning_rate),
                  metrics=['mean_absolute_error'])

    # Train the model
    model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=200,callbacks=[early_stopping])

    # Evaluate the model on the validation set and return the validation loss
    loss = model.evaluate(X_val, y_val)[0]
    return loss

# %%
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=100)
best_params = study.best_params
print("Best hyperparameters:", best_params)
# Out:
# [I 2024-03-12 11:27:54,965] A new study created in memory with name: no-name-dd3a5962-1781-4fc6-b568-b49ab06b1fdb
# Epoch 1/200
# 8/8 [==============================] - 1s 26ms/step - loss: 0.2560 - mean_absolute_error: 0.4067 - val_loss: 0.0163 - val_mean_absolute_error: 0.1258
# Epoch 2/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2551 - mean_absolute_error: 0.4056 - val_loss: 0.0161 - val_mean_absolute_error: 0.1251
# Epoch 3/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2541 - mean_absolute_error: 0.4047 - val_loss: 0.0159 - val_mean_absolute_error: 0.1243
# Epoch 4/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2531 - mean_absolute_error: 0.4037 - val_loss: 0.0157 - val_mean_absolute_error: 0.1236
# Epoch 5/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2522 - mean_absolute_error: 0.4027 - val_loss: 0.0155 - val_mean_absolute_error: 0.1229
# Epoch 6/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2512 - mean_absolute_error: 0.4017 - val_loss: 0.0153 - val_mean_absolute_error: 0.1222
# Epoch 7/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2502 - mean_absolute_error: 0.4007 - val_loss: 0.0152 - val_mean_absolute_error: 0.1214
# Epoch 8/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2493 - mean_absolute_error: 0.3997 - val_loss: 0.0150 - val_mean_absolute_error: 0.1207
# Epoch 9/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2483 - mean_absolute_error: 0.3987 - val_loss: 0.0148 - val_mean_absolute_error: 0.1199
# Epoch 10/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2473 - mean_absolute_error: 0.3977 - val_loss: 0.0146 - val_mean_absolute_error: 0.1192
# Epoch 11/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2464 - mean_absolute_error: 0.3967 - val_loss: 0.0144 - val_mean_absolute_error: 0.1184
# Epoch 12/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2454 - mean_absolute_error: 0.3957 - val_loss: 0.0143 - val_mean_absolute_error: 0.1176
# Epoch 13/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2444 - mean_absolute_error: 0.3947 - val_loss: 0.0141 - val_mean_absolute_error: 0.1169
# Epoch 14/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2434 - mean_absolute_error: 0.3937 - val_loss: 0.0139 - val_mean_absolute_error: 0.1161
# Epoch 15/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2425 - mean_absolute_error: 0.3927 - val_loss: 0.0137 - val_mean_absolute_error: 0.1152
# Epoch 16/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2415 - mean_absolute_error: 0.3917 - val_loss: 0.0135 - val_mean_absolute_error: 0.1144
# Epoch 17/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2405 - mean_absolute_error: 0.3906 - val_loss: 0.0133 - val_mean_absolute_error: 0.1135
# Epoch 18/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2396 - mean_absolute_error: 0.3896 - val_loss: 0.0131 - val_mean_absolute_error: 0.1126
# Epoch 19/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2386 - mean_absolute_error: 0.3886 - val_loss: 0.0129 - val_mean_absolute_error: 0.1118
# Epoch 20/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2376 - mean_absolute_error: 0.3875 - val_loss: 0.0127 - val_mean_absolute_error: 0.1109
# Epoch 21/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2365 - mean_absolute_error: 0.3864 - val_loss: 0.0125 - val_mean_absolute_error: 0.1100
# Epoch 22/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2356 - mean_absolute_error: 0.3853 - val_loss: 0.0123 - val_mean_absolute_error: 0.1091
# Epoch 23/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2345 - mean_absolute_error: 0.3843 - val_loss: 0.0121 - val_mean_absolute_error: 0.1082
# Epoch 24/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2335 - mean_absolute_error: 0.3832 - val_loss: 0.0119 - val_mean_absolute_error: 0.1072
# Epoch 25/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2325 - mean_absolute_error: 0.3820 - val_loss: 0.0117 - val_mean_absolute_error: 0.1062
# Epoch 26/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2314 - mean_absolute_error: 0.3809 - val_loss: 0.0115 - val_mean_absolute_error: 0.1052
# Epoch 27/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2304 - mean_absolute_error: 0.3798 - val_loss: 0.0113 - val_mean_absolute_error: 0.1042
# Epoch 28/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2294 - mean_absolute_error: 0.3786 - val_loss: 0.0111 - val_mean_absolute_error: 0.1032
# Epoch 29/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2283 - mean_absolute_error: 0.3775 - val_loss: 0.0108 - val_mean_absolute_error: 0.1022
# Epoch 30/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2272 - mean_absolute_error: 0.3763 - val_loss: 0.0106 - val_mean_absolute_error: 0.1011
# Epoch 31/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2261 - mean_absolute_error: 0.3751 - val_loss: 0.0104 - val_mean_absolute_error: 0.1000
# Epoch 32/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2250 - mean_absolute_error: 0.3738 - val_loss: 0.0102 - val_mean_absolute_error: 0.0989
# Epoch 33/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2239 - mean_absolute_error: 0.3726 - val_loss: 0.0100 - val_mean_absolute_error: 0.0978
# Epoch 34/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2227 - mean_absolute_error: 0.3714 - val_loss: 0.0098 - val_mean_absolute_error: 0.0967
# Epoch 35/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2217 - mean_absolute_error: 0.3702 - val_loss: 0.0095 - val_mean_absolute_error: 0.0956
# Epoch 36/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2205 - mean_absolute_error: 0.3689 - val_loss: 0.0093 - val_mean_absolute_error: 0.0945
# Epoch 37/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2193 - mean_absolute_error: 0.3676 - val_loss: 0.0091 - val_mean_absolute_error: 0.0934
# Epoch 38/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2181 - mean_absolute_error: 0.3663 - val_loss: 0.0089 - val_mean_absolute_error: 0.0923
# Epoch 39/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2170 - mean_absolute_error: 0.3651 - val_loss: 0.0087 - val_mean_absolute_error: 0.0912
# Epoch 40/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2159 - mean_absolute_error: 0.3638 - val_loss: 0.0085 - val_mean_absolute_error: 0.0901
# Epoch 41/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2148 - mean_absolute_error: 0.3625 - val_loss: 0.0083 - val_mean_absolute_error: 0.0890
# Epoch 42/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2137 - mean_absolute_error: 0.3613 - val_loss: 0.0081 - val_mean_absolute_error: 0.0880
# Epoch 43/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2126 - mean_absolute_error: 0.3601 - val_loss: 0.0079 - val_mean_absolute_error: 0.0869
# Epoch 44/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2115 - mean_absolute_error: 0.3589 - val_loss: 0.0078 - val_mean_absolute_error: 0.0858
# Epoch 45/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2103 - mean_absolute_error: 0.3576 - val_loss: 0.0076 - val_mean_absolute_error: 0.0847
# Epoch 46/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2092 - mean_absolute_error: 0.3563 - val_loss: 0.0074 - val_mean_absolute_error: 0.0837
# Epoch 47/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2080 - mean_absolute_error: 0.3549 - val_loss: 0.0072 - val_mean_absolute_error: 0.0826
# Epoch 48/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2067 - mean_absolute_error: 0.3536 - val_loss: 0.0070 - val_mean_absolute_error: 0.0815
# Epoch 49/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2055 - mean_absolute_error: 0.3522 - val_loss: 0.0068 - val_mean_absolute_error: 0.0804
# Epoch 50/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2044 - mean_absolute_error: 0.3509 - val_loss: 0.0067 - val_mean_absolute_error: 0.0793
# Epoch 51/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2032 - mean_absolute_error: 0.3497 - val_loss: 0.0065 - val_mean_absolute_error: 0.0783
# Epoch 52/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2021 - mean_absolute_error: 0.3484 - val_loss: 0.0063 - val_mean_absolute_error: 0.0772
# Epoch 53/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2009 - mean_absolute_error: 0.3471 - val_loss: 0.0062 - val_mean_absolute_error: 0.0762
# Epoch 54/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1998 - mean_absolute_error: 0.3458 - val_loss: 0.0060 - val_mean_absolute_error: 0.0751
# Epoch 55/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1987 - mean_absolute_error: 0.3446 - val_loss: 0.0059 - val_mean_absolute_error: 0.0741
# Epoch 56/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1976 - mean_absolute_error: 0.3434 - val_loss: 0.0057 - val_mean_absolute_error: 0.0731
# Epoch 57/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1965 - mean_absolute_error: 0.3421 - val_loss: 0.0056 - val_mean_absolute_error: 0.0721
# Epoch 58/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1954 - mean_absolute_error: 0.3409 - val_loss: 0.0054 - val_mean_absolute_error: 0.0711
# Epoch 59/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1943 - mean_absolute_error: 0.3396 - val_loss: 0.0053 - val_mean_absolute_error: 0.0700
# Epoch 60/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1932 - mean_absolute_error: 0.3383 - val_loss: 0.0051 - val_mean_absolute_error: 0.0690
# Epoch 61/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1921 - mean_absolute_error: 0.3371 - val_loss: 0.0050 - val_mean_absolute_error: 0.0680
# Epoch 62/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1909 - mean_absolute_error: 0.3358 - val_loss: 0.0049 - val_mean_absolute_error: 0.0670
# Epoch 63/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1897 - mean_absolute_error: 0.3344 - val_loss: 0.0047 - val_mean_absolute_error: 0.0659
# Epoch 64/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1886 - mean_absolute_error: 0.3331 - val_loss: 0.0046 - val_mean_absolute_error: 0.0649
# Epoch 65/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1874 - mean_absolute_error: 0.3318 - val_loss: 0.0044 - val_mean_absolute_error: 0.0638
# Epoch 66/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1863 - mean_absolute_error: 0.3305 - val_loss: 0.0043 - val_mean_absolute_error: 0.0628
# Epoch 67/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1852 - mean_absolute_error: 0.3293 - val_loss: 0.0042 - val_mean_absolute_error: 0.0618
# Epoch 68/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1842 - mean_absolute_error: 0.3280 - val_loss: 0.0041 - val_mean_absolute_error: 0.0608
# Epoch 69/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1831 - mean_absolute_error: 0.3268 - val_loss: 0.0039 - val_mean_absolute_error: 0.0598
# Epoch 70/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1820 - mean_absolute_error: 0.3256 - val_loss: 0.0038 - val_mean_absolute_error: 0.0588
# Epoch 71/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1809 - mean_absolute_error: 0.3243 - val_loss: 0.0037 - val_mean_absolute_error: 0.0577
# Epoch 72/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1798 - mean_absolute_error: 0.3230 - val_loss: 0.0036 - val_mean_absolute_error: 0.0568
# Epoch 73/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1787 - mean_absolute_error: 0.3218 - val_loss: 0.0035 - val_mean_absolute_error: 0.0557
# Epoch 74/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1777 - mean_absolute_error: 0.3205 - val_loss: 0.0033 - val_mean_absolute_error: 0.0547
# Epoch 75/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1766 - mean_absolute_error: 0.3193 - val_loss: 0.0032 - val_mean_absolute_error: 0.0536
# Epoch 76/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1755 - mean_absolute_error: 0.3180 - val_loss: 0.0031 - val_mean_absolute_error: 0.0526
# Epoch 77/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1745 - mean_absolute_error: 0.3168 - val_loss: 0.0030 - val_mean_absolute_error: 0.0517
# Epoch 78/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1735 - mean_absolute_error: 0.3156 - val_loss: 0.0029 - val_mean_absolute_error: 0.0507
# Epoch 79/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1725 - mean_absolute_error: 0.3144 - val_loss: 0.0028 - val_mean_absolute_error: 0.0497
# Epoch 80/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1715 - mean_absolute_error: 0.3132 - val_loss: 0.0027 - val_mean_absolute_error: 0.0487
# Epoch 81/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1705 - mean_absolute_error: 0.3120 - val_loss: 0.0026 - val_mean_absolute_error: 0.0477
# Epoch 82/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1695 - mean_absolute_error: 0.3109 - val_loss: 0.0025 - val_mean_absolute_error: 0.0468
# Epoch 83/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1686 - mean_absolute_error: 0.3099 - val_loss: 0.0024 - val_mean_absolute_error: 0.0459
# Epoch 84/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1676 - mean_absolute_error: 0.3088 - val_loss: 0.0024 - val_mean_absolute_error: 0.0449
# Epoch 85/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1667 - mean_absolute_error: 0.3077 - val_loss: 0.0023 - val_mean_absolute_error: 0.0439
# Epoch 86/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1657 - mean_absolute_error: 0.3065 - val_loss: 0.0022 - val_mean_absolute_error: 0.0429
# Epoch 87/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1647 - mean_absolute_error: 0.3053 - val_loss: 0.0021 - val_mean_absolute_error: 0.0419
# Epoch 88/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1637 - mean_absolute_error: 0.3042 - val_loss: 0.0020 - val_mean_absolute_error: 0.0409
# Epoch 89/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1627 - mean_absolute_error: 0.3031 - val_loss: 0.0019 - val_mean_absolute_error: 0.0399
# Epoch 90/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1617 - mean_absolute_error: 0.3019 - val_loss: 0.0018 - val_mean_absolute_error: 0.0390
# Epoch 91/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1607 - mean_absolute_error: 0.3008 - val_loss: 0.0018 - val_mean_absolute_error: 0.0381
# Epoch 92/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1598 - mean_absolute_error: 0.2996 - val_loss: 0.0017 - val_mean_absolute_error: 0.0371
# Epoch 93/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1588 - mean_absolute_error: 0.2985 - val_loss: 0.0016 - val_mean_absolute_error: 0.0363
# Epoch 94/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1579 - mean_absolute_error: 0.2974 - val_loss: 0.0016 - val_mean_absolute_error: 0.0355
# Epoch 95/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1569 - mean_absolute_error: 0.2962 - val_loss: 0.0015 - val_mean_absolute_error: 0.0347
# Epoch 96/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1560 - mean_absolute_error: 0.2951 - val_loss: 0.0014 - val_mean_absolute_error: 0.0338
# Epoch 97/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1551 - mean_absolute_error: 0.2940 - val_loss: 0.0014 - val_mean_absolute_error: 0.0329
# Epoch 98/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1541 - mean_absolute_error: 0.2929 - val_loss: 0.0013 - val_mean_absolute_error: 0.0321
# Epoch 99/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1531 - mean_absolute_error: 0.2918 - val_loss: 0.0012 - val_mean_absolute_error: 0.0313
# Epoch 100/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1522 - mean_absolute_error: 0.2906 - val_loss: 0.0012 - val_mean_absolute_error: 0.0305
# Epoch 101/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1512 - mean_absolute_error: 0.2894 - val_loss: 0.0011 - val_mean_absolute_error: 0.0297
# Epoch 102/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1503 - mean_absolute_error: 0.2882 - val_loss: 0.0010 - val_mean_absolute_error: 0.0288
# Epoch 103/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1494 - mean_absolute_error: 0.2871 - val_loss: 9.9537e-04 - val_mean_absolute_error: 0.0280
# Epoch 104/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1484 - mean_absolute_error: 0.2860 - val_loss: 9.4494e-04 - val_mean_absolute_error: 0.0273
# Epoch 105/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1475 - mean_absolute_error: 0.2849 - val_loss: 8.9786e-04 - val_mean_absolute_error: 0.0266
# Epoch 106/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1466 - mean_absolute_error: 0.2837 - val_loss: 8.5048e-04 - val_mean_absolute_error: 0.0259
# Epoch 107/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1457 - mean_absolute_error: 0.2826 - val_loss: 8.0451e-04 - val_mean_absolute_error: 0.0252
# Epoch 108/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1448 - mean_absolute_error: 0.2814 - val_loss: 7.5946e-04 - val_mean_absolute_error: 0.0245
# Epoch 109/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1439 - mean_absolute_error: 0.2803 - val_loss: 7.1741e-04 - val_mean_absolute_error: 0.0239
# Epoch 110/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1430 - mean_absolute_error: 0.2791 - val_loss: 6.7830e-04 - val_mean_absolute_error: 0.0232
# Epoch 111/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1420 - mean_absolute_error: 0.2780 - val_loss: 6.4333e-04 - val_mean_absolute_error: 0.0226
# Epoch 112/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1412 - mean_absolute_error: 0.2769 - val_loss: 6.0627e-04 - val_mean_absolute_error: 0.0219
# Epoch 113/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1402 - mean_absolute_error: 0.2757 - val_loss: 5.7224e-04 - val_mean_absolute_error: 0.0212
# Epoch 114/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1393 - mean_absolute_error: 0.2745 - val_loss: 5.3799e-04 - val_mean_absolute_error: 0.0205
# Epoch 115/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1384 - mean_absolute_error: 0.2733 - val_loss: 5.0785e-04 - val_mean_absolute_error: 0.0199
# Epoch 116/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1375 - mean_absolute_error: 0.2722 - val_loss: 4.8021e-04 - val_mean_absolute_error: 0.0192
# Epoch 117/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1367 - mean_absolute_error: 0.2711 - val_loss: 4.5477e-04 - val_mean_absolute_error: 0.0185
# Epoch 118/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1358 - mean_absolute_error: 0.2699 - val_loss: 4.3046e-04 - val_mean_absolute_error: 0.0179
# Epoch 119/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1349 - mean_absolute_error: 0.2687 - val_loss: 4.0917e-04 - val_mean_absolute_error: 0.0173
# Epoch 120/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1341 - mean_absolute_error: 0.2676 - val_loss: 3.8952e-04 - val_mean_absolute_error: 0.0167
# Epoch 121/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1332 - mean_absolute_error: 0.2665 - val_loss: 3.7265e-04 - val_mean_absolute_error: 0.0162
# Epoch 122/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1323 - mean_absolute_error: 0.2653 - val_loss: 3.5559e-04 - val_mean_absolute_error: 0.0156
# Epoch 123/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1315 - mean_absolute_error: 0.2642 - val_loss: 3.4056e-04 - val_mean_absolute_error: 0.0149
# Epoch 124/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1306 - mean_absolute_error: 0.2630 - val_loss: 3.2816e-04 - val_mean_absolute_error: 0.0144
# Epoch 125/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1297 - mean_absolute_error: 0.2618 - val_loss: 3.1792e-04 - val_mean_absolute_error: 0.0139
# Epoch 126/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1288 - mean_absolute_error: 0.2606 - val_loss: 3.0970e-04 - val_mean_absolute_error: 0.0134
# Epoch 127/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1279 - mean_absolute_error: 0.2594 - val_loss: 3.0361e-04 - val_mean_absolute_error: 0.0130
# Epoch 128/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1271 - mean_absolute_error: 0.2583 - val_loss: 2.9995e-04 - val_mean_absolute_error: 0.0127
# Epoch 129/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1262 - mean_absolute_error: 0.2572 - val_loss: 2.9815e-04 - val_mean_absolute_error: 0.0125
# Epoch 130/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1254 - mean_absolute_error: 0.2560 - val_loss: 2.9809e-04 - val_mean_absolute_error: 0.0122
# Epoch 131/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1246 - mean_absolute_error: 0.2550 - val_loss: 2.9997e-04 - val_mean_absolute_error: 0.0122
# Epoch 132/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1237 - mean_absolute_error: 0.2538 - val_loss: 3.0373e-04 - val_mean_absolute_error: 0.0123
# Epoch 133/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1229 - mean_absolute_error: 0.2527 - val_loss: 3.0973e-04 - val_mean_absolute_error: 0.0125
# Epoch 134/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1221 - mean_absolute_error: 0.2515 - val_loss: 3.1726e-04 - val_mean_absolute_error: 0.0129
# Epoch 135/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1212 - mean_absolute_error: 0.2504 - val_loss: 3.2564e-04 - val_mean_absolute_error: 0.0132
# Epoch 136/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1205 - mean_absolute_error: 0.2493 - val_loss: 3.3703e-04 - val_mean_absolute_error: 0.0135
# Epoch 137/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1197 - mean_absolute_error: 0.2483 - val_loss: 3.4866e-04 - val_mean_absolute_error: 0.0139
# Epoch 138/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1190 - mean_absolute_error: 0.2473 - val_loss: 3.6232e-04 - val_mean_absolute_error: 0.0143
# Epoch 139/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1182 - mean_absolute_error: 0.2462 - val_loss: 3.7905e-04 - val_mean_absolute_error: 0.0147
# Epoch 140/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1174 - mean_absolute_error: 0.2452 - val_loss: 3.9610e-04 - val_mean_absolute_error: 0.0152
# 1/1 [==============================] - 0s 10ms/step - loss: 2.9809e-04 - mean_absolute_error: 0.0122
# [I 2024-03-12 11:27:59,076] Trial 0 finished with value: 0.00029808803810738027 and parameters: {'lstm_units': 124, 'dense_units': 72, 'learning_rate': 1e-05}. Best is trial 0 with value: 0.00029808803810738027.
# Epoch 1/200
# 8/8 [==============================] - 1s 26ms/step - loss: 0.2607 - mean_absolute_error: 0.4094 - val_loss: 0.0149 - val_mean_absolute_error: 0.1204
# Epoch 2/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2486 - mean_absolute_error: 0.3976 - val_loss: 0.0131 - val_mean_absolute_error: 0.1125
# Epoch 3/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2367 - mean_absolute_error: 0.3860 - val_loss: 0.0112 - val_mean_absolute_error: 0.1041
# Epoch 4/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2254 - mean_absolute_error: 0.3745 - val_loss: 0.0095 - val_mean_absolute_error: 0.0952
# Epoch 5/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2141 - mean_absolute_error: 0.3626 - val_loss: 0.0078 - val_mean_absolute_error: 0.0859
# Epoch 6/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2026 - mean_absolute_error: 0.3505 - val_loss: 0.0062 - val_mean_absolute_error: 0.0763
# Epoch 7/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1915 - mean_absolute_error: 0.3380 - val_loss: 0.0048 - val_mean_absolute_error: 0.0665
# Epoch 8/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1802 - mean_absolute_error: 0.3252 - val_loss: 0.0036 - val_mean_absolute_error: 0.0566
# Epoch 9/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1697 - mean_absolute_error: 0.3128 - val_loss: 0.0025 - val_mean_absolute_error: 0.0464
# Epoch 10/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1589 - mean_absolute_error: 0.3005 - val_loss: 0.0017 - val_mean_absolute_error: 0.0367
# Epoch 11/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1486 - mean_absolute_error: 0.2884 - val_loss: 0.0010 - val_mean_absolute_error: 0.0282
# Epoch 12/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1387 - mean_absolute_error: 0.2762 - val_loss: 5.3727e-04 - val_mean_absolute_error: 0.0205
# Epoch 13/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1284 - mean_absolute_error: 0.2630 - val_loss: 3.1559e-04 - val_mean_absolute_error: 0.0140
# Epoch 14/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1193 - mean_absolute_error: 0.2504 - val_loss: 3.2614e-04 - val_mean_absolute_error: 0.0133
# Epoch 15/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1102 - mean_absolute_error: 0.2381 - val_loss: 5.6191e-04 - val_mean_absolute_error: 0.0196
# Epoch 16/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1019 - mean_absolute_error: 0.2263 - val_loss: 0.0011 - val_mean_absolute_error: 0.0285
# Epoch 17/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0935 - mean_absolute_error: 0.2147 - val_loss: 0.0018 - val_mean_absolute_error: 0.0388
# Epoch 18/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0854 - mean_absolute_error: 0.2039 - val_loss: 0.0026 - val_mean_absolute_error: 0.0487
# Epoch 19/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0781 - mean_absolute_error: 0.1953 - val_loss: 0.0037 - val_mean_absolute_error: 0.0585
# Epoch 20/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0715 - mean_absolute_error: 0.1878 - val_loss: 0.0047 - val_mean_absolute_error: 0.0672
# Epoch 21/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0649 - mean_absolute_error: 0.1807 - val_loss: 0.0059 - val_mean_absolute_error: 0.0753
# Epoch 22/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0591 - mean_absolute_error: 0.1751 - val_loss: 0.0072 - val_mean_absolute_error: 0.0838
# Epoch 23/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0543 - mean_absolute_error: 0.1709 - val_loss: 0.0090 - val_mean_absolute_error: 0.0936
# 1/1 [==============================] - 0s 10ms/step - loss: 3.1559e-04 - mean_absolute_error: 0.0140
# [I 2024-03-12 11:28:00,546] Trial 1 finished with value: 0.0003155904996674508 and parameters: {'lstm_units': 228, 'dense_units': 77, 'learning_rate': 0.0001}. Best is trial 0 with value: 0.00029808803810738027.
# Epoch 1/200
# 8/8 [==============================] - 1s 26ms/step - loss: 0.2312 - mean_absolute_error: 0.3792 - val_loss: 0.0042 - val_mean_absolute_error: 0.0622
# Epoch 2/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1564 - mean_absolute_error: 0.2939 - val_loss: 4.5416e-04 - val_mean_absolute_error: 0.0168
# Epoch 3/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0937 - mean_absolute_error: 0.2141 - val_loss: 0.0090 - val_mean_absolute_error: 0.0938
# Epoch 4/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0516 - mean_absolute_error: 0.1768 - val_loss: 0.0296 - val_mean_absolute_error: 0.1716
# Epoch 5/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0340 - mean_absolute_error: 0.1648 - val_loss: 0.0469 - val_mean_absolute_error: 0.2162
# Epoch 6/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0312 - mean_absolute_error: 0.1566 - val_loss: 0.0357 - val_mean_absolute_error: 0.1886
# Epoch 7/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0237 - mean_absolute_error: 0.1333 - val_loss: 0.0156 - val_mean_absolute_error: 0.1243
# Epoch 8/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0182 - mean_absolute_error: 0.1100 - val_loss: 0.0097 - val_mean_absolute_error: 0.0979
# Epoch 9/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0131 - mean_absolute_error: 0.0874 - val_loss: 0.0069 - val_mean_absolute_error: 0.0827
# Epoch 10/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0102 - mean_absolute_error: 0.0647 - val_loss: 0.0035 - val_mean_absolute_error: 0.0586
# Epoch 11/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0082 - mean_absolute_error: 0.0440 - val_loss: 4.8869e-04 - val_mean_absolute_error: 0.0206
# Epoch 12/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0074 - mean_absolute_error: 0.0305 - val_loss: 2.2810e-04 - val_mean_absolute_error: 0.0133
# Epoch 13/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0074 - mean_absolute_error: 0.0242 - val_loss: 1.3069e-04 - val_mean_absolute_error: 0.0088
# Epoch 14/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0073 - mean_absolute_error: 0.0231 - val_loss: 1.0660e-04 - val_mean_absolute_error: 0.0071
# Epoch 15/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0073 - mean_absolute_error: 0.0229 - val_loss: 1.2040e-04 - val_mean_absolute_error: 0.0081
# Epoch 16/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0073 - mean_absolute_error: 0.0237 - val_loss: 1.0715e-04 - val_mean_absolute_error: 0.0072
# Epoch 17/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0073 - mean_absolute_error: 0.0262 - val_loss: 1.2485e-04 - val_mean_absolute_error: 0.0084
# Epoch 18/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0074 - mean_absolute_error: 0.0248 - val_loss: 2.2840e-04 - val_mean_absolute_error: 0.0130
# Epoch 19/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0073 - mean_absolute_error: 0.0237 - val_loss: 1.0945e-04 - val_mean_absolute_error: 0.0072
# Epoch 20/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0073 - mean_absolute_error: 0.0259 - val_loss: 1.0963e-04 - val_mean_absolute_error: 0.0074
# Epoch 21/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0072 - mean_absolute_error: 0.0242 - val_loss: 1.4395e-04 - val_mean_absolute_error: 0.0094
# Epoch 22/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0073 - mean_absolute_error: 0.0247 - val_loss: 1.1184e-04 - val_mean_absolute_error: 0.0075
# Epoch 23/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0072 - mean_absolute_error: 0.0254 - val_loss: 1.2790e-04 - val_mean_absolute_error: 0.0086
# Epoch 24/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0072 - mean_absolute_error: 0.0244 - val_loss: 1.3272e-04 - val_mean_absolute_error: 0.0088
# 1/1 [==============================] - 0s 9ms/step - loss: 1.0660e-04 - mean_absolute_error: 0.0071
# [I 2024-03-12 11:28:01,956] Trial 2 finished with value: 0.00010659548570401967 and parameters: {'lstm_units': 106, 'dense_units': 67, 'learning_rate': 0.001}. Best is trial 2 with value: 0.00010659548570401967.
# Epoch 1/200
# 8/8 [==============================] - 1s 24ms/step - loss: 0.2702 - mean_absolute_error: 0.4177 - val_loss: 0.0171 - val_mean_absolute_error: 0.1292
# Epoch 2/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2691 - mean_absolute_error: 0.4166 - val_loss: 0.0169 - val_mean_absolute_error: 0.1284
# Epoch 3/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2680 - mean_absolute_error: 0.4155 - val_loss: 0.0167 - val_mean_absolute_error: 0.1276
# Epoch 4/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2669 - mean_absolute_error: 0.4144 - val_loss: 0.0165 - val_mean_absolute_error: 0.1268
# Epoch 5/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2658 - mean_absolute_error: 0.4133 - val_loss: 0.0163 - val_mean_absolute_error: 0.1260
# Epoch 6/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2648 - mean_absolute_error: 0.4123 - val_loss: 0.0161 - val_mean_absolute_error: 0.1252
# Epoch 7/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2637 - mean_absolute_error: 0.4113 - val_loss: 0.0160 - val_mean_absolute_error: 0.1246
# Epoch 8/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2626 - mean_absolute_error: 0.4102 - val_loss: 0.0158 - val_mean_absolute_error: 0.1239
# Epoch 9/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2615 - mean_absolute_error: 0.4092 - val_loss: 0.0156 - val_mean_absolute_error: 0.1232
# Epoch 10/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2605 - mean_absolute_error: 0.4082 - val_loss: 0.0155 - val_mean_absolute_error: 0.1226
# Epoch 11/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2595 - mean_absolute_error: 0.4072 - val_loss: 0.0153 - val_mean_absolute_error: 0.1219
# Epoch 12/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2584 - mean_absolute_error: 0.4062 - val_loss: 0.0151 - val_mean_absolute_error: 0.1213
# Epoch 13/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2574 - mean_absolute_error: 0.4052 - val_loss: 0.0150 - val_mean_absolute_error: 0.1206
# Epoch 14/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2564 - mean_absolute_error: 0.4043 - val_loss: 0.0148 - val_mean_absolute_error: 0.1200
# Epoch 15/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2554 - mean_absolute_error: 0.4033 - val_loss: 0.0147 - val_mean_absolute_error: 0.1193
# Epoch 16/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2544 - mean_absolute_error: 0.4023 - val_loss: 0.0145 - val_mean_absolute_error: 0.1186
# Epoch 17/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2534 - mean_absolute_error: 0.4013 - val_loss: 0.0143 - val_mean_absolute_error: 0.1180
# Epoch 18/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2524 - mean_absolute_error: 0.4004 - val_loss: 0.0142 - val_mean_absolute_error: 0.1173
# Epoch 19/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2514 - mean_absolute_error: 0.3994 - val_loss: 0.0140 - val_mean_absolute_error: 0.1166
# Epoch 20/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2504 - mean_absolute_error: 0.3984 - val_loss: 0.0139 - val_mean_absolute_error: 0.1159
# Epoch 21/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2494 - mean_absolute_error: 0.3974 - val_loss: 0.0137 - val_mean_absolute_error: 0.1152
# Epoch 22/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2484 - mean_absolute_error: 0.3964 - val_loss: 0.0135 - val_mean_absolute_error: 0.1145
# Epoch 23/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2474 - mean_absolute_error: 0.3955 - val_loss: 0.0134 - val_mean_absolute_error: 0.1138
# Epoch 24/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2465 - mean_absolute_error: 0.3945 - val_loss: 0.0132 - val_mean_absolute_error: 0.1131
# Epoch 25/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2455 - mean_absolute_error: 0.3935 - val_loss: 0.0131 - val_mean_absolute_error: 0.1124
# Epoch 26/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2446 - mean_absolute_error: 0.3926 - val_loss: 0.0129 - val_mean_absolute_error: 0.1117
# Epoch 27/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2436 - mean_absolute_error: 0.3916 - val_loss: 0.0127 - val_mean_absolute_error: 0.1110
# Epoch 28/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2426 - mean_absolute_error: 0.3907 - val_loss: 0.0126 - val_mean_absolute_error: 0.1103
# Epoch 29/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2417 - mean_absolute_error: 0.3897 - val_loss: 0.0124 - val_mean_absolute_error: 0.1096
# Epoch 30/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2408 - mean_absolute_error: 0.3888 - val_loss: 0.0123 - val_mean_absolute_error: 0.1089
# Epoch 31/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2398 - mean_absolute_error: 0.3878 - val_loss: 0.0121 - val_mean_absolute_error: 0.1081
# Epoch 32/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2388 - mean_absolute_error: 0.3868 - val_loss: 0.0119 - val_mean_absolute_error: 0.1073
# Epoch 33/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2378 - mean_absolute_error: 0.3858 - val_loss: 0.0118 - val_mean_absolute_error: 0.1065
# Epoch 34/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2367 - mean_absolute_error: 0.3848 - val_loss: 0.0116 - val_mean_absolute_error: 0.1057
# Epoch 35/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2357 - mean_absolute_error: 0.3837 - val_loss: 0.0114 - val_mean_absolute_error: 0.1049
# Epoch 36/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2346 - mean_absolute_error: 0.3827 - val_loss: 0.0113 - val_mean_absolute_error: 0.1041
# Epoch 37/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2336 - mean_absolute_error: 0.3816 - val_loss: 0.0111 - val_mean_absolute_error: 0.1033
# Epoch 38/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2326 - mean_absolute_error: 0.3806 - val_loss: 0.0109 - val_mean_absolute_error: 0.1025
# Epoch 39/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2316 - mean_absolute_error: 0.3796 - val_loss: 0.0108 - val_mean_absolute_error: 0.1018
# Epoch 40/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2307 - mean_absolute_error: 0.3786 - val_loss: 0.0106 - val_mean_absolute_error: 0.1010
# Epoch 41/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2297 - mean_absolute_error: 0.3776 - val_loss: 0.0104 - val_mean_absolute_error: 0.1002
# Epoch 42/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2288 - mean_absolute_error: 0.3766 - val_loss: 0.0103 - val_mean_absolute_error: 0.0994
# Epoch 43/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2278 - mean_absolute_error: 0.3756 - val_loss: 0.0101 - val_mean_absolute_error: 0.0986
# Epoch 44/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2269 - mean_absolute_error: 0.3747 - val_loss: 0.0100 - val_mean_absolute_error: 0.0979
# Epoch 45/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2260 - mean_absolute_error: 0.3737 - val_loss: 0.0098 - val_mean_absolute_error: 0.0971
# Epoch 46/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2250 - mean_absolute_error: 0.3727 - val_loss: 0.0097 - val_mean_absolute_error: 0.0963
# Epoch 47/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2241 - mean_absolute_error: 0.3717 - val_loss: 0.0095 - val_mean_absolute_error: 0.0955
# Epoch 48/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2232 - mean_absolute_error: 0.3707 - val_loss: 0.0094 - val_mean_absolute_error: 0.0948
# Epoch 49/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2223 - mean_absolute_error: 0.3698 - val_loss: 0.0092 - val_mean_absolute_error: 0.0940
# Epoch 50/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2214 - mean_absolute_error: 0.3688 - val_loss: 0.0091 - val_mean_absolute_error: 0.0932
# Epoch 51/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2205 - mean_absolute_error: 0.3678 - val_loss: 0.0089 - val_mean_absolute_error: 0.0925
# Epoch 52/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2196 - mean_absolute_error: 0.3668 - val_loss: 0.0088 - val_mean_absolute_error: 0.0917
# Epoch 53/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2186 - mean_absolute_error: 0.3658 - val_loss: 0.0087 - val_mean_absolute_error: 0.0909
# Epoch 54/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2177 - mean_absolute_error: 0.3649 - val_loss: 0.0085 - val_mean_absolute_error: 0.0901
# Epoch 55/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2168 - mean_absolute_error: 0.3639 - val_loss: 0.0084 - val_mean_absolute_error: 0.0893
# Epoch 56/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2158 - mean_absolute_error: 0.3628 - val_loss: 0.0082 - val_mean_absolute_error: 0.0885
# Epoch 57/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2149 - mean_absolute_error: 0.3618 - val_loss: 0.0081 - val_mean_absolute_error: 0.0877
# Epoch 58/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2138 - mean_absolute_error: 0.3606 - val_loss: 0.0079 - val_mean_absolute_error: 0.0868
# Epoch 59/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2128 - mean_absolute_error: 0.3596 - val_loss: 0.0078 - val_mean_absolute_error: 0.0860
# Epoch 60/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2117 - mean_absolute_error: 0.3584 - val_loss: 0.0076 - val_mean_absolute_error: 0.0851
# Epoch 61/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2106 - mean_absolute_error: 0.3573 - val_loss: 0.0075 - val_mean_absolute_error: 0.0842
# Epoch 62/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2096 - mean_absolute_error: 0.3562 - val_loss: 0.0073 - val_mean_absolute_error: 0.0834
# Epoch 63/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2085 - mean_absolute_error: 0.3551 - val_loss: 0.0072 - val_mean_absolute_error: 0.0825
# Epoch 64/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2075 - mean_absolute_error: 0.3539 - val_loss: 0.0071 - val_mean_absolute_error: 0.0817
# Epoch 65/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2065 - mean_absolute_error: 0.3528 - val_loss: 0.0069 - val_mean_absolute_error: 0.0808
# Epoch 66/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2055 - mean_absolute_error: 0.3518 - val_loss: 0.0068 - val_mean_absolute_error: 0.0800
# Epoch 67/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2045 - mean_absolute_error: 0.3507 - val_loss: 0.0067 - val_mean_absolute_error: 0.0792
# Epoch 68/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2035 - mean_absolute_error: 0.3496 - val_loss: 0.0065 - val_mean_absolute_error: 0.0783
# Epoch 69/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2024 - mean_absolute_error: 0.3485 - val_loss: 0.0064 - val_mean_absolute_error: 0.0775
# Epoch 70/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2014 - mean_absolute_error: 0.3474 - val_loss: 0.0063 - val_mean_absolute_error: 0.0766
# Epoch 71/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2004 - mean_absolute_error: 0.3463 - val_loss: 0.0061 - val_mean_absolute_error: 0.0758
# Epoch 72/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1995 - mean_absolute_error: 0.3453 - val_loss: 0.0060 - val_mean_absolute_error: 0.0750
# Epoch 73/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1985 - mean_absolute_error: 0.3442 - val_loss: 0.0059 - val_mean_absolute_error: 0.0742
# Epoch 74/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1976 - mean_absolute_error: 0.3432 - val_loss: 0.0058 - val_mean_absolute_error: 0.0734
# Epoch 75/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1966 - mean_absolute_error: 0.3421 - val_loss: 0.0056 - val_mean_absolute_error: 0.0725
# Epoch 76/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1957 - mean_absolute_error: 0.3411 - val_loss: 0.0055 - val_mean_absolute_error: 0.0717
# Epoch 77/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1947 - mean_absolute_error: 0.3400 - val_loss: 0.0054 - val_mean_absolute_error: 0.0708
# Epoch 78/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1937 - mean_absolute_error: 0.3389 - val_loss: 0.0053 - val_mean_absolute_error: 0.0700
# Epoch 79/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1928 - mean_absolute_error: 0.3378 - val_loss: 0.0052 - val_mean_absolute_error: 0.0692
# Epoch 80/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1918 - mean_absolute_error: 0.3368 - val_loss: 0.0050 - val_mean_absolute_error: 0.0684
# Epoch 81/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1909 - mean_absolute_error: 0.3358 - val_loss: 0.0049 - val_mean_absolute_error: 0.0676
# Epoch 82/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1900 - mean_absolute_error: 0.3347 - val_loss: 0.0048 - val_mean_absolute_error: 0.0668
# Epoch 83/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1891 - mean_absolute_error: 0.3337 - val_loss: 0.0047 - val_mean_absolute_error: 0.0659
# Epoch 84/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1881 - mean_absolute_error: 0.3326 - val_loss: 0.0046 - val_mean_absolute_error: 0.0651
# Epoch 85/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1872 - mean_absolute_error: 0.3316 - val_loss: 0.0045 - val_mean_absolute_error: 0.0643
# Epoch 86/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1863 - mean_absolute_error: 0.3306 - val_loss: 0.0044 - val_mean_absolute_error: 0.0635
# Epoch 87/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1854 - mean_absolute_error: 0.3296 - val_loss: 0.0043 - val_mean_absolute_error: 0.0627
# Epoch 88/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1846 - mean_absolute_error: 0.3286 - val_loss: 0.0042 - val_mean_absolute_error: 0.0619
# Epoch 89/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1837 - mean_absolute_error: 0.3276 - val_loss: 0.0041 - val_mean_absolute_error: 0.0611
# Epoch 90/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1828 - mean_absolute_error: 0.3265 - val_loss: 0.0040 - val_mean_absolute_error: 0.0603
# Epoch 91/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1819 - mean_absolute_error: 0.3256 - val_loss: 0.0039 - val_mean_absolute_error: 0.0595
# Epoch 92/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1810 - mean_absolute_error: 0.3245 - val_loss: 0.0038 - val_mean_absolute_error: 0.0587
# Epoch 93/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1802 - mean_absolute_error: 0.3235 - val_loss: 0.0037 - val_mean_absolute_error: 0.0579
# Epoch 94/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1793 - mean_absolute_error: 0.3225 - val_loss: 0.0036 - val_mean_absolute_error: 0.0571
# Epoch 95/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1784 - mean_absolute_error: 0.3215 - val_loss: 0.0035 - val_mean_absolute_error: 0.0563
# Epoch 96/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1775 - mean_absolute_error: 0.3204 - val_loss: 0.0034 - val_mean_absolute_error: 0.0554
# Epoch 97/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1765 - mean_absolute_error: 0.3193 - val_loss: 0.0033 - val_mean_absolute_error: 0.0546
# Epoch 98/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1757 - mean_absolute_error: 0.3183 - val_loss: 0.0032 - val_mean_absolute_error: 0.0537
# Epoch 99/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1747 - mean_absolute_error: 0.3173 - val_loss: 0.0031 - val_mean_absolute_error: 0.0529
# Epoch 100/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1738 - mean_absolute_error: 0.3162 - val_loss: 0.0031 - val_mean_absolute_error: 0.0520
# Epoch 101/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1729 - mean_absolute_error: 0.3151 - val_loss: 0.0030 - val_mean_absolute_error: 0.0512
# Epoch 102/200
# ...
# Epoch 23/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0079 - mean_absolute_error: 0.0245 - val_loss: 1.3093e-04 - val_mean_absolute_error: 0.0089
# Epoch 24/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0078 - mean_absolute_error: 0.0254 - val_loss: 1.1184e-04 - val_mean_absolute_error: 0.0077
# Epoch 25/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0078 - mean_absolute_error: 0.0288 - val_loss: 2.2372e-04 - val_mean_absolute_error: 0.0131
# Epoch 26/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0077 - mean_absolute_error: 0.0255 - val_loss: 2.4383e-04 - val_mean_absolute_error: 0.0138
# Epoch 27/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0077 - mean_absolute_error: 0.0254 - val_loss: 1.8207e-04 - val_mean_absolute_error: 0.0114
# Epoch 28/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0077 - mean_absolute_error: 0.0275 - val_loss: 2.2642e-04 - val_mean_absolute_error: 0.0132
# 1/1 [==============================] - 0s 10ms/step - loss: 9.6436e-05 - mean_absolute_error: 0.0065
# [I 2024-03-12 11:30:51,212] Trial 96 finished with value: 9.643598605180159e-05 and parameters: {'lstm_units': 228, 'dense_units': 101, 'learning_rate': 0.001}. Best is trial 82 with value: 9.397701069246978e-05.
# Epoch 1/200
# 8/8 [==============================] - 1s 25ms/step - loss: 0.2330 - mean_absolute_error: 0.3841 - val_loss: 0.0038 - val_mean_absolute_error: 0.0590
# Epoch 2/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1430 - mean_absolute_error: 0.2803 - val_loss: 0.0020 - val_mean_absolute_error: 0.0423
# Epoch 3/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0637 - mean_absolute_error: 0.1842 - val_loss: 0.0262 - val_mean_absolute_error: 0.1613
# Epoch 4/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0329 - mean_absolute_error: 0.1585 - val_loss: 0.0463 - val_mean_absolute_error: 0.2149
# Epoch 5/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0276 - mean_absolute_error: 0.1460 - val_loss: 0.0234 - val_mean_absolute_error: 0.1524
# Epoch 6/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0195 - mean_absolute_error: 0.1171 - val_loss: 0.0116 - val_mean_absolute_error: 0.1074
# Epoch 7/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0142 - mean_absolute_error: 0.0906 - val_loss: 0.0048 - val_mean_absolute_error: 0.0688
# Epoch 8/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0097 - mean_absolute_error: 0.0618 - val_loss: 0.0019 - val_mean_absolute_error: 0.0427
# Epoch 9/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0083 - mean_absolute_error: 0.0366 - val_loss: 3.3689e-04 - val_mean_absolute_error: 0.0168
# Epoch 10/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0078 - mean_absolute_error: 0.0235 - val_loss: 2.3557e-04 - val_mean_absolute_error: 0.0128
# Epoch 11/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0079 - mean_absolute_error: 0.0276 - val_loss: 1.1610e-04 - val_mean_absolute_error: 0.0073
# Epoch 12/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0077 - mean_absolute_error: 0.0232 - val_loss: 1.1342e-04 - val_mean_absolute_error: 0.0078
# Epoch 13/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0076 - mean_absolute_error: 0.0251 - val_loss: 2.1632e-04 - val_mean_absolute_error: 0.0128
# Epoch 14/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0076 - mean_absolute_error: 0.0253 - val_loss: 2.0519e-04 - val_mean_absolute_error: 0.0124
# Epoch 15/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0079 - mean_absolute_error: 0.0304 - val_loss: 1.6674e-04 - val_mean_absolute_error: 0.0107
# Epoch 16/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0076 - mean_absolute_error: 0.0250 - val_loss: 2.5123e-04 - val_mean_absolute_error: 0.0140
# Epoch 17/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0077 - mean_absolute_error: 0.0260 - val_loss: 1.3602e-04 - val_mean_absolute_error: 0.0091
# Epoch 18/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0077 - mean_absolute_error: 0.0245 - val_loss: 1.3830e-04 - val_mean_absolute_error: 0.0092
# Epoch 19/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0078 - mean_absolute_error: 0.0236 - val_loss: 1.1238e-04 - val_mean_absolute_error: 0.0077
# Epoch 20/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0076 - mean_absolute_error: 0.0270 - val_loss: 1.3433e-04 - val_mean_absolute_error: 0.0090
# Epoch 21/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0077 - mean_absolute_error: 0.0261 - val_loss: 1.4056e-04 - val_mean_absolute_error: 0.0094
# Epoch 22/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0088 - mean_absolute_error: 0.0465 - val_loss: 1.4395e-04 - val_mean_absolute_error: 0.0097
# Epoch 23/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0081 - mean_absolute_error: 0.0381 - val_loss: 0.0017 - val_mean_absolute_error: 0.0405
# Epoch 24/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0079 - mean_absolute_error: 0.0316 - val_loss: 1.0219e-04 - val_mean_absolute_error: 0.0069
# Epoch 25/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0079 - mean_absolute_error: 0.0282 - val_loss: 1.1510e-04 - val_mean_absolute_error: 0.0078
# Epoch 26/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0077 - mean_absolute_error: 0.0260 - val_loss: 1.0620e-04 - val_mean_absolute_error: 0.0070
# Epoch 27/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0076 - mean_absolute_error: 0.0245 - val_loss: 2.1442e-04 - val_mean_absolute_error: 0.0126
# Epoch 28/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0077 - mean_absolute_error: 0.0273 - val_loss: 1.8351e-04 - val_mean_absolute_error: 0.0114
# Epoch 29/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0076 - mean_absolute_error: 0.0248 - val_loss: 1.8922e-04 - val_mean_absolute_error: 0.0116
# Epoch 30/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0077 - mean_absolute_error: 0.0231 - val_loss: 1.1113e-04 - val_mean_absolute_error: 0.0072
# Epoch 31/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0077 - mean_absolute_error: 0.0297 - val_loss: 2.1423e-04 - val_mean_absolute_error: 0.0126
# Epoch 32/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0076 - mean_absolute_error: 0.0268 - val_loss: 3.1330e-04 - val_mean_absolute_error: 0.0159
# Epoch 33/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0075 - mean_absolute_error: 0.0251 - val_loss: 1.1265e-04 - val_mean_absolute_error: 0.0076
# Epoch 34/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0077 - mean_absolute_error: 0.0233 - val_loss: 1.2713e-04 - val_mean_absolute_error: 0.0078
# 1/1 [==============================] - 0s 9ms/step - loss: 1.0219e-04 - mean_absolute_error: 0.0069
# [I 2024-03-12 11:30:52,912] Trial 97 finished with value: 0.00010219171963399276 and parameters: {'lstm_units': 239, 'dense_units': 103, 'learning_rate': 0.001}. Best is trial 82 with value: 9.397701069246978e-05.
# Epoch 1/200
# 8/8 [==============================] - 1s 24ms/step - loss: 0.2348 - mean_absolute_error: 0.3843 - val_loss: 0.0051 - val_mean_absolute_error: 0.0686
# Epoch 2/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1584 - mean_absolute_error: 0.2989 - val_loss: 6.1497e-04 - val_mean_absolute_error: 0.0206
# Epoch 3/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0826 - mean_absolute_error: 0.2033 - val_loss: 0.0166 - val_mean_absolute_error: 0.1282
# Epoch 4/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0386 - mean_absolute_error: 0.1700 - val_loss: 0.0514 - val_mean_absolute_error: 0.2264
# Epoch 5/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0349 - mean_absolute_error: 0.1650 - val_loss: 0.0459 - val_mean_absolute_error: 0.2140
# Epoch 6/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0253 - mean_absolute_error: 0.1394 - val_loss: 0.0177 - val_mean_absolute_error: 0.1325
# Epoch 7/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0196 - mean_absolute_error: 0.1144 - val_loss: 0.0077 - val_mean_absolute_error: 0.0869
# Epoch 8/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0135 - mean_absolute_error: 0.0864 - val_loss: 0.0056 - val_mean_absolute_error: 0.0745
# Epoch 9/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0097 - mean_absolute_error: 0.0597 - val_loss: 0.0022 - val_mean_absolute_error: 0.0456
# Epoch 10/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0080 - mean_absolute_error: 0.0371 - val_loss: 1.0354e-04 - val_mean_absolute_error: 0.0071
# Epoch 11/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0078 - mean_absolute_error: 0.0240 - val_loss: 1.1016e-04 - val_mean_absolute_error: 0.0073
# Epoch 12/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0077 - mean_absolute_error: 0.0217 - val_loss: 1.8708e-04 - val_mean_absolute_error: 0.0106
# Epoch 13/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0076 - mean_absolute_error: 0.0260 - val_loss: 1.0834e-04 - val_mean_absolute_error: 0.0073
# Epoch 14/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0076 - mean_absolute_error: 0.0256 - val_loss: 2.6107e-04 - val_mean_absolute_error: 0.0143
# Epoch 15/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0076 - mean_absolute_error: 0.0270 - val_loss: 2.6711e-04 - val_mean_absolute_error: 0.0145
# Epoch 16/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0076 - mean_absolute_error: 0.0268 - val_loss: 1.2208e-04 - val_mean_absolute_error: 0.0082
# Epoch 17/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0077 - mean_absolute_error: 0.0243 - val_loss: 1.2261e-04 - val_mean_absolute_error: 0.0083
# Epoch 18/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0077 - mean_absolute_error: 0.0226 - val_loss: 2.0330e-04 - val_mean_absolute_error: 0.0114
# Epoch 19/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0098 - mean_absolute_error: 0.0577 - val_loss: 1.2270e-04 - val_mean_absolute_error: 0.0076
# Epoch 20/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0085 - mean_absolute_error: 0.0420 - val_loss: 0.0028 - val_mean_absolute_error: 0.0524
# 1/1 [==============================] - 0s 10ms/step - loss: 1.0354e-04 - mean_absolute_error: 0.0071
# [I 2024-03-12 11:30:54,241] Trial 98 finished with value: 0.00010353929246775806 and parameters: {'lstm_units': 230, 'dense_units': 100, 'learning_rate': 0.001}. Best is trial 82 with value: 9.397701069246978e-05.
# Epoch 1/200
# 8/8 [==============================] - 1s 24ms/step - loss: 0.2361 - mean_absolute_error: 0.3863 - val_loss: 0.0059 - val_mean_absolute_error: 0.0744
# Epoch 2/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1669 - mean_absolute_error: 0.3099 - val_loss: 3.1629e-04 - val_mean_absolute_error: 0.0133
# Epoch 3/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1023 - mean_absolute_error: 0.2262 - val_loss: 0.0079 - val_mean_absolute_error: 0.0876
# Epoch 4/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0493 - mean_absolute_error: 0.1741 - val_loss: 0.0353 - val_mean_absolute_error: 0.1874
# Epoch 5/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0349 - mean_absolute_error: 0.1674 - val_loss: 0.0529 - val_mean_absolute_error: 0.2297
# Epoch 6/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0308 - mean_absolute_error: 0.1555 - val_loss: 0.0315 - val_mean_absolute_error: 0.1770
# Epoch 7/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0231 - mean_absolute_error: 0.1305 - val_loss: 0.0160 - val_mean_absolute_error: 0.1260
# Epoch 8/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0183 - mean_absolute_error: 0.1103 - val_loss: 0.0097 - val_mean_absolute_error: 0.0979
# Epoch 9/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0130 - mean_absolute_error: 0.0861 - val_loss: 0.0083 - val_mean_absolute_error: 0.0904
# Epoch 10/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0101 - mean_absolute_error: 0.0630 - val_loss: 0.0025 - val_mean_absolute_error: 0.0489
# Epoch 11/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0084 - mean_absolute_error: 0.0432 - val_loss: 5.7218e-04 - val_mean_absolute_error: 0.0224
# Epoch 12/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0080 - mean_absolute_error: 0.0289 - val_loss: 2.1872e-04 - val_mean_absolute_error: 0.0131
# Epoch 13/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0079 - mean_absolute_error: 0.0255 - val_loss: 9.6068e-05 - val_mean_absolute_error: 0.0065
# Epoch 14/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0078 - mean_absolute_error: 0.0242 - val_loss: 1.3118e-04 - val_mean_absolute_error: 0.0090
# Epoch 15/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0078 - mean_absolute_error: 0.0233 - val_loss: 1.0349e-04 - val_mean_absolute_error: 0.0072
# Epoch 16/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0077 - mean_absolute_error: 0.0286 - val_loss: 1.3897e-04 - val_mean_absolute_error: 0.0095
# Epoch 17/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0078 - mean_absolute_error: 0.0305 - val_loss: 3.3433e-04 - val_mean_absolute_error: 0.0168
# Epoch 18/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0081 - mean_absolute_error: 0.0274 - val_loss: 4.8521e-04 - val_mean_absolute_error: 0.0205
# Epoch 19/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0082 - mean_absolute_error: 0.0289 - val_loss: 9.5278e-05 - val_mean_absolute_error: 0.0065
# Epoch 20/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0076 - mean_absolute_error: 0.0263 - val_loss: 2.3894e-04 - val_mean_absolute_error: 0.0137
# Epoch 21/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0077 - mean_absolute_error: 0.0235 - val_loss: 1.7420e-04 - val_mean_absolute_error: 0.0111
# Epoch 22/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0077 - mean_absolute_error: 0.0276 - val_loss: 1.0597e-04 - val_mean_absolute_error: 0.0074
# Epoch 23/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0076 - mean_absolute_error: 0.0260 - val_loss: 2.3944e-04 - val_mean_absolute_error: 0.0137
# Epoch 24/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0076 - mean_absolute_error: 0.0247 - val_loss: 2.3489e-04 - val_mean_absolute_error: 0.0135
# Epoch 25/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0076 - mean_absolute_error: 0.0249 - val_loss: 1.1910e-04 - val_mean_absolute_error: 0.0083
# Epoch 26/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0076 - mean_absolute_error: 0.0265 - val_loss: 1.1788e-04 - val_mean_absolute_error: 0.0082
# Epoch 27/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0076 - mean_absolute_error: 0.0251 - val_loss: 1.9758e-04 - val_mean_absolute_error: 0.0120
# Epoch 28/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0076 - mean_absolute_error: 0.0240 - val_loss: 1.5357e-04 - val_mean_absolute_error: 0.0101
# Epoch 29/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0076 - mean_absolute_error: 0.0262 - val_loss: 1.0242e-04 - val_mean_absolute_error: 0.0070
# 1/1 [==============================] - 0s 10ms/step - loss: 9.5278e-05 - mean_absolute_error: 0.0065
# [I 2024-03-12 11:30:55,676] Trial 99 finished with value: 9.527804650133476e-05 and parameters: {'lstm_units': 136, 'dense_units': 99, 'learning_rate': 0.001}. Best is trial 82 with value: 9.397701069246978e-05.
# Best hyperparameters: {'lstm_units': 238, 'dense_units': 103, 'learning_rate': 0.001}

# %%
best_params
# Out:
# {'lstm_units': 238, 'dense_units': 103, 'learning_rate': 0.001}

# %%
#best_lstm_units = best_params['lstm_units']
#best_gru_units = best_params['gru_units']
num_filters = best_params['num_filters']
kernel_size = best_params['kernel_size']
best_dense_units = best_params['dense_units']
best_learning_rate = best_params['learning_rate']
#best_num_lstm_layers = best_params['num_lstm_layers']
model = Sequential([
    layers.Input((shift, 1)),
    #layers.LSTM(best_lstm_units),
    #layers.Bidirectional(layers.LSTM(best_lstm_units)),
    #layers.GRU(64),
    layers.Conv1D(num_filters, kernel_size, activation='relu',padding='same'),
    layers.MaxPooling1D(),
    layers.Flatten(),
    layers.Dense(32, activation='relu'),
    layers.Dense(1)
])
'''
model = Sequential()
model.add(layers.Input((1, 1)))
for _ in range(best_num_lstm_layers):
    model.add(layers.LSTM(best_lstm_units, return_sequences=True))
model.add(layers.Flatten())
model.add(layers.Dense(best_dense_units, activation='relu'))
model.add(layers.Dense(1))
'''

# Compile the final model
model.compile(loss='mse', 
                optimizer=Adam(learning_rate=best_learning_rate),
                metrics=['mean_absolute_error'])

# Train the final model on the entire training data
h=model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=200)
# Out:
# Epoch 1/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.2007 - mean_absolute_error: 0.3513 - val_loss: 0.0015 - val_mean_absolute_error: 0.0360
# Epoch 2/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0796 - mean_absolute_error: 0.2018 - val_loss: 0.0021 - val_mean_absolute_error: 0.0449
# Epoch 3/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0264 - mean_absolute_error: 0.1180 - val_loss: 0.0098 - val_mean_absolute_error: 0.0982
# Epoch 4/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0164 - mean_absolute_error: 0.0883 - val_loss: 0.0104 - val_mean_absolute_error: 0.1012
# Epoch 5/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0142 - mean_absolute_error: 0.0721 - val_loss: 0.0030 - val_mean_absolute_error: 0.0538
# Epoch 6/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0117 - mean_absolute_error: 0.0586 - val_loss: 3.8550e-04 - val_mean_absolute_error: 0.0166
# Epoch 7/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0103 - mean_absolute_error: 0.0434 - val_loss: 3.0038e-04 - val_mean_absolute_error: 0.0140
# Epoch 8/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0100 - mean_absolute_error: 0.0360 - val_loss: 2.0679e-04 - val_mean_absolute_error: 0.0114
# Epoch 9/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0095 - mean_absolute_error: 0.0322 - val_loss: 1.5766e-04 - val_mean_absolute_error: 0.0104
# Epoch 10/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0092 - mean_absolute_error: 0.0301 - val_loss: 1.6017e-04 - val_mean_absolute_error: 0.0102
# Epoch 11/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0089 - mean_absolute_error: 0.0324 - val_loss: 1.5538e-04 - val_mean_absolute_error: 0.0101
# Epoch 12/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0089 - mean_absolute_error: 0.0316 - val_loss: 1.4606e-04 - val_mean_absolute_error: 0.0100
# Epoch 13/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0086 - mean_absolute_error: 0.0329 - val_loss: 1.4083e-04 - val_mean_absolute_error: 0.0097
# Epoch 14/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0084 - mean_absolute_error: 0.0320 - val_loss: 1.4500e-04 - val_mean_absolute_error: 0.0100
# Epoch 15/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0082 - mean_absolute_error: 0.0322 - val_loss: 1.6380e-04 - val_mean_absolute_error: 0.0098
# Epoch 16/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0081 - mean_absolute_error: 0.0296 - val_loss: 1.4250e-04 - val_mean_absolute_error: 0.0099
# Epoch 17/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0081 - mean_absolute_error: 0.0270 - val_loss: 1.3663e-04 - val_mean_absolute_error: 0.0095
# Epoch 18/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0079 - mean_absolute_error: 0.0298 - val_loss: 1.4522e-04 - val_mean_absolute_error: 0.0094
# Epoch 19/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0078 - mean_absolute_error: 0.0307 - val_loss: 1.5286e-04 - val_mean_absolute_error: 0.0101
# Epoch 20/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0078 - mean_absolute_error: 0.0292 - val_loss: 1.4661e-04 - val_mean_absolute_error: 0.0098
# Epoch 21/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0077 - mean_absolute_error: 0.0287 - val_loss: 1.2953e-04 - val_mean_absolute_error: 0.0092
# Epoch 22/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0080 - mean_absolute_error: 0.0269 - val_loss: 1.3480e-04 - val_mean_absolute_error: 0.0091
# Epoch 23/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0078 - mean_absolute_error: 0.0307 - val_loss: 1.9917e-04 - val_mean_absolute_error: 0.0110
# Epoch 24/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0078 - mean_absolute_error: 0.0275 - val_loss: 1.8619e-04 - val_mean_absolute_error: 0.0110
# Epoch 25/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0078 - mean_absolute_error: 0.0277 - val_loss: 1.2208e-04 - val_mean_absolute_error: 0.0087
# Epoch 26/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0076 - mean_absolute_error: 0.0286 - val_loss: 1.2250e-04 - val_mean_absolute_error: 0.0088
# Epoch 27/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0076 - mean_absolute_error: 0.0262 - val_loss: 1.2876e-04 - val_mean_absolute_error: 0.0089
# Epoch 28/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0075 - mean_absolute_error: 0.0275 - val_loss: 1.2474e-04 - val_mean_absolute_error: 0.0087
# Epoch 29/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0076 - mean_absolute_error: 0.0266 - val_loss: 1.3545e-04 - val_mean_absolute_error: 0.0093
# Epoch 30/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0077 - mean_absolute_error: 0.0299 - val_loss: 1.3205e-04 - val_mean_absolute_error: 0.0087
# Epoch 31/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0077 - mean_absolute_error: 0.0258 - val_loss: 1.2549e-04 - val_mean_absolute_error: 0.0088
# Epoch 32/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0075 - mean_absolute_error: 0.0266 - val_loss: 2.6776e-04 - val_mean_absolute_error: 0.0138
# Epoch 33/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0097 - mean_absolute_error: 0.0563 - val_loss: 1.3233e-04 - val_mean_absolute_error: 0.0090
# Epoch 34/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0085 - mean_absolute_error: 0.0457 - val_loss: 0.0019 - val_mean_absolute_error: 0.0424
# Epoch 35/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0084 - mean_absolute_error: 0.0371 - val_loss: 2.3342e-04 - val_mean_absolute_error: 0.0125
# Epoch 36/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0077 - mean_absolute_error: 0.0350 - val_loss: 1.9575e-04 - val_mean_absolute_error: 0.0109
# Epoch 37/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0075 - mean_absolute_error: 0.0255 - val_loss: 1.3594e-04 - val_mean_absolute_error: 0.0093
# Epoch 38/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0077 - mean_absolute_error: 0.0264 - val_loss: 1.6407e-04 - val_mean_absolute_error: 0.0097
# Epoch 39/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0074 - mean_absolute_error: 0.0272 - val_loss: 1.2540e-04 - val_mean_absolute_error: 0.0088
# Epoch 40/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0075 - mean_absolute_error: 0.0282 - val_loss: 1.4172e-04 - val_mean_absolute_error: 0.0095
# Epoch 41/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0076 - mean_absolute_error: 0.0272 - val_loss: 1.2820e-04 - val_mean_absolute_error: 0.0090
# Epoch 42/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0076 - mean_absolute_error: 0.0283 - val_loss: 1.8656e-04 - val_mean_absolute_error: 0.0106
# Epoch 43/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0074 - mean_absolute_error: 0.0266 - val_loss: 1.2576e-04 - val_mean_absolute_error: 0.0088
# Epoch 44/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0076 - mean_absolute_error: 0.0252 - val_loss: 1.7995e-04 - val_mean_absolute_error: 0.0103
# Epoch 45/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0076 - mean_absolute_error: 0.0317 - val_loss: 1.2556e-04 - val_mean_absolute_error: 0.0088
# Epoch 46/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0074 - mean_absolute_error: 0.0269 - val_loss: 1.3007e-04 - val_mean_absolute_error: 0.0090
# Epoch 47/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0074 - mean_absolute_error: 0.0263 - val_loss: 1.6521e-04 - val_mean_absolute_error: 0.0098
# Epoch 48/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0075 - mean_absolute_error: 0.0252 - val_loss: 1.2334e-04 - val_mean_absolute_error: 0.0085
# Epoch 49/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0074 - mean_absolute_error: 0.0262 - val_loss: 1.5455e-04 - val_mean_absolute_error: 0.0094
# Epoch 50/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0074 - mean_absolute_error: 0.0267 - val_loss: 1.3041e-04 - val_mean_absolute_error: 0.0090
# Epoch 51/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0074 - mean_absolute_error: 0.0255 - val_loss: 1.3046e-04 - val_mean_absolute_error: 0.0086
# Epoch 52/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0074 - mean_absolute_error: 0.0258 - val_loss: 1.2560e-04 - val_mean_absolute_error: 0.0085
# Epoch 53/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0075 - mean_absolute_error: 0.0247 - val_loss: 1.2436e-04 - val_mean_absolute_error: 0.0086
# Epoch 54/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0074 - mean_absolute_error: 0.0281 - val_loss: 1.3901e-04 - val_mean_absolute_error: 0.0089
# Epoch 55/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0074 - mean_absolute_error: 0.0285 - val_loss: 1.3848e-04 - val_mean_absolute_error: 0.0093
# Epoch 56/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0074 - mean_absolute_error: 0.0274 - val_loss: 1.7806e-04 - val_mean_absolute_error: 0.0103
# Epoch 57/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0074 - mean_absolute_error: 0.0256 - val_loss: 1.2357e-04 - val_mean_absolute_error: 0.0087
# Epoch 58/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0075 - mean_absolute_error: 0.0281 - val_loss: 1.2484e-04 - val_mean_absolute_error: 0.0085
# Epoch 59/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0076 - mean_absolute_error: 0.0272 - val_loss: 1.6938e-04 - val_mean_absolute_error: 0.0100
# Epoch 60/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0088 - mean_absolute_error: 0.0519 - val_loss: 1.1067e-04 - val_mean_absolute_error: 0.0078
# Epoch 61/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0082 - mean_absolute_error: 0.0433 - val_loss: 0.0010 - val_mean_absolute_error: 0.0301
# Epoch 62/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0080 - mean_absolute_error: 0.0331 - val_loss: 5.9715e-04 - val_mean_absolute_error: 0.0226
# Epoch 63/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0075 - mean_absolute_error: 0.0288 - val_loss: 1.2854e-04 - val_mean_absolute_error: 0.0088
# Epoch 64/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0074 - mean_absolute_error: 0.0242 - val_loss: 1.1977e-04 - val_mean_absolute_error: 0.0084
# Epoch 65/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0073 - mean_absolute_error: 0.0265 - val_loss: 1.1261e-04 - val_mean_absolute_error: 0.0082
# Epoch 66/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0073 - mean_absolute_error: 0.0281 - val_loss: 1.1352e-04 - val_mean_absolute_error: 0.0082
# Epoch 67/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0073 - mean_absolute_error: 0.0261 - val_loss: 1.2565e-04 - val_mean_absolute_error: 0.0084
# Epoch 68/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0074 - mean_absolute_error: 0.0289 - val_loss: 1.3812e-04 - val_mean_absolute_error: 0.0089
# Epoch 69/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0075 - mean_absolute_error: 0.0262 - val_loss: 1.2537e-04 - val_mean_absolute_error: 0.0088
# Epoch 70/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0074 - mean_absolute_error: 0.0285 - val_loss: 1.2275e-04 - val_mean_absolute_error: 0.0084
# Epoch 71/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0073 - mean_absolute_error: 0.0280 - val_loss: 1.3809e-04 - val_mean_absolute_error: 0.0093
# Epoch 72/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0073 - mean_absolute_error: 0.0267 - val_loss: 1.4898e-04 - val_mean_absolute_error: 0.0093
# Epoch 73/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0074 - mean_absolute_error: 0.0287 - val_loss: 1.3090e-04 - val_mean_absolute_error: 0.0090
# Epoch 74/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0074 - mean_absolute_error: 0.0254 - val_loss: 1.4060e-04 - val_mean_absolute_error: 0.0090
# Epoch 75/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0075 - mean_absolute_error: 0.0308 - val_loss: 1.2560e-04 - val_mean_absolute_error: 0.0084
# Epoch 76/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0074 - mean_absolute_error: 0.0274 - val_loss: 1.2370e-04 - val_mean_absolute_error: 0.0087
# Epoch 77/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0075 - mean_absolute_error: 0.0294 - val_loss: 1.1611e-04 - val_mean_absolute_error: 0.0083
# Epoch 78/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0074 - mean_absolute_error: 0.0266 - val_loss: 1.1826e-04 - val_mean_absolute_error: 0.0085
# Epoch 79/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0075 - mean_absolute_error: 0.0296 - val_loss: 2.1156e-04 - val_mean_absolute_error: 0.0117
# Epoch 80/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0074 - mean_absolute_error: 0.0259 - val_loss: 1.4407e-04 - val_mean_absolute_error: 0.0095
# Epoch 81/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0073 - mean_absolute_error: 0.0252 - val_loss: 1.5786e-04 - val_mean_absolute_error: 0.0095
# Epoch 82/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0073 - mean_absolute_error: 0.0279 - val_loss: 1.4132e-04 - val_mean_absolute_error: 0.0095
# Epoch 83/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0073 - mean_absolute_error: 0.0266 - val_loss: 1.2873e-04 - val_mean_absolute_error: 0.0086
# Epoch 84/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0073 - mean_absolute_error: 0.0247 - val_loss: 1.5859e-04 - val_mean_absolute_error: 0.0095
# Epoch 85/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0074 - mean_absolute_error: 0.0239 - val_loss: 1.3979e-04 - val_mean_absolute_error: 0.0088
# Epoch 86/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0072 - mean_absolute_error: 0.0260 - val_loss: 1.2024e-04 - val_mean_absolute_error: 0.0082
# Epoch 87/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0073 - mean_absolute_error: 0.0290 - val_loss: 1.7599e-04 - val_mean_absolute_error: 0.0106
# Epoch 88/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0073 - mean_absolute_error: 0.0267 - val_loss: 1.2337e-04 - val_mean_absolute_error: 0.0087
# Epoch 89/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0073 - mean_absolute_error: 0.0241 - val_loss: 1.9936e-04 - val_mean_absolute_error: 0.0112
# Epoch 90/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0073 - mean_absolute_error: 0.0247 - val_loss: 1.1564e-04 - val_mean_absolute_error: 0.0084
# Epoch 91/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0073 - mean_absolute_error: 0.0242 - val_loss: 1.2405e-04 - val_mean_absolute_error: 0.0083
# Epoch 92/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0072 - mean_absolute_error: 0.0259 - val_loss: 1.1528e-04 - val_mean_absolute_error: 0.0082
# Epoch 93/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0073 - mean_absolute_error: 0.0281 - val_loss: 1.8924e-04 - val_mean_absolute_error: 0.0110
# Epoch 94/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0073 - mean_absolute_error: 0.0285 - val_loss: 1.3710e-04 - val_mean_absolute_error: 0.0093
# Epoch 95/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0072 - mean_absolute_error: 0.0248 - val_loss: 1.6069e-04 - val_mean_absolute_error: 0.0095
# Epoch 96/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0073 - mean_absolute_error: 0.0246 - val_loss: 1.2988e-04 - val_mean_absolute_error: 0.0085
# Epoch 97/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0072 - mean_absolute_error: 0.0266 - val_loss: 1.6034e-04 - val_mean_absolute_error: 0.0100
# Epoch 98/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0072 - mean_absolute_error: 0.0275 - val_loss: 1.5679e-04 - val_mean_absolute_error: 0.0099
# Epoch 99/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0072 - mean_absolute_error: 0.0271 - val_loss: 1.2234e-04 - val_mean_absolute_error: 0.0087
# Epoch 100/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0074 - mean_absolute_error: 0.0242 - val_loss: 1.4601e-04 - val_mean_absolute_error: 0.0091
# Epoch 101/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0077 - mean_absolute_error: 0.0328 - val_loss: 1.2702e-04 - val_mean_absolute_error: 0.0088
# Epoch 102/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0073 - mean_absolute_error: 0.0278 - val_loss: 2.0230e-04 - val_mean_absolute_error: 0.0115
# Epoch 103/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0073 - mean_absolute_error: 0.0296 - val_loss: 1.2921e-04 - val_mean_absolute_error: 0.0085
# Epoch 104/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0073 - mean_absolute_error: 0.0268 - val_loss: 1.3834e-04 - val_mean_absolute_error: 0.0094
# Epoch 105/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0072 - mean_absolute_error: 0.0266 - val_loss: 1.3863e-04 - val_mean_absolute_error: 0.0089
# Epoch 106/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0072 - mean_absolute_error: 0.0272 - val_loss: 1.9084e-04 - val_mean_absolute_error: 0.0111
# Epoch 107/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0074 - mean_absolute_error: 0.0267 - val_loss: 1.7318e-04 - val_mean_absolute_error: 0.0099
# Epoch 108/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0073 - mean_absolute_error: 0.0270 - val_loss: 1.3354e-04 - val_mean_absolute_error: 0.0093
# Epoch 109/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0072 - mean_absolute_error: 0.0252 - val_loss: 1.2003e-04 - val_mean_absolute_error: 0.0085
# Epoch 110/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0072 - mean_absolute_error: 0.0257 - val_loss: 1.3007e-04 - val_mean_absolute_error: 0.0086
# Epoch 111/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0071 - mean_absolute_error: 0.0252 - val_loss: 1.1540e-04 - val_mean_absolute_error: 0.0083
# Epoch 112/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0073 - mean_absolute_error: 0.0272 - val_loss: 1.5762e-04 - val_mean_absolute_error: 0.0099
# Epoch 113/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0073 - mean_absolute_error: 0.0277 - val_loss: 1.2777e-04 - val_mean_absolute_error: 0.0089
# Epoch 114/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0073 - mean_absolute_error: 0.0273 - val_loss: 1.3616e-04 - val_mean_absolute_error: 0.0087
# Epoch 115/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0072 - mean_absolute_error: 0.0252 - val_loss: 1.2711e-04 - val_mean_absolute_error: 0.0089
# Epoch 116/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0072 - mean_absolute_error: 0.0256 - val_loss: 1.4032e-04 - val_mean_absolute_error: 0.0088
# Epoch 117/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0076 - mean_absolute_error: 0.0274 - val_loss: 1.1743e-04 - val_mean_absolute_error: 0.0084
# Epoch 118/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0074 - mean_absolute_error: 0.0309 - val_loss: 1.1517e-04 - val_mean_absolute_error: 0.0082
# Epoch 119/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0072 - mean_absolute_error: 0.0258 - val_loss: 1.3215e-04 - val_mean_absolute_error: 0.0090
# Epoch 120/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0072 - mean_absolute_error: 0.0247 - val_loss: 1.5842e-04 - val_mean_absolute_error: 0.0094
# Epoch 121/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0072 - mean_absolute_error: 0.0279 - val_loss: 1.2174e-04 - val_mean_absolute_error: 0.0086
# Epoch 122/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0072 - mean_absolute_error: 0.0280 - val_loss: 1.5536e-04 - val_mean_absolute_error: 0.0099
# Epoch 123/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0072 - mean_absolute_error: 0.0253 - val_loss: 1.3608e-04 - val_mean_absolute_error: 0.0086
# Epoch 124/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0075 - mean_absolute_error: 0.0300 - val_loss: 1.5116e-04 - val_mean_absolute_error: 0.0097
# Epoch 125/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0073 - mean_absolute_error: 0.0270 - val_loss: 1.2926e-04 - val_mean_absolute_error: 0.0089
# Epoch 126/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0072 - mean_absolute_error: 0.0266 - val_loss: 1.3814e-04 - val_mean_absolute_error: 0.0086
# Epoch 127/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0072 - mean_absolute_error: 0.0278 - val_loss: 2.6168e-04 - val_mean_absolute_error: 0.0137
# Epoch 128/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0072 - mean_absolute_error: 0.0280 - val_loss: 1.3127e-04 - val_mean_absolute_error: 0.0086
# Epoch 129/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0070 - mean_absolute_error: 0.0267 - val_loss: 1.4168e-04 - val_mean_absolute_error: 0.0095
# Epoch 130/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0072 - mean_absolute_error: 0.0244 - val_loss: 1.6398e-04 - val_mean_absolute_error: 0.0096
# Epoch 131/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0073 - mean_absolute_error: 0.0250 - val_loss: 1.2292e-04 - val_mean_absolute_error: 0.0082
# Epoch 132/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0072 - mean_absolute_error: 0.0281 - val_loss: 1.6657e-04 - val_mean_absolute_error: 0.0103
# Epoch 133/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0073 - mean_absolute_error: 0.0266 - val_loss: 1.1700e-04 - val_mean_absolute_error: 0.0081
# Epoch 134/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0071 - mean_absolute_error: 0.0255 - val_loss: 1.2282e-04 - val_mean_absolute_error: 0.0082
# Epoch 135/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0071 - mean_absolute_error: 0.0262 - val_loss: 1.8317e-04 - val_mean_absolute_error: 0.0109
# Epoch 136/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0071 - mean_absolute_error: 0.0258 - val_loss: 1.1864e-04 - val_mean_absolute_error: 0.0085
# Epoch 137/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0075 - mean_absolute_error: 0.0250 - val_loss: 1.9626e-04 - val_mean_absolute_error: 0.0110
# Epoch 138/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0072 - mean_absolute_error: 0.0243 - val_loss: 1.1948e-04 - val_mean_absolute_error: 0.0083
# Epoch 139/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0072 - mean_absolute_error: 0.0289 - val_loss: 1.4276e-04 - val_mean_absolute_error: 0.0094
# Epoch 140/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0071 - mean_absolute_error: 0.0277 - val_loss: 1.4181e-04 - val_mean_absolute_error: 0.0094
# Epoch 141/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0072 - mean_absolute_error: 0.0248 - val_loss: 1.8633e-04 - val_mean_absolute_error: 0.0105
# Epoch 142/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0074 - mean_absolute_error: 0.0246 - val_loss: 1.4268e-04 - val_mean_absolute_error: 0.0088
# Epoch 143/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0071 - mean_absolute_error: 0.0250 - val_loss: 1.2018e-04 - val_mean_absolute_error: 0.0084
# Epoch 144/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0071 - mean_absolute_error: 0.0249 - val_loss: 1.1927e-04 - val_mean_absolute_error: 0.0082
# Epoch 145/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0072 - mean_absolute_error: 0.0251 - val_loss: 1.4196e-04 - val_mean_absolute_error: 0.0088
# Epoch 146/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0071 - mean_absolute_error: 0.0256 - val_loss: 1.3068e-04 - val_mean_absolute_error: 0.0085
# Epoch 147/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0072 - mean_absolute_error: 0.0282 - val_loss: 1.1936e-04 - val_mean_absolute_error: 0.0084
# Epoch 148/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0071 - mean_absolute_error: 0.0257 - val_loss: 1.2207e-04 - val_mean_absolute_error: 0.0082
# Epoch 149/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0073 - mean_absolute_error: 0.0273 - val_loss: 1.1082e-04 - val_mean_absolute_error: 0.0078
# Epoch 150/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0072 - mean_absolute_error: 0.0248 - val_loss: 1.0905e-04 - val_mean_absolute_error: 0.0078
# Epoch 151/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0072 - mean_absolute_error: 0.0277 - val_loss: 1.8786e-04 - val_mean_absolute_error: 0.0111
# Epoch 152/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0077 - mean_absolute_error: 0.0296 - val_loss: 2.7169e-04 - val_mean_absolute_error: 0.0139
# Epoch 153/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0075 - mean_absolute_error: 0.0321 - val_loss: 1.2207e-04 - val_mean_absolute_error: 0.0085
# Epoch 154/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0073 - mean_absolute_error: 0.0271 - val_loss: 1.1539e-04 - val_mean_absolute_error: 0.0082
# Epoch 155/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0073 - mean_absolute_error: 0.0320 - val_loss: 1.4359e-04 - val_mean_absolute_error: 0.0094
# Epoch 156/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0075 - mean_absolute_error: 0.0293 - val_loss: 1.1623e-04 - val_mean_absolute_error: 0.0083
# Epoch 157/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0071 - mean_absolute_error: 0.0271 - val_loss: 1.2546e-04 - val_mean_absolute_error: 0.0083
# Epoch 158/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0070 - mean_absolute_error: 0.0258 - val_loss: 1.5526e-04 - val_mean_absolute_error: 0.0099
# Epoch 159/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0073 - mean_absolute_error: 0.0261 - val_loss: 1.2374e-04 - val_mean_absolute_error: 0.0081
# Epoch 160/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0072 - mean_absolute_error: 0.0260 - val_loss: 1.3695e-04 - val_mean_absolute_error: 0.0091
# Epoch 161/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0071 - mean_absolute_error: 0.0271 - val_loss: 1.9735e-04 - val_mean_absolute_error: 0.0115
# Epoch 162/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0072 - mean_absolute_error: 0.0264 - val_loss: 1.6965e-04 - val_mean_absolute_error: 0.0099
# Epoch 163/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0074 - mean_absolute_error: 0.0300 - val_loss: 1.5116e-04 - val_mean_absolute_error: 0.0097
# Epoch 164/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0072 - mean_absolute_error: 0.0264 - val_loss: 1.1574e-04 - val_mean_absolute_error: 0.0082
# Epoch 165/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0072 - mean_absolute_error: 0.0275 - val_loss: 1.1829e-04 - val_mean_absolute_error: 0.0082
# Epoch 166/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0071 - mean_absolute_error: 0.0264 - val_loss: 1.5200e-04 - val_mean_absolute_error: 0.0098
# Epoch 167/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0071 - mean_absolute_error: 0.0270 - val_loss: 1.1704e-04 - val_mean_absolute_error: 0.0084
# Epoch 168/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0071 - mean_absolute_error: 0.0246 - val_loss: 1.3518e-04 - val_mean_absolute_error: 0.0086
# Epoch 169/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0072 - mean_absolute_error: 0.0246 - val_loss: 1.2351e-04 - val_mean_absolute_error: 0.0082
# Epoch 170/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0072 - mean_absolute_error: 0.0285 - val_loss: 1.8624e-04 - val_mean_absolute_error: 0.0111
# Epoch 171/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0072 - mean_absolute_error: 0.0276 - val_loss: 1.1267e-04 - val_mean_absolute_error: 0.0081
# Epoch 172/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0072 - mean_absolute_error: 0.0238 - val_loss: 1.6012e-04 - val_mean_absolute_error: 0.0095
# Epoch 173/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0071 - mean_absolute_error: 0.0254 - val_loss: 1.3623e-04 - val_mean_absolute_error: 0.0091
# Epoch 174/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0071 - mean_absolute_error: 0.0266 - val_loss: 1.1318e-04 - val_mean_absolute_error: 0.0081
# Epoch 175/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0071 - mean_absolute_error: 0.0277 - val_loss: 1.5619e-04 - val_mean_absolute_error: 0.0099
# Epoch 176/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0070 - mean_absolute_error: 0.0259 - val_loss: 1.1931e-04 - val_mean_absolute_error: 0.0084
# Epoch 177/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0071 - mean_absolute_error: 0.0248 - val_loss: 1.2533e-04 - val_mean_absolute_error: 0.0083
# Epoch 178/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0071 - mean_absolute_error: 0.0258 - val_loss: 1.3094e-04 - val_mean_absolute_error: 0.0089
# Epoch 179/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0071 - mean_absolute_error: 0.0268 - val_loss: 1.2737e-04 - val_mean_absolute_error: 0.0089
# Epoch 180/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0072 - mean_absolute_error: 0.0246 - val_loss: 1.5653e-04 - val_mean_absolute_error: 0.0093
# Epoch 181/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0071 - mean_absolute_error: 0.0250 - val_loss: 1.1135e-04 - val_mean_absolute_error: 0.0080
# Epoch 182/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0071 - mean_absolute_error: 0.0243 - val_loss: 1.0834e-04 - val_mean_absolute_error: 0.0078
# Epoch 183/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0072 - mean_absolute_error: 0.0284 - val_loss: 2.0688e-04 - val_mean_absolute_error: 0.0119
# Epoch 184/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0074 - mean_absolute_error: 0.0267 - val_loss: 1.8775e-04 - val_mean_absolute_error: 0.0107
# Epoch 185/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0073 - mean_absolute_error: 0.0264 - val_loss: 1.1585e-04 - val_mean_absolute_error: 0.0082
# Epoch 186/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0071 - mean_absolute_error: 0.0256 - val_loss: 1.3022e-04 - val_mean_absolute_error: 0.0088
# Epoch 187/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0070 - mean_absolute_error: 0.0274 - val_loss: 1.2984e-04 - val_mean_absolute_error: 0.0089
# Epoch 188/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0072 - mean_absolute_error: 0.0251 - val_loss: 1.6722e-04 - val_mean_absolute_error: 0.0098
# Epoch 189/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0073 - mean_absolute_error: 0.0299 - val_loss: 2.2015e-04 - val_mean_absolute_error: 0.0123
# Epoch 190/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0072 - mean_absolute_error: 0.0263 - val_loss: 1.8205e-04 - val_mean_absolute_error: 0.0105
# Epoch 191/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0072 - mean_absolute_error: 0.0296 - val_loss: 1.4935e-04 - val_mean_absolute_error: 0.0096
# Epoch 192/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0072 - mean_absolute_error: 0.0282 - val_loss: 1.5776e-04 - val_mean_absolute_error: 0.0100
# Epoch 193/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0071 - mean_absolute_error: 0.0254 - val_loss: 1.3648e-04 - val_mean_absolute_error: 0.0086
# Epoch 194/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0071 - mean_absolute_error: 0.0243 - val_loss: 1.3083e-04 - val_mean_absolute_error: 0.0084
# Epoch 195/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0071 - mean_absolute_error: 0.0271 - val_loss: 1.6872e-04 - val_mean_absolute_error: 0.0104
# Epoch 196/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0071 - mean_absolute_error: 0.0267 - val_loss: 1.3155e-04 - val_mean_absolute_error: 0.0090
# Epoch 197/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0074 - mean_absolute_error: 0.0268 - val_loss: 2.9993e-04 - val_mean_absolute_error: 0.0149
# Epoch 198/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0071 - mean_absolute_error: 0.0277 - val_loss: 1.2507e-04 - val_mean_absolute_error: 0.0085
# Epoch 199/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0072 - mean_absolute_error: 0.0269 - val_loss: 1.4267e-04 - val_mean_absolute_error: 0.0093
# Epoch 200/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0070 - mean_absolute_error: 0.0250 - val_loss: 1.0824e-04 - val_mean_absolute_error: 0.0077

# %%
train_loss = model.evaluate(X_train, y_train, verbose=0)
print(f'Training Loss: {train_loss}')
test_loss = model.evaluate(X_test, y_test, verbose=0)
print(f'Testing Loss: {test_loss}')

plt.plot(h.history['loss'], label='Training Loss')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Training Loss: [0.006984000559896231, 0.024143148213624954]
# Testing Loss: [0.00014242502220440656, 0.009426623582839966]

# %%
train_predictions = model.predict(X_train)

plt.plot(dates_train, train_predictions,linestyle="-", marker='o', markersize=3)
plt.plot(dates_train, y_train, linestyle="--", marker='x', markersize=3)

##plt.plot(train_predictions)
##plt.plot(y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 8/8 [==============================] - 0s 581us/step

# %%
val_predictions = model.predict(X_val)#.flatten()

plt.plot(dates_val, val_predictions,linestyle="-", marker='o', markersize=3)
plt.plot(dates_val, y_val,linestyle="--", marker='x', markersize=3)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 1/1 [==============================] - 0s 11ms/step

# %%
test_predictions = model.predict(X_test)#.flatten()

plt.plot(dates_test, test_predictions,linestyle="-", marker='o', markersize=3)
plt.plot(dates_test, y_test,linestyle="--", marker='x', markersize=3)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 1/1 [==============================] - 0s 10ms/step

# %%
#test_predictions

# %%
# Inverse transform to get actual prices
y_train_actual = scaler.inverse_transform(y_train.reshape(-1, 1))
y_test_actual = scaler.inverse_transform(y_test.reshape(-1, 1))
y_train_pred_actual = scaler.inverse_transform(train_predictions.reshape(-1,1))
y_test_pred_actual = scaler.inverse_transform(test_predictions.reshape(-1,1))
y_val_pred_actual = scaler.inverse_transform(val_predictions.reshape(-1,1))
y_val_actual = scaler.inverse_transform(y_val.reshape(-1,1))

# %%
# Calculate evaluation metrics
train_mae = mean_absolute_error(y_train_actual, y_train_pred_actual)
train_mse = mean_squared_error(y_train_actual, y_train_pred_actual)
val_mae = mean_absolute_error(y_val_actual, y_val_pred_actual)
test_mae = mean_absolute_error(y_test_actual, y_test_pred_actual)
test_mse = mean_squared_error(y_test_actual, y_test_pred_actual)
val_mse = mean_squared_error(y_val_actual, y_val_pred_actual)

print(f'Training MAE: {train_mae}')
print(f'Training MSE: {train_mse}')
print(f'Val MAE: {val_mae}')
print(f'Val MSE: {val_mse}')
print(f'Testing MAE: {test_mae}')
print(f'Testing MSE: {test_mse}')


train_r = np.sqrt(train_mse)
train_r2 = r2_score(y_train_actual, y_train_pred_actual)
test_r = np.sqrt(test_mse)
test_r2 = r2_score(y_test_actual, y_test_pred_actual)
val_r = np.sqrt(val_mse)
val_r2 = r2_score(y_val_actual, y_val_pred_actual)


print(train_r)
print(train_r2)
print(val_r)
print(val_r2)
print(test_r)
print(test_r2)
# Out:
# Training MAE: 2.6291890144348145
# Training MSE: 82.82472229003906
# Val MAE: 0.8423674702644348
# Val MSE: 1.2836666107177734
# Testing MAE: 1.026558756828308
# Testing MSE: 1.6890453100204468
# 9.100809
# 0.9275509451192243
# 1.1329901
# 0.7148243612272049
# 1.2996328
# 0.9811233205161837

# %%
model.save('rice_cnn')
# Out:
# INFO:tensorflow:Assets written to: rice_cnn/assets
# INFO:tensorflow:Assets written to: rice_cnn/assets

# %%
import tensorflow as tf
m1=tf.keras.models.load_model('rice_lstm')
m1.layers[0].input_shape
# Out:
# (None, 1, 1)

# %%
test_predictions = m1.predict(X_test)#.flatten()

y_test_actual = scaler.inverse_transform(y_test.reshape(-1, 1))
y_test_pred_actual = scaler.inverse_transform(test_predictions.reshape(-1,1))

test_r2 = r2_score(y_test_actual, y_test_pred_actual)
print(test_r2)
#plt.plot(dates_test, test_predictions)
#plt.plot(dates_test, y_test)
#plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 1/1 [==============================] - 0s 155ms/step
# 0.9879600055290938

# %%
plt.plot(figsize=(100,100))
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations'],loc='upper left')

# %%
n = 12  # Change this value to forecast more or fewer values
forecast = []
last_data = X[-1]  # Last X data point
for i in range(n):
    next_y = model.predict(last_data.reshape(1, X.shape[1], X.shape[2]))  # Predict next y
    forecast.append(next_y)
    last_data = np.append(last_data[1:], next_y)  # Shift data by 1 and append next_y
forecast = scaler.inverse_transform(np.array(forecast).reshape(-1, 1))
y_act=scaler.inverse_transform(np.array(y).reshape(-1, 1))
# Out:
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step

# %%
plt.figure(figsize=(10, 6))
plt.plot(dates, y_act, label='Original Data')
plt.xlabel('Time')
plt.ylabel('Value')
plt.title('Original Data and Forecast')
plt.xticks(rotation=45)
plt.legend()

# Plot forecast
forecast_dates = np.arange(len(y), len(y) + n)
plt.plot(forecast_dates, forecast, label='Forecast', color='red')
plt.legend()

plt.show()
