# %%
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.preprocessing import MinMaxScaler
from statsmodels.tsa.stattools import kpss

# %%
df=pd.read_csv("DATA/wheat.csv")

df
# Out:
#                     Date  price
# 0    2000-01-01 00:00:00  180.8
# 1    2000-02-01 00:00:00  180.7
# 2    2000-03-01 00:00:00  180.3
# 3    2000-04-01 00:00:00  179.8
# 4    2000-05-01 00:00:00  178.4
# ..                   ...    ...
# 277  2023-02-01 00:00:00  196.8
# 278  2023-03-01 00:00:00  187.1
# 279  2023-04-01 00:00:00  186.4
# 280  2023-05-01 00:00:00  184.9
# 281  2023-06-01 00:00:00  187.3
#
# [282 rows x 2 columns]

# %%
df.plot()
# Out:
# <Axes: >

# %%
sn.boxplot(df['price'])
# Out:
# <Axes: >

# %%
t=kpss(df['price'],'ct')
t
# Out:
# /var/folders/35/vcbg9sn9479dqrdl_3fgrrkh0000gn/T/ipykernel_43309/1514378212.py:1: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   t=kpss(df['price'],'ct')
# (0.30667012535484883,
#  0.01,
#  10,
#  {'10%': 0.119, '5%': 0.146, '2.5%': 0.176, '1%': 0.216})

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose

# Assuming df is your DataFrame with a 'date' column and a 'value' column representing the time series
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)

# Perform seasonal decomposition
decomposition = seasonal_decompose(df['price'], model='additive')

# Plot the original time series
plt.figure(figsize=(10, 6))
plt.subplot(411)
plt.plot(df['price'], label='Original', color='blue')
plt.legend(loc='upper left')

# Plot the trend component
plt.subplot(412)
plt.plot(decomposition.trend, label='Trend', color='green')
plt.legend(loc='upper left')

# Plot the seasonal component
plt.subplot(413)
plt.plot(decomposition.seasonal, label='Seasonal', color='red')
plt.legend(loc='upper left')

# Plot the residual component
plt.subplot(414)
plt.plot(decomposition.resid, label='Residual', color='purple')
plt.legend(loc='upper left')

plt.tight_layout()
plt.show()

# %%
df=pd.read_csv("DATA/Backup/wheat.csv")

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
df['price'] = scaler.fit_transform(df['price'].values.reshape(-1,1))

# %%
import matplotlib.pyplot as plt
plt.plot(df['Date'],df['price'])

# %%
# Convert 'date' column to datetime if it's not already
# Shift the 'price' column to create new columns
shift=3
for i in range(shift):
    df['target-'+str(i+1)] = df['price'].shift(i+1)
#df['target-1'] = df['price'].shift(1)
#df['target-2'] = df['price'].shift(2)
#df['target-3'] = df['price'].shift(3)
#df['target-4'] = df['price'].shift(4)
#df['target-5'] = df['price'].shift(5)
#df['target-6'] = df['price'].shift(6)
#df['target-7'] = df['price'].shift(7)
#df['target-8'] = df['price'].shift(8)
#df['target-9'] = df['price'].shift(9)
#df['target-10'] = df['price'].shift(10)

# %%
d=df[shift:]
d
# Out:
#                     Date     price  target-1  target-2  target-3
# 3    2000-04-01 00:00:00  0.284505  0.287760  0.290365  0.291016
# 4    2000-05-01 00:00:00  0.275391  0.284505  0.287760  0.290365
# 5    2000-06-01 00:00:00  0.277995  0.275391  0.284505  0.287760
# 6    2000-07-01 00:00:00  0.274740  0.277995  0.275391  0.284505
# 7    2000-08-01 00:00:00  0.268880  0.274740  0.277995  0.275391
# ..                   ...       ...       ...       ...       ...
# 283  2023-08-01 00:00:00  0.339844  0.332031  0.333333  0.317708
# 284  2023-09-01 00:00:00  0.355469  0.339844  0.332031  0.333333
# 285  2023-10-01 00:00:00  0.376953  0.355469  0.339844  0.332031
# 286  2023-11-01 00:00:00  0.398438  0.376953  0.355469  0.339844
# 287  2023-12-01 00:00:00  0.399089  0.398438  0.376953  0.355469
#
# [285 rows x 5 columns]

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
    df_as_np = windowed_dataframe.to_numpy()
    dates = df_as_np[:, 0]
    middle_matrix = df_as_np[:, 1:-1]
    X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))
    Y = df_as_np[:, -1]
    return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(d)

dates.shape, X.shape, y.shape
# Out:
# ((285,), (285, 3, 1), (285,))

# %%
#y

# %%
#dates
#X
#y

# %%
q_80 = int(len(dates) * .8)
q_90 = int(len(dates) * .9)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %%
X_train.shape,
# Out:
# ((228, 3, 1),)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers.legacy import Adam
from tensorflow.keras import layers
from keras.callbacks import EarlyStopping
from keras.regularizers import l2

#early_stopping = EarlyStopping(monitor='val_loss', patience=10, mode='min')

model = Sequential([layers.Input((shift, 1)),
                    #layers.GRU(64),
                    #layers.LSTM(64),
                    layers.LSTM(64, return_sequences=True),
                    layers.LSTM(64),
                    #layers.Bidirectional(layers.LSTM(64)),
                    #layers.Conv1D(filters=64, kernel_size=3, activation='relu'),
                    #layers.Flatten(),
                    #layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)
                   ])

model.compile(loss='mse', 
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=160)
# Out:
# Epoch 1/160
# 8/8 [==============================] - 1s 40ms/step - loss: 0.1808 - mean_absolute_error: 0.3680 - val_loss: 0.0029 - val_mean_absolute_error: 0.0418
# Epoch 2/160
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0858 - mean_absolute_error: 0.2360 - val_loss: 0.0139 - val_mean_absolute_error: 0.1134
# Epoch 3/160
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0214 - mean_absolute_error: 0.1127 - val_loss: 0.0633 - val_mean_absolute_error: 0.2500
# Epoch 4/160
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0257 - mean_absolute_error: 0.1344 - val_loss: 0.0246 - val_mean_absolute_error: 0.1539
# Epoch 5/160
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0184 - mean_absolute_error: 0.1018 - val_loss: 0.0132 - val_mean_absolute_error: 0.1110
# Epoch 6/160
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0150 - mean_absolute_error: 0.0866 - val_loss: 0.0197 - val_mean_absolute_error: 0.1374
# Epoch 7/160
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0128 - mean_absolute_error: 0.0812 - val_loss: 0.0099 - val_mean_absolute_error: 0.0951
# Epoch 8/160
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0108 - mean_absolute_error: 0.0639 - val_loss: 0.0056 - val_mean_absolute_error: 0.0695
# Epoch 9/160
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0098 - mean_absolute_error: 0.0548 - val_loss: 0.0040 - val_mean_absolute_error: 0.0567
# Epoch 10/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0095 - mean_absolute_error: 0.0476 - val_loss: 0.0021 - val_mean_absolute_error: 0.0377
# Epoch 11/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0095 - mean_absolute_error: 0.0449 - val_loss: 0.0020 - val_mean_absolute_error: 0.0370
# Epoch 12/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0097 - mean_absolute_error: 0.0497 - val_loss: 0.0016 - val_mean_absolute_error: 0.0329
# Epoch 13/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0098 - mean_absolute_error: 0.0461 - val_loss: 0.0019 - val_mean_absolute_error: 0.0363
# Epoch 14/160
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0095 - mean_absolute_error: 0.0481 - val_loss: 0.0024 - val_mean_absolute_error: 0.0408
# Epoch 15/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0094 - mean_absolute_error: 0.0457 - val_loss: 0.0020 - val_mean_absolute_error: 0.0371
# Epoch 16/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0094 - mean_absolute_error: 0.0463 - val_loss: 0.0021 - val_mean_absolute_error: 0.0383
# Epoch 17/160
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0094 - mean_absolute_error: 0.0452 - val_loss: 0.0027 - val_mean_absolute_error: 0.0442
# Epoch 18/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0099 - mean_absolute_error: 0.0577 - val_loss: 0.0030 - val_mean_absolute_error: 0.0474
# Epoch 19/160
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0095 - mean_absolute_error: 0.0485 - val_loss: 0.0033 - val_mean_absolute_error: 0.0505
# Epoch 20/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0093 - mean_absolute_error: 0.0502 - val_loss: 0.0029 - val_mean_absolute_error: 0.0462
# Epoch 21/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0092 - mean_absolute_error: 0.0457 - val_loss: 0.0019 - val_mean_absolute_error: 0.0361
# Epoch 22/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0092 - mean_absolute_error: 0.0443 - val_loss: 0.0021 - val_mean_absolute_error: 0.0379
# Epoch 23/160
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0092 - mean_absolute_error: 0.0443 - val_loss: 0.0018 - val_mean_absolute_error: 0.0354
# Epoch 24/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0092 - mean_absolute_error: 0.0446 - val_loss: 0.0021 - val_mean_absolute_error: 0.0379
# Epoch 25/160
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0092 - mean_absolute_error: 0.0487 - val_loss: 0.0031 - val_mean_absolute_error: 0.0481
# Epoch 26/160
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0090 - mean_absolute_error: 0.0491 - val_loss: 0.0029 - val_mean_absolute_error: 0.0463
# Epoch 27/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0092 - mean_absolute_error: 0.0476 - val_loss: 0.0026 - val_mean_absolute_error: 0.0431
# Epoch 28/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0090 - mean_absolute_error: 0.0477 - val_loss: 0.0020 - val_mean_absolute_error: 0.0371
# Epoch 29/160
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0090 - mean_absolute_error: 0.0440 - val_loss: 0.0018 - val_mean_absolute_error: 0.0350
# Epoch 30/160
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0090 - mean_absolute_error: 0.0434 - val_loss: 0.0019 - val_mean_absolute_error: 0.0361
# Epoch 31/160
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0088 - mean_absolute_error: 0.0453 - val_loss: 0.0017 - val_mean_absolute_error: 0.0334
# Epoch 32/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0089 - mean_absolute_error: 0.0447 - val_loss: 0.0023 - val_mean_absolute_error: 0.0405
# Epoch 33/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0086 - mean_absolute_error: 0.0436 - val_loss: 0.0018 - val_mean_absolute_error: 0.0351
# Epoch 34/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0086 - mean_absolute_error: 0.0430 - val_loss: 0.0020 - val_mean_absolute_error: 0.0368
# Epoch 35/160
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0086 - mean_absolute_error: 0.0428 - val_loss: 0.0022 - val_mean_absolute_error: 0.0392
# Epoch 36/160
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0086 - mean_absolute_error: 0.0461 - val_loss: 0.0014 - val_mean_absolute_error: 0.0310
# Epoch 37/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0086 - mean_absolute_error: 0.0426 - val_loss: 0.0022 - val_mean_absolute_error: 0.0389
# Epoch 38/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0085 - mean_absolute_error: 0.0442 - val_loss: 0.0016 - val_mean_absolute_error: 0.0332
# Epoch 39/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0084 - mean_absolute_error: 0.0437 - val_loss: 0.0025 - val_mean_absolute_error: 0.0420
# Epoch 40/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0084 - mean_absolute_error: 0.0446 - val_loss: 0.0022 - val_mean_absolute_error: 0.0390
# Epoch 41/160
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0085 - mean_absolute_error: 0.0499 - val_loss: 0.0032 - val_mean_absolute_error: 0.0501
# Epoch 42/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0083 - mean_absolute_error: 0.0465 - val_loss: 0.0030 - val_mean_absolute_error: 0.0480
# Epoch 43/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0082 - mean_absolute_error: 0.0441 - val_loss: 0.0028 - val_mean_absolute_error: 0.0462
# Epoch 44/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0082 - mean_absolute_error: 0.0461 - val_loss: 0.0013 - val_mean_absolute_error: 0.0296
# Epoch 45/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0081 - mean_absolute_error: 0.0423 - val_loss: 0.0021 - val_mean_absolute_error: 0.0385
# Epoch 46/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0079 - mean_absolute_error: 0.0416 - val_loss: 0.0013 - val_mean_absolute_error: 0.0297
# Epoch 47/160
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0078 - mean_absolute_error: 0.0413 - val_loss: 0.0018 - val_mean_absolute_error: 0.0348
# Epoch 48/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0079 - mean_absolute_error: 0.0400 - val_loss: 0.0017 - val_mean_absolute_error: 0.0343
# Epoch 49/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0076 - mean_absolute_error: 0.0412 - val_loss: 0.0013 - val_mean_absolute_error: 0.0295
# Epoch 50/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0076 - mean_absolute_error: 0.0410 - val_loss: 0.0019 - val_mean_absolute_error: 0.0365
# Epoch 51/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0074 - mean_absolute_error: 0.0401 - val_loss: 0.0017 - val_mean_absolute_error: 0.0336
# Epoch 52/160
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0074 - mean_absolute_error: 0.0403 - val_loss: 0.0022 - val_mean_absolute_error: 0.0403
# Epoch 53/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0074 - mean_absolute_error: 0.0403 - val_loss: 0.0013 - val_mean_absolute_error: 0.0296
# Epoch 54/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0072 - mean_absolute_error: 0.0401 - val_loss: 8.2898e-04 - val_mean_absolute_error: 0.0249
# Epoch 55/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0071 - mean_absolute_error: 0.0388 - val_loss: 0.0014 - val_mean_absolute_error: 0.0308
# Epoch 56/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0069 - mean_absolute_error: 0.0363 - val_loss: 0.0011 - val_mean_absolute_error: 0.0279
# Epoch 57/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0068 - mean_absolute_error: 0.0351 - val_loss: 0.0020 - val_mean_absolute_error: 0.0379
# Epoch 58/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0075 - mean_absolute_error: 0.0516 - val_loss: 0.0028 - val_mean_absolute_error: 0.0470
# Epoch 59/160
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0076 - mean_absolute_error: 0.0535 - val_loss: 0.0026 - val_mean_absolute_error: 0.0454
# Epoch 60/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0073 - mean_absolute_error: 0.0457 - val_loss: 0.0030 - val_mean_absolute_error: 0.0496
# Epoch 61/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0070 - mean_absolute_error: 0.0405 - val_loss: 0.0011 - val_mean_absolute_error: 0.0279
# Epoch 62/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0063 - mean_absolute_error: 0.0363 - val_loss: 7.1488e-04 - val_mean_absolute_error: 0.0233
# Epoch 63/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0064 - mean_absolute_error: 0.0364 - val_loss: 8.7906e-04 - val_mean_absolute_error: 0.0251
# Epoch 64/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0061 - mean_absolute_error: 0.0332 - val_loss: 8.0440e-04 - val_mean_absolute_error: 0.0242
# Epoch 65/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0060 - mean_absolute_error: 0.0346 - val_loss: 0.0012 - val_mean_absolute_error: 0.0286
# Epoch 66/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0060 - mean_absolute_error: 0.0338 - val_loss: 0.0016 - val_mean_absolute_error: 0.0339
# Epoch 67/160
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0060 - mean_absolute_error: 0.0381 - val_loss: 6.6180e-04 - val_mean_absolute_error: 0.0223
# Epoch 68/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0058 - mean_absolute_error: 0.0358 - val_loss: 7.4269e-04 - val_mean_absolute_error: 0.0232
# Epoch 69/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0055 - mean_absolute_error: 0.0322 - val_loss: 4.8255e-04 - val_mean_absolute_error: 0.0195
# Epoch 70/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0061 - mean_absolute_error: 0.0418 - val_loss: 0.0020 - val_mean_absolute_error: 0.0394
# Epoch 71/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0060 - mean_absolute_error: 0.0389 - val_loss: 0.0021 - val_mean_absolute_error: 0.0401
# Epoch 72/160
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0058 - mean_absolute_error: 0.0395 - val_loss: 7.2452e-04 - val_mean_absolute_error: 0.0228
# Epoch 73/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0053 - mean_absolute_error: 0.0319 - val_loss: 4.4705e-04 - val_mean_absolute_error: 0.0188
# Epoch 74/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0055 - mean_absolute_error: 0.0338 - val_loss: 6.0450e-04 - val_mean_absolute_error: 0.0212
# Epoch 75/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0052 - mean_absolute_error: 0.0302 - val_loss: 7.9446e-04 - val_mean_absolute_error: 0.0237
# Epoch 76/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0050 - mean_absolute_error: 0.0289 - val_loss: 8.1265e-04 - val_mean_absolute_error: 0.0239
# Epoch 77/160
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0050 - mean_absolute_error: 0.0286 - val_loss: 8.6789e-04 - val_mean_absolute_error: 0.0246
# Epoch 78/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0050 - mean_absolute_error: 0.0281 - val_loss: 9.0282e-04 - val_mean_absolute_error: 0.0250
# Epoch 79/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0051 - mean_absolute_error: 0.0294 - val_loss: 9.8203e-04 - val_mean_absolute_error: 0.0261
# Epoch 80/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0051 - mean_absolute_error: 0.0330 - val_loss: 6.5328e-04 - val_mean_absolute_error: 0.0216
# Epoch 81/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0050 - mean_absolute_error: 0.0316 - val_loss: 4.1088e-04 - val_mean_absolute_error: 0.0179
# Epoch 82/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0050 - mean_absolute_error: 0.0317 - val_loss: 4.9187e-04 - val_mean_absolute_error: 0.0192
# Epoch 83/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0050 - mean_absolute_error: 0.0309 - val_loss: 5.9403e-04 - val_mean_absolute_error: 0.0207
# Epoch 84/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0047 - mean_absolute_error: 0.0285 - val_loss: 8.9051e-04 - val_mean_absolute_error: 0.0249
# Epoch 85/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0047 - mean_absolute_error: 0.0263 - val_loss: 9.9244e-04 - val_mean_absolute_error: 0.0265
# Epoch 86/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0053 - mean_absolute_error: 0.0345 - val_loss: 6.1270e-04 - val_mean_absolute_error: 0.0209
# Epoch 87/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0049 - mean_absolute_error: 0.0287 - val_loss: 5.2497e-04 - val_mean_absolute_error: 0.0195
# Epoch 88/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0049 - mean_absolute_error: 0.0299 - val_loss: 4.5890e-04 - val_mean_absolute_error: 0.0185
# Epoch 89/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0046 - mean_absolute_error: 0.0275 - val_loss: 5.6982e-04 - val_mean_absolute_error: 0.0202
# Epoch 90/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0046 - mean_absolute_error: 0.0287 - val_loss: 9.5917e-04 - val_mean_absolute_error: 0.0261
# Epoch 91/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0048 - mean_absolute_error: 0.0290 - val_loss: 0.0013 - val_mean_absolute_error: 0.0307
# Epoch 92/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0048 - mean_absolute_error: 0.0306 - val_loss: 6.3472e-04 - val_mean_absolute_error: 0.0211
# Epoch 93/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0045 - mean_absolute_error: 0.0268 - val_loss: 4.5669e-04 - val_mean_absolute_error: 0.0182
# Epoch 94/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0045 - mean_absolute_error: 0.0255 - val_loss: 6.9370e-04 - val_mean_absolute_error: 0.0221
# Epoch 95/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0044 - mean_absolute_error: 0.0271 - val_loss: 8.2680e-04 - val_mean_absolute_error: 0.0242
# Epoch 96/160
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0045 - mean_absolute_error: 0.0269 - val_loss: 5.9789e-04 - val_mean_absolute_error: 0.0205
# Epoch 97/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0044 - mean_absolute_error: 0.0243 - val_loss: 6.8871e-04 - val_mean_absolute_error: 0.0220
# Epoch 98/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0044 - mean_absolute_error: 0.0244 - val_loss: 4.6505e-04 - val_mean_absolute_error: 0.0182
# Epoch 99/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0043 - mean_absolute_error: 0.0259 - val_loss: 7.6832e-04 - val_mean_absolute_error: 0.0233
# Epoch 100/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0044 - mean_absolute_error: 0.0259 - val_loss: 4.0713e-04 - val_mean_absolute_error: 0.0171
# Epoch 101/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0045 - mean_absolute_error: 0.0253 - val_loss: 6.2570e-04 - val_mean_absolute_error: 0.0210
# Epoch 102/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0044 - mean_absolute_error: 0.0250 - val_loss: 7.6260e-04 - val_mean_absolute_error: 0.0232
# Epoch 103/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0043 - mean_absolute_error: 0.0247 - val_loss: 7.4737e-04 - val_mean_absolute_error: 0.0230
# Epoch 104/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0043 - mean_absolute_error: 0.0251 - val_loss: 4.0476e-04 - val_mean_absolute_error: 0.0171
# Epoch 105/160
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0044 - mean_absolute_error: 0.0278 - val_loss: 7.4985e-04 - val_mean_absolute_error: 0.0230
# Epoch 106/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0043 - mean_absolute_error: 0.0244 - val_loss: 7.0366e-04 - val_mean_absolute_error: 0.0223
# Epoch 107/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0045 - mean_absolute_error: 0.0255 - val_loss: 5.6504e-04 - val_mean_absolute_error: 0.0199
# Epoch 108/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0044 - mean_absolute_error: 0.0256 - val_loss: 7.3967e-04 - val_mean_absolute_error: 0.0229
# Epoch 109/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0043 - mean_absolute_error: 0.0270 - val_loss: 6.6663e-04 - val_mean_absolute_error: 0.0217
# Epoch 110/160
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0043 - mean_absolute_error: 0.0270 - val_loss: 3.4457e-04 - val_mean_absolute_error: 0.0158
# Epoch 111/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0043 - mean_absolute_error: 0.0248 - val_loss: 3.6105e-04 - val_mean_absolute_error: 0.0161
# Epoch 112/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0043 - mean_absolute_error: 0.0234 - val_loss: 7.6917e-04 - val_mean_absolute_error: 0.0234
# Epoch 113/160
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0044 - mean_absolute_error: 0.0263 - val_loss: 0.0012 - val_mean_absolute_error: 0.0305
# Epoch 114/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0044 - mean_absolute_error: 0.0275 - val_loss: 6.7934e-04 - val_mean_absolute_error: 0.0219
# Epoch 115/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0043 - mean_absolute_error: 0.0257 - val_loss: 9.5855e-04 - val_mean_absolute_error: 0.0266
# Epoch 116/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0046 - mean_absolute_error: 0.0327 - val_loss: 2.6574e-04 - val_mean_absolute_error: 0.0137
# Epoch 117/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0044 - mean_absolute_error: 0.0269 - val_loss: 3.2937e-04 - val_mean_absolute_error: 0.0155
# Epoch 118/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0044 - mean_absolute_error: 0.0264 - val_loss: 7.6421e-04 - val_mean_absolute_error: 0.0234
# Epoch 119/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0043 - mean_absolute_error: 0.0248 - val_loss: 9.2024e-04 - val_mean_absolute_error: 0.0261
# Epoch 120/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0043 - mean_absolute_error: 0.0247 - val_loss: 7.6066e-04 - val_mean_absolute_error: 0.0233
# Epoch 121/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0044 - mean_absolute_error: 0.0281 - val_loss: 4.4209e-04 - val_mean_absolute_error: 0.0177
# Epoch 122/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0044 - mean_absolute_error: 0.0277 - val_loss: 4.0083e-04 - val_mean_absolute_error: 0.0169
# Epoch 123/160
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0043 - mean_absolute_error: 0.0262 - val_loss: 6.7104e-04 - val_mean_absolute_error: 0.0218
# Epoch 124/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0043 - mean_absolute_error: 0.0254 - val_loss: 0.0028 - val_mean_absolute_error: 0.0502
# Epoch 125/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0065 - mean_absolute_error: 0.0546 - val_loss: 4.6704e-04 - val_mean_absolute_error: 0.0181
# Epoch 126/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0061 - mean_absolute_error: 0.0501 - val_loss: 0.0017 - val_mean_absolute_error: 0.0382
# Epoch 127/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0047 - mean_absolute_error: 0.0312 - val_loss: 0.0012 - val_mean_absolute_error: 0.0312
# Epoch 128/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0042 - mean_absolute_error: 0.0260 - val_loss: 3.2550e-04 - val_mean_absolute_error: 0.0155
# Epoch 129/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0044 - mean_absolute_error: 0.0256 - val_loss: 8.3809e-04 - val_mean_absolute_error: 0.0246
# Epoch 130/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0043 - mean_absolute_error: 0.0242 - val_loss: 4.9905e-04 - val_mean_absolute_error: 0.0187
# Epoch 131/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0042 - mean_absolute_error: 0.0246 - val_loss: 4.9386e-04 - val_mean_absolute_error: 0.0186
# Epoch 132/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0042 - mean_absolute_error: 0.0227 - val_loss: 4.0202e-04 - val_mean_absolute_error: 0.0168
# Epoch 133/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0043 - mean_absolute_error: 0.0248 - val_loss: 9.5302e-04 - val_mean_absolute_error: 0.0268
# Epoch 134/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0041 - mean_absolute_error: 0.0247 - val_loss: 5.5647e-04 - val_mean_absolute_error: 0.0198
# Epoch 135/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0042 - mean_absolute_error: 0.0246 - val_loss: 5.2864e-04 - val_mean_absolute_error: 0.0193
# Epoch 136/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0044 - mean_absolute_error: 0.0247 - val_loss: 7.1941e-04 - val_mean_absolute_error: 0.0226
# Epoch 137/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0044 - mean_absolute_error: 0.0262 - val_loss: 3.9988e-04 - val_mean_absolute_error: 0.0167
# Epoch 138/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0042 - mean_absolute_error: 0.0243 - val_loss: 4.4645e-04 - val_mean_absolute_error: 0.0177
# Epoch 139/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0042 - mean_absolute_error: 0.0241 - val_loss: 5.6437e-04 - val_mean_absolute_error: 0.0199
# Epoch 140/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0042 - mean_absolute_error: 0.0235 - val_loss: 6.2746e-04 - val_mean_absolute_error: 0.0211
# Epoch 141/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0041 - mean_absolute_error: 0.0223 - val_loss: 4.7277e-04 - val_mean_absolute_error: 0.0182
# Epoch 142/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0042 - mean_absolute_error: 0.0219 - val_loss: 4.6645e-04 - val_mean_absolute_error: 0.0180
# Epoch 143/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0042 - mean_absolute_error: 0.0215 - val_loss: 6.4630e-04 - val_mean_absolute_error: 0.0215
# Epoch 144/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0042 - mean_absolute_error: 0.0248 - val_loss: 3.9941e-04 - val_mean_absolute_error: 0.0168
# Epoch 145/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0042 - mean_absolute_error: 0.0234 - val_loss: 7.2353e-04 - val_mean_absolute_error: 0.0229
# Epoch 146/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0042 - mean_absolute_error: 0.0232 - val_loss: 2.9919e-04 - val_mean_absolute_error: 0.0146
# Epoch 147/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0042 - mean_absolute_error: 0.0228 - val_loss: 4.1410e-04 - val_mean_absolute_error: 0.0169
# Epoch 148/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0041 - mean_absolute_error: 0.0223 - val_loss: 5.7191e-04 - val_mean_absolute_error: 0.0201
# Epoch 149/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0041 - mean_absolute_error: 0.0227 - val_loss: 4.8328e-04 - val_mean_absolute_error: 0.0184
# Epoch 150/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0041 - mean_absolute_error: 0.0231 - val_loss: 7.0969e-04 - val_mean_absolute_error: 0.0226
# Epoch 151/160
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0041 - mean_absolute_error: 0.0230 - val_loss: 5.8883e-04 - val_mean_absolute_error: 0.0204
# Epoch 152/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0042 - mean_absolute_error: 0.0231 - val_loss: 6.0378e-04 - val_mean_absolute_error: 0.0207
# Epoch 153/160
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0041 - mean_absolute_error: 0.0232 - val_loss: 4.4451e-04 - val_mean_absolute_error: 0.0176
# Epoch 154/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0042 - mean_absolute_error: 0.0246 - val_loss: 5.1623e-04 - val_mean_absolute_error: 0.0191
# Epoch 155/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0042 - mean_absolute_error: 0.0235 - val_loss: 7.1312e-04 - val_mean_absolute_error: 0.0227
# Epoch 156/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0042 - mean_absolute_error: 0.0231 - val_loss: 5.5277e-04 - val_mean_absolute_error: 0.0197
# Epoch 157/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0042 - mean_absolute_error: 0.0223 - val_loss: 4.1533e-04 - val_mean_absolute_error: 0.0169
# Epoch 158/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0041 - mean_absolute_error: 0.0218 - val_loss: 3.7309e-04 - val_mean_absolute_error: 0.0161
# Epoch 159/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0042 - mean_absolute_error: 0.0221 - val_loss: 8.6329e-04 - val_mean_absolute_error: 0.0253
# Epoch 160/160
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0043 - mean_absolute_error: 0.0249 - val_loss: 5.7959e-04 - val_mean_absolute_error: 0.0202

# %%
# Evaluate the model
train_loss = model.evaluate(X_train, y_train, verbose=0)
print(f'Training Loss: {train_loss}')

test_loss = model.evaluate(X_test, y_test, verbose=0)
print(f'Testing Loss: {test_loss}')
# Out:
# Training Loss: [0.004142480902373791, 0.023442281410098076]
# Testing Loss: [0.0007559870718978345, 0.02288990095257759]

# %%
train_predictions = model.predict(X_train)

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)

#plt.plot(train_predictions)
#plt.plot(y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 8/8 [==============================] - 0s 910us/step

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 1/1 [==============================] - 0s 10ms/step

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 1/1 [==============================] - 0s 9ms/step

# %%
#test_predictions

# %%
# Inverse transform to get actual prices
y_train_actual = scaler.inverse_transform(y_train.reshape(-1, 1))
y_test_actual = scaler.inverse_transform(y_test.reshape(-1, 1))
y_train_pred_actual = scaler.inverse_transform(train_predictions.reshape(-1,1))
y_test_pred_actual = scaler.inverse_transform(test_predictions.reshape(-1,1))
y_val_pred_actual = scaler.inverse_transform(val_predictions.reshape(-1,1))
y_val_actual = scaler.inverse_transform(y_val.reshape(-1,1))

# %%
# Calculate evaluation metrics
train_mae = mean_absolute_error(y_train_actual, y_train_pred_actual)
train_mse = mean_squared_error(y_train_actual, y_train_pred_actual)
val_mae = mean_absolute_error(y_val_actual, y_val_pred_actual)
test_mae = mean_absolute_error(y_test_actual, y_test_pred_actual)
test_mse = mean_squared_error(y_test_actual, y_test_pred_actual)
val_mse = mean_squared_error(y_val_actual, y_val_pred_actual)

print(f'Training MAE: {train_mae}')
print(f'Training MSE: {train_mse}')
print(f'Val MAE: {val_mae}')
print(f'Val MSE: {val_mse}')
print(f'Testing MAE: {test_mae}')
print(f'Testing MSE: {test_mse}')


train_r = np.sqrt(train_mse)
train_r2 = r2_score(y_train_actual, y_train_pred_actual)
test_r = np.sqrt(test_mse)
test_r2 = r2_score(y_test_actual, y_test_pred_actual)
val_r = np.sqrt(val_mse)
val_r2 = r2_score(y_val_actual, y_val_pred_actual)


print(train_r)
print(train_r2)
print(val_r)
print(val_r2)
print(test_r)
print(test_r2)
# Out:
# Training MAE: 3.6030333042144775
# Training MSE: 94.78656768798828
# Val MAE: 3.6055874824523926
# Val MSE: 17.174922943115234
# Testing MAE: 3.3417153358459473
# Testing MSE: 16.70295524597168
# 9.735839
# 0.918121266378245
# 4.1442637
# 0.5436912082511548
# 4.086925
# 0.9202732448574635

# %%
# Calculate evaluation metrics
train_mae = mean_absolute_error(y_train, train_predictions)
train_mse = mean_squared_error(y_train, train_predictions)
val_mae = mean_absolute_error(y_val, val_predictions)
test_mae = mean_absolute_error(y_test, test_predictions)
test_mse = mean_squared_error(y_test, test_predictions)
val_mse = mean_squared_error(y_val, val_predictions)

print(f'Training MAE: {train_mae}')
print(f'Training MSE: {train_mse}')
print(f'Testing MAE: {test_mae}')
print(f'Testing MSE: {test_mse}')
print(f'Testing MAE: {val_mae}')
print(f'Testing MSE: {val_mse}')

train_r = np.sqrt(train_mse)
train_r2 = r2_score(y_train_actual, y_train_pred_actual)
test_r = np.sqrt(test_mse)
test_r2 = r2_score(y_test_actual, y_test_pred_actual)
val_r = np.sqrt(val_mse)
val_r2 = r2_score(y_val_actual, y_val_pred_actual)


print(train_r)
print(val_r)
print(test_r)
print(train_r2)
print(val_r2)
print(test_r2)
# Out:
# Training MAE: 0.0358649305999279
# Training MSE: 0.004852921701967716
# Testing MAE: 0.01752581261098385
# Testing MSE: 0.0005585874314419925
# Testing MAE: 0.012687440030276775
# Testing MSE: 0.0002566634211689234
# 0.06966291
# 0.016020719
# 0.023634454
# 0.9010968554138479
# 0.839117163740561
# 0.9370951049343192

# %%
model.save('wheat_lstm')
# Out:
# INFO:tensorflow:Assets written to: wheat_lstm/assets
# INFO:tensorflow:Assets written to: wheat_lstm/assets

# %%
import tensorflow as tf
m1=tf.keras.models.load_model('wheat_cnn')
m1.layers[0].input_shape
# Out:
# (None, 3, 1)

# %%
test_predictions = m1.predict(X_test).flatten()

y_test_actual = scaler.inverse_transform(y_test.reshape(-1, 1))
y_test_pred_actual = scaler.inverse_transform(test_predictions.reshape(-1,1))

test_r2 = r2_score(y_test_actual, y_test_pred_actual)
print(test_r2)
#plt.plot(dates_test, test_predictions)
#plt.plot(dates_test, y_test)
#plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 1/1 [==============================] - 0s 36ms/step
# 0.9370951049343192

# %%
plt.plot(figsize=(100,100))
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations'])

# %%
from copy import deepcopy

recursive_predictions = []
recursive_dates = np.concatenate([dates_val, dates_test])

for target_date in recursive_dates:
    last_window = deepcopy(X_train[-1])
    next_prediction = model.predict(np.array([last_window])).flatten()
    recursive_predictions.append(next_prediction)
    last_window[-1] = next_prediction
# Out:
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.plot(recursive_dates, recursive_predictions)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations',
            'Recursive Predictions'])

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import EarlyStopping
# Sample DataFrame
#data = {'date': pd.date_range(start='2024-01-01', periods=100),
#        'price': np.random.rand(100)}
#df = pd.DataFrame(data)

# %%
# Normalize the price data
scaler = MinMaxScaler(feature_range=(0, 1))
d['price'] = scaler.fit_transform(d['Rice'].values.reshape(-1,1))

# %%
x=d.pop('Rice')
d
# Out:
#           date     price
# 0   2000-02-01  0.053404
# 1   2000-03-01  0.043292
# 2   2000-04-01  0.049974
# 3   2000-05-01  0.049490
# 4   2000-06-01  0.049135
# ..         ...       ...
# 235 2019-09-01  0.058386
# 236 2019-10-01  0.056683
# 237 2019-11-01  0.075554
# 238 2019-12-01  0.081035
# 239 2020-01-01  0.089746
#
# [240 rows x 2 columns]

# %%
# Function to create sequences for LSTM
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i + seq_length])
        y.append(data[i + seq_length])
    return np.array(X), np.array(y)

# Hyperparameters
sequence_length = 10  # Adjust according to your choice
batch_size = 64
epochs = 100

# Create sequences
X, y = create_sequences(d['price'].values, sequence_length)

# Split the data into training and testing sets
split = int(0.8 * len(X))
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

# Reshape input data for LSTM [samples, time steps, features]
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# %%
# Define the LSTM model
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(sequence_length, 1)))
model.add(LSTM(units=50))
model.add(Dense(units=1))

# %%
# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
# Train the model
model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, verbose=1)
# Define Early Stopping Callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5, verbose=1, restore_best_weights=True)
# Out:
# Epoch 1/100
# 3/3 [==============================] - 1s 6ms/step - loss: 0.0041
# Epoch 2/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0026
# Epoch 3/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0027
# Epoch 4/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0023
# Epoch 5/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0023
# Epoch 6/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 7/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0021
# Epoch 8/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0020
# Epoch 9/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0021
# Epoch 10/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0020
# Epoch 11/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0019
# Epoch 12/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0019
# Epoch 13/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0019
# Epoch 14/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0018
# Epoch 15/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0018
# Epoch 16/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0018
# Epoch 17/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0017
# Epoch 18/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0017
# Epoch 19/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0016
# Epoch 20/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0016
# Epoch 21/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0016
# Epoch 22/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0015
# Epoch 23/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0015
# Epoch 24/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0014
# Epoch 25/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0014
# Epoch 26/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0013
# Epoch 27/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0013
# Epoch 28/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0013
# Epoch 29/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0012
# Epoch 30/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0012
# Epoch 31/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0012
# Epoch 32/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0012
# Epoch 33/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0012
# Epoch 34/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0012
# Epoch 35/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0012
# Epoch 36/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0012
# Epoch 37/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0011
# Epoch 38/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0011
# Epoch 39/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0011
# Epoch 40/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0011
# Epoch 41/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0011
# Epoch 42/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0011
# Epoch 43/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0011
# Epoch 44/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0011
# Epoch 45/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0010
# Epoch 46/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0010
# Epoch 47/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0010
# Epoch 48/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0010
# Epoch 49/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0010
# Epoch 50/100
# 3/3 [==============================] - 0s 6ms/step - loss: 9.9526e-04
# Epoch 51/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0010
# Epoch 52/100
# 3/3 [==============================] - 0s 6ms/step - loss: 9.7158e-04
# Epoch 53/100
# 3/3 [==============================] - 0s 6ms/step - loss: 9.6520e-04
# Epoch 54/100
# 3/3 [==============================] - 0s 6ms/step - loss: 9.5791e-04
# Epoch 55/100
# 3/3 [==============================] - 0s 5ms/step - loss: 9.5454e-04
# Epoch 56/100
# 3/3 [==============================] - 0s 6ms/step - loss: 9.4484e-04
# Epoch 57/100
# 3/3 [==============================] - 0s 6ms/step - loss: 9.3222e-04
# Epoch 58/100
# 3/3 [==============================] - 0s 6ms/step - loss: 9.2266e-04
# Epoch 59/100
# 3/3 [==============================] - 0s 6ms/step - loss: 9.0965e-04
# Epoch 60/100
# 3/3 [==============================] - 0s 5ms/step - loss: 9.0117e-04
# Epoch 61/100
# 3/3 [==============================] - 0s 6ms/step - loss: 8.9130e-04
# Epoch 62/100
# 3/3 [==============================] - 0s 6ms/step - loss: 8.8937e-04
# Epoch 63/100
# 3/3 [==============================] - 0s 5ms/step - loss: 8.7434e-04
# Epoch 64/100
# 3/3 [==============================] - 0s 5ms/step - loss: 8.6231e-04
# Epoch 65/100
# 3/3 [==============================] - 0s 6ms/step - loss: 8.8836e-04
# Epoch 66/100
# 3/3 [==============================] - 0s 5ms/step - loss: 8.4441e-04
# Epoch 67/100
# 3/3 [==============================] - 0s 6ms/step - loss: 8.4663e-04
# Epoch 68/100
# 3/3 [==============================] - 0s 5ms/step - loss: 8.2159e-04
# Epoch 69/100
# 3/3 [==============================] - 0s 5ms/step - loss: 8.1547e-04
# Epoch 70/100
# 3/3 [==============================] - 0s 5ms/step - loss: 8.0546e-04
# Epoch 71/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.9839e-04
# Epoch 72/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.9681e-04
# Epoch 73/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.8139e-04
# Epoch 74/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.7697e-04
# Epoch 75/100
# 3/3 [==============================] - 0s 6ms/step - loss: 7.7261e-04
# Epoch 76/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.6035e-04
# Epoch 77/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.4825e-04
# Epoch 78/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.4420e-04
# Epoch 79/100
# 3/3 [==============================] - 0s 6ms/step - loss: 7.4013e-04
# Epoch 80/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.3297e-04
# Epoch 81/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.3705e-04
# Epoch 82/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.2424e-04
# Epoch 83/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.3513e-04
# Epoch 84/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.0972e-04
# Epoch 85/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.0489e-04
# Epoch 86/100
# 3/3 [==============================] - 0s 5ms/step - loss: 6.9739e-04
# Epoch 87/100
# 3/3 [==============================] - 0s 5ms/step - loss: 6.9600e-04
# Epoch 88/100
# 3/3 [==============================] - 0s 5ms/step - loss: 6.8829e-04
# Epoch 89/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.0131e-04
# Epoch 90/100
# 3/3 [==============================] - 0s 5ms/step - loss: 6.7832e-04
# Epoch 91/100
# 3/3 [==============================] - 0s 5ms/step - loss: 7.0200e-04
# Epoch 92/100
# 3/3 [==============================] - 0s 5ms/step - loss: 6.8064e-04
# Epoch 93/100
# 3/3 [==============================] - 0s 6ms/step - loss: 6.7383e-04
# Epoch 94/100
# 3/3 [==============================] - 0s 6ms/step - loss: 6.7962e-04
# Epoch 95/100
# 3/3 [==============================] - 0s 5ms/step - loss: 6.8475e-04
# Epoch 96/100
# 3/3 [==============================] - 0s 5ms/step - loss: 6.8147e-04
# Epoch 97/100
# 3/3 [==============================] - 0s 5ms/step - loss: 6.7189e-04
# Epoch 98/100
# 3/3 [==============================] - 0s 5ms/step - loss: 6.7507e-04
# Epoch 99/100
# 3/3 [==============================] - 0s 5ms/step - loss: 6.7166e-04
# Epoch 100/100
# 3/3 [==============================] - 0s 6ms/step - loss: 7.0050e-04

# %%
# Evaluate the model
train_loss = model.evaluate(X_train, y_train, verbose=0)
print(f'Training Loss: {train_loss}')

test_loss = model.evaluate(X_test, y_test, verbose=0)
print(f'Testing Loss: {test_loss}')
# Out:
# Training Loss: 0.0006569024408236146
# Testing Loss: 0.04776032641530037

# %%
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

# Inverse transform to get actual prices
y_train_actual = scaler.inverse_transform(y_train.reshape(-1, 1))
y_test_actual = scaler.inverse_transform(y_test.reshape(-1, 1))
y_train_pred_actual = scaler.inverse_transform(y_train_pred)
y_test_pred_actual = scaler.inverse_transform(y_test_pred)

# Calculate evaluation metrics
train_mae = mean_absolute_error(y_train_actual, y_train_pred_actual)
train_mse = mean_squared_error(y_train_actual, y_train_pred_actual)
test_mae = mean_absolute_error(y_test_actual, y_test_pred_actual)
test_mse = mean_squared_error(y_test_actual, y_test_pred_actual)
#
train_r = np.sqrt(train_mse)
train_r2 = r2_score(y_train_actual, y_train_pred_actual)
test_r = np.sqrt(test_mse)
test_r2 = r2_score(y_test_actual, y_test_pred_actual)

print(f'Training MAE: {train_mae}')
print(f'Training MSE: {train_mse}')
print(f'Testing MAE: {test_mae}')
print(f'Testing MSE: {test_mse}')
print(train_r)
print(test_r)
print(train_r2)
print(test_r2)
# Out:
# 6/6 [==============================] - 0s 857us/step
# 1/1 [==============================] - 0s 8ms/step
# Training MAE: 15.197800636291504
# Training MSE: 980.4922485351562
# Testing MAE: 217.68800354003906
# Testing MSE: 190393.921875
# 31.312813
# 436.34152
# 0.80162733858064
# 0.20735048207608497

# %%
import matplotlib.pyplot as plt

# Plot actual vs predicted for training set
plt.figure(figsize=(12, 6))
plt.plot(y_train_actual, label='Actual')
plt.plot(y_train_pred_actual, label='Predicted')
plt.title('Actual vs Predicted Prices - Training Set')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()

# Plot actual vs predicted for testing set
plt.figure(figsize=(12, 6))
plt.plot(y_test_actual, label='Actual')
plt.plot(y_test_pred_actual, label='Predicted')
plt.title('Actual vs Predicted Prices - Testing Set')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
d
# Out:
#           date     price
# 0   2000-02-01  0.053404
# 1   2000-03-01  0.043292
# 2   2000-04-01  0.049974
# 3   2000-05-01  0.049490
# 4   2000-06-01  0.049135
# ..         ...       ...
# 235 2019-09-01  0.058386
# 236 2019-10-01  0.056683
# 237 2019-11-01  0.075554
# 238 2019-12-01  0.081035
# 239 2020-01-01  0.089746
#
# [240 rows x 2 columns]
